# %%
import pandas as pd

# --- 設定項目 (ここを書き換えてください) ---

# 1. 調べたいCSVファイルのパスを指定します．
file_path = 'odaiba_reviews.csv'

# 2. 種類を数えたい列の名前を指定します．
column_name = 'shop_name'  # (例: 'shop_name' や 'tag' など)

try:
    # CSVファイルを読み込みます．
    df = pd.read_csv(file_path)

    # 指定した列が存在するかどうかを確認します．
    if column_name in df.columns:
        # 指定された列の種類数（ユニークな値の数）を数えます．
        num_unique = df[column_name].nunique()

        # 指定された列の具体的な種類（ユニークな値そのもの）を取得します．
        unique_values = df[column_name].unique()

        # 結果を分かりやすく表示します．
        print(f"■ ファイル: {file_path}")
        print(f"■ 列の名前: {column_name}")
        print("----------------------------------")
        print(f"⇒ 種類数: {num_unique}")
        print(f"⇒ 具体的な種類: {unique_values.tolist()}")

    else:
        # 指定した列がファイル内に見つからなかった場合のエラーメッセージです．
        print(f"エラー: 列 '{column_name}' が見つかりませんでした．")
        print(f"ファイルに含まれている列の名前: {df.columns.tolist()}")

except FileNotFoundError:
    # 指定したパスにファイルが見つからなかった場合のエラーメッセージです．
    print(f"エラー: ファイル '{file_path}' が見つかりませんでした．")
    print("ヒント: ファイルのパスが正しいか，もう一度確認してください．")

except Exception as e:
    # その他のエラーが発生した場合のメッセージです．
    print(f"エラーが発生しました: {e}")
    print("ヒント: 日本語のファイルでエラーが出る場合，文字コードが原因かもしれません．")
    print("その際は， pd.read_csv(file_path, encoding='cp932') のように書き換えてみてください．")
# Out:
# ■ ファイル: odaiba_reviews.csv
# ■ 列の名前: shop_name
# ----------------------------------
# ⇒ 種類数: 563
# ⇒ 具体的な種類: ['オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明)', 'シュマッツ 有明ガーデン', 'Trattoria&Pizzeria LOGIC お台場', 'ディップガーデン テラス 有明ガーデン店', 'くいもの屋わん お台場デックス東京ビーチ店', '鮨 玉かがり 天ぷら 玉衣', 'bills お台場', '北京ダック専門店 嘉園 お台場店', 'チャイナグリーン', '肉菜工房うしすけ 台場店', '焼鳥トリフク食堂', 'ビッグシェフ お台場・デックス東京ビーチ', '唐苑', 'KING OF THE PIRATES', 'ガルーバ', '串家物語 ダイバーシティ東京プラザ店', 'こだわりから揚げの酒処 くらふと', 'しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場', 'インコントロ オステリア&グリル', '焼肉と夜景 醍醐 お台場店', '鮮魚旬菜 魚福', 'オイスターハウス お台場店', 'シーフードレストラン メヒコ 東京ベイ有明店', '東京寿司 ITAMAE SUSHI アクアシティお台場店', '南風花 アクアシティお台場店', 'シーフードレストランネプチューン', 'お食事処 ゆき', 'なんで、や お台場店', 'YORIMICHI Odaiba', '春華秋実', '江戸湾直送 回転 東京すし街道by ITAMAE SUSHI アクアシティお台場店', 'しゃぶしゃぶ 吟半 お台場店', '日本料理 「さくら」   ヒルトン東京お台場', 'アルポルト 東京ビッグサイト店', 'マロリーポークステーキ お台場店', 'モンスーンカフェ お台場', 'トゥ・ザ・ハーブズ アクアシティーお台場店', '飛車角 有明ガーデン店', 'シースケープ テラス・ダイニング', 'プロント ワンザ有明店', 'ゼスト キャンティーナ お台場', 'BISTRO うしすけ', 'カフェ ラ・ボエム お台場', '権八 お台場', '泉天空の湯 有明キッチン', 'ピッツェリア ドォーロ ローマ 台場店', 'インド料理ムンバイ アクアシティお台場店', 'レッドロブスター アクアシティお台場店', '山下本気うどん デックス東京ビーチ', 'がぜん 有明', '京鼎樓 アクアシティお台場店', '焼肉 平城苑 アクアシティお台場店', 'カレス', '中国料理 桃李', 'ほおずきや', '鮒忠 有明店', '鉄板焼 銀杏', 'TGI FRIDAYS 有明ガーデン店', '中國料理 跳龍門', 'ガーデン ダイニング', '笑笑 お台場海浜公園駅前店', 'ニルワナム 東京ビッグサイト店', '越後屋 竹千代', 'しゃぶ食べ 有明ガーデン店', '1129 by Ogawa', 'The Grill on 30th', 'The Lobby Cafe', 'TGIフライデーズ お台場アクアシティ店', '東京焼肉 平城苑 ダイバーシティ東京プラザ店', '炭火焼肉・韓国料理 KollaBo アクアシティお台場店', 'ニルワナム 有明店', 'カザーナ お台場店', '牛たん炭焼利久 有明ガーデン店', '和カフェ Tsumugi 有明ガーデン店', 'Seaside Café SOLARIS', 'PIZZA&WINE カヤバール 有明ガーデン店', 'むら田', '潮見スキッパーズ 有明店', '築地銀だこ ダイバーシティ東京プラザ店', 'グリーン アジア トウキョウ', 'Ariake Miraie', 'ジョンノ屋台村＆ネネチキン 有明ガーデン', 'ロハスカフェARIAKE', 'スターバックスコーヒー 東京ビッグサイト店', '北陸富山回転寿司\u3000プレミアム 海王 ダイバーシティ東京店', 'タリーズコーヒー 有明ガーデン店', 'da pai dang 105 有明ガーデン店', 'たこ家道頓堀くくる お台場たこ焼きミュージアム店', 'カフェ＆レストラン レインボー', 'DOLCE VITA', 'そじ坊 ダイバーシティ東京プラザ店', 'タコベル アクアシティお台場店', '都会の農園バーベキュー広場', 'ベーカリーレストランサンマルク 有明ガーデン店', 'とんかつ八千代', 'ココス 有明パークビル店', 'ウェンディーズ・ファーストキッチン アクアシティお台場店', 'マジソン プレミアム バーガー', '手打ち中華 玉 アクアシティお台場店', 'ホップ＆ステップ カフェ', 'カンテボーレ イオンスタイル有明ガーデン', 'オリジナルパンケーキハウス 有明ガーデン店', 'タコベル 有明ガーデン店', "mal D'amour", '餃子の王様 龍吟 ダイバーシティ店', 'タリーズコーヒー ダイバーシティ東京プラザ店', 'マダムドリュック 有明ガーデン店', '博多うどん呑処 一㐂 下町居酒屋 台場店', 'OSMIC DISH', 'こなな 有明ガーデン店', 'ゼッテリア TFT有明店', 'つけ麺らーめん春樹 お台場店', 'ミスタードーナツ ダイバーシティ東京プラザショップ', 'まはらに', 'ヨゴリーノ\u3000 お台場デックス東京ビーチ店', 'グランディール 有明ガーデン店', 'GODIVA アクアシティお台場店', 'すき家 ワンザ有明店', '創菜Patio', 'タリーズコーヒー がん研有明病院店', '居酒屋いっき 有明別邸', '東京ベイ有明ワシントンホテル', 'マディソンラウンジ', 'サイゼリヤ 有明フロンティアビル店', 'ワフーズ\u3000タコス&モア', 'スターバックス コーヒー ダイバーシティ東京プラザ店', '道頓堀 赤鬼', 'milky70 since1951 アクアシティお台場店', 'ドトールコーヒーショップ 有明セントラルタワー店', 'パティスリー ピネード 有明ガーデンシティ店', 'ブリッジ', 'モミアンドトイズ デックス東京ビーチ店', '塩らーめん専門 ひるがお アクアシティお台場店', 'サブウェイ TFT有明店', '千房 有明ガーデン支店', '日本料理\u3000時宜', 'LAWSON 国際展示場駅前店', '築地食堂 源ちゃん アクアシティお台場店', 'はなまるうどん ダイバーシティ東京店', '韓美膳 有明ガーデン店', 'こめらく みんなで、お茶漬け日和。 有明ガーデン店', 'バイロンベイミートパイ  有明店', 'ジョージタウン', 'Hobson’s アクアシティお台場', '鶴橋風月 お台場店', '和食ダイニング 田久井', '札幌 みその アクアシティお台場店', 'ウマミバーガー 有明ガーデン店', 'カーサ・ディ・ペロー二', 'ディッピンドッツ・アイスクリーム 東京ジョイポリス', '三代目文治 ダイバーシティ東京プラザ店', 'パンドクレム', 'つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店', 'いろり庵 きらく 国際展示場駅店', '親子丼 トリカイ エクスプレス ダイバーシティ東京店', '北海道うまいもの館 ダイバーシティ東京店', 'Deli&Cafe Uran', '東京ベイコート倶楽部', 'マーメイド', '健康中華 青蓮 TOC有明店', "creperie kenny's ダイバーシティ店", 'カレーショップ C&Cダイニング 東京ビッグサイト店', 'カツオたまご食堂', 'Tokyo 串家', 'つきじ丼匠', '鮨\u3000宇田川', 'てっぱん屋台 ダイバーシティ東京プラザ店', 'メインバー「キャプテンズバー」 ヒルトン東京お台場', 'エッグスンシングス お台場店', '築地食堂\u3000源ちゃん TFT有明店', '天天有 お台場デックス東京ビーチ店', 'ビオラルカフェ 有明ガーデン店', 'ザ バー&ラウンジ', 'エスプレッソ アメリカーノ テレコムセンター店', 'ベジテジや ダイバーシティ東京プラザ店', 'エグゼクティブラウンジ', '日比谷松本楼 東京ビッグサイト店', 'クルックス カフェオ ヨーロピアンリゾートカフェ', '吉野家 お台場 デックス店', '青海珈琲 青海本店', 'サーティワンアイスクリーム デックス東京ビーチ店', 'Eat it! 東京ビッグサイト店', '鶏味座 ダイバーシティ東京プラザ店', '久臨 ダイバーシティ東京プラザ店', '小樽ザンギとサケ 半身揚げのジョニー', 'タリーズコーヒー 東京ビッグサイト店', 'アイランド・ヴィンテージ・コーヒー 台場店', 'マクドナルド お台場デックス店', '三代目 博多 だるま', 'ロイヤルキャフェテリア', 'バーガーキング  有明ガーデン店', 'サーティワンアイスクリーム 有明ガーデン店', 'ウイスキーボイス 台場', 'ヴィラフォンテーヌ グランド 東京有明', '伝説のすた丼屋 ダイバーシティ東京プラザ店', 'どうとんぼり神座 有明ガーデン店', 'ABURI 百貫 有明ガーデン店', 'CoCo壱番屋 ワンザ有明店', 'キムカツ亭 有明ガーデン店', '十割蕎麦 さがたに 有明ガーデン店', 'ゲンの中華そば 東京ビックサイト南展示棟店', 'ノイタミナSHOP', '茂助だんご 豊洲市場', 'フレームカフェ', 'ベビーカステラ専門店 KUTSURO ...
