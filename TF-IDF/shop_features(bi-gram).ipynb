# %% [markdown]
# ## bi-gramのtf-idfスコア

# %%
# 02_calculate_tfidf.py

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# --- メインの実行処理 ---
if __name__ == '__main__':
    # 1. 前処理済みのCSVファイルを読み込む
    try:
        df_preprocessed = pd.read_csv('csv/preprocessed_bigrams.csv')
    except FileNotFoundError:
        print("エラー: 'preprocessed_bigrams.csv'が見つかりません。")
        print("先に01_preprocess_bigrams.pyを実行してください。")
        exit()

    # レビューが空の行を念のため削除
    df_preprocessed.dropna(subset=['bigram_corpus'], inplace=True)

    # 2. 分析対象のデータ（コーパス）と店舗名リストを作成
    corpus = df_preprocessed['bigram_corpus'].tolist()
    shop_names = df_preprocessed['shop_name'].tolist()

    if corpus:
        print("Bi-gramのTF-IDFスコアを計算中...")
        
        # 3. TfidfVectorizerを使い、Bi-gramごとのTF-IDFを計算
        # min_df=2: 2店舗以上で出現するBi-gramのみを対象とし、レアすぎる単語ペアは無視
        vectorizer = TfidfVectorizer(min_df=2, max_df=0.9)
        tfidf_matrix = vectorizer.fit_transform(corpus)
        
        # Bi-gramのリスト（特徴量名）を取得
        feature_names = vectorizer.get_feature_names_out()

        print("\n--- 【結果】店舗ごとの特徴的なBi-gram（TF-IDFスコア上位）---\n")
        
        # 4. 各店舗ごとに、スコアの高いBi-gramを表示
        for i, shop_name in enumerate(shop_names):
            print(f"★★★ {shop_name} ★★★")
            # i番目の店舗に対応するTF-IDFスコアの行を取得
            row = tfidf_matrix.toarray()[i]
            # スコアが高い順にトップ7のインデックスを取得
            top_n_indices = row.argsort()[::-1][:7]
            
            for index in top_n_indices:
                # スコアが0より大きいものだけ表示
                if row[index] > 0:
                    # アンダースコアを「, 」に戻して見やすく表示
                    bigram_display = feature_names[index].replace('_', ', ')
                    print(f"  - {bigram_display} (スコア: {row[index]:.3f})")
            print("-" * 30)
    else:
        print("分析対象のデータがありません。")
# Out:
# Bi-gramのTF-IDFスコアを計算中...
#
# --- 【結果】店舗ごとの特徴的なBi-gram（TF-IDFスコア上位）---
#
# ★★★ 1129 by Ogawa ★★★
#   - レインボー, ブリッジ (スコア: 0.241)
#   - デックス, 東京 (スコア: 0.210)
#   - 東京, ビーチ (スコア: 0.171)
#   - ハンバーグ, ランチ (スコア: 0.167)
#   - ビーチ, 6 (スコア: 0.159)
#   - 6, 階 (スコア: 0.148)
#   - 窓際, 席 (スコア: 0.127)
# ------------------------------
# ★★★ 82 築地店 ★★★
#   - 築地, 店 (スコア: 0.284)
#   - 築地, 駅 (スコア: 0.244)
#   - ２, 築地 (スコア: 0.171)
#   - 店, hub (スコア: 0.134)
#   - 東, 銀座 (スコア: 0.131)
#   - メトロ, 日比谷線 (スコア: 0.103)
#   - 東京, メトロ (スコア: 0.101)
# ------------------------------
# ★★★ ABURI 百貫 有明ガーデン店 ★★★
#   - 回転, 寿司 (スコア: 0.611)
#   - 有明, ガーデン (スコア: 0.310)
#   - 百, 貫 (スコア: 0.221)
#   - 炙る, 寿司 (スコア: 0.156)
#   - 寿司, 屋 (スコア: 0.150)
#   - 通り, 炙る (スコア: 0.143)
#   - 塩, レモン (スコア: 0.112)
# ------------------------------
# ★★★ ARIAKE ARENA CAFE ★★★
#   - 有明, アリーナ (スコア: 0.547)
#   - アリーナ, 行く (スコア: 0.142)
#   - ライブ, 有明 (スコア: 0.132)
#   - アリーナ, イベント (スコア: 0.129)
#   - 参加, する (スコア: 0.125)
#   - 日,  (スコア: 0.108)
#   - ライブ, 前 (スコア: 0.087)
# ------------------------------
# ★★★ ARIAKE ARENA DINING MOON RIVER ★★★
#   - 有明, アリーナ (スコア: 0.370)
#   - イベント, 日 (スコア: 0.137)
#   - 組, 入口 (スコア: 0.099)
#   - 考え, 人 (スコア: 0.099)
#   - ハンバーガー, ワッフル (スコア: 0.099)
#   - 帰る, 予定 (スコア: 0.099)
#   - そう, いい (スコア: 0.099)
# ------------------------------
# ★★★ AkeruE ★★★
#   - カフェ, 子連れ (スコア: 0.313)
#   - よい, きのこ (スコア: 0.313)
#   - ポテト, 塩 (スコア: 0.299)
#   - ある, 選べる (スコア: 0.278)
#   - 出る, 左手 (スコア: 0.271)
#   - センター, 内 (スコア: 0.271)
#   - ピザ,  (スコア: 0.264)
# ------------------------------
# ★★★ Ariake Miraie ★★★
#   - ディーラー, 中 (スコア: 0.327)
#   - 中, カフェ (スコア: 0.259)
#   - する, 車 (スコア: 0.188)
#   - カフェ, スペース (スコア: 0.167)
#   - 車, 行ける (スコア: 0.109)
#   - 豚, ロ (スコア: 0.109)
#   - 気分, ご飯 (スコア: 0.109)
# ------------------------------
# ★★★ BBQ PLAY GROUND お台場デックス東京ビーチ店 ★★★
#   - 持ち込み, 可能 (スコア: 0.130)
#   - bbq, 楽しめる (スコア: 0.130)
#   - 風, 強い (スコア: 0.125)
#   - 景色, よい (スコア: 0.124)
#   - 場所, 景色 (スコア: 0.124)
#   - 6, 階 (スコア: 0.121)
#   - ある, ない (スコア: 0.119)
# ------------------------------
# ★★★ BISTRO うしすけ ★★★
#   - うし, すける (スコア: 0.428)
#   - ビス, トロ (スコア: 0.251)
#   - わん, ちゃん (スコア: 0.192)
#   - ワン, ちゃん (スコア: 0.157)
#   - トロ, うし (スコア: 0.143)
#   - 犬, 用 (スコア: 0.132)
#   - すける, さ (スコア: 0.126)
# ------------------------------
# ★★★ BLUE TABLE Odaiba ★★★
#   - 海浜, 公園 (スコア: 0.200)
#   - 台場, 海浜 (スコア: 0.146)
#   - グリーン, カレー (スコア: 0.140)
#   - 公園, 中 (スコア: 0.118)
#   - レインボー, ブリッジ (スコア: 0.112)
#   - 窓, 開ける (スコア: 0.108)
#   - リゾート, 感 (スコア: 0.102)
# ------------------------------
# ★★★ Bistro961 ★★★
#   - ワイン, バー (スコア: 0.161)
#   - 月島, 駅 (スコア: 0.154)
#   - ビス, トロ (スコア: 0.145)
#   - パスタ, ランチ (スコア: 0.137)
#   - 橋, 近く (スコア: 0.125)
#   - 階, ワイン (スコア: 0.125)
#   - 日本, ワイン (スコア: 0.125)
# ------------------------------
# ★★★ Bomb! Dogs ★★★
#   - ポテト, 好き (スコア: 0.252)
#   - 階, 隣 (スコア: 0.252)
#   - ソース, ソーセージ (スコア: 0.252)
#   - 美味しい, 大きい (スコア: 0.240)
#   - ドリンク, 店 (スコア: 0.240)
#   - 食べる, そこ (スコア: 0.231)
#   - 細かい, 刻む (スコア: 0.231)
# ------------------------------
# ★★★ Brew33 Bar ★★★
#   - ダブル, ツリー (スコア: 0.380)
#   - ツリー, by (スコア: 0.380)
#   - レストラン, 様 (スコア: 0.380)
#   - 場所, ダブル (スコア: 0.380)
#   - 賑やか, さ (スコア: 0.362)
#   - カウンター, 夜景 (スコア: 0.348)
#   - ダイニング, レストラン (スコア: 0.348)
# ------------------------------
# ★★★ CAFE TERIA BLUE ★★★
#   - 特別, 展 (スコア: 0.348)
#   - 科学, 来館 (スコア: 0.170)
#   - 乗る, パスタ (スコア: 0.116)
#   - 混む, 待ち時間 (スコア: 0.116)
#   - カフェ, ラウンジ (スコア: 0.116)
#   - 10, 20 (スコア: 0.116)
#   - 人, みたい (スコア: 0.116)
# ------------------------------
# ★★★ Cha pi ★★★
#   - ミルク, ティー (スコア: 0.195)
#   - ミルク, フォーム (スコア: 0.164)
#   - ３, 枚 (スコア: 0.157)
#   - 抹茶, ミルク (スコア: 0.146)
#   - 甘い, さ (スコア: 0.121)
#   - デックス, 東京 (スコア: 0.090)
#   - 良い, 抹茶 (スコア: 0.082)
# ------------------------------
# ★★★ Chez コバラヘッタ 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.455)
#   - たい, 焼き (スコア: 0.311)
#   - ランチ, プレート (スコア: 0.099)
#   - ガーデン, 内 (スコア: 0.095)
#   - ドリンク, 有明 (スコア: 0.081)
#   - ガーデン, 5 (スコア: 0.077)
#   - テラス, 席 (スコア: 0.076)
# ------------------------------
# ★★★ CoCo壱番屋 ワンザ有明店 ★★★
#   - coco, 壱 (スコア: 0.313)
#   - カレー, 食べる (スコア: 0.195)
#   - カレー, サラダ (スコア: 0.130)
#   - ビッグ, サイト (スコア: 0.103)
#   - 限定, メニュ (スコア: 0.085)
#   - 無難, チェーン (スコア: 0.085)
#   - さ, 上げる (スコア: 0.085)
# ------------------------------
# ★★★ Cuore ★★★
#   - ベイ, サイド (スコア: 0.387)
#   - ホテルトラスティ, 東京 (スコア: 0.365)
#   - 東京, ベイ (スコア: 0.298)
#   - ベイ, コート (スコア: 0.129)
#   - コート, 倶楽部 (スコア: 0.129)
#   - ラウンジ, レストラン (スコア: 0.122)
#   - 宿泊, 時 (スコア: 0.087)
# ------------------------------
# ★★★ D-ラウンジ ★★★
#   - 東京, ジョイポリス (スコア: 0.529)
#   - ちゃう,  (スコア: 0.154)
#   - 分, 東京 (スコア: 0.143)
#   - 2, 階 (スコア: 0.134)
#   - テレポート, 駅 (スコア: 0.117)
#   - 鉄道, 東京 (スコア: 0.115)
#   - 簡単, ランチ (スコア: 0.115)
# ------------------------------
# ★★★ DAIBA ★★★
#   - 社員, 食堂 (スコア: 0.532)
#   - 台場, 合衆国 (スコア: 0.218)
#   - 関係, 者 (スコア: 0.178)
#   - 二, 回 (スコア: 0.157)
#   - 中, ふう (スコア: 0.126)
#   - 者, 入れる (スコア: 0.126)
#   - 者, 懇親 (スコア: 0.126)
# ------------------------------
# ★★★ DOG DEPT お台場東京ビーチ店 ★★★
#   - 美味しい, ロコモコ (スコア: 0.263)
#   - ステーキ, グリル (スコア: 0.263)
#   - 愉しい, ん (スコア: 0.251)
#   - デザート, いただく (スコア: 0.251)
#   - dog, dept (スコア: 0.251)
#   - 年, ３月 (スコア: 0.241)
#   - 以前, 訪れる (スコア: 0.241)
# ------------------------------
# ★★★ DOLCE VITA ★★★
#   - メロン, パン (スコア: 0.211)
#   - イタリア, 語 (スコア: 0.174)
#   - する, イマーシブフォート (スコア: 0.166)
#   - イマーシブフォート, 行く (スコア: 0.160)
#   - 月, オープン (スコア: 0.145)
#   - 可能,  (スコア: 0.144)
#   - 3, 月 (スコア: 0.136)
# ------------------------------
# ★★★ Deli&Cafe Uran ★★★
#   - 海浜, 公園 (スコア: 0.174)
#   - ４, 種 (スコア: 0.148)
#   - 台場, 海浜 (スコア: 0.133)
#   - 4, 種 (スコア: 0.114)
#   - 公園, 駅 (スコア: 0.100)
#   - メイン, 系 (スコア: 0.090)
#   - すごい, 優しい (スコア: 0.090)
# ------------------------------
# ★★★ Domino's Pizza  ARIAKE GARDEN ★★★
#   - ドミノ, ピザ (スコア: 0.356)
#   - 有明, ガーデン (スコア: 0.260)
#   - 円, 行列 (スコア: 0.178)
#   - シアター, 開催 (スコア: 0.178)
#   - セット, 900 (スコア: 0.178)
#   - コート, 到着 (スコア: 0.170)
#   - 向かい, 有明 (スコア: 0.170)
# ------------------------------
# ★★★ Eat it! 東京ビッグサイト店 ★★★
#   - ビッグ, サイト (スコア: 0.384)
#   - フード, コート (スコア: 0.377)
#   - 東京, ビッグ (スコア: 0.265)
#   - つけ, 麺 (スコア: 0.235)
#   - 展示, 会 (スコア: 0.157)
#   - eat, it (スコア: 0.145)
#   - 国際, 展示 (スコア: 0.102)
# ------------------------------
# ★★★ FARMS' KITCHEN MIKIKE TOKYO ODAIBA ★★★
#   - 観光, 地 (スコア: 0.136)
#   - たくさん, 使う (スコア: 0.135)
#   - 次, ディナー (スコア: 0.135)
#   - ロケーション, 接客 (スコア: 0.135)
#   - ディナー, おじゃま (スコア: 0.135)
#   - イクラ, 美味しい (スコア: 0.135)
#   - 頂ける, レストラン (スコア: 0.135)
# ------------------------------
# ★★★ GODIVA アクアシティお台場店 ★★★
#   - ゴディバ, ショコリキサー (スコア: 0.217)
#   - ダーク, チョコレート (スコア: 0.217)
#   - ホワイト, チョコレート (スコア: 0.199)
#   - チョコレート, ドリンク (スコア: 0.192)
#   - 期間, 限定 (スコア: 0.161)
#   - godiva, ショコリキサー (スコア: 0.144)
#   - godiva, ドリンク (スコア: 0.144)
# ------------------------------
# ★★★ GODIVA ダイバーシティ東京プラザ店 ★★★
#   - ダイバー, シティ (スコア: 0.442)
#   - シティ, 東京 (スコア: 0.201)
#   - チョコ, ミント (スコア: 0.162)
#   - 東京, プラザ (スコア: 0.158)
#   - ダーク, チョコレート (スコア: 0.133)
#   - , ショコリキサー (スコア: 0.133)
#   - ゴディバ, ショコリキサー (スコア: 0.133)
# ------------------------------
# ★★★ GOKUGOKU 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.247)
#   - 完熟, バナナ (スコア: 0.169)
#   - バナナ, ミルク (スコア: 0.169)
#   - オレンジ, パイン (スコア: 0.169)
#   - 程よい, 甘い (スコア: 0.156)
#   - ジュース, スタンド (スコア: 0.146)
#   - 美味しい, そう (スコア: 0.092)
# ------------------------------
# ★★★ GREAT STEAK ★★★
#   - 60, g (スコア: 0.312)
#   - オーダー, ブザー (スコア: 0.312)
#   - ステーキ, 店 (スコア: 0.277)
#   - コート, 見る (スコア: 0.277)
#   - 抜,  (スコア: 0.277)
#   - , 1280 (スコア: 0.270)
#   - ブザー, 渡す (スコア: 0.263)
# ------------------------------
# ★★★ GUNDAM Café　キッチンカー ★★★
#   - 付き, 通常 (スコア: 0.354)
#   - 通常, メニ (スコア: 0.354)
#   - ホット, ドリンク (スコア: 0.354)
#   - ドリンク, 販売 (スコア: 0.337)
#   - メイン, 3 (スコア: 0.325)
#   - 描く, れる (スコア: 0.325)
#   - メニュー, 追加 (スコア: 0.314)
# ------------------------------
# ★★★ Green×Green ★★★
#   - サラダ, 丼 (スコア: 0.246)
#   - 台場, フード (スコア: 0.240)
#   - サラダ, ボウル (スコア: 0.235)
#   - フード, コート (スコア: 0.185)
#   - ハーブ, チキン (スコア: 0.164)
#   - 穀, 米 (スコア: 0.157)
#   - 雑穀, 米 (スコア: 0.151)
# ------------------------------
# ★★★ H.B.GRILL ★★★
#   - h,  (スコア: 0.388)
#   - , b (スコア: 0.297)
#   - , grill (スコア: 0.261)
#   - b,  (スコア: 0.248)
#   - アクアシティ, 台場 (スコア: 0.149)
#   - テラス, 席 (スコア: 0.135)
#   - オニオン, フライ (スコア: 0.083)
# ------------------------------
# ★★★ HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店 ★★★
#   - ダイバー, シティ (スコア: 0.344)
#   - ハロー, キティ (スコア: 0.301)
#   - ベビー, カステラ (スコア: 0.258)
#   - シティ, 東京 (スコア: 0.220)
#   - 東京, プラザ (スコア: 0.154)
#   - 20, 個 (スコア: 0.118)
#   - 施設, ダイバー (スコア: 0.104)
# ------------------------------
# ★★★ HIRO ダイバーシティ東京店 ★★★
#   - ダイバー, シティ (スコア: 0.388)
#   - 牛, ハンバーグ (スコア: 0.274)
#   - 神戸, 牛 (スコア: 0.173)
#   - 仙台, 牛 (スコア: 0.163)
#   - 肉, 食べる (スコア: 0.160)
#   - ハンバーグ, ステーキ (スコア: 0.155)
#   - シティ, 東京 (スコア: 0.117)
# ------------------------------
# ★★★ HUNZA ★★★
#   - ビリ, ヤニ (スコア: 0.590)
#   - 葛西, 駅 (スコア: 0.245)
#   - インド, カレー (スコア: 0.223)
#   - 百, 名店 (スコア: 0.148)
#   - インド, 人 (スコア: 0.133)
#   - カレー, 屋 (スコア: 0.113)
#   - ヤニ, 食べる (スコア: 0.102)
# ------------------------------
# ★★★ Hobson’s アクアシティお台場 ★★★
#   - フード, コート (スコア: 0.289)
#   - hobson,  (スコア: 0.165)
#   - アイスクリーム, 食べる (スコア: 0.147)
#   - ブレンド, する (スコア: 0.143)
#   - 家具, 見る (スコア: 0.110)
#   - , ホブソンズ (スコア: 0.110)
#   - hobson, s (スコア: 0.110)
# ------------------------------
# ★★★ KING OF THE PIRATES ★★★
#   - テラス, 席 (スコア: 0.283)
#   - レインボー, ブリッジ (スコア: 0.235)
#   - アクアシティ, 台場 (スコア: 0.152)
#   - 飲む, 放題 (スコア: 0.150)
#   - 予約, する (スコア: 0.140)
#   - オブ (スコア: 0.113)
#   - パ, エリア (スコア: 0.113)
# ------------------------------
# ★★★ L'Agréable Esprit de GAMIN ★★★
#   - 門前仲町, 駅 (スコア: 0.244)
#   - 毎月, 通う (スコア: 0.165)
#   - 門前仲, 町 (スコア: 0.152)
#   - 月, 替わり (スコア: 0.121)
#   - l,  (スコア: 0.108)
#   - 冷, 製 (スコア: 0.097)
#   - 梅, 肉 (スコア: 0.093)
# ------------------------------
# ★★★ LAWSON Tokyoビッグベイ店 ★★★
#   - 手, 取る (スコア: 0.308)
#   - ガーリック,  (スコア: 0.308)
#   - 取る, 普通 (スコア: 0.308)
#   - 日, 発売 (スコア: 0.308)
#   - さ, 食 (スコア: 0.293)
#   - , 黒 (スコア: 0.282)
#   - 重い, さ (スコア: 0.282)
# ------------------------------
# ★★★ LAWSON お台場店 ★★★
#   - , 禁断 (スコア: 0.287)
#   - ー,  (スコア: 0.180)
#   - テレポート, 駅 (スコア: 0.159)
#   - 抜ける, 右 (スコア: 0.156)
#   - 右, エスカレーター (スコア: 0.156)
#   - コンビニエンスストア, チェーン (スコア: 0.156)
#   - 進む, 先 (スコア: 0.156)
# ------------------------------
# ★★★ LAWSON しののめ店 ★★★
#   - とちる, おとめ (スコア: 0.452)
#   - 県, 産 (スコア: 0.318)
#   - 豊洲, 向かう (スコア: 0.226)
#   - 円, 買う (スコア: 0.215)
#   - テン, 系 (スコア: 0.215)
#   - 向かう, 左側 (スコア: 0.215)
#   - シナモン, ロール (スコア: 0.215)
# ------------------------------
# ★★★ LAWSON りんかい線東雲駅店 ★★★
#   - カスタード, クリーム (スコア: 0.575)
#   - カリ, する (スコア: 0.324)
#   - デニッシュ, 生地 (スコア: 0.324)
#   - 注入, する (スコア: 0.324)
#   - 生地, 中 (スコア: 0.297)
#   - 茨城, 県 (スコア: 0.288)
#   - 感, 楽しめる (スコア: 0.261)
# ------------------------------
# ★★★ LAWSON アクアシティお台場 ★★★
#   - ー,  (スコア: 0.176)
#   - アクアシティ, 台場 (スコア: 0.156)
#   - 甘い, デザート (スコア: 0.153)
#   - すぎる, w (スコア: 0.153)
#   - 普通, ローソン (スコア: 0.153)
#   - 階, ローソン (スコア: 0.153)
#   - デザート, 欲しい (スコア: 0.153)
# ------------------------------
# ★★★ LAWSON フジテレビ店 ★★★
#   - 月, 台場 (スコア: 0.308)
#   - 8, 月 (スコア: 0.206)
#   - 思う, フジテレビ (スコア: 0.198)
#   - みたい, 一 (スコア: 0.198)
#   - グリーンスムージー, 178 (スコア: 0.198)
#   - 写真, 無い (スコア: 0.189)
#   - する, コンビニ (スコア: 0.189)
# ------------------------------
# ★★★ LAWSON ポートストア有明 ★★★
#   - 財団, 法人 (スコア: 0.270)
#   - 法人, 東京 (スコア: 0.270)
#   - 各所, ある (スコア: 0.270)
#   - 有明, サービス (スコア: 0.270)
#   - 一般, 財団 (スコア: 0.270)
#   - チン, 有明 (スコア: 0.258)
#   - 港湾, 福利 (スコア: 0.258)
# ------------------------------
# ★★★ LAWSON 国際展示場駅前店 ★★★
#   - 国際, 展示 (スコア: 0.237)
#   - 展示, 場 (スコア: 0.237)
#   - コンビニエンスストア, チェーン (スコア: 0.189)
#   - 場, 駅 (スコア: 0.178)
#   - , 国際 (スコア: 0.147)
#   - 場, 駅前 (スコア: 0.147)
#   - , 仕事 (スコア: 0.135)
# ------------------------------
# ★★★ LAWSON 有明コロシアム前店 ★★★
#   - カカオ, 香り (スコア: 0.286)
#   - 不便, 場所 (スコア: 0.286)
#   - 近く, ローソン (スコア: 0.286)
#   - チョコ, アイス (スコア: 0.286)
#   - 場, 広い (スコア: 0.273)
#   - 濃い, 台場 (スコア: 0.273)
#   - ある, ラッキー (スコア: 0.254)
# ------------------------------
# ★★★ LAWSON 有明セントラルタワー店 ★★★
#   - 桔梗, 屋 (スコア: 0.343)
#   - 有明, セントラルタワー (スコア: 0.305)
#   - 近く, ローソン (スコア: 0.171)
#   - 木村, 屋 (スコア: 0.171)
#   - 無い, 見つける (スコア: 0.171)
#   - マヨ,  (スコア: 0.171)
#   - 普通, ローソン (スコア: 0.171)
# ------------------------------
# ★★★ LAWSON 東京テレポート駅前店 ★★★
#   - 区, 店 (スコア: 0.344)
#   - 拡大, する (スコア: 0.344)
#   - コンビニ, ある (スコア: 0.344)
#   - する, 新規 (スコア: 0.344)
#   - 店名, 変更 (スコア: 0.344)
#   - する, 店名 (スコア: 0.297)
#   - 新規, オープン (スコア: 0.268)
# ------------------------------
# ★★★ LAWSON 東京ビッグサイトエントランス ★★★
#   - ビッグ, サイト (スコア: 0.214)
#   - ギフト, ショー (スコア: 0.188)
#   - 東京, ビッグ (スコア: 0.188)
#   - の, めんどくさい (スコア: 0.182)
#   - スペース, ある (スコア: 0.141)
#   - プロント, 使う (スコア: 0.106)
#   - レジ, 人 (スコア: 0.106)
# ------------------------------
# ★★★ LAWSON 東雲一丁目店 ★★★
#   - おにぎり, 購入 (スコア: 0.394)
#   - ７, 年 (スコア: 0.327)
#   - 階, 私 (スコア: 0.207)
#   - 47,  (スコア: 0.207)
#   - 日, 発売 (スコア: 0.207)
#   - 朝食, 思う (スコア: 0.207)
#   - 今日, 2 (スコア: 0.207)
# ------------------------------
# ★★★ LAWSON 相鉄グランドフレッサ有明店 ★★★
#   - 階, ローソン (スコア: 0.274)
#   - ビル, オフィス (スコア: 0.274)
#   - 迎える, 前 (スコア: 0.274)
#   - グランドフレッサ, 東京 (スコア: 0.261)
#   - 相鉄, グランドフレッサ (スコア: 0.261)
#   - 内, コンビニ (スコア: 0.251)
#   - なる, 際 (スコア: 0.251)
# ------------------------------
# ★★★ LAWSON Ｈ台場駅前店 ★★★
#   - 店名, 頭文字 (スコア: 0.250)
#   - なる, ググ (スコア: 0.250)
#   - 頭文字, h (スコア: 0.250)
#   - h, 気 (スコア: 0.250)
#   - ググ, 出自 (スコア: 0.250)
#   - 軒, １つ (スコア: 0.250)
#   - グリーンスムージー, 178 (スコア: 0.250)
# ------------------------------
# ★★★ Louis Hamburger Restaurant ★★★
#   - 東陽, 町 (スコア: 0.528)
#   - ハンバーガー, 屋 (スコア: 0.259)
#   - チーズ, バーガー (スコア: 0.219)
#   - 東陽町, 駅 (スコア: 0.210)
#   - バーガー, 専門 (スコア: 0.187)
#   - 人形, 町 (スコア: 0.162)
#   - 団地, 中 (スコア: 0.146)
# ------------------------------
# ★★★ MOMI&TOY'S 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.263)
#   - クレープ, 屋 (スコア: 0.247)
#   - フード, コート (スコア: 0.203)
#   - クレープ, 食べる (スコア: 0.145)
#   - 甘い, 食べる (スコア: 0.125)
#   - いちご, チーズタルト (スコア: 0.120)
#   - とろける, クレープ (スコア: 0.120)
# ------------------------------
# ★★★ MONPAL 8 ★★★
#   - 日本, 酒 (スコア: 0.335)
#   - 飲む, 放題 (スコア: 0.285)
#   - お通し, 刺身 (スコア: 0.165)
#   - 白, 穂 (スコア: 0.138)
#   - 酒, 種類 (スコア: 0.124)
#   - 軒, 目 (スコア: 0.118)
#   - 門前仲, 町 (スコア: 0.097)
# ------------------------------
# ★★★ N．Y．Kカフェ お台場・デックス東京ビーチ ★★★
#   - 甘い, 食べる (スコア: 0.208)
#   - 写真, アップ (スコア: 0.149)
#   - する, 2011 (スコア: 0.149)
#   - ドリンク, クレープ (スコア: 0.149)
#   - 午後, 夫 (スコア: 0.149)
#   - 香り, 誘う (スコア: 0.149)
#   - , y (スコア: 0.149)
# ------------------------------
# ★★★ OEDO ARIAKE STYLE ★★★
#   - いる, なる (スコア: 0.260)
#   - 老舗, 海鮮 (スコア: 0.215)
#   - 有明, ガーデン (スコア: 0.209)
#   - 丼, 専門 (スコア: 0.191)
#   - なる, 寿司 (スコア: 0.185)
#   - 豊洲, 市場 (スコア: 0.184)
#   - 海鮮, 丼 (スコア: 0.181)
# ------------------------------
# ★★★ OSMIC DISH ★★★
#   - 220, 円 (スコア: 0.204)
#   - トマト, 濃厚 (スコア: 0.165)
#   - いる, トマト (スコア: 0.158)
#   - , 220 (スコア: 0.147)
#   - 専門, 店 (スコア: 0.145)
#   - アクアシティ, 台場 (スコア: 0.127)
#   - 円,  (スコア: 0.123)
# ------------------------------
# ★★★ Ozgur Kitchen Kebab ★★★
#   - ビーチ, アイランドモール (スコア: 0.433)
#   - 円, ゆり (スコア: 0.374)
#   - キッチン, カー (スコア: 0.374)
#   - 分, 東京 (スコア: 0.269)
#   - 東京, ビーチ (スコア: 0.245)
#   - 徒歩, 4 (スコア: 0.244)
#   - 公園, 駅 (スコア: 0.242)
# ------------------------------
# ★★★ PATISSERIE L11S ★★★
#   - 来る, 関わる (スコア: 0.251)
#   - 行く, 駐車 (スコア: 0.251)
#   - 状態, 親子 (スコア: 0.251)
#   - ブッフェ, 楽しむ (スコア: 0.251)
#   - する, マンション (スコア: 0.251)
#   - 満腹, 状態 (スコア: 0.251)
#   - いる, ケーキ (スコア: 0.239)
# ------------------------------
# ★★★ PERFECT BEER STAND MONNAKA ★★★
#   - 門前仲, 町 (スコア: 0.262)
#   - 門前仲町, 駅 (スコア: 0.224)
#   - 軒, 目 (スコア: 0.218)
#   - クラフト, ビール (スコア: 0.157)
#   - 常連, 多い (スコア: 0.128)
#   - 立ち, 飲む (スコア: 0.128)
#   - ビール, 好き (スコア: 0.122)
# ------------------------------
# ★★★ PHO365 ★★★
#   - フォー, 専門 (スコア: 0.309)
#   - 春巻き, セット (スコア: 0.265)
#   - フォー, 春巻き (スコア: 0.265)
#   - 春, 巻 (スコア: 0.229)
#   - 牛肉, フォー (スコア: 0.177)
#   - 麺類, 探訪 (スコア: 0.162)
#   - 葛西, 麺類 (スコア: 0.162)
# ------------------------------
# ★★★ PIZZA SALVATORE CUOMO 豊洲 ★★★
#   - 豊洲, 駅 (スコア: 0.267)
#   - ピザ, パスタ (スコア: 0.117)
#   - 豊洲, 店 (スコア: 0.107)
#   - サラダ, ドリンク (スコア: 0.107)
#   - パスタ, ランチ (スコア: 0.087)
#   - ピザ, 食べる (スコア: 0.086)
#   - ハッピー, アワー (スコア: 0.083)
# ------------------------------
# ★★★ PIZZA&WINE カヤバール 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.387)
#   - ピザ, パスタ (スコア: 0.291)
#   - ガーデン, 店 (スコア: 0.102)
#   - テラス, 席 (スコア: 0.096)
#   - ピザ, 美味しい (スコア: 0.086)
#   - トリュフ, 風味 (スコア: 0.081)
#   - 飲む, 放題 (スコア: 0.081)
# ------------------------------
# ★★★ PLANT LOVE ★★★
#   - 貸切, 笑 (スコア: 0.242)
#   - 待ち, 待ち (スコア: 0.242)
#   - ７, ９ (スコア: 0.242)
#   - 本, いただく (スコア: 0.231)
#   - ない, 最初 (スコア: 0.231)
#   - 時半, 来る (スコア: 0.231)
#   - 来る, 待ち (スコア: 0.223)
# ------------------------------
# ★★★ Pacific PICKLE CLUB ★★★
#   - タコ, ライス (スコア: 0.319)
#   - 有明, アーバンスポーツパーク (スコア: 0.298)
#   - ワン, ちゃん (スコア: 0.153)
#   - 姉妹, 店 (スコア: 0.142)
#   - 開放, 感 (スコア: 0.110)
#   - 18, new (スコア: 0.104)
#   - 感, サイズ (スコア: 0.104)
# ------------------------------
# ★★★ R's Cafe ★★★
#   - 広い, 個室 (スコア: 0.151)
#   - シャンパン, ワイン (スコア: 0.151)
#   - 行う, つもり (スコア: 0.151)
#   - 家具, インテリア (スコア: 0.151)
#   - バー, いう (スコア: 0.151)
#   - カフェ, 明るい (スコア: 0.151)
#   - 近い, カフェ (スコア: 0.151)
# ------------------------------
# ★★★ RESTAURANT WHITE ART ★★★
#   - 上手い, 使う (スコア: 0.328)
#   - テーマパーク, スモールワールズ (スコア: 0.328)
#   - 店, テーマパーク (スコア: 0.328)
#   - レストラン, 軽食 (スコア: 0.328)
#   - small, worlds (スコア: 0.313)
#   - チケット, 購入 (スコア: 0.291)
#   - 幻想, 的 (スコア: 0.291)
# ------------------------------
# ★★★ RIN&GOカレー 東京有明セントラルタワー店 ★★★
#   - 小麦粉, 使う (スコア: 0.495)
#   - カレー, ルー (スコア: 0.403)
#   - ある, 自社 (スコア: 0.259)
#   - なる, カツ (スコア: 0.259)
#   - の, 一般 (スコア: 0.247)
#   - 一般, 向け (スコア: 0.238)
#   - 味, なる (スコア: 0.238)
# ------------------------------
# ★★★ RISTORANTE OZIO ★★★
#   - ベイ, コート (スコア: 0.667)
#   - 東京, ベイ (スコア: 0.322)
#   - コート, 倶楽部 (スコア: 0.302)
#   - アフタヌーン, ティー (スコア: 0.261)
#   - ristorante, ozio (スコア: 0.112)
#   - 会員, 制 (スコア: 0.100)
#   - 倶楽部, ホテル (スコア: 0.070)
# ------------------------------
# ★★★ SAUS ★★★
#   - ツリー, by (スコア: 0.263)
#   - ダブル, ツリー (スコア: 0.263)
#   - ヒルトン, 東京 (スコア: 0.198)
#   - 東京, 有明 (スコア: 0.164)
#   - 国際, 展示 (スコア: 0.110)
#   - 展示, 場 (スコア: 0.109)
#   - 店, 一番乗り (スコア: 0.088)
# ------------------------------
# ★★★ SONAE CAFE ★★★
#   - そ, エリア (スコア: 0.436)
#   - 広域, 防災 (スコア: 0.327)
#   - 公園, そ (スコア: 0.327)
#   - 防災, 公園 (スコア: 0.327)
#   - 臨海, 広域 (スコア: 0.327)
#   - 東京, 臨海 (スコア: 0.226)
#   - 国営, 東京 (スコア: 0.218)
# ------------------------------
# ★★★ STONE FACTORY Jr. ★★★
#   - 牛, ステーキ (スコア: 0.318)
#   - 国産, 牛 (スコア: 0.278)
#   - フード, コート (スコア: 0.223)
#   - 石, 焼き (スコア: 0.185)
#   - 石, 焼 (スコア: 0.172)
#   - いる, ワン (スコア: 0.119)
#   - アジア, 各国 (スコア: 0.119)
# ------------------------------
# ★★★ SWITCH STAND ODAIBA ★★★
#   - 最高, ご飯 (スコア: 0.251)
#   - カレー, ボリューム (スコア: 0.251)
#   - ご飯, すっごい (スコア: 0.251)
#   - 選べる, 行う (スコア: 0.239)
#   - 違う, 良い (スコア: 0.239)
#   - 広い, 人 (スコア: 0.239)
#   - とき, パスタ (スコア: 0.239)
# ------------------------------
# ★★★ Seaside Café SOLARIS ★★★
#   - バス, 乗り場 (スコア: 0.303)
#   - 水上, バス (スコア: 0.287)
#   - 公園, 水上 (スコア: 0.190)
#   - 台場, 海浜 (スコア: 0.188)
#   - 海浜, 公園 (スコア: 0.184)
#   - ミルク, アイス (スコア: 0.127)
#   - フェリー, 乗り場 (スコア: 0.127)
# ------------------------------
# ★★★ Sky Restaurant シーガル ★★★
#   - 24, ビル (スコア: 0.277)
#   - 社, 食 (スコア: 0.258)
#   - タイム, 24 (スコア: 0.230)
#   - , 3 (スコア: 0.230)
#   - テレコム, センター (スコア: 0.177)
#   - 1, 点 (スコア: 0.166)
#   - 3,  (スコア: 0.165)
# ------------------------------
# ★★★ TGI FRIDAYS 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.390)
#   - コブ, サラダ (スコア: 0.175)
#   - 飲む, 放題 (スコア: 0.111)
#   - シェア, する (スコア: 0.072)
#   - tgi, フライデーズ (スコア: 0.071)
#   - ボリューム, ある (スコア: 0.069)
#   - 2200, 円 (スコア: 0.067)
# ------------------------------
# ★★★ TGIフライデーズ お台場アクアシティ店 ★★★
#   - テラス, 席 (スコア: 0.140)
#   - レインボー, ブリッジ (スコア: 0.129)
#   - tgi, フライデーズ (スコア: 0.121)
#   - 誕生, 日 (スコア: 0.108)
#   - ランチ, メニュー (スコア: 0.096)
#   - , i (スコア: 0.091)
#   - 予約, する (スコア: 0.090)
# ------------------------------
# ★★★ THE BBQ BEACH in AQUA CITY ODAIBA ★★★
#   - 7, 階 (スコア: 0.354)
#   - 屋上, ある (スコア: 0.154)
#   - bbq, 楽しめる (スコア: 0.154)
#   - 飲む, 放題 (スコア: 0.121)
#   - 良い, 台場 (スコア: 0.120)
#   - 肉, 野菜 (スコア: 0.110)
#   - レインボー, ブリッジ (スコア: 0.109)
# ------------------------------
# ★★★ THEキャラCAFE お台場デックス店 ★★★
#   - ラブ, ライブ (スコア: 0.418)
#   - 味, コラボレーション (スコア: 0.418)
#   - 高い, いい (スコア: 0.398)
#   - ランチョン, マット (スコア: 0.383)
#   - カフェ, する (スコア: 0.331)
#   - 特筆, する (スコア: 0.305)
#   - クオリティ, 高い (スコア: 0.244)
# ------------------------------
# ★★★ The Cabaret ★★★
#   - フォート (スコア: 0.392)
#   - イマーシブ (スコア: 0.379)
#   - フォート, 東京 (スコア: 0.296)
#   - イマーシブフォート, 東京 (スコア: 0.201)
#   - ショー, 見る (スコア: 0.196)
#   - 東京, 中 (スコア: 0.121)
#   - する, ショー (スコア: 0.116)
# ------------------------------
# ★★★ The Grill on 30th ★★★
#   - グランド, ニッコー (スコア: 0.378)
#   - 30, 階 (スコア: 0.322)
#   - ニッコー, 東京 (スコア: 0.277)
#   - 30, th (スコア: 0.198)
#   - 東京, 台場 (スコア: 0.190)
#   - on, 30 (スコア: 0.184)
#   - デザート, ビュッフェ (スコア: 0.179)
# ------------------------------
# ★★★ The Lobby Cafe ★★★
#   - アフタヌーン, ティー (スコア: 0.503)
#   - グランド, ニッコー (スコア: 0.379)
#   - ニッコー, 東京 (スコア: 0.323)
#   - 東京, 台場 (スコア: 0.186)
#   - lobby, cafe (スコア: 0.163)
#   - the, lobby (スコア: 0.163)
#   - アフタヌーン, ティーセット (スコア: 0.123)
# ------------------------------
# ★★★ Tokyo 串家 ★★★
#   - 串, 家 (スコア: 0.487)
#   - フロンティア, ビル (スコア: 0.163)
#   - 台場, フロンティア (スコア: 0.155)
#   - タレ, 甘い (スコア: 0.131)
#   - 週, 替わり (スコア: 0.117)
#   - 定番, メニュー (スコア: 0.116)
#   - く, 夜 (スコア: 0.099)
# ------------------------------
# ★★★ Trattoria&Pizzeria LOGIC お台場 ★★★
#   - ドリンク, バー (スコア: 0.173)
#   - 誕生, 日 (スコア: 0.167)
#   - テラス, 席 (スコア: 0.151)
#   - ピザ, 生地 (スコア: 0.141)
#   - パスタ, ピザ (スコア: 0.132)
#   - ピザ, 美味しい (スコア: 0.128)
#   - 美味しい, ピザ (スコア: 0.117)
# ------------------------------
# ★★★ WAGYU USHITOMI GINZA ★★★
#   - 新富, 町 (スコア: 0.682)
#   - 八丁堀, 駅 (スコア: 0.228)
#   - 新富町, 駅 (スコア: 0.200)
#   - 黒毛, 和牛 (スコア: 0.160)
#   - 割烹, 店 (スコア: 0.158)
#   - 町, 駅 (スコア: 0.136)
#   - 8, 席 (スコア: 0.100)
# ------------------------------
# ★★★ WINESTAND TEO ★★★
#   - 清澄, 白河 (スコア: 0.300)
#   - ナチュラル, ワイン (スコア: 0.280)
#   - 2, 階 (スコア: 0.171)
#   - サクッ, 行う (スコア: 0.126)
#   - 白河, 駅 (スコア: 0.126)
#   - ワイン, バー (スコア: 0.109)
#   - 1, 階 (スコア: 0.105)
# ------------------------------
# ★★★ WOOD DESIGN PARK お台場店 ★★★
#   - バーベキュー, 最高 (スコア: 0.321)
#   - よい, 最初 (スコア: 0.168)
#   - コップ, 食器 (スコア: 0.168)
#   - ドリンク, の (スコア: 0.168)
#   - 快適, 過ごす (スコア: 0.168)
#   - 友達, いる (スコア: 0.168)
#   - パワー, ワード (スコア: 0.168)
# ------------------------------
# ★★★ YORIMICHI Odaiba ★★★
#   - アフタヌーン, ティー (スコア: 0.371)
#   - レインボー, ブリッジ (スコア: 0.178)
#   - 創作, 和食 (スコア: 0.144)
#   - 台場, 夜景 (スコア: 0.116)
#   - 土鍋, ご飯 (スコア: 0.108)
#   - 相談, する (スコア: 0.084)
#   - ブリッジ, 一望 (スコア: 0.083)
# ------------------------------
# ★★★ Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉 ★★★
#   - 一, 枚 (スコア: 0.382)
#   - 焼肉, 屋 (スコア: 0.230)
#   - 1, 枚 (スコア: 0.196)
#   - 冷, 麺 (スコア: 0.181)
#   - 焼肉, 激戦 (スコア: 0.178)
#   - 激戦, 区 (スコア: 0.163)
#   - 焼肉, 店 (スコア: 0.149)
# ------------------------------
# ★★★ bills お台場 ★★★
#   - 世界一, 朝食 (スコア: 0.283)
#   - bills, 台場 (スコア: 0.258)
#   - パンケーキ, 食べる (スコア: 0.234)
#   - 台場, bills (スコア: 0.232)
#   - パンケーキ, 美味しい (スコア: 0.178)
#   - テラス, 席 (スコア: 0.156)
#   - スクランブル, エッグ (スコア: 0.134)
# ------------------------------
# ★★★ creperie kenny's ダイバーシティ店 ★★★
#   - ダイバー, シティ (スコア: 0.273)
#   - クレープ, 屋 (スコア: 0.270)
#   - チョコ, 生クリーム (スコア: 0.219)
#   - バナナ, チョコ (スコア: 0.189)
#   - シティ, 店 (スコア: 0.158)
#   - クレープ, 店 (スコア: 0.151)
#   - , s (スコア: 0.139)
# ------------------------------
# ★★★ da pai dang 105 有明ガーデン店 ★★★
#   - 小籠, 包 (スコア: 0.681)
#   - フード, コート (スコア: 0.246)
#   - 焼く, 小籠 (スコア: 0.242)
#   - 包, セット (スコア: 0.165)
#   - 有明, ガーデン (スコア: 0.151)
#   - 焼き, 小籠 (スコア: 0.104)
#   - 階, フード (スコア: 0.089)
# ------------------------------
# ★★★ mal D'amour ★★★
#   - ベイ, コート (スコア: 0.585)
#   - 東京, ベイ (スコア: 0.351)
#   - コート, 倶楽部 (スコア: 0.325)
#   - 会員, 制 (スコア: 0.265)
#   - 24, 階 (スコア: 0.128)
#   - 倶楽部, 24 (スコア: 0.117)
#   - フレンチ, レストラン (スコア: 0.113)
# ------------------------------
# ★★★ milky70 since1951 アクアシティお台場店 ★★★
#   - ミルキー, ソフトクリーム (スコア: 0.226)
#   - ペコ, ちゃん (スコア: 0.216)
#   - アイス, 屋 (スコア: 0.216)
#   - フード, コート (スコア: 0.198)
#   - アクアシティ, 台場 (スコア: 0.193)
#   - , ミルキー (スコア: 0.151)
#   - ソフトクリーム, ミックス (スコア: 0.151)
# ------------------------------
# ★★★ mode super smoothie ★★★
#   - できる, 店内 (スコア: 0.318)
#   - 飲む, 価格 (スコア: 0.248)
#   - どれ, 千 (スコア: 0.248)
#   - 気, なれる (スコア: 0.248)
#   - アーバンスポーツパーク, 中 (スコア: 0.248)
#   - 有明, アーバンスポーツパーク (スコア: 0.237)
#   - 価格, 行く (スコア: 0.237)
# ------------------------------
# ★★★ root C 日本科学未来館 5Fロビー ★★★
#   - にぎる, 頼む (スコア: 0.296)
#   - ドリンク, ドリンク (スコア: 0.296)
#   - バー, 1 (スコア: 0.296)
#   - 店舗, 好き (スコア: 0.282)
#   - 色々, 場所 (スコア: 0.271)
#   - 試す, の (スコア: 0.263)
#   - 美味しい, ドリンク (スコア: 0.223)
# ------------------------------
# ★★★ the BAR ★★★
#   - プレ, オープン (スコア: 0.326)
#   - 豊富, シ (スコア: 0.202)
#   - the, bar (スコア: 0.202)
#   - 眺める, れる (スコア: 0.202)
#   - 貼る, おる (スコア: 0.202)
#   - 何, 情報 (スコア: 0.202)
#   - 言う, 夜景 (スコア: 0.193)
# ------------------------------
# ★★★ the open bakery ★★★
#   - パン, 屋 (スコア: 0.529)
#   - カレー, パン (スコア: 0.203)
#   - 台場, 海浜 (スコア: 0.185)
#   - 海浜, 公園 (スコア: 0.181)
#   - テラス, 席 (スコア: 0.149)
#   - ルー, ベン (スコア: 0.127)
#   - 公園, 駅 (スコア: 0.104)
# ------------------------------
# ★★★ あのり ★★★
#   - 台場, 入る (スコア: 0.243)
#   - 台場, 海浜 (スコア: 0.209)
#   - 海浜, 公園 (スコア: 0.204)
#   - ８, ３ (スコア: 0.140)
#   - 肴, 豊富 (スコア: 0.140)
#   - ローカル, フード (スコア: 0.140)
#   - 時刻, １ (スコア: 0.140)
# ------------------------------
# ★★★ あばら大根 西葛西店 ★★★
#   - 刺身, 盛り合わせ (スコア: 0.202)
#   - 西葛西, 駅 (スコア: 0.190)
#   - テラス, 席 (スコア: 0.156)
#   - 美味しい, 刺身 (スコア: 0.100)
#   - ご飯, 美味しい (スコア: 0.094)
#   - 飲む, 放題 (スコア: 0.092)
#   - 西葛西, 店 (スコア: 0.090)
# ------------------------------
# ★★★ いろり庵 きらく 国際展示場駅店 ★★★
#   - 立ち, 食い (スコア: 0.354)
#   - 券売, 機 (スコア: 0.194)
#   - 展示, 場 (スコア: 0.182)
#   - 国際, 展示 (スコア: 0.173)
#   - 場, 駅 (スコア: 0.173)
#   - 蕎麦, 屋 (スコア: 0.172)
#   - 食い, そば (スコア: 0.154)
# ------------------------------
# ★★★ うなぎ 明月川 豊洲店 ★★★
#   - 食べる, 歩き (スコア: 0.265)
#   - 豊洲, 千客万来 (スコア: 0.212)
#   - 鰻, 屋 (スコア: 0.204)
#   - 豊洲, 市場 (スコア: 0.187)
#   - 白, 焼き (スコア: 0.181)
#   - 海鮮, 丼 (スコア: 0.161)
#   - 店, 千客万来 (スコア: 0.122)
# ------------------------------
# ★★★ おいらんち 葛西駅前店 ★★★
#   - 葛西, 駅 (スコア: 0.223)
#   - 99, 円 (スコア: 0.177)
#   - メニュー, 豊富 (スコア: 0.160)
#   - 知人, 紹介 (スコア: 0.149)
#   - 肉, 寿司 (スコア: 0.147)
#   - 洋食, ある (スコア: 0.123)
#   - 299, 円 (スコア: 0.118)
# ------------------------------
# ★★★ おぼんdeごはん ダイバーシティ東京プラザ店 ★★★
#   - de, ごはん (スコア: 0.218)
#   - ぼん, de (スコア: 0.218)
#   - 味噌汁, かわり (スコア: 0.169)
#   - びん, ちょう (スコア: 0.163)
#   - ちょう, まぐろ (スコア: 0.163)
#   - ダイバー, シティ (スコア: 0.163)
#   - ごはん, 味噌汁 (スコア: 0.141)
# ------------------------------
# ★★★ お食事処 ゆき ★★★
#   - 台場, 海浜 (スコア: 0.229)
#   - 海浜, 公園 (スコア: 0.224)
#   - 焼き, 定食 (スコア: 0.186)
#   - 公園, 駅 (スコア: 0.173)
#   - 海, 家 (スコア: 0.172)
#   - 定食, 屋 (スコア: 0.159)
#   - 生姜, 焼き (スコア: 0.153)
# ------------------------------
# ★★★ かつゑもん ダイバーシティ東京プラザ ★★★
#   - フード, コート (スコア: 0.339)
#   - ダイバー, シティ (スコア: 0.261)
#   - カツ, 丼 (スコア: 0.224)
#   - シティ, 東京 (スコア: 0.217)
#   - チーズ, トマト (スコア: 0.190)
#   - 東京, プラザ (スコア: 0.170)
#   - 卵, とじる (スコア: 0.131)
# ------------------------------
# ★★★ がぜん 有明 ★★★
#   - 海鮮, 丼 (スコア: 0.335)
#   - ビッグ, サイト (スコア: 0.259)
#   - ワシントン, ホテル (スコア: 0.225)
#   - パーク, ビル (スコア: 0.175)
#   - 有明, パーク (スコア: 0.155)
#   - 国際, 展示 (スコア: 0.148)
#   - 展示, 会 (スコア: 0.148)
# ------------------------------
# ★★★ くいもの屋わん お台場デックス東京ビーチ店 ★★★
#   - わん, 台場 (スコア: 0.223)
#   - 牛, タン (スコア: 0.141)
#   - 夜, 仕事 (スコア: 0.139)
#   - ビーチ, 店 (スコア: 0.132)
#   - の, 早い (スコア: 0.093)
#   - 東京, ビーチ (スコア: 0.088)
#   - 台場, デックス (スコア: 0.088)
# ------------------------------
# ★★★ くずし割烹 天ぷら竹の庵 東銀座店 ★★★
#   - 東, 銀座 (スコア: 0.377)
#   - ビル, 地下 (スコア: 0.338)
#   - 天ぷら, 膳 (スコア: 0.196)
#   - 天ぷら, 屋 (スコア: 0.158)
#   - 銀座, 店 (スコア: 0.111)
#   - 銀座, 駅 (スコア: 0.099)
#   - 揚げたて, 天ぷら (スコア: 0.094)
# ------------------------------
# ★★★ こだわりから揚げの酒処 くらふと ★★★
#   - 唐, 揚げ (スコア: 0.546)
#   - 国際, 展示 (スコア: 0.176)
#   - 展示, 場 (スコア: 0.176)
#   - ハッピー, アワー (スコア: 0.147)
#   - 場, 駅 (スコア: 0.141)
#   - ビッグ, サイト (スコア: 0.097)
#   - 揚げ, 美味しい (スコア: 0.087)
# ------------------------------
# ★★★ こなな 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.351)
#   - 和風, パスタ (スコア: 0.331)
#   - こ, 有明 (スコア: 0.160)
#   - ドリンク, バー (スコア: 0.139)
#   - パスタ, 屋 (スコア: 0.101)
#   - する, パスタ (スコア: 0.092)
#   - する, 有明 (スコア: 0.092)
# ------------------------------
# ★★★ こめらく みんなで、お茶漬け日和。 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.302)
#   - フード, コート (スコア: 0.292)
#   - ガーデン, フード (スコア: 0.161)
#   - 丼, お茶漬け (スコア: 0.156)
#   - 出汁, かける (スコア: 0.148)
#   - 切り, 豚 (スコア: 0.148)
#   - 二, 度 (スコア: 0.134)
# ------------------------------
# ★★★ さち福や 台場アクアシティ店 ★★★
#   - 和, 定食 (スコア: 0.249)
#   - １, 人 (スコア: 0.182)
#   - ちる, 福 (スコア: 0.147)
#   - アクアシティ, ちる (スコア: 0.147)
#   - 度, コスパ (スコア: 0.147)
#   - 最近, 新しい (スコア: 0.147)
#   - ゆず, 風味 (スコア: 0.147)
# ------------------------------
# ★★★ さち福やCAFE 有明ガーデン ★★★
#   - 有明, ガーデン (スコア: 0.374)
#   - ちる, 福 (スコア: 0.246)
#   - チキン, 南蛮 (スコア: 0.171)
#   - 米, 選べる (スコア: 0.147)
#   - 牡蠣, フライ (スコア: 0.102)
#   - 五穀, 米 (スコア: 0.102)
#   - ガーデン, シアター (スコア: 0.101)
# ------------------------------
# ★★★ しゃぶしゃぶ 吟半 お台場店 ★★★
#   - 半, 台場 (スコア: 0.298)
#   - デックス, 東京 (スコア: 0.238)
#   - 東京, ビーチ (スコア: 0.222)
#   - 上, ロース (スコア: 0.204)
#   - 国産, 牛 (スコア: 0.179)
#   - 贅沢, コース (スコア: 0.169)
#   - ビーチ, 1 (スコア: 0.168)
# ------------------------------
# ★★★ しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場 ★★★
#   - 食べる, 放題 (スコア: 0.310)
#   - ベトナム, 人 (スコア: 0.184)
#   - 6, 階 (スコア: 0.120)
#   - ゴマ, だれ (スコア: 0.109)
#   - アクアシティ, 台場 (スコア: 0.099)
#   - 景色, 綺麗 (スコア: 0.085)
#   - 予約, する (スコア: 0.085)
# ------------------------------
# ★★★ しゃぶ食べ 有明ガーデン店 ★★★
#   - 食べる, 放題 (スコア: 0.426)
#   - 有明, ガーデン (スコア: 0.239)
#   - しゃぶしゃぶ, 屋 (スコア: 0.156)
#   - 元, 豚 (スコア: 0.150)
#   - 三, 元 (スコア: 0.150)
#   - 放題, 店 (スコア: 0.125)
#   - 豚, 食べる (スコア: 0.120)
# ------------------------------
# ★★★ しゅん ★★★
#   - ヒレ, カツ (スコア: 0.141)
#   - 靴, 脱ぐ (スコア: 0.131)
#   - 昔, 上司 (スコア: 0.114)
#   - エリア, 東雲 (スコア: 0.114)
#   - 陸, 孤島 (スコア: 0.109)
#   - 東雲, 方面 (スコア: 0.109)
#   - 豊洲, 東雲 (スコア: 0.109)
# ------------------------------
# ★★★ すき家 ワンザ有明店 ★★★
#   - すき, 家 (スコア: 0.603)
#   - 牛, 丼 (スコア: 0.371)
#   - ワンザ, 有明 (スコア: 0.171)
#   - フード, コート (スコア: 0.124)
#   - 展示, 場 (スコア: 0.122)
#   - する, すき (スコア: 0.110)
#   - 国際, 展示 (スコア: 0.092)
# ------------------------------
# ★★★ すき家 東雲晴海通り店 ★★★
#   - すき, 家 (スコア: 0.542)
#   - 牛, 丼 (スコア: 0.269)
#   - 仕事場, 近く (スコア: 0.209)
#   - 白髪, ねぎ (スコア: 0.114)
#   - ふき, 大根 (スコア: 0.114)
#   - ふろ, ふき (スコア: 0.114)
#   - 牛, すき鍋 (スコア: 0.114)
# ------------------------------
# ★★★ すしざんまい 奥の院 ★★★
#   - すし, ざんまい (スコア: 0.867)
#   - 寿司, 屋 (スコア: 0.115)
#   - 築地, すし (スコア: 0.100)
#   - する, ざんまい (スコア: 0.087)
#   - 寿司, 食べる (スコア: 0.081)
#   - 築地, 場外 (スコア: 0.068)
#   - 築地, 寿司 (スコア: 0.067)
# ------------------------------
# ★★★ すしざんまい 築地駅前店 ★★★
#   - すし, ざんまい (スコア: 0.795)
#   - 築地, 駅前 (スコア: 0.184)
#   - ざんまい, 築地 (スコア: 0.161)
#   - 築地, 駅 (スコア: 0.149)
#   - 駅前, 店 (スコア: 0.108)
#   - 築地, 本願寺 (スコア: 0.102)
#   - 寿司, 食べる (スコア: 0.074)
# ------------------------------
# ★★★ すし処おかめ ★★★
#   - 豊洲, 市場 (スコア: 0.489)
#   - 立ち, 食い (スコア: 0.175)
#   - 寿司, 屋 (スコア: 0.158)
#   - 市場, 行く (スコア: 0.157)
#   - おまかせ, 握り (スコア: 0.152)
#   - 管理, 棟 (スコア: 0.144)
#   - 市場, 見学 (スコア: 0.113)
# ------------------------------
# ★★★ せきどうばなな ★★★
#   - バナナ, 甘い (スコア: 0.483)
#   - , バナナ (スコア: 0.443)
#   - 頂く, 後 (スコア: 0.429)
#   - , アルコール (スコア: 0.417)
#   - チョイス,  (スコア: 0.369)
#   - 食, する (スコア: 0.275)
# ------------------------------
# ★★★ そじ坊 ダイバーシティ東京プラザ店 ★★★
#   - す, 坊 (スコア: 0.460)
#   - ダイバー, シティ (スコア: 0.243)
#   - カレー, 南蛮 (スコア: 0.223)
#   - チキン, カツ (スコア: 0.150)
#   - カツ, 丼 (スコア: 0.146)
#   - 温かい, 蕎麦 (スコア: 0.137)
#   - 揚げる, 餅 (スコア: 0.129)
# ------------------------------
# ★★★ そじ坊 ワンザ有明店 ★★★
#   - す, 坊 (スコア: 0.229)
#   - ワンザ, 有明 (スコア: 0.208)
#   - とろろ, そば (スコア: 0.198)
#   - 蕎麦, 屋 (スコア: 0.182)
#   - カツ, 丼 (スコア: 0.180)
#   - ビッグ, サイト (スコア: 0.170)
#   - 丼, 定食 (スコア: 0.128)
# ------------------------------
# ★★★ そなエリア東京バーベキューガーデン ★★★
#   - 広域, 防災 (スコア: 0.251)
#   - そ, エリア (スコア: 0.251)
#   - 防災, 公園 (スコア: 0.251)
#   - 臨海, 広域 (スコア: 0.251)
#   - エリア, 東京 (スコア: 0.241)
#   - bbq,  (スコア: 0.241)
#   - 東京, 臨海 (スコア: 0.173)
# ------------------------------
# ★★★ たけぞー ★★★
#   - ビッグ, サイト (スコア: 0.281)
#   - たけ, ー (スコア: 0.190)
#   - 有明, セントラルタワー (スコア: 0.177)
#   - かける, うどん (スコア: 0.168)
#   - 東京, ビッグ (スコア: 0.162)
#   - かける, そば (スコア: 0.127)
#   - セントラルタワー, 2 (スコア: 0.126)
# ------------------------------
# ★★★ たこやきやの元祖 本家 会津屋 お台場店 ★★★
#   - たこ焼き, ミュージアム (スコア: 0.654)
#   - 台場, たこ焼き (スコア: 0.385)
#   - たこ焼き, 屋 (スコア: 0.124)
#   - 発祥, 店 (スコア: 0.119)
#   - 12, 個 (スコア: 0.107)
#   - ミュージアム, 中 (スコア: 0.101)
#   - 牛, すじ (スコア: 0.097)
# ------------------------------
# ★★★ たこ家道頓堀くくる お台場たこ焼きミュージアム店 ★★★
#   - たこ焼き, ミュージアム (スコア: 0.635)
#   - 台場, たこ焼き (スコア: 0.321)
#   - たこ焼き, 屋 (スコア: 0.191)
#   - 明石, 焼き (スコア: 0.179)
#   - 道頓堀, くくる (スコア: 0.164)
#   - 8, 個 (スコア: 0.130)
#   - たこ焼き, 食べる (スコア: 0.122)
# ------------------------------
# ★★★ つきじ丼匠 ★★★
#   - 豊洲, 市場 (スコア: 0.513)
#   - 海鮮, 丼 (スコア: 0.286)
#   - 豪快, 丼 (スコア: 0.194)
#   - 丼, 店 (スコア: 0.132)
#   - 管理, 棟 (スコア: 0.122)
#   - 街, 区 (スコア: 0.100)
#   - 寿司, 屋 (スコア: 0.098)
# ------------------------------
# ★★★ つきぢ神楽寿司 豊洲市場店 ★★★
#   - 豊洲, 市場 (スコア: 0.440)
#   - 赤, 酢 (スコア: 0.422)
#   - つく, ぢ (スコア: 0.186)
#   - 寿司, 豊洲 (スコア: 0.171)
#   - 寿司, 屋 (スコア: 0.161)
#   - 酢, シャリ (スコア: 0.101)
#   - 管理, 棟 (スコア: 0.098)
# ------------------------------
# ★★★ つけ麺らーめん春樹 お台場店 ★★★
#   - つけ, 麺 (スコア: 0.580)
#   - 特, 盛 (スコア: 0.197)
#   - 山, 盛 (スコア: 0.160)
#   - 豚, 骨 (スコア: 0.156)
#   - 麺, ら (スコア: 0.128)
#   - 麺, 特 (スコア: 0.128)
#   - 太, 麺 (スコア: 0.115)
# ------------------------------
# ★★★ つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店 ★★★
#   - つけ, 麺 (スコア: 0.520)
#   - 三田, 製 (スコア: 0.428)
#   - 麺, 所 (スコア: 0.337)
#   - 製, 麺 (スコア: 0.316)
#   - 特, 濃い (スコア: 0.168)
#   - つけ, 汁 (スコア: 0.159)
#   - つける, 麺 (スコア: 0.154)
# ------------------------------
# ★★★ てしごとや ふくの鳥 木場店 ★★★
#   - 唐, 揚げ (スコア: 0.233)
#   - ふく, 鳥 (スコア: 0.210)
#   - １１月, １ (スコア: 0.158)
#   - チキン, 南蛮 (スコア: 0.146)
#   - 木場, 駅 (スコア: 0.136)
#   - 揚げ, 定食 (スコア: 0.107)
#   - いる, 木場 (スコア: 0.100)
# ------------------------------
# ★★★ てっぱん屋台 ダイバーシティ東京プラザ店 ★★★
#   - ぱん, 屋台 (スコア: 0.370)
#   - フード, コート (スコア: 0.367)
#   - てる, ぱん (スコア: 0.326)
#   - ダイバー, シティ (スコア: 0.326)
#   - モダン, 焼き (スコア: 0.180)
#   - やく, そば (スコア: 0.174)
#   - シティ, 東京 (スコア: 0.149)
# ------------------------------
# ★★★ とんかつ八千代 ★★★
#   - チャーシュー, エッグ (スコア: 0.660)
#   - 豊洲, 市場 (スコア: 0.370)
#   - アジ, フライ (スコア: 0.328)
#   - エッグ, 定食 (スコア: 0.251)
#   - とる, 八千代 (スコア: 0.171)
#   - 車, エビ (スコア: 0.105)
#   - とぶ, 八千代 (スコア: 0.105)
# ------------------------------
# ★★★ どうとんぼり神座 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.536)
#   - フード, コート (スコア: 0.408)
#   - おいしい, ラーメン (スコア: 0.190)
#   - ガーデン, フード (スコア: 0.179)
#   - ん, ぼる (スコア: 0.175)
#   - ラーメン, 屋 (スコア: 0.146)
#   - ガーデン, 店 (スコア: 0.133)
# ------------------------------
# ★★★ なんで、や お台場店 ★★★
#   - アクアシティ, 台場 (スコア: 0.222)
#   - 台場, 店 (スコア: 0.164)
#   - アクアシティ, １ (スコア: 0.157)
#   - 居酒屋, する (スコア: 0.105)
#   - 大衆, 酒場 (スコア: 0.105)
#   - フード, コート (スコア: 0.103)
#   - 大衆, 居酒屋 (スコア: 0.095)
# ------------------------------
# ★★★ にばん家 勝どき ★★★
#   - 勝どき, 駅 (スコア: 0.347)
#   - 焼き, 弁当 (スコア: 0.270)
#   - 路地, 裏 (スコア: 0.254)
#   - 裏, 隠れ家 (スコア: 0.189)
#   - 焼, 丼 (スコア: 0.189)
#   - 見つける, づらい (スコア: 0.094)
#   - いう, 入る (スコア: 0.094)
# ------------------------------
# ★★★ ねぎま屋 武蔵 葛西店 ★★★
#   - 99, 円 (スコア: 0.258)
#   - 焼き鳥, 屋 (スコア: 0.171)
#   - 葛西, 駅 (スコア: 0.156)
#   - 美味しい, 焼き鳥 (スコア: 0.131)
#   - ナポリ, タン (スコア: 0.120)
#   - 得, クーポン (スコア: 0.103)
#   - 串, 美味しい (スコア: 0.103)
# ------------------------------
# ★★★ ねこねこチーズケーキ 有明ガーデンシティ店 ★★★
#   - チーズ, ケーキ (スコア: 0.463)
#   - ねこ, ねこ (スコア: 0.222)
#   - 有明, ガーデン (スコア: 0.215)
#   - 形, する (スコア: 0.172)
#   - する, チーズ (スコア: 0.152)
#   - 店, 可愛らしい (スコア: 0.148)
#   - 感, 濃厚 (スコア: 0.148)
# ------------------------------
# ★★★ はなまるうどん ダイバーシティ東京店 ★★★
#   - なまる, うどん (スコア: 0.621)
#   - 冷, かける (スコア: 0.251)
#   - ダイバー, シティ (スコア: 0.250)
#   - フード, コート (スコア: 0.219)
#   - の, なまる (スコア: 0.175)
#   - うどん, 食べる (スコア: 0.149)
#   - うどん, 小 (スコア: 0.134)
# ------------------------------
# ★★★ はなまる屋 アクアシティお台場店 ★★★
#   - なまる, うどん (スコア: 0.407)
#   - フード, コート (スコア: 0.212)
#   - 台場, フード (スコア: 0.207)
#   - アクアシティ, 台場 (スコア: 0.193)
#   - 通り, 混雑 (スコア: 0.094)
#   - 考える, 緊急 (スコア: 0.094)
#   - 宣言, 以前 (スコア: 0.094)
# ------------------------------
# ★★★ ふくの鳥 東陽町 ★★★
#   - チキン, 南蛮 (スコア: 0.377)
#   - メンチ, カツ (スコア: 0.266)
#   - ふく, 鳥 (スコア: 0.191)
#   - ひな, 鶏 (スコア: 0.183)
#   - 東陽, 町 (スコア: 0.177)
#   - カツ, 定食 (スコア: 0.149)
#   - 粗, 挽く (スコア: 0.122)
# ------------------------------
# ★★★ ふぐ倶楽部ビルヂング ★★★
#   - 店, ふぐ (スコア: 0.214)
#   - ふぐ, 専門 (スコア: 0.214)
#   - 新富, 町 (スコア: 0.170)
#   - 専門, 店 (スコア: 0.141)
#   - 00,  (スコア: 0.134)
#   - 店, 外 (スコア: 0.110)
#   - 090,  (スコア: 0.107)
# ------------------------------
# ★★★ ほおずきや ★★★
#   - ワンザ, 有明 (スコア: 0.301)
#   - ビッグ, サイト (スコア: 0.241)
#   - 国際, 展示 (スコア: 0.187)
#   - 展示, 場 (スコア: 0.186)
#   - ら, ー (スコア: 0.157)
#   - ー, めん (スコア: 0.156)
#   - ベイ, モール (スコア: 0.154)
# ------------------------------
# ★★★ ほっともっと 東雲店 ★★★
#   - 東雲, 1 (スコア: 0.191)
#   - 東雲, 店 (スコア: 0.175)
#   - 区, 東雲 (スコア: 0.169)
#   - 打ち合わせ, 帰り (スコア: 0.095)
#   - , すき焼き (スコア: 0.095)
#   - くれる, こ (スコア: 0.095)
#   - 店, 祝日 (スコア: 0.095)
# ------------------------------
# ★★★ ぼてや アクアシティお台場店 ★★★
#   - フード, コート (スコア: 0.331)
#   - アクアシティ, 台場 (スコア: 0.169)
#   - ぜん, 焼きそば (スコア: 0.165)
#   - ひる, ぜん (スコア: 0.165)
#   - モダン, 焼き (スコア: 0.152)
#   - 台場, フード (スコア: 0.121)
#   - 月見, 焼きそば (スコア: 0.110)
# ------------------------------
# ★★★ まいばすけっと 台場1丁目店 ★★★
#   - かける, 好き (スコア: 0.407)
#   - ipa, 探す (スコア: 0.407)
#   - 品数, 割 (スコア: 0.407)
#   - 好き, ビール (スコア: 0.407)
#   - 入口, 近い (スコア: 0.388)
#   - 手, する (スコア: 0.388)
#   - レインボー, ブリッジ (スコア: 0.193)
# ------------------------------
# ★★★ まはらに ★★★
#   - 居酒屋, 定食 (スコア: 0.180)
#   - とる, くれる (スコア: 0.160)
#   - 予約, とる (スコア: 0.156)
#   - 国際, 展示 (スコア: 0.151)
#   - 展示, 場 (スコア: 0.150)
#   - インド, 屋 (スコア: 0.143)
#   - 定食, 屋 (スコア: 0.124)
# ------------------------------
# ★★★ むら田 ★★★
#   - ワシントン, ホテル (スコア: 0.349)
#   - 有明, ワシントン (スコア: 0.231)
#   - チキン, 南蛮 (スコア: 0.220)
#   - ビッグ, サイト (スコア: 0.192)
#   - むら, 田 (スコア: 0.188)
#   - 展示, 会 (スコア: 0.176)
#   - 展示, 場 (スコア: 0.132)
# ------------------------------
# ★★★ やまちゃん お台場店 ★★★
#   - たこ焼き, ミュージアム (スコア: 0.650)
#   - 台場, たこ焼き (スコア: 0.302)
#   - たこ焼き, 屋 (スコア: 0.209)
#   - やむ, ちゃん (スコア: 0.192)
#   - 明石, 焼き (スコア: 0.139)
#   - デックス, 東京 (スコア: 0.115)
#   - 東京, ビーチ (スコア: 0.111)
# ------------------------------
# ★★★ アイランド・ヴィンテージ・コーヒー 台場店 ★★★
#   - コーヒー (スコア: 0.248)
#   - アサイーボウル, 食べる (スコア: 0.206)
#   - コナ, コーヒー (スコア: 0.145)
#   - アサイー, 食べる (スコア: 0.138)
#   - ハーフ, サイズ (スコア: 0.118)
#   - デックス, 東京 (スコア: 0.111)
#   - テラス, 席 (スコア: 0.108)
# ------------------------------
# ★★★ アニミル お台場店 ★★★
#   - がる, てる (スコア: 0.269)
#   - そう, 家族 (スコア: 0.269)
#   - てる, 連れる (スコア: 0.256)
#   - する, ふる (スコア: 0.256)
#   - decks, 東京 (スコア: 0.247)
#   - 内, できる (スコア: 0.247)
#   - 大阪, 人気 (スコア: 0.247)
# ------------------------------
# ★★★ アマラ ダイバーシティ東京店 ★★★
#   - ダイバー, シティ (スコア: 0.331)
#   - フード, コート (スコア: 0.287)
#   - シティ, フード (スコア: 0.211)
#   - スペシャル, セット (スコア: 0.181)
#   - 内, インド (スコア: 0.140)
#   - カレー, 屋 (スコア: 0.140)
#   - インド, ネパール (スコア: 0.136)
# ------------------------------
# ★★★ アルポルト 東京ビッグサイト店 ★★★
#   - ビッグ, サイト (スコア: 0.482)
#   - 8, 階 (スコア: 0.265)
#   - 東京, ビッグ (スコア: 0.238)
#   - 会議, 棟 (スコア: 0.229)
#   - パスタ, ランチ (スコア: 0.218)
#   - 展示, 会 (スコア: 0.186)
#   - サイト, 会議 (スコア: 0.117)
# ------------------------------
# ★★★ ア・タ・ゴール ★★★
#   - 木場, 公園 (スコア: 0.433)
#   - 木場, 駅 (スコア: 0.325)
#   - フレンチ, レストラン (スコア: 0.225)
#   - ゴール (スコア: 0.188)
#   - オーナー, シェフ (スコア: 0.170)
#   - 誕生, 日 (スコア: 0.129)
#   - 気, なる (スコア: 0.109)
# ------------------------------
# ★★★ イオンスタイル 有明ガーデン ★★★
#   - t,  (スコア: 0.166)
#   - , t (スコア: 0.164)
#   - ある, おく (スコア: 0.117)
#   - 中華, 惣菜 (スコア: 0.117)
#   - レジ, 袋 (スコア: 0.117)
#   - あり, ない (スコア: 0.117)
#   - 餃子, 微妙 (スコア: 0.117)
# ------------------------------
# ★★★ イタリアン酒場 パステーカ ★★★
#   - ビッグ, サイト (スコア: 0.183)
#   - トマト, ソース (スコア: 0.148)
#   - 展示, 会 (スコア: 0.134)
#   - ソース, パスタ (スコア: 0.121)
#   - , о (スコア: 0.119)
#   - о,  (スコア: 0.117)
#   - サイト, イベント (スコア: 0.116)
# ------------------------------
# ★★★ イマーシブ・フォート東京 ★★★
#   - ディ (スコア: 0.303)
#   - 粉, チーズ (スコア: 0.159)
#   - ペローニ (スコア: 0.159)
#   - 可能,  (スコア: 0.131)
#   - 具合,  (スコア: 0.123)
#   - 事, できる (スコア: 0.090)
#   - 肉, 美味しい (スコア: 0.087)
# ------------------------------
# ★★★ インコントロ オステリア&グリル ★★★
#   - ニッコー, 東京 (スコア: 0.193)
#   - グランド, ニッコー (スコア: 0.190)
#   - , グリル (スコア: 0.183)
#   - 記念, 日 (スコア: 0.160)
#   - 誕生, 日 (スコア: 0.128)
#   - 台場, 駅 (スコア: 0.112)
#   - メイン, 肉 (スコア: 0.110)
# ------------------------------
# ★★★ インドレストラン＆バー ムナル ★★★
#   - チーズ, ナン (スコア: 0.359)
#   - カレー, 屋 (スコア: 0.238)
#   - インド, カレー (スコア: 0.220)
#   - インド, ネパール (スコア: 0.176)
#   - インド, 人 (スコア: 0.160)
#   - 西葛西, インド (スコア: 0.148)
#   - 西葛西, 駅 (スコア: 0.140)
# ------------------------------
# ★★★ インド料理ムンバイ アクアシティお台場店 ★★★
#   - カレー, ナン (スコア: 0.227)
#   - アクアシティ, 台場 (スコア: 0.177)
#   - ナン, セット (スコア: 0.147)
#   - レインボー, ブリッジ (スコア: 0.127)
#   - インド, 人 (スコア: 0.124)
#   - インド, カレー (スコア: 0.114)
#   - 感, インド (スコア: 0.110)
# ------------------------------
# ★★★ ウイスキーボイス 台場 ★★★
#   - カツ, カレー (スコア: 0.223)
#   - 間接, 照明 (スコア: 0.165)
#   - ビル, 地下 (スコア: 0.159)
#   - , 1300 (スコア: 0.133)
#   - 1300, 円 (スコア: 0.125)
#   - 漬け, 物 (スコア: 0.110)
#   - ダイニング, バー (スコア: 0.106)
# ------------------------------
# ★★★ ウェンディーズ・ファーストキッチン アクアシティお台場店 ★★★
#   - アクアシティ, 台場 (スコア: 0.236)
#   - 台場, フード (スコア: 0.202)
#   - フード, コート (スコア: 0.173)
#   - セルフ, レジ (スコア: 0.149)
#   - 番号, 呼ぶ (スコア: 0.143)
#   - 呼ぶ, れる (スコア: 0.105)
#   - 台場, アクアシティ (スコア: 0.101)
# ------------------------------
# ★★★ ウマミバーガー 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.655)
#   - ポテト, セット (スコア: 0.124)
#   - ガーデン, 店 (スコア: 0.106)
#   - ガーデン, 5 (スコア: 0.090)
#   - ハンバーガー, 食べる (スコア: 0.085)
#   - ポテト, ドリンク (スコア: 0.081)
#   - ハンバーガー, 屋 (スコア: 0.079)
# ------------------------------
# ★★★ エクセルシオール カフェ ダイバーシティ東京プラザ店 ★★★
#   - ダイバー, シティ (スコア: 0.358)
#   - 東京, プラザ (スコア: 0.321)
#   - シティ, 東京 (スコア: 0.306)
#   - プラザ, 店 (スコア: 0.183)
#   - ５, 階 (スコア: 0.106)
#   - テレポート, 駅 (スコア: 0.091)
#   - 笑, ダイバー (スコア: 0.090)
# ------------------------------
# ★★★ エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店 ★★★
#   - 感, チーズ (スコア: 0.181)
#   - , ほうじ茶 (スコア: 0.181)
#   - 不思議, 思う (スコア: 0.181)
#   - センター, カフェ (スコア: 0.181)
#   - 休日, 子供 (スコア: 0.181)
#   - 探す, 見当たる (スコア: 0.181)
#   - フロア, マップ (スコア: 0.181)
# ------------------------------
# ★★★ エグゼクティブラウンジ ★★★
#   - カクテル, タイム (スコア: 0.328)
#   - 東京, 台場 (スコア: 0.264)
#   - ヒルトン, 東京 (スコア: 0.247)
#   - 台場, エグゼクティブラウンジ (スコア: 0.246)
#   - ヒルトン, 台場 (スコア: 0.188)
#   - 2020,  (スコア: 0.145)
#   - ティー, タイム (スコア: 0.135)
# ------------------------------
# ★★★ エスプレッソ アメリカーノ テレコムセンター店 ★★★
#   - テレコム, センター (スコア: 0.672)
#   - センター, 1 (スコア: 0.175)
#   - センター, 駅 (スコア: 0.136)
#   - オープン, カフェ (スコア: 0.125)
#   - オープン, スペース (スコア: 0.108)
#   - する, テレコム (スコア: 0.083)
#   - 一, 階 (スコア: 0.081)
# ------------------------------
# ★★★ エッグスンシングス お台場店 ★★★
#   - パンケーキ, 食べる (スコア: 0.288)
#   - テラス, 席 (スコア: 0.204)
#   - パンケーキ, 美味しい (スコア: 0.146)
#   - n, things (スコア: 0.135)
#   - パンケーキ, 有名 (スコア: 0.129)
#   - パンケーキ,  (スコア: 0.114)
#   - , n (スコア: 0.105)
# ------------------------------
# ★★★ エフアイランド ★★★
#   - , パパ (スコア: 0.224)
#   - by, bankara (スコア: 0.214)
#   - 再訪, 日 (スコア: 0.214)
#   - named, by (スコア: 0.214)
#   - ー, ２ (スコア: 0.214)
#   - bankara,  (スコア: 0.214)
#   - どこ, 足跡 (スコア: 0.206)
# ------------------------------
# ★★★ エフカイビーチ ★★★
#   - 海浜, 公園 (スコア: 0.428)
#   - 台場, 海浜 (スコア: 0.378)
#   - 缶, ビール (スコア: 0.107)
#   - 犬, 連れる (スコア: 0.102)
#   - 台場, 賑わう (スコア: 0.080)
#   - 海沿い, 歩く (スコア: 0.080)
#   - 公園, 来る (スコア: 0.077)
# ------------------------------
# ★★★ オイスターハウス お台場店 ★★★
#   - 牡蠣, 食べる (スコア: 0.270)
#   - パン, 食べる (スコア: 0.218)
#   - 食べる, 放題 (スコア: 0.179)
#   - レインボー, ブリッジ (スコア: 0.144)
#   - テラス, 席 (スコア: 0.142)
#   - 円, 牡蠣 (スコア: 0.124)
#   - , 牡蠣 (スコア: 0.120)
# ------------------------------
# ★★★ オリジナルパンケーキハウス 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.483)
#   - パンケーキ, 食べる (スコア: 0.193)
#   - ある, パンケーキ (スコア: 0.158)
#   - パンケーキ, 屋 (スコア: 0.158)
#   - パンケーキ, 店 (スコア: 0.123)
#   - パンケーキ,  (スコア: 0.116)
#   - 美味しい, パンケーキ (スコア: 0.098)
# ------------------------------
# ★★★ オーケー お台場店 ★★★
#   - カナダ, 産 (スコア: 0.158)
#   - 限定, 言葉 (スコア: 0.158)
#   - 大好き, 定番 (スコア: 0.158)
#   - 周辺, 勤務 (スコア: 0.158)
#   - ９, 円 (スコア: 0.158)
#   - 過ぎ, 東京 (スコア: 0.158)
#   - 産, 三 (スコア: 0.158)
# ------------------------------
# ★★★ オーケー 東雲店 ★★★
#   - 17, オープン (スコア: 0.243)
#   - いう, ピザ (スコア: 0.243)
#   - リーズナブル, 定番 (スコア: 0.243)
#   - おいしい, リーズナブル (スコア: 0.243)
#   - 前, 買う (スコア: 0.243)
#   - カツ, 重 (スコア: 0.231)
#   - 購入, 食べる (スコア: 0.231)
# ------------------------------
# ★★★ オーシャンクラブビュッフェ デックス東京ビーチ店 ★★★
#   - デックス, 東京 (スコア: 0.296)
#   - 東京, ビーチ (スコア: 0.180)
#   - 台場, デックス (スコア: 0.126)
#   - ドリンク, バー (スコア: 0.110)
#   - テラス, 席 (スコア: 0.103)
#   - 和洋, 中 (スコア: 0.099)
#   - サラダ, コーナー (スコア: 0.095)
# ------------------------------
# ★★★ オーシャン東九フェリー ★★★
#   - 販売, 機 (スコア: 0.279)
#   - 居酒屋, 食べる (スコア: 0.161)
#   - れる, 食品 (スコア: 0.161)
#   - 円, 缶 (スコア: 0.161)
#   - フェリー, 乗り場 (スコア: 0.161)
#   - いる, 品 (スコア: 0.161)
#   - 現金, 以外 (スコア: 0.161)
# ------------------------------
# ★★★ オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明) ★★★
#   - 海鮮, 丼 (スコア: 0.232)
#   - 勝手, 丼 (スコア: 0.177)
#   - 就学, 児 (スコア: 0.153)
#   - 児, 無料 (スコア: 0.148)
#   - 3500, 円 (スコア: 0.133)
#   - ランチ, ビュッフェ (スコア: 0.130)
#   - 有明, ガーデン (スコア: 0.129)
# ------------------------------
# ★★★ カザーナ お台場店 ★★★
#   - 食べる, 放題 (スコア: 0.300)
#   - ランチ, バイキング (スコア: 0.271)
#   - インド, カレー (スコア: 0.257)
#   - カレー, 4 (スコア: 0.231)
#   - 4, 種類 (スコア: 0.174)
#   - デックス, 東京 (スコア: 0.142)
#   - 種類, カレー (スコア: 0.132)
# ------------------------------
# ★★★ カツオたまご食堂 ★★★
#   - テレコム, センター (スコア: 0.348)
#   - たま, 定食 (スコア: 0.297)
#   - センター, 駅 (スコア: 0.139)
#   - スタミナ, 豚 (スコア: 0.119)
#   - 券売, 機 (スコア: 0.116)
#   - 青海, フロンティア (スコア: 0.109)
#   - 社員, 食堂 (スコア: 0.100)
# ------------------------------
# ★★★ カフェ ラ・ボエム お台場 ★★★
#   - ボエム (スコア: 0.314)
#   - レインボー, ブリッジ (スコア: 0.222)
#   - 窓際, 席 (スコア: 0.194)
#   - グローバル, ダイニング (スコア: 0.139)
#   - 蒸す, 鶏 (スコア: 0.131)
#   - 予約, する (スコア: 0.125)
#   - 窓側, 席 (スコア: 0.120)
# ------------------------------
# ★★★ カフェ&ミール ムジ 東京有明 ★★★
#   - 無印, 良品 (スコア: 0.614)
#   - 有明, ガーデン (スコア: 0.181)
#   - アイス, コーヒー (スコア: 0.111)
#   - 東京, 有明 (スコア: 0.106)
#   - ミール, ムジ (スコア: 0.102)
#   - 関東, 最大 (スコア: 0.093)
#   - カフェ,  (スコア: 0.093)
# ------------------------------
# ★★★ カフェテラス　ロイヤル ★★★
#   - ビッグ, サイト (スコア: 0.347)
#   - 西, 展示 (スコア: 0.275)
#   - サイト, 西 (スコア: 0.275)
#   - 東京, ビッグ (スコア: 0.236)
#   - 展示, 場 (スコア: 0.187)
#   - 展示, 会 (スコア: 0.182)
#   - 会場, 内 (スコア: 0.086)
# ------------------------------
# ★★★ カフェ＆レストラン レインボー ★★★
#   - がん, 研 (スコア: 0.355)
#   - 病院, 内 (スコア: 0.311)
#   - 有明, 病院 (スコア: 0.299)
#   - レストラン, レインボー (スコア: 0.192)
#   - 研, 有明 (スコア: 0.186)
#   - 有明, がん (スコア: 0.186)
#   - 癌, 研 (スコア: 0.177)
# ------------------------------
# ★★★ カフェ･ベローチェ  有明店 ★★★
#   - 国際, 展示 (スコア: 0.338)
#   - 展示, 場 (スコア: 0.327)
#   - ビッグ, サイト (スコア: 0.231)
#   - 場, 駅 (スコア: 0.212)
#   - 有明, フロンティア (スコア: 0.180)
#   - フロンティア, ビル (スコア: 0.179)
#   - コーヒー, ゼリー (スコア: 0.160)
# ------------------------------
# ★★★ カレス ★★★
#   - トマト, ソース (スコア: 0.363)
#   - テラス, 席 (スコア: 0.223)
#   - ランチ, 今日 (スコア: 0.211)
#   - 1000, 円 (スコア: 0.205)
#   - 海浜, 公園 (スコア: 0.202)
#   - 台場, 海浜 (スコア: 0.200)
#   - コーヒー, 付き (スコア: 0.157)
# ------------------------------
# ★★★ カレーショップ C&Cダイニング 東京ビッグサイト店 ★★★
#   - c,  (スコア: 0.350)
#   - , c (スコア: 0.324)
#   - ビッグ, サイト (スコア: 0.296)
#   - 東京, ビッグ (スコア: 0.239)
#   - カツ, カレー (スコア: 0.235)
#   - ショップ, c (スコア: 0.192)
#   - カレー, ショップ (スコア: 0.184)
# ------------------------------
# ★★★ カレー香房 ★★★
#   - フード, コート (スコア: 0.273)
#   - 香, 房 (スコア: 0.243)
#   - ビッグ, サイト (スコア: 0.221)
#   - カレー, 香 (スコア: 0.174)
#   - 東京, ビッグ (スコア: 0.162)
#   - 西, ホール (スコア: 0.158)
#   - 展示, 会 (スコア: 0.135)
# ------------------------------
# ★★★ カンテボーレ イオンスタイル有明ガーデン ★★★
#   - パン, 屋 (スコア: 0.434)
#   - 塩, パン (スコア: 0.374)
#   - 頂く, 物 (スコア: 0.288)
#   - イオン, スタイル (スコア: 0.157)
#   - リベイク, する (スコア: 0.150)
#   - チーズ,  (スコア: 0.144)
#   - メロン, パン (スコア: 0.127)
# ------------------------------
# ★★★ カーサ・ディ・ペロー二 ★★★
#   - ディ (スコア: 0.271)
#   - フォート, 東京 (スコア: 0.226)
#   - フォート (スコア: 0.218)
#   - イマーシブ (スコア: 0.211)
#   - イマーシブフォート, 東京 (スコア: 0.205)
#   - 具合,  (スコア: 0.148)
#   - カーサ (スコア: 0.142)
# ------------------------------
# ★★★ カールスジュニア ダイバーシティ東京 プラザレストラン ★★★
#   - フード, コート (スコア: 0.389)
#   - ダイバー, シティ (スコア: 0.288)
#   - ハンバーガー, 屋 (スコア: 0.233)
#   - ドリンク, バー (スコア: 0.160)
#   - コート, 内 (スコア: 0.124)
#   - バーガー, キング (スコア: 0.123)
#   - ハンバーガー, チェーン (スコア: 0.120)
# ------------------------------
# ★★★ ガルーバ ★★★
#   - レインボー, ブリッジ (スコア: 0.249)
#   - 焼肉, 屋 (スコア: 0.220)
#   - 台場, 焼肉 (スコア: 0.137)
#   - アクアシティ, 台場 (スコア: 0.126)
#   - 窓際, 席 (スコア: 0.105)
#   - カルビ, ランチ (スコア: 0.104)
#   - 黒毛, 和牛 (スコア: 0.104)
# ------------------------------
# ★★★ ガーデン ダイニング ★★★
#   - グランド, ニッコー (スコア: 0.411)
#   - ニッコー, 東京 (スコア: 0.290)
#   - ロースト, ビーフ (スコア: 0.216)
#   - ランチ, ビュッフェ (スコア: 0.176)
#   - 東京, 台場 (スコア: 0.168)
#   - ニッコー, 台場 (スコア: 0.134)
#   - フェア, やる (スコア: 0.112)
# ------------------------------
# ★★★ キッチン有明 ★★★
#   - 週, 替る (スコア: 0.447)
#   - 替る, ラーメン (スコア: 0.445)
#   - チン, 有明 (スコア: 0.224)
#   - 有明, 食堂 (スコア: 0.172)
#   - 味噌, ラーメン (スコア: 0.167)
#   - 食堂, 週 (スコア: 0.141)
#   - 職場, 近く (スコア: 0.109)
# ------------------------------
# ★★★ キッチン青海珈琲 ★★★
#   - 11,  (スコア: 0.266)
#   - ハンバーグ, 定食 (スコア: 0.259)
#   - 000, 円 (スコア: 0.235)
#   - , 000 (スコア: 0.222)
#   - トマト, 酸味 (スコア: 0.214)
#   - 1,  (スコア: 0.171)
#   - 円, 11 (スコア: 0.160)
# ------------------------------
# ★★★ キムカツ亭 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.491)
#   - フード, コート (スコア: 0.366)
#   - ガーデン, 店 (スコア: 0.175)
#   - ガーデン, フード (スコア: 0.162)
#   - カツ, 膳 (スコア: 0.161)
#   - カツ, 丼 (スコア: 0.159)
#   - コート, 内 (スコア: 0.108)
# ------------------------------
# ★★★ キラキラドンキ ダイバーシティ東京 プラザ店 ★★★
#   - てる, 購入 (スコア: 0.309)
#   - 会, 中核 (スコア: 0.309)
#   - 中核, 不動産 (スコア: 0.309)
#   - 購入, 味 (スコア: 0.309)
#   - 会社, ショッピング (スコア: 0.309)
#   - たち, 人気 (スコア: 0.295)
#   - 不動産, 会社 (スコア: 0.255)
# ------------------------------
# ★★★ キリンシティプラス 有明ガーデン店 ★★★
#   - キリン, シティ (スコア: 0.550)
#   - 有明, ガーデン (スコア: 0.178)
#   - 一番, 搾る (スコア: 0.148)
#   - ビール, 美味しい (スコア: 0.134)
#   - ガーデン, シアター (スコア: 0.121)
#   - ビール, 飲む (スコア: 0.119)
#   - 注ぐ, 方 (スコア: 0.110)
# ------------------------------
# ★★★ クアアイナ アクアシティお台場店 ★★★
#   - 台場, 店 (スコア: 0.209)
#   - ハンバーガー, 食べる (スコア: 0.185)
#   - ハンバーガー, 屋 (スコア: 0.179)
#   - アクアシティ, 台場 (スコア: 0.177)
#   - レインボー, ブリッジ (スコア: 0.158)
#   - 自由, 女神 (スコア: 0.154)
#   - 厚, 切り (スコア: 0.137)
# ------------------------------
# ★★★ クルックス カフェオ ヨーロピアンリゾートカフェ ★★★
#   - テレポート, 駅 (スコア: 0.147)
#   - オフィス, ビル (スコア: 0.146)
#   - フロンティア, ビル (スコア: 0.145)
#   - 台場, フロンティア (スコア: 0.138)
#   - 東京, テレポート (スコア: 0.120)
#   - 台場, 海浜 (スコア: 0.119)
#   - 海浜, 公園 (スコア: 0.116)
# ------------------------------
# ★★★ クレープおじさん お台場店 ★★★
#   - , ジョイポリス (スコア: 0.254)
#   - クレープ, 屋 (スコア: 0.236)
#   - ジョイポリス, 中 (スコア: 0.191)
#   - 誕生, 日月 (スコア: 0.182)
#   - 日,  (スコア: 0.171)
#   - , n (スコア: 0.169)
#   - , 日 (スコア: 0.138)
# ------------------------------
# ★★★ グランディール 有明ガーデン店 ★★★
#   - パン, 屋 (スコア: 0.639)
#   - 有明, ガーデン (スコア: 0.270)
#   - ガーデン, 2 (スコア: 0.144)
#   - もち, もち (スコア: 0.140)
#   - する, パン (スコア: 0.128)
#   - パン, ある (スコア: 0.096)
#   - , 230 (スコア: 0.090)
# ------------------------------
# ★★★ グランドニッコー東京 台場 ★★★
#   - グランド, ニッコー (スコア: 0.450)
#   - ニッコー, 東京 (スコア: 0.334)
#   - 東京, 台場 (スコア: 0.225)
#   - アフタヌーン, ティー (スコア: 0.131)
#   - 会社, 行事 (スコア: 0.111)
#   - ルーム, サービス (スコア: 0.101)
#   - ニッコー, 台場 (スコア: 0.092)
# ------------------------------
# ★★★ グランドニッコー東京 台場 エグゼクティブラウンジ ★★★
#   - メロン, パフェ (スコア: 0.153)
#   - 宿泊, する (スコア: 0.135)
#   - 中, 食事 (スコア: 0.134)
#   - ニッコー, 東京 (スコア: 0.130)
# ...
# ★★★ 相鉄グランドフレッサ 東京ベイ有明 ★★★
#   - 朝食, 付き (スコア: 0.185)
#   - 朝食, バイキング (スコア: 0.178)
#   - 階, ビュッフェ (スコア: 0.137)
#   - ホテル, 2 (スコア: 0.114)
#   - 予約, 制 (スコア: 0.111)
#   - 期間, 中 (スコア: 0.094)
#   - , 3 (スコア: 0.085)
# ------------------------------
# ★★★ 眺遊楼 ★★★
#   - ベイ, コート (スコア: 0.715)
#   - 東京, ベイ (スコア: 0.276)
#   - コート, 倶楽部 (スコア: 0.263)
#   - フカ, ヒレ (スコア: 0.200)
#   - 会員, 制 (スコア: 0.153)
#   - コート, クラブ (スコア: 0.117)
#   - 北京, ダック (スコア: 0.103)
# ------------------------------
# ★★★ 石臼挽きそば 石楽 ★★★
#   - 蕎麦, 屋 (スコア: 0.343)
#   - 石臼, 挽く (スコア: 0.216)
#   - 豊洲, フロント (スコア: 0.192)
#   - 豊洲, 駅 (スコア: 0.169)
#   - せい, ろ (スコア: 0.163)
#   - 蕎麦, 食べる (スコア: 0.138)
#   - 蕎麦, セット (スコア: 0.121)
# ------------------------------
# ★★★ 磯寿司 ★★★
#   - 豊洲, 市場 (スコア: 0.555)
#   - 磯, 寿司 (スコア: 0.462)
#   - 寿司, 屋 (スコア: 0.154)
#   - 特, 上 (スコア: 0.140)
#   - 市場, 寿司 (スコア: 0.117)
#   - おまかせ, 15 (スコア: 0.115)
#   - 寿司, 食べる (スコア: 0.112)
# ------------------------------
# ★★★ 社食DELI ★★★
#   - ビニール, 袋 (スコア: 0.261)
#   - 食堂, なる (スコア: 0.261)
#   - 内, 弁当 (スコア: 0.261)
#   - 袋, 入れる (スコア: 0.261)
#   - 場所, 今 (スコア: 0.261)
#   - みそ, 汁 (スコア: 0.261)
#   - なる, オープン (スコア: 0.249)
# ------------------------------
# ★★★ 社食デリ ★★★
#   - せる, 弁当 (スコア: 0.219)
#   - 洋, 中 (スコア: 0.219)
#   - 人気, 飲食 (スコア: 0.219)
#   - 屋, 集合 (スコア: 0.219)
#   - 斜, 向かい (スコア: 0.219)
#   - 窓, 越し (スコア: 0.209)
#   - 弁当, 種類 (スコア: 0.209)
# ------------------------------
# ★★★ 秀徳市場マルマサ ★★★
#   - 店, やる (スコア: 0.132)
#   - 焼肉, たべる (スコア: 0.098)
#   - ない, 探す (スコア: 0.098)
#   - 高い, テーブル (スコア: 0.098)
#   - 築地, 秀徳 (スコア: 0.098)
#   - 一品, つまむ (スコア: 0.098)
#   - する, ナス (スコア: 0.098)
# ------------------------------
# ★★★ 笑笑 お台場海浜公園駅前店 ★★★
#   - 笑, 笑 (スコア: 0.477)
#   - おろす, そば (スコア: 0.424)
#   - 公園, 駅前 (スコア: 0.143)
#   - 笑, 入る (スコア: 0.095)
#   - そば,  (スコア: 0.095)
#   - 600, 円 (スコア: 0.094)
#   - 田舎, 蕎麦 (スコア: 0.088)
# ------------------------------
# ★★★ 笑笑 月島駅前店 ★★★
#   - 笑, 笑 (スコア: 0.343)
#   - ある, 月島 (スコア: 0.137)
#   - モンテローザ, 系列 (スコア: 0.137)
#   - 月島, 店 (スコア: 0.131)
#   - 行く, 月島 (スコア: 0.131)
#   - チェーン, 居酒屋 (スコア: 0.119)
#   - 分煙, する (スコア: 0.119)
# ------------------------------
# ★★★ 築地 すし Omakase ★★★
#   - 血, 抜き (スコア: 0.254)
#   - 熟成, する (スコア: 0.231)
#   - 築地, すし (スコア: 0.178)
#   - 寿司, 屋 (スコア: 0.169)
#   - 予約, する (スコア: 0.137)
#   - する, れる (スコア: 0.125)
#   - 鮨, 屋 (スコア: 0.117)
# ------------------------------
# ★★★ 築地 挙母鮨 ★★★
#   - 15, 貫 (スコア: 0.192)
#   - 築地, 場外 (スコア: 0.175)
#   - 9, 席 (スコア: 0.164)
#   - 晴海, 通り (スコア: 0.159)
#   - 寿司, 屋 (スコア: 0.155)
#   - 7, 貫 (スコア: 0.149)
#   - 上, 握り (スコア: 0.149)
# ------------------------------
# ★★★ 築地さらしなの里 ★★★
#   - 蕎麦, 屋 (スコア: 0.532)
#   - 十, 割 (スコア: 0.241)
#   - 築地, 駅 (スコア: 0.206)
#   - 三, 色 (スコア: 0.204)
#   - カレー, 南蛮 (スコア: 0.155)
#   - 新富, 町 (スコア: 0.144)
#   - 老舗, 蕎麦 (スコア: 0.121)
# ------------------------------
# ★★★ 築地玉寿司 晴海通り店 ★★★
#   - 晴海, 通り (スコア: 0.384)
#   - 寿司, 屋 (スコア: 0.272)
#   - 通り, 店 (スコア: 0.232)
#   - 寿司, 食べる (スコア: 0.148)
#   - 築地, 寿司 (スコア: 0.131)
#   - , 3 (スコア: 0.128)
#   - 通り, 沿い (スコア: 0.111)
# ------------------------------
# ★★★ 築地秀徳元祖 ★★★
#   - 赤, 酢 (スコア: 0.259)
#   - 築地, 場外 (スコア: 0.236)
#   - 号, 店 (スコア: 0.227)
#   - 寿司, 屋 (スコア: 0.220)
#   - 2, 号 (スコア: 0.152)
#   - 秀徳, 本店 (スコア: 0.149)
#   - 寿司, 食べる (スコア: 0.126)
# ------------------------------
# ★★★ 築地銀だこ ダイバーシティ東京プラザ店 ★★★
#   - 銀, だこ (スコア: 0.762)
#   - ダイバー, シティ (スコア: 0.234)
#   - 6, 個 (スコア: 0.184)
#   - フード, コート (スコア: 0.183)
#   - シティ, フード (スコア: 0.132)
#   - 個, 入り (スコア: 0.123)
#   - 8, 個 (スコア: 0.092)
# ------------------------------
# ★★★ 築地青空三代目 本店 ★★★
#   - 三, 代目 (スコア: 0.472)
#   - 青空, 三 (スコア: 0.405)
#   - 築地, 青空 (スコア: 0.354)
#   - 寿司, 屋 (スコア: 0.174)
#   - 築地, 場外 (スコア: 0.174)
#   - 予約, する (スコア: 0.128)
#   - 築地, 寿司 (スコア: 0.111)
# ------------------------------
# ★★★ 築地食堂 源ちゃん アクアシティお台場店 ★★★
#   - 源, ちゃん (スコア: 0.436)
#   - 築地, 食堂 (スコア: 0.308)
#   - 食堂, 源 (スコア: 0.256)
#   - アクアシティ, 台場 (スコア: 0.179)
#   - 海鮮, 丼 (スコア: 0.118)
#   - ちゃん, 丼 (スコア: 0.107)
#   - 刺身, 定食 (スコア: 0.089)
# ------------------------------
# ★★★ 築地食堂 源ちゃん 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.343)
#   - 源, ちゃん (スコア: 0.319)
#   - 築地, 食堂 (スコア: 0.225)
#   - 海鮮, 丼 (スコア: 0.218)
#   - ちゃん, 有明 (スコア: 0.182)
#   - 食堂, 源 (スコア: 0.173)
#   - 刺身, 定食 (スコア: 0.139)
# ------------------------------
# ★★★ 築地食堂 源ちゃん 東京ビックサイト店 ★★★
#   - 源, ちゃん (スコア: 0.370)
#   - ビッグ, サイト (スコア: 0.339)
#   - 東京, ビッグ (スコア: 0.241)
#   - 築地, 食堂 (スコア: 0.186)
#   - 展示, 会 (スコア: 0.182)
#   - 食堂, 源 (スコア: 0.172)
#   - しらす, 丼 (スコア: 0.146)
# ------------------------------
# ★★★ 築地食堂　源ちゃん TFT有明店 ★★★
#   - 源, ちゃん (スコア: 0.336)
#   - ビッグ, サイト (スコア: 0.238)
#   - 築地, 食堂 (スコア: 0.226)
#   - 海鮮, 丼 (スコア: 0.187)
#   - 食堂, 源 (スコア: 0.165)
#   - 東京, ビッグ (スコア: 0.139)
#   - アジ, フライ (スコア: 0.131)
# ------------------------------
# ★★★ 米三角 ★★★
#   - 豊洲, 千客万来 (スコア: 0.263)
#   - 千客万来, 2 (スコア: 0.203)
#   - 日本, 酒 (スコア: 0.181)
#   - 万葉, 倶楽部 (スコア: 0.152)
#   - 豊洲, 市場 (スコア: 0.146)
#   - 市場, 千客万来 (スコア: 0.140)
#   - 立ち, 飲み屋 (スコア: 0.135)
# ------------------------------
# ★★★ 翠苑 ★★★
#   - 削る, 麺 (スコア: 0.186)
#   - 刀, 削る (スコア: 0.186)
#   - ワンザ, 有明 (スコア: 0.168)
#   - tft, ビル (スコア: 0.140)
#   - 展示, 会 (スコア: 0.132)
#   - ビッグ, サイト (スコア: 0.131)
#   - 中華, 店 (スコア: 0.123)
# ------------------------------
# ★★★ 肉菜工房うしすけ 台場店 ★★★
#   - うし, すける (スコア: 0.282)
#   - 焼肉, 屋 (スコア: 0.266)
#   - わん, ちゃん (スコア: 0.217)
#   - わん, こ (スコア: 0.201)
#   - ワン, ちゃん (スコア: 0.193)
#   - 犬, 用 (スコア: 0.151)
#   - 焼肉, 食べる (スコア: 0.133)
# ------------------------------
# ★★★ 自由が丘 蔭山 有明ガーデン店 ★★★
#   - 鶏, 白湯 (スコア: 0.646)
#   - 白湯, 塩 (スコア: 0.325)
#   - 塩, そば (スコア: 0.315)
#   - フード, コート (スコア: 0.302)
#   - 有明, ガーデン (スコア: 0.281)
#   - 味, 玉 (スコア: 0.199)
#   - ガーデン, フード (スコア: 0.126)
# ------------------------------
# ★★★ 芋蛸 お台場たこやきミュージアム店 ★★★
#   - たこ焼き, ミュージアム (スコア: 0.559)
#   - 芋, 蛸 (スコア: 0.388)
#   - たこ焼き, 屋 (スコア: 0.252)
#   - 台場, たこ焼き (スコア: 0.209)
#   - たこやき, ミュージアム (スコア: 0.172)
#   - ミュージアム, 内 (スコア: 0.116)
#   - ミュージアム, 中 (スコア: 0.113)
# ------------------------------
# ★★★ 花水木 ★★★
#   - 門前仲, 町 (スコア: 0.234)
#   - すき焼き, しゃぶしゃぶ (スコア: 0.166)
#   - 深川, 不動尊 (スコア: 0.166)
#   - 不動尊, 参道 (スコア: 0.166)
#   - しゃぶしゃぶ, 屋 (スコア: 0.158)
#   - すき焼き, 食べる (スコア: 0.152)
#   - 門前仲町, 駅 (スコア: 0.125)
# ------------------------------
# ★★★ 茂助だんご 豊洲市場 ★★★
#   - 茂助, ん (スコア: 0.641)
#   - 豊洲, 市場 (スコア: 0.498)
#   - 管理, 棟 (スコア: 0.142)
#   - 施設, 棟 (スコア: 0.131)
#   - 管理, 施設 (スコア: 0.128)
#   - あん, みつ (スコア: 0.124)
#   - こす, ある (スコア: 0.113)
# ------------------------------
# ★★★ 茶寮 伊藤園 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.479)
#   - 抹茶, ほうじ茶 (スコア: 0.239)
#   - 抹茶, ソフト (スコア: 0.179)
#   - 抹茶, ラテ (スコア: 0.169)
#   - ガーデン, 内 (スコア: 0.121)
#   - ガーデン, 店 (スコア: 0.121)
#   - 白玉, あずき (スコア: 0.119)
# ------------------------------
# ★★★ 菊屋 ★★★
#   - 町中, 華 (スコア: 0.311)
#   - 東雲, 駅 (スコア: 0.200)
#   - 線, 東雲 (スコア: 0.129)
#   - もやし, そば (スコア: 0.097)
#   - 中華, 食堂 (スコア: 0.097)
#   - 東雲, 1 (スコア: 0.097)
#   - 味噌, チャーシュー (スコア: 0.097)
# ------------------------------
# ★★★ 葛西ビアバー ★★★
#   - 神, 泡 (スコア: 0.298)
#   - 泡, ビール (スコア: 0.284)
#   - 一, 週間 (スコア: 0.177)
#   - オープン, 17 (スコア: 0.149)
#   - 回, ビール (スコア: 0.149)
#   - ビール, 半額 (スコア: 0.142)
#   - 17, 時 (スコア: 0.141)
# ------------------------------
# ★★★ 葛西臨海公園バーベキュー広場 ★★★
#   - 臨海, 公園 (スコア: 0.289)
#   - 葛西, 臨海 (スコア: 0.281)
#   - 公園, 内 (スコア: 0.193)
#   - バーベキュー, する (スコア: 0.193)
#   - 飲む, 放題 (スコア: 0.170)
#   - , 飲む (スコア: 0.137)
#   - 公園, バーベキュー (スコア: 0.108)
# ------------------------------
# ★★★ 蔵乃ゑ ★★★
#   - ここ, 勧め (スコア: 0.263)
#   - くれる, 置く (スコア: 0.263)
#   - 一切, ある (スコア: 0.263)
#   - ドリンク, 類 (スコア: 0.263)
#   - 内, ドリンク (スコア: 0.263)
#   - られる, 飲める (スコア: 0.263)
#   - ココ, 食べる (スコア: 0.263)
# ------------------------------
# ★★★ 親子丼 トリカイ エクスプレス ダイバーシティ東京店 ★★★
#   - 親子, 丼 (スコア: 0.678)
#   - ダイバー, シティ (スコア: 0.275)
#   - フード, コート (スコア: 0.255)
#   - 唐, 揚げ (スコア: 0.115)
#   - チキン, 南蛮 (スコア: 0.090)
#   - 丼, 店 (スコア: 0.076)
#   - 東京, 店 (スコア: 0.072)
# ------------------------------
# ★★★ 豊洲市場 共同食堂 ★★★
#   - 棟, 5 (スコア: 0.234)
#   - 豊洲, 市場 (スコア: 0.141)
#   - 5, 階 (スコア: 0.128)
#   - 立ち寄る, 豊洲 (スコア: 0.123)
#   - なる, 水産 (スコア: 0.123)
#   - 定食, 1150 (スコア: 0.123)
#   - 望む, ロケーション (スコア: 0.123)
# ------------------------------
# ★★★ 豊海ワイン食堂 ★★★
#   - 作る, れる (スコア: 0.162)
#   - チーズ, ハム (スコア: 0.148)
#   - いただく, 水 (スコア: 0.148)
#   - 階, 今日 (スコア: 0.148)
#   - 替り, メニュー (スコア: 0.148)
#   - 人, 大切 (スコア: 0.148)
#   - たっぷり, ソース (スコア: 0.148)
# ------------------------------
# ★★★ 越後屋 竹千代 ★★★
#   - ビッグ, サイト (スコア: 0.318)
#   - 有明, セントラルタワー (スコア: 0.246)
#   - 展示, 会 (スコア: 0.214)
#   - セントラルタワー, 2 (スコア: 0.208)
#   - 東京, ビッグ (スコア: 0.194)
#   - 竹, 千 (スコア: 0.187)
#   - 千, 代 (スコア: 0.176)
# ------------------------------
# ★★★ 道頓堀 赤鬼 ★★★
#   - たこ焼き, ミュージアム (スコア: 0.448)
#   - 台場, たこ焼き (スコア: 0.241)
#   - 赤, 鬼 (スコア: 0.183)
#   - 明石, 焼き (スコア: 0.163)
#   - ミュージアム, 内 (スコア: 0.158)
#   - たこ焼き, 屋 (スコア: 0.123)
#   - ふう, トロ (スコア: 0.105)
# ------------------------------
# ★★★ 都会の農園バーベキュー広場 ★★★
#   - バーベキュー, 広場 (スコア: 0.286)
#   - ダイバー, シティ (スコア: 0.262)
#   - シティ, 屋上 (スコア: 0.227)
#   - 風, 強い (スコア: 0.214)
#   - 飲む, 放題 (スコア: 0.205)
#   - 屋上, bbq (スコア: 0.182)
#   - 東京, プラザ (スコア: 0.142)
# ------------------------------
# ★★★ 都立潮風公園バーベキュー広場 ★★★
#   - 潮風, 公園 (スコア: 0.643)
#   - バーベキュー, 広場 (スコア: 0.321)
#   - 公園, バーベキュー (スコア: 0.321)
#   - れる, スタート (スコア: 0.161)
#   - 竹, 芝 (スコア: 0.161)
#   - 気分, 予約 (スコア: 0.161)
#   - エリア, の (スコア: 0.153)
# ------------------------------
# ★★★ 金澤濃厚豚骨ラーメン 神仙 アクアシティ店 ★★★
#   - 豚, 骨 (スコア: 0.566)
#   - 濃厚, 豚 (スコア: 0.414)
#   - 国技, 館 (スコア: 0.259)
#   - ラーメン, 国技 (スコア: 0.259)
#   - 骨, 醤油 (スコア: 0.256)
#   - 骨, ラーメン (スコア: 0.218)
#   - 特製, 濃厚 (スコア: 0.129)
# ------------------------------
# ★★★ 鉄板焼 銀杏 ★★★
#   - 鉄板, 焼き (スコア: 0.571)
#   - 30, 階 (スコア: 0.258)
#   - グランド, ニッコー (スコア: 0.161)
#   - レインボー, ブリッジ (スコア: 0.128)
#   - 階, 鉄板 (スコア: 0.126)
#   - 誕生, 日 (スコア: 0.113)
#   - ニッコー, 東京 (スコア: 0.109)
# ------------------------------
# ★★★ 銀座 深川玄庵 ★★★
#   - 門前仲, 町 (スコア: 0.230)
#   - 蕎麦, 前 (スコア: 0.156)
#   - 移転, する (スコア: 0.153)
#   - 門, 仲 (スコア: 0.112)
#   - 2, 年 (スコア: 0.090)
#   - 印象, する (スコア: 0.082)
#   - 達,  (スコア: 0.082)
# ------------------------------
# ★★★ 銀座 祭や ★★★
#   - 日本, 酒 (スコア: 0.179)
#   - あん, 肝 (スコア: 0.119)
#   - 地下, 店 (スコア: 0.111)
#   - タバコ, 吸える (スコア: 0.108)
#   - 皆さん, 元気 (スコア: 0.100)
#   - 焼酎, 種類 (スコア: 0.096)
#   - 焼酎, 日本 (スコア: 0.096)
# ------------------------------
# ★★★ 長寿韓酒房 ダイバーシティ東京プラザ店 ★★★
#   - 冷, 麺 (スコア: 0.461)
#   - みぞ, 冷 (スコア: 0.431)
#   - 長寿, 韓 (スコア: 0.339)
#   - 酒, 房 (スコア: 0.300)
#   - 韓, 酒 (スコア: 0.281)
#   - ダイバー, シティ (スコア: 0.168)
#   - スープ, 冷 (スコア: 0.155)
# ------------------------------
# ★★★ 長寿韓酒房 有明店 ★★★
#   - 韓, 酒 (スコア: 0.311)
#   - 酒, 房 (スコア: 0.311)
#   - 長寿, 韓 (スコア: 0.272)
#   - ビッグ, サイト (スコア: 0.220)
#   - 韓国, 食べる (スコア: 0.138)
#   - 石, 焼 (スコア: 0.131)
#   - 国際, 展示 (スコア: 0.130)
# ------------------------------
# ★★★ 長生庵 ★★★
#   - 蕎麦, 屋 (スコア: 0.444)
#   - 築地, 場外 (スコア: 0.284)
#   - 日本, 酒 (スコア: 0.239)
#   - 朝, 定食 (スコア: 0.230)
#   - 丼, そば (スコア: 0.156)
#   - 海鮮, 丼 (スコア: 0.143)
#   - しらす, 丼 (スコア: 0.140)
# ------------------------------
# ★★★ 門仲STAND ★★★
#   - , 度 (スコア: 0.333)
#   - 自然, 派 (スコア: 0.259)
#   - 門, 仲 (スコア: 0.201)
#   - 派, ワイン (スコア: 0.199)
#   - 前菜, 盛り合わせ (スコア: 0.127)
#   - 日々, 記録 (スコア: 0.125)
#   - , 日々 (スコア: 0.125)
# ------------------------------
# ★★★ 門前仲町 らっきょう ★★★
#   - かう, ぼう (スコア: 0.211)
#   - 揚げる, やつ (スコア: 0.134)
#   - 店, 移転 (スコア: 0.129)
#   - 魚, 定食 (スコア: 0.119)
#   - やつ, 美味しい (スコア: 0.116)
#   - 酒, つまむ (スコア: 0.100)
#   - の, よい (スコア: 0.088)
# ------------------------------
# ★★★ 青海珈琲 青海本店 ★★★
#   - 青海, 珈琲 (スコア: 0.386)
#   - テレコム, センター (スコア: 0.242)
#   - 焙る, 煎る (スコア: 0.221)
#   - センター, 駅 (スコア: 0.214)
#   - 100, 円 (スコア: 0.170)
#   - 水, 出し (スコア: 0.158)
#   - 青海, フロンティア (スコア: 0.152)
# ------------------------------
# ★★★ 青海食堂 ★★★
#   - 青海, 食堂 (スコア: 0.284)
#   - テレコム, センター (スコア: 0.247)
#   - 定食, 650 (スコア: 0.141)
#   - ①, ① (スコア: 0.141)
#   - センター, 駅 (スコア: 0.131)
#   - 650, 円 (スコア: 0.124)
#   - 天ぷら, そば (スコア: 0.122)
# ------------------------------
# ★★★ 韓美膳 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.356)
#   - 石, 焼 (スコア: 0.322)
#   - 冷, 麺 (スコア: 0.309)
#   - フード, コート (スコア: 0.287)
#   - 焼, ビビンバ (スコア: 0.231)
#   - 韓国, 店 (スコア: 0.175)
#   - ガーデン, フード (スコア: 0.153)
# ------------------------------
# ★★★ 頑者NEXT LEVEL ★★★
#   - つけ, 麺 (スコア: 0.705)
#   - ラーメン, 国技 (スコア: 0.350)
#   - 国技, 館 (スコア: 0.346)
#   - 海老, つけ (スコア: 0.186)
#   - つけ, めん (スコア: 0.154)
#   - 特製, つけ (スコア: 0.123)
#   - 豚, 骨 (スコア: 0.119)
# ------------------------------
# ★★★ 飛車角 有明ガーデン店 ★★★
#   - 有明, ガーデン (スコア: 0.319)
#   - ハラ, ミ (スコア: 0.268)
#   - 焼肉, 屋 (スコア: 0.182)
#   - 牛, タン (スコア: 0.131)
#   - カルビ, ハラ (スコア: 0.103)
#   - 冷, 麺 (スコア: 0.101)
#   - ビビンバ, 冷 (スコア: 0.094)
# ------------------------------
# ★★★ 餃子の王様 龍吟 ダイバーシティ店 ★★★
#   - ダイバー, シティ (スコア: 0.311)
#   - 町中, 華 (スコア: 0.164)
#   - 餃子, 2 (スコア: 0.156)
#   - 婆, 豆腐 (スコア: 0.123)
#   - 麻, 婆 (スコア: 0.119)
#   - レ, バニラ (スコア: 0.110)
#   - 2, 個 (スコア: 0.103)
# ------------------------------
# ★★★ 餃子酒家 築地店 ★★★
#   - 餃子, 酒家 (スコア: 0.427)
#   - 新富, 町 (スコア: 0.338)
#   - 新富町, 駅 (スコア: 0.235)
#   - 中華, 屋 (スコア: 0.169)
#   - 町, 中華 (スコア: 0.163)
#   - 円, 均一 (スコア: 0.142)
#   - ラーメン, セット (スコア: 0.125)
# ------------------------------
# ★★★ 香港飲茶楼 ル・パルク ★★★
#   - ビッグ, サイト (スコア: 0.401)
#   - 東京, ビッグ (スコア: 0.268)
#   - 展示, 会 (スコア: 0.217)
#   - あん, かける (スコア: 0.164)
#   - 展示, 場 (スコア: 0.162)
#   - 東, 展示 (スコア: 0.151)
#   - 五目, あん (スコア: 0.134)
# ------------------------------
# ★★★ 魚とと 東京ビックサイトEat iT!店 ★★★
#   - ビッグ, サイト (スコア: 0.224)
#   - 東京, ビッグ (スコア: 0.219)
#   - ネギ, トロ (スコア: 0.194)
#   - サラダ, 丼 (スコア: 0.185)
#   - フード, コート (スコア: 0.184)
#   - 丼, 魚 (スコア: 0.164)
#   - 西, 棟 (スコア: 0.156)
# ------------------------------
# ★★★ 魚民 勝どき駅前店 ★★★
#   - 魚, 民 (スコア: 0.225)
#   - 長居, する (スコア: 0.184)
#   - 過ごせる, いい (スコア: 0.122)
#   - メイン, 刺身 (スコア: 0.122)
#   - 満席, 為 (スコア: 0.122)
#   - 多い, シェア (スコア: 0.122)
#   - シェア, サイズ (スコア: 0.122)
# ------------------------------
# ★★★ 魚民 潮見駅前店 ★★★
#   - 魚, 民 (スコア: 0.277)
#   - 有難い, メニュー (スコア: 0.151)
#   - 味, 際立つ (スコア: 0.151)
#   - 潮見, 店 (スコア: 0.151)
#   - 毎日, 更新 (スコア: 0.151)
#   - 生ビール, キリン (スコア: 0.151)
#   - 言う, 難い (スコア: 0.151)
# ------------------------------
# ★★★ 魚河岸トミーナ 豊洲市場店 ★★★
#   - 豊洲, 市場 (スコア: 0.586)
#   - 海鮮, ピザ (スコア: 0.201)
#   - 市場, 内 (スコア: 0.176)
#   - ピザ, 食べる (スコア: 0.152)
#   - 管理, 棟 (スコア: 0.101)
#   - 茂助, ん (スコア: 0.090)
#   - 人, 行う (スコア: 0.087)
# ------------------------------
# ★★★ 鮒忠 有明店 ★★★
#   - 鮒, 忠 (スコア: 0.436)
#   - チキン, 南蛮 (スコア: 0.286)
#   - ビッグ, サイト (スコア: 0.187)
#   - 南蛮, 定食 (スコア: 0.166)
#   - 有明, 店 (スコア: 0.119)
#   - 展示, 会 (スコア: 0.114)
#   - 国際, 展示 (スコア: 0.107)
# ------------------------------
# ★★★ 鮨 もりなり ★★★
#   - ネタ, 大きい (スコア: 0.265)
#   - 寿司, 屋 (スコア: 0.232)
#   - 鮨, 屋 (スコア: 0.202)
#   - 絵画, 飾る (スコア: 0.126)
#   - 修行, する (スコア: 0.124)
#   - 帆, 立 (スコア: 0.115)
#   - 独立, する (スコア: 0.103)
# ------------------------------
# ★★★ 鮨 玉かがり 天ぷら 玉衣 ★★★
#   - グランド, ニッコー (スコア: 0.456)
#   - 30, 階 (スコア: 0.323)
#   - ニッコー, 東京 (スコア: 0.270)
#   - 寿司, 天ぷら (スコア: 0.164)
#   - 朝, 寿司 (スコア: 0.155)
#   - ニッコー, 台場 (スコア: 0.142)
#   - 東京, 台場 (スコア: 0.137)
# ------------------------------
# ★★★ 鮨 酒 肴 杉玉 新木場 ★★★
#   - 杉, 玉 (スコア: 0.437)
#   - 新木場, 駅 (スコア: 0.362)
#   - 寿司, 居酒屋 (スコア: 0.167)
#   - 肴, 杉 (スコア: 0.087)
#   - 創作, 系 (スコア: 0.087)
#   - 寿司, セット (スコア: 0.083)
#   - 鮨, 酒 (スコア: 0.083)
# ------------------------------
# ★★★ 鮨　宇田川 ★★★
#   - ワシントン, ホテル (スコア: 0.224)
#   - パーク, ビル (スコア: 0.223)
#   - 有明, パーク (スコア: 0.219)
#   - にぎる, 1 (スコア: 0.141)
#   - ビッグ, サイト (スコア: 0.133)
#   - 5, 人前 (スコア: 0.116)
#   - 展示, 会 (スコア: 0.105)
# ------------------------------
# ★★★ 鮨･酒･肴 杉玉 葛西店 ★★★
#   - 杉, 玉 (スコア: 0.256)
#   - 葛西, 駅前 (スコア: 0.144)
#   - ポテト, サラダ (スコア: 0.111)
#   - 赤, 酢 (スコア: 0.105)
#   - 19, 時 (スコア: 0.092)
#   - ハッピー, アワー (スコア: 0.089)
#   - 肴, 杉 (スコア: 0.085)
# ------------------------------
# ★★★ 鮮魚旬菜 魚福 ★★★
#   - toc, 有明 (スコア: 0.239)
#   - ビッグ, サイト (スコア: 0.163)
#   - 国際, 展示 (スコア: 0.150)
#   - 展示, 場 (スコア: 0.150)
#   - 品, 選ぶ (スコア: 0.140)
#   - 1, 品 (スコア: 0.134)
#   - おかず, 2 (スコア: 0.120)
# ------------------------------
# ★★★ 鶏味座 ダイバーシティ東京プラザ店 ★★★
#   - 親子, 丼 (スコア: 0.860)
#   - 究極, 親子 (スコア: 0.316)
#   - ダイバー, シティ (スコア: 0.187)
#   - 鶏, 味 (スコア: 0.137)
#   - ら, ー (スコア: 0.052)
#   - ー, めん (スコア: 0.052)
#   - 丼, ラーメン (スコア: 0.046)
# ------------------------------
# ★★★ 鶏鬨はなれ 勝どき清澄通り店 ★★★
#   - 鶏, 鬨 (スコア: 0.499)
#   - ひつ, まぶしい (スコア: 0.458)
#   - 勝どき, 駅 (スコア: 0.251)
#   - 十, 割 (スコア: 0.133)
#   - 清澄, 通り (スコア: 0.106)
#   - 割, そば (スコア: 0.092)
#   - 焼き鳥, 屋 (スコア: 0.089)
# ------------------------------
# ★★★ 鶴橋風月 お台場店 ★★★
#   - モダン, 焼き (スコア: 0.331)
#   - お好み焼き, 食べる (スコア: 0.248)
#   - お好み焼き, 屋 (スコア: 0.221)
#   - 豚, 玉 (スコア: 0.214)
#   - 焼く, くれる (スコア: 0.162)
#   - 大阪, お好み焼き (スコア: 0.120)
#   - 台場, 6 (スコア: 0.119)
# ------------------------------
# ★★★ 黄金鉄鍋餃子 HUG ★★★
#   - 鍋, 餃子 (スコア: 0.250)
#   - 鉄, 鍋 (スコア: 0.211)
#   - 餃子, 6 (スコア: 0.159)
#   - 塩, 塩 (スコア: 0.153)
#   - 焼き, 餃子 (スコア: 0.148)
#   - 味噌汁, 菜 (スコア: 0.125)
#   - 6, 個 (スコア: 0.120)
# ------------------------------
# ★★★ 龍記 お台場デックス東京ビーチ店 ★★★
#   - 削る, 麺 (スコア: 0.549)
#   - 刀, 削る (スコア: 0.508)
#   - 婆, 豆腐 (スコア: 0.177)
#   - 麻, 婆 (スコア: 0.171)
#   - エビ, チリ (スコア: 0.085)
#   - 四川, 風 (スコア: 0.078)
#   - 石鍋, 麻 (スコア: 0.071)
# ------------------------------
# ★★★ ＆ Ovo ★★★
#   - 築地, 本願寺 (スコア: 0.560)
#   - 築地, 駅 (スコア: 0.265)
#   - モーニング, プレート (スコア: 0.174)
#   - 階, 2 (スコア: 0.149)
#   - 目, 前 (スコア: 0.138)
#   - テラス, 席 (スコア: 0.133)
#   - カフェ,  (スコア: 0.125)
# ------------------------------

# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# CSVファイルを読み込む
try:
    df = pd.read_csv('/Users/dangararara/lecture/miraisouzou/csv/odaiba_reviews.csv')
except FileNotFoundError:
    print("エラー: 'odaiba_reviews.csv'が見つかりません。")
    df = pd.DataFrame()

# JanomeのTokenizerを準備
t = Tokenizer()

# ストップワード
stop_words = [
    'こと', 'もの', 'それ', 'これ', 'さん', 'よう', 'ため', '的', '的', '気', '感',
    'いる', 'する', 'なる', 'ある', 'ない', 'くる', 'いく', '思う', '言う',
    '美味しい', 'うまい', '普通', '良い', '悪い', '最高', '本当', '今回', '前回', 
    '初', '再訪', '人気', '有名', '定番', '満足', '好き', 'おすすめ', 'ごちそうさま', '様',
    '料理', '食事', 'メニュー', 'ドリンク', 'デザート', '一品', 'ご飯', 'ビール',  '肉', '魚', '野菜',
    '食べる', '飲む', '行く', '来る', '入る', '出る', '頼む', '注文', 
    '訪問', '利用', '頂く', 'いただく', '会計',
    '時間', '日', '時', '分', 
    'お店', 'レストラン', 'こちら', 'ところ', '場所', '雰囲気', '店内', 
    '外観', '席', 'スタッフ', '店員', 
    '自分', '私', '人',
    '一つ', 'たくさん', '少し', 'ちょっと', 'かなり', '非常', 'いろいろ', '色々', 
    '種類', '豊富', '一番', '円', '...',
]


# <--- 変更点：Bi-gram用のTokenizer関数 ---
def tokenize_for_bigrams(text):
    """テキストを形態素解析し、Bi-gramの文字列を返す"""
    # まずは単語に分解
    tokens = []
    for token in t.tokenize(text):
        part_of_speech = token.part_of_speech.split(',')[0]
        if part_of_speech in ['名詞', '動詞', '形容詞'] and token.surface not in stop_words:
            tokens.append(token.base_form)
    
    # 単語リストからBi-gramを作成
    bigrams = [f"{tokens[i]}_{tokens[i+1]}" for i in range(len(tokens) - 1)]
    return ' '.join(bigrams)

if not df.empty:
    shop_docs = df.groupby('shop_name')['review_text'].apply(lambda x: ' '.join(x.dropna())).reset_index()
    
    print("各店舗の口コミをBi-gramに変換中...")
    # <--- 変更点：Bi-gram用の関数を適用 ---
    shop_docs['tokens'] = shop_docs['review_text'].apply(tokenize_for_bigrams)
    
    corpus = shop_docs['tokens'].tolist()
    shop_names = shop_docs['shop_name'].tolist()

    if corpus:
        print("Bi-gramのTF-IDFスコアを計算中...")
        vectorizer = TfidfVectorizer(min_df=2, max_df=0.95)
        tfidf_matrix = vectorizer.fit_transform(corpus)
        feature_names = vectorizer.get_feature_names_out()

        print("\n--- 店舗ごとの特徴語（Bi-gramスコア上位）---\n")
        
        for i, shop_name in enumerate(shop_names):
            print(f"【{shop_name}】")
            row = tfidf_matrix.toarray()[i]
            top_n_indices = row.argsort()[::-1][:7]
            
            for index in top_n_indices:
                if row[index] > 0:
                    # <--- 変更点：見やすいようにアンダースコアを置換 ---
                    display_name = feature_names[index].replace('_', ', ')
                    print(f"  - {display_name} (スコア: {row[index]:.3f})")
            print("-" * 20)
# Out:
# 各店舗の口コミをBi-gramに変換中...
# Bi-gramのTF-IDFスコアを計算中...
#
# --- 店舗ごとの特徴語（Bi-gramスコア上位）---
#
# 【1129 by Ogawa】
#   - レインボー, ブリッジ (スコア: 0.259)
#   - デックス, 東京 (スコア: 0.225)
#   - 東京, ビーチ (スコア: 0.184)
#   - ハンバーグ, ランチ (スコア: 0.179)
#   - ビーチ, 6 (スコア: 0.171)
#   - 6, 階 (スコア: 0.159)
#   - 台場, 海浜 (スコア: 0.119)
# --------------------
# 【82 築地店】
#   - 築地, 店 (スコア: 0.289)
#   - 築地, 駅 (スコア: 0.251)
#   - ８, ２ (スコア: 0.185)
#   - ２, 築地 (スコア: 0.176)
#   - 店, hub (スコア: 0.138)
#   - 東, 銀座 (スコア: 0.135)
#   - メトロ, 日比谷線 (スコア: 0.106)
# --------------------
# 【ABURI 百貫 有明ガーデン店】
#   - 回転, 寿司 (スコア: 0.623)
#   - 有明, ガーデン (スコア: 0.316)
#   - 百, 貫 (スコア: 0.226)
#   - 炙る, 寿司 (スコア: 0.159)
#   - 寿司, 屋 (スコア: 0.153)
#   - 通り, 炙る (スコア: 0.146)
#   - 塩, レモン (スコア: 0.115)
# --------------------
# 【ARIAKE ARENA CAFE】
#   - 有明, アリーナ (スコア: 0.556)
#   - アリーナ, 行く (スコア: 0.163)
#   - アリーナ, イベント (スコア: 0.131)
#   - ライブ, 有明 (スコア: 0.131)
#   - 参加, する (スコア: 0.127)
#   - ライブ, 前 (スコア: 0.089)
#   - バスケ, 試合 (スコア: 0.081)
# --------------------
# 【ARIAKE ARENA DINING MOON RIVER】
#   - 有明, アリーナ (スコア: 0.384)
#   - ハンバーガー, ワッフル (スコア: 0.103)
#   - くれる, 事 (スコア: 0.103)
#   - 店, 手洗い (スコア: 0.103)
#   - アリーナ, 来る (スコア: 0.103)
#   - そう, いい (スコア: 0.103)
#   - いい, ライブ (スコア: 0.103)
# --------------------
# 【AkeruE】
#   - よい, きのこ (スコア: 0.302)
#   - ある, マルゲリータ (スコア: 0.302)
#   - 出る, 左手 (スコア: 0.302)
#   - カフェ, 子連れ (スコア: 0.302)
#   - ポテト, 塩 (スコア: 0.288)
#   - ある, 選べる (スコア: 0.269)
#   - センター, 内 (スコア: 0.261)
# --------------------
# 【Ariake Miraie】
#   - ディーラー, 中 (スコア: 0.336)
#   - 中, カフェ (スコア: 0.262)
#   - する, 車 (スコア: 0.189)
#   - カフェ, スペース (スコア: 0.172)
#   - 気分, 美味しい (スコア: 0.112)
#   - 中, スペース (スコア: 0.112)
#   - できる, お茶 (スコア: 0.112)
# --------------------
# 【BBQ PLAY GROUND お台場デックス東京ビーチ店】
#   - bbq, 楽しめる (スコア: 0.138)
#   - 持ち込み, 可能 (スコア: 0.138)
#   - 風, 強い (スコア: 0.133)
#   - 景色, よい (スコア: 0.132)
#   - 6, 階 (スコア: 0.129)
#   - ある, ない (スコア: 0.127)
#   - 紙, 皿 (スコア: 0.127)
# --------------------
# 【BISTRO うしすけ】
#   - うし, すける (スコア: 0.447)
#   - ビス, トロ (スコア: 0.262)
#   - わん, ちゃん (スコア: 0.201)
#   - ワン, ちゃん (スコア: 0.164)
#   - トロ, うし (スコア: 0.150)
#   - 犬, 用 (スコア: 0.138)
#   - すける, さ (スコア: 0.131)
# --------------------
# 【BLUE TABLE Odaiba】
#   - 海浜, 公園 (スコア: 0.213)
#   - 台場, 海浜 (スコア: 0.156)
#   - グリーン, カレー (スコア: 0.149)
#   - 公園, 中 (スコア: 0.126)
#   - レインボー, ブリッジ (スコア: 0.119)
#   - 窓, 開ける (スコア: 0.115)
#   - ペット, 可 (スコア: 0.098)
# --------------------
# 【Bistro961】
#   - ワイン, バー (スコア: 0.167)
#   - 月島, 駅 (スコア: 0.159)
#   - ビス, トロ (スコア: 0.150)
#   - パスタ, ランチ (スコア: 0.140)
#   - 階, ワイン (スコア: 0.129)
#   - 橋, 近く (スコア: 0.129)
#   - 日本, ワイン (スコア: 0.129)
# --------------------
# 【Bomb! Dogs】
#   - ソース, ソーセージ (スコア: 0.268)
#   - 階, 隣 (スコア: 0.268)
#   - 美味しい, 大きい (スコア: 0.246)
#   - 細かい, 刻む (スコア: 0.246)
#   - 店, クレープ (スコア: 0.238)
#   - 食べる, そこ (スコア: 0.238)
#   - 刻む, れる (スコア: 0.238)
# --------------------
# 【Brew33 Bar】
#   - ツリー, by (スコア: 0.494)
#   - ダブル, ツリー (スコア: 0.494)
#   - 賑やか, さ (スコア: 0.471)
#   - カウンター, 夜景 (スコア: 0.453)
#   - 夜景, 見る (スコア: 0.291)
# --------------------
# 【CAFE TERIA BLUE】
#   - 特別, 展 (スコア: 0.352)
#   - 科学, 来館 (スコア: 0.172)
#   - 先, 腹ごしらえ (スコア: 0.117)
#   - 10, 20 (スコア: 0.117)
#   - 売り切れ, できる (スコア: 0.117)
#   - 屋外, テラス (スコア: 0.117)
#   - レモン, 汁 (スコア: 0.117)
# --------------------
# 【Cha pi】
#   - ミルク, ティー (スコア: 0.204)
#   - ミルク, フォーム (スコア: 0.172)
#   - ３, 枚 (スコア: 0.164)
#   - 抹茶, ミルク (スコア: 0.153)
#   - 甘い, さ (スコア: 0.127)
#   - デックス, 東京 (スコア: 0.094)
#   - 味, ファミレス (スコア: 0.086)
# --------------------
# 【Chez コバラヘッタ 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.480)
#   - たい, 焼き (スコア: 0.328)
#   - ランチ, プレート (スコア: 0.104)
#   - ガーデン, 内 (スコア: 0.100)
#   - ガーデン, 5 (スコア: 0.081)
#   - かもめ, 有明 (スコア: 0.079)
#   - 置く, 店 (スコア: 0.076)
# --------------------
# 【CoCo壱番屋 ワンザ有明店】
#   - coco, 壱 (スコア: 0.319)
#   - カレー, 食べる (スコア: 0.199)
#   - カレー, サラダ (スコア: 0.138)
#   - ビッグ, サイト (スコア: 0.105)
#   - チキン, クリーム (スコア: 0.087)
#   - する, 我慢 (スコア: 0.087)
#   - なる, 嬉しい (スコア: 0.087)
# --------------------
# 【Cuore】
#   - ベイ, サイド (スコア: 0.402)
#   - ホテルトラスティ, 東京 (スコア: 0.379)
#   - 東京, ベイ (スコア: 0.309)
#   - コート, 倶楽部 (スコア: 0.133)
#   - ベイ, コート (スコア: 0.133)
#   - スキ, レット (スコア: 0.084)
#   - ランチ, 1600 (スコア: 0.084)
# --------------------
# 【D-ラウンジ】
#   - 東京, ジョイポリス (スコア: 0.533)
#   - ちゃう,  (スコア: 0.157)
#   - 2, 階 (スコア: 0.135)
#   - テレポート, 駅 (スコア: 0.118)
#   - ジョイポリス, コラボ (スコア: 0.116)
#   - ポテト, チキン (スコア: 0.116)
#   - ホットドッグ, 等 (スコア: 0.116)
# --------------------
# 【DAIBA】
#   - 社員, 食堂 (スコア: 0.548)
#   - 台場, 合衆国 (スコア: 0.225)
#   - 関係, 者 (スコア: 0.183)
#   - 二, 回 (スコア: 0.161)
#   - 果物, 屋 (スコア: 0.130)
#   - 去年, 夏 (スコア: 0.130)
#   - 食堂, 開く (スコア: 0.130)
# --------------------
# 【DOG DEPT お台場東京ビーチ店】
#   - 変, ２ (スコア: 0.280)
#   - ステーキ, グリル (スコア: 0.280)
#   - ん, 達 (スコア: 0.280)
#   - 愉しい, ん (スコア: 0.268)
#   - dog, dept (スコア: 0.268)
#   - 連休, 真ん中 (スコア: 0.258)
#   - 以前, 訪れる (スコア: 0.258)
# --------------------
# 【DOLCE VITA】
#   - メロン, パン (スコア: 0.217)
#   - イタリア, 語 (スコア: 0.179)
#   - する, イマーシブフォート (スコア: 0.171)
#   - イマーシブフォート, 行く (スコア: 0.165)
#   - 月, オープン (スコア: 0.149)
#   - 可能,  (スコア: 0.148)
#   - 3, 月 (スコア: 0.140)
# --------------------
# 【Deli&Cafe Uran】
#   - 海浜, 公園 (スコア: 0.184)
#   - ４, 種 (スコア: 0.157)
#   - 台場, 海浜 (スコア: 0.141)
#   - 4, 種 (スコア: 0.121)
#   - 公園, 駅 (スコア: 0.106)
#   - 味, とろろ (スコア: 0.095)
#   - つける, 1000 (スコア: 0.095)
# --------------------
# 【Domino's Pizza  ARIAKE GARDEN】
#   - ドミノ, ピザ (スコア: 0.392)
#   - 有明, ガーデン (スコア: 0.286)
#   - セット, 900 (スコア: 0.196)
#   - シアター, 開催 (スコア: 0.196)
#   - 向かい, 有明 (スコア: 0.187)
#   - コート, 到着 (スコア: 0.187)
#   - 月, 上旬 (スコア: 0.187)
# --------------------
# 【Eat it! 東京ビッグサイト店】
#   - ビッグ, サイト (スコア: 0.393)
#   - フード, コート (スコア: 0.385)
#   - 東京, ビッグ (スコア: 0.272)
#   - つけ, 麺 (スコア: 0.241)
#   - 展示, 会 (スコア: 0.161)
#   - eat, it (スコア: 0.148)
#   - 国際, 展示 (スコア: 0.105)
# --------------------
# 【FARMS' KITCHEN MIKIKE TOKYO ODAIBA】
#   - 観光, 地 (スコア: 0.146)
#   - ディナー, おじゃま (スコア: 0.145)
#   - みたい, 安い (スコア: 0.145)
#   - 同席, する (スコア: 0.145)
#   - 方, 喜ぶ (スコア: 0.145)
#   - 素晴らしい, コース (スコア: 0.145)
#   - 関わる, 快い (スコア: 0.145)
# --------------------
# 【GODIVA アクアシティお台場店】
#   - godiva,  (スコア: 0.223)
#   - ダーク, チョコレート (スコア: 0.223)
#   - ゴディバ, ショコリキサー (スコア: 0.223)
#   - ホワイト, チョコレート (スコア: 0.205)
#   - 期間, 限定 (スコア: 0.166)
#   - godiva, ショコリキサー (スコア: 0.149)
#   - ホワイト, チョコ (スコア: 0.142)
# --------------------
# 【GODIVA ダイバーシティ東京プラザ店】
#   - ダイバー, シティ (スコア: 0.454)
#   - シティ, 東京 (スコア: 0.207)
#   - チョコ, ミント (スコア: 0.167)
#   - 東京, プラザ (スコア: 0.163)
#   - , ショコリキサー (スコア: 0.136)
#   - ダーク, チョコレート (スコア: 0.136)
#   - ゴディバ, ショコリキサー (スコア: 0.136)
# --------------------
# 【GOKUGOKU 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.256)
#   - バナナ, ミルク (スコア: 0.176)
#   - オレンジ, パイン (スコア: 0.176)
#   - 完熟, バナナ (スコア: 0.176)
#   - 程よい, 甘い (スコア: 0.161)
#   - ジュース, スタンド (スコア: 0.152)
#   - する, 程よい (スコア: 0.152)
# --------------------
# 【GREAT STEAK】
#   - 1280, 税 (スコア: 0.312)
#   - 60, g (スコア: 0.312)
#   - オーダー, ブザー (スコア: 0.312)
#   - ステーキ, 店 (スコア: 0.277)
#   - 抜,  (スコア: 0.277)
#   - コート, 見る (スコア: 0.270)
#   - , 1280 (スコア: 0.270)
# --------------------
# 【GUNDAM Café　キッチンカー】
#   - 付き, 通常 (スコア: 0.422)
#   - 通常, メニ (スコア: 0.422)
#   - メイン, 3 (スコア: 0.388)
#   - 描く, れる (スコア: 0.388)
#   - する, 追加 (スコア: 0.356)
#   - テーマ, する (スコア: 0.348)
#   - 販売, する (スコア: 0.260)
# --------------------
# 【Green×Green】
#   - サラダ, 丼 (スコア: 0.259)
#   - 台場, フード (スコア: 0.253)
#   - サラダ, ボウル (スコア: 0.247)
#   - フード, コート (スコア: 0.194)
#   - ハーブ, チキン (スコア: 0.173)
#   - 穀, 米 (スコア: 0.165)
#   - 雑穀, 米 (スコア: 0.159)
# --------------------
# 【H.B.GRILL】
#   - h,  (スコア: 0.410)
#   - , b (スコア: 0.310)
#   - , grill (スコア: 0.276)
#   - b,  (スコア: 0.262)
#   - アクアシティ, 台場 (スコア: 0.157)
#   - オニオン, フライ (スコア: 0.088)
#   - コブ, サラダ (スコア: 0.076)
# --------------------
# 【HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店】
#   - ダイバー, シティ (スコア: 0.354)
#   - ハロー, キティ (スコア: 0.310)
#   - ベビー, カステラ (スコア: 0.266)
#   - シティ, 東京 (スコア: 0.227)
#   - 東京, プラザ (スコア: 0.159)
#   - 20, 個 (スコア: 0.122)
#   - 施設, ダイバー (スコア: 0.107)
# --------------------
# 【HIRO ダイバーシティ東京店】
#   - ダイバー, シティ (スコア: 0.408)
#   - 牛, ハンバーグ (スコア: 0.288)
#   - 神戸, 牛 (スコア: 0.182)
#   - 仙台, 牛 (スコア: 0.171)
#   - ハンバーグ, ステーキ (スコア: 0.163)
#   - シティ, 東京 (スコア: 0.123)
#   - サラダ, バー (スコア: 0.117)
# --------------------
# 【HUNZA】
#   - ビリ, ヤニ (スコア: 0.611)
#   - 葛西, 駅 (スコア: 0.253)
#   - インド, カレー (スコア: 0.230)
#   - 百, 名店 (スコア: 0.153)
#   - カレー, 屋 (スコア: 0.117)
#   - ヤニ, 食べる (スコア: 0.105)
#   - チーズ, ナン (スコア: 0.105)
# --------------------
# 【Hobson’s アクアシティお台場】
#   - フード, コート (スコア: 0.299)
#   - hobson,  (スコア: 0.171)
#   - アイスクリーム, 食べる (スコア: 0.152)
#   - ブレンド, する (スコア: 0.148)
#   - hobson, s (スコア: 0.114)
#   - 家具, 見る (スコア: 0.114)
#   - , ホブソンズ (スコア: 0.114)
# --------------------
# 【KING OF THE PIRATES】
#   - レインボー, ブリッジ (スコア: 0.263)
#   - アクアシティ, 台場 (スコア: 0.171)
#   - 飲む, 放題 (スコア: 0.168)
#   - 予約, する (スコア: 0.157)
#   - オブ (スコア: 0.127)
#   - パ, エリア (スコア: 0.127)
#   - 店, 海賊 (スコア: 0.111)
# --------------------
# 【L'Agréable Esprit de GAMIN】
#   - 門前仲町, 駅 (スコア: 0.255)
#   - 毎月, 通う (スコア: 0.173)
#   - 門前仲, 町 (スコア: 0.159)
#   - 月, 替わり (スコア: 0.127)
#   - l,  (スコア: 0.113)
#   - 恵比寿, 店 (スコア: 0.104)
#   - 冷, 製 (スコア: 0.101)
# --------------------
# 【LAWSON Tokyoビッグベイ店】
#   - さ, 感じ (スコア: 0.335)
#   - 手, 取る (スコア: 0.335)
#   - ガーリック,  (スコア: 0.335)
#   - 重い, さ (スコア: 0.307)
#   - , 黒 (スコア: 0.307)
#   - 感じ, 食 (スコア: 0.307)
#   - 店, 購入 (スコア: 0.297)
# --------------------
# 【LAWSON お台場店】
#   - , 禁断 (スコア: 0.287)
#   - ー,  (スコア: 0.181)
#   - テレポート, 駅 (スコア: 0.159)
#   - , スーパードライ (スコア: 0.156)
#   - 右, エスカレーター (スコア: 0.156)
#   - 先, コンビニエンスストア (スコア: 0.156)
#   - , named (スコア: 0.156)
# --------------------
# 【LAWSON しののめ店】
#   - とちる, おとめ (スコア: 0.481)
#   - 県, 産 (スコア: 0.339)
#   - 豊洲, 向かう (スコア: 0.240)
#   - シナモン, ロール (スコア: 0.229)
#   - 用品, 店 (スコア: 0.229)
#   - 向かう, 左側 (スコア: 0.229)
#   - テン, 系 (スコア: 0.229)
# --------------------
# 【LAWSON りんかい線東雲駅店】
#   - カスタード, クリーム (スコア: 0.580)
#   - デニッシュ, 生地 (スコア: 0.326)
#   - カリ, する (スコア: 0.326)
#   - 注入, する (スコア: 0.326)
#   - 生地, 中 (スコア: 0.300)
#   - 茨城, 県 (スコア: 0.290)
#   - 食, 楽しめる (スコア: 0.269)
# --------------------
# 【LAWSON アクアシティお台場】
#   - ー,  (スコア: 0.184)
#   - アクアシティ, 台場 (スコア: 0.163)
#   - 欲しい, アクアシティ (スコア: 0.160)
#   - 階, ローソン (スコア: 0.160)
#   - 場, ヒルトン (スコア: 0.160)
#   - すぎる, w (スコア: 0.160)
#   - 今年, お盆 (スコア: 0.152)
# --------------------
# 【LAWSON フジテレビ店】
#   - 月, 台場 (スコア: 0.325)
#   - 8, 月 (スコア: 0.227)
#   - 思う, フジテレビ (スコア: 0.219)
#   - グリーンスムージー, 178 (スコア: 0.219)
#   - みたい, 一 (スコア: 0.219)
#   - 台場, 夢 (スコア: 0.209)
#   - 夢, 大陸 (スコア: 0.209)
# --------------------
# 【LAWSON ポートストア有明】
#   - 一般, 財団 (スコア: 0.271)
#   - 有明, サービス (スコア: 0.271)
#   - 法人, 東京 (スコア: 0.271)
#   - 財団, 法人 (スコア: 0.271)
#   - 各所, ある (スコア: 0.271)
#   - チン, 有明 (スコア: 0.258)
#   - 厚生, 協会 (スコア: 0.258)
# --------------------
# 【LAWSON 国際展示場駅前店】
#   - 国際, 展示 (スコア: 0.248)
#   - 展示, 場 (スコア: 0.247)
#   - コンビニエンスストア, チェーン (スコア: 0.198)
#   - 場, 駅 (スコア: 0.186)
#   - , 国際 (スコア: 0.154)
#   - 場, 駅前 (スコア: 0.154)
#   - t,  (スコア: 0.141)
# --------------------
# 【LAWSON 有明コロシアム前店】
#   - チョコ, アイス (スコア: 0.301)
#   - カカオ, 香り (スコア: 0.301)
#   - 近く, ローソン (スコア: 0.301)
#   - 場, 広い (スコア: 0.287)
#   - 台場, 途中 (スコア: 0.287)
#   - 濃い, 台場 (スコア: 0.276)
#   - バーガー, キング (スコア: 0.267)
# --------------------
# 【LAWSON 有明セントラルタワー店】
#   - 桔梗, 屋 (スコア: 0.361)
#   - 有明, セントラルタワー (スコア: 0.321)
#   - ちる, 購入 (スコア: 0.181)
#   - マヨ,  (スコア: 0.181)
#   - 在宅, 勤務 (スコア: 0.181)
#   - 木村, 屋 (スコア: 0.181)
#   - セントラルタワー, 1 (スコア: 0.181)
# --------------------
# 【LAWSON 東京テレポート駅前店】
#   - 店名, 変更 (スコア: 0.344)
#   - コンビニ, ある (スコア: 0.344)
#   - する, 新規 (スコア: 0.344)
#   - 区, 店 (スコア: 0.344)
#   - 拡大, する (スコア: 0.344)
#   - する, 店名 (スコア: 0.297)
#   - 新規, オープン (スコア: 0.268)
# --------------------
# 【LAWSON 東京ビッグサイトエントランス】
#   - ビッグ, サイト (スコア: 0.229)
#   - ギフト, ショー (スコア: 0.201)
#   - 東京, ビッグ (スコア: 0.201)
#   - の, めんどくさい (スコア: 0.196)
#   - スペース, ある (スコア: 0.151)
#   - プロント, 使う (スコア: 0.113)
#   - 厚い, する (スコア: 0.113)
# --------------------
# 【LAWSON 東雲一丁目店】
#   - おにぎり, 購入 (スコア: 0.408)
#   - ７, 年 (スコア: 0.338)
#   - 今日, 2 (スコア: 0.214)
#   - 東雲, 一 (スコア: 0.214)
#   - 階, ７ (スコア: 0.214)
#   - 朝食, 思う (スコア: 0.214)
#   - 47,  (スコア: 0.214)
# --------------------
# 【LAWSON 相鉄グランドフレッサ有明店】
#   - 迎える, 前 (スコア: 0.274)
#   - ビル, オフィス (スコア: 0.274)
#   - 階, ローソン (スコア: 0.274)
#   - グランドフレッサ, 東京 (スコア: 0.262)
#   - 相鉄, グランドフレッサ (スコア: 0.262)
#   - なる, 際 (スコア: 0.252)
#   - 内, コンビニ (スコア: 0.252)
# --------------------
# 【LAWSON Ｈ台場駅前店】
#   - 推測, できる (スコア: 0.268)
#   - ググ, 出自 (スコア: 0.268)
#   - なる, ググ (スコア: 0.268)
#   - スイーツ, お気に入り (スコア: 0.268)
#   - 頭文字, h (スコア: 0.268)
#   - グリーンスムージー, 178 (スコア: 0.268)
#   - h, なる (スコア: 0.268)
# --------------------
# 【Louis Hamburger Restaurant】
#   - 東陽, 町 (スコア: 0.553)
#   - ハンバーガー, 屋 (スコア: 0.272)
#   - チーズ, バーガー (スコア: 0.238)
#   - 東陽町, 駅 (スコア: 0.220)
#   - バーガー, 専門 (スコア: 0.196)
#   - 人形, 町 (スコア: 0.170)
#   - 団地, 中 (スコア: 0.153)
# --------------------
# 【MOMI&TOY'S 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.268)
#   - クレープ, 屋 (スコア: 0.252)
#   - フード, コート (スコア: 0.207)
#   - クレープ, 食べる (スコア: 0.155)
#   - 甘い, 食べる (スコア: 0.128)
#   - いちご, チーズタルト (スコア: 0.123)
#   - いる, クレープ (スコア: 0.123)
# --------------------
# 【MONPAL 8】
#   - 日本, 酒 (スコア: 0.357)
#   - 飲む, 放題 (スコア: 0.304)
#   - お通し, 刺身 (スコア: 0.176)
#   - 白, 穂 (スコア: 0.148)
#   - 軒, 目 (スコア: 0.126)
#   - 門前仲, 町 (スコア: 0.104)
#   - 2, 軒 (スコア: 0.092)
# --------------------
# 【N．Y．Kカフェ お台場・デックス東京ビーチ】
#   - 甘い, 食べる (スコア: 0.213)
#   - 香り, 誘う (スコア: 0.153)
#   - する, 2011 (スコア: 0.153)
#   - 午後, 夫 (スコア: 0.153)
#   - する, タピオカ (スコア: 0.153)
#   - , y (スコア: 0.153)
#   - ある, クレープ (スコア: 0.153)
# --------------------
# 【OEDO ARIAKE STYLE】
#   - 老舗, 海鮮 (スコア: 0.215)
#   - 店, 大江戸 (スコア: 0.215)
#   - 有明, ガーデン (スコア: 0.209)
#   - 丼, 専門 (スコア: 0.191)
#   - いる, なる (スコア: 0.186)
#   - なる, 寿司 (スコア: 0.186)
#   - 豊洲, 市場 (スコア: 0.185)
# --------------------
# 【OSMIC DISH】
#   - 220,  (スコア: 0.175)
#   - トマト, 濃厚 (スコア: 0.175)
#   - いる, トマト (スコア: 0.167)
#   - する, トマト (スコア: 0.167)
#   - , 220 (スコア: 0.156)
#   - 専門, 店 (スコア: 0.153)
#   - 1100,  (スコア: 0.136)
# --------------------
# 【Ozgur Kitchen Kebab】
#   - ビーチ, アイランドモール (スコア: 0.478)
#   - キッチン, カー (スコア: 0.413)
#   - 4, 東京 (スコア: 0.403)
#   - 東京, ビーチ (スコア: 0.270)
#   - 徒歩, 4 (スコア: 0.269)
#   - 公園, 駅 (スコア: 0.267)
#   - かもめ, 台場 (スコア: 0.256)
# --------------------
# 【PATISSERIE L11S】
#   - 来る, 関わる (スコア: 0.257)
#   - 満腹, 状態 (スコア: 0.257)
#   - 状態, 親子 (スコア: 0.257)
#   - ブッフェ, 楽しむ (スコア: 0.257)
#   - 車, 行く (スコア: 0.245)
#   - 朝, ブッフェ (スコア: 0.245)
#   - いる, ケーキ (スコア: 0.245)
# --------------------
# 【PERFECT BEER STAND MONNAKA】
#   - 門前仲, 町 (スコア: 0.293)
#   - 門前仲町, 駅 (スコア: 0.250)
#   - 軒, 目 (スコア: 0.243)
#   - 立ち, 飲む (スコア: 0.144)
#   - 常連, 多い (スコア: 0.144)
#   - １, 杯 (スコア: 0.137)
#   - 1, 軒 (スコア: 0.118)
# --------------------
# 【PHO365】
#   - フォー, 専門 (スコア: 0.326)
#   - フォー, 春巻き (スコア: 0.279)
#   - 春巻き, セット (スコア: 0.266)
#   - 春, 巻 (スコア: 0.241)
#   - 牛肉, フォー (スコア: 0.186)
#   - フォー (スコア: 0.171)
#   - 葛西, 麺類 (スコア: 0.171)
# --------------------
# 【PIZZA SALVATORE CUOMO 豊洲】
#   - 豊洲, 駅 (スコア: 0.285)
#   - ピザ, パスタ (スコア: 0.125)
#   - 豊洲, 店 (スコア: 0.114)
#   - ランチ, ピザ (スコア: 0.093)
#   - パスタ, ランチ (スコア: 0.091)
#   - ハッピー, アワー (スコア: 0.088)
#   - チェーン, 店 (スコア: 0.086)
# --------------------
# 【PIZZA&WINE カヤバール 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.402)
#   - ピザ, パスタ (スコア: 0.302)
#   - ガーデン, 店 (スコア: 0.106)
#   - パスタ, ピザ (スコア: 0.092)
#   - , ピザ (スコア: 0.084)
#   - トリュフ, 風味 (スコア: 0.084)
#   - 飲む, 放題 (スコア: 0.084)
# --------------------
# 【PLANT LOVE】
#   - 貸切, 笑 (スコア: 0.245)
#   - ７, ９ (スコア: 0.245)
#   - 時半, 来る (スコア: 0.234)
#   - ない, 最初 (スコア: 0.234)
#   - 待ち, 待ち (スコア: 0.234)
#   - 本, いただく (スコア: 0.234)
#   - 来る, 待ち (スコア: 0.225)
# --------------------
# 【Pacific PICKLE CLUB】
#   - タコ, ライス (スコア: 0.335)
#   - 有明, アーバンスポーツパーク (スコア: 0.314)
#   - ワン, ちゃん (スコア: 0.160)
#   - 姉妹, 店 (スコア: 0.149)
#   - 七里ヶ浜, 店 (スコア: 0.110)
#   - ボリューム, 有明 (スコア: 0.110)
#   - めちゃくちゃ, オシャレ (スコア: 0.110)
# --------------------
# 【R's Cafe】
#   - 広い, 個室 (スコア: 0.160)
#   - 他, 唐 (スコア: 0.160)
#   - バー, いう (スコア: 0.160)
#   - 行く, 落ち着く (スコア: 0.160)
#   - シャンパン, ワイン (スコア: 0.160)
#   - 行う, つもり (スコア: 0.160)
#   - 近い, カフェ (スコア: 0.160)
# --------------------
# 【RESTAURANT WHITE ART】
#   - 店, テーマパーク (スコア: 0.349)
#   - テーマパーク, スモールワールズ (スコア: 0.349)
#   - 内, 軽食 (スコア: 0.349)
#   - 上手い, 使う (スコア: 0.349)
#   - small, worlds (スコア: 0.332)
#   - チケット, 購入 (スコア: 0.310)
#   - 力, 入れる (スコア: 0.271)
# --------------------
# 【RIN&GOカレー 東京有明セントラルタワー店】
#   - 小麦粉, 使う (スコア: 0.509)
#   - カレー, ルー (スコア: 0.415)
#   - なる, カツ (スコア: 0.267)
#   - ある, 自社 (スコア: 0.267)
#   - の, 一般 (スコア: 0.255)
#   - 一般, 向け (スコア: 0.245)
#   - 味, なる (スコア: 0.237)
# --------------------
# 【RISTORANTE OZIO】
#   - ベイ, コート (スコア: 0.677)
#   - 東京, ベイ (スコア: 0.327)
#   - コート, 倶楽部 (スコア: 0.307)
#   - アフタヌーン, ティー (スコア: 0.265)
#   - ristorante, ozio (スコア: 0.114)
#   - 会員, 制 (スコア: 0.101)
#   - 倶楽部, ホテル (スコア: 0.071)
# --------------------
# 【SAUS】
#   - ツリー, by (スコア: 0.275)
#   - ダブル, ツリー (スコア: 0.275)
#   - ヒルトン, 東京 (スコア: 0.207)
#   - 東京, 有明 (スコア: 0.172)
#   - 国際, 展示 (スコア: 0.115)
#   - 展示, 場 (スコア: 0.115)
#   - 今朝, 朝食 (スコア: 0.092)
# --------------------
# 【SONAE CAFE】
#   - そ, エリア (スコア: 0.443)
#   - 防災, 公園 (スコア: 0.332)
#   - 広域, 防災 (スコア: 0.332)
#   - 臨海, 広域 (スコア: 0.332)
#   - 公園, そ (スコア: 0.332)
#   - 東京, 臨海 (スコア: 0.230)
#   - 国営, 東京 (スコア: 0.221)
# --------------------
# 【STONE FACTORY Jr.】
#   - 牛, ステーキ (スコア: 0.336)
#   - 国産, 牛 (スコア: 0.294)
#   - フード, コート (スコア: 0.236)
#   - 石, 焼き (スコア: 0.196)
#   - 石, 焼 (スコア: 0.182)
#   - 他, ステーキ (スコア: 0.126)
#   - いる, ワン (スコア: 0.126)
# --------------------
# 【SWITCH STAND ODAIBA】
#   - くれる, すっごい (スコア: 0.262)
#   - 広い, 少ない (スコア: 0.262)
#   - とき, パスタ (スコア: 0.250)
#   - 選べる, 行う (スコア: 0.250)
#   - カレー, ボリューム (スコア: 0.250)
#   - 優しい, 丁寧 (スコア: 0.241)
#   - 美味しい, 広い (スコア: 0.241)
# --------------------
# 【Seaside Café SOLARIS】
#   - バス, 乗り場 (スコア: 0.315)
#   - 水上, バス (スコア: 0.298)
#   - 公園, 水上 (スコア: 0.198)
#   - 台場, 海浜 (スコア: 0.196)
#   - 海浜, 公園 (スコア: 0.192)
#   - ミルク, アイス (スコア: 0.132)
#   - 海上, バス (スコア: 0.132)
# --------------------
# 【Sky Restaurant シーガル】
#   - 24, ビル (スコア: 0.287)
#   - 社, 食 (スコア: 0.267)
#   - タイム, 24 (スコア: 0.238)
#   - , 3 (スコア: 0.237)
#   - テレコム, センター (スコア: 0.183)
#   - 1, 点 (スコア: 0.172)
#   - 3,  (スコア: 0.168)
# --------------------
# 【TGI FRIDAYS 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.418)
#   - コブ, サラダ (スコア: 0.188)
#   - 飲む, 放題 (スコア: 0.119)
#   - シェア, する (スコア: 0.077)
#   - tgi, フライデーズ (スコア: 0.076)
#   - ボリューム, ある (スコア: 0.073)
#   - 平日, ランチ (スコア: 0.068)
# --------------------
# 【TGIフライデーズ お台場アクアシティ店】
#   - レインボー, ブリッジ (スコア: 0.140)
#   - tgi, フライデーズ (スコア: 0.131)
#   - , i (スコア: 0.098)
#   - 予約, する (スコア: 0.097)
#   - アメリカン, サイズ (スコア: 0.094)
#   - ブリッジ, 見える (スコア: 0.077)
#   - g,  (スコア: 0.072)
# --------------------
# 【THE BBQ BEACH in AQUA CITY ODAIBA】
#   - 7, 階 (スコア: 0.368)
#   - bbq, 楽しめる (スコア: 0.241)
#   - 屋上, ある (スコア: 0.160)
#   - 飲む, 放題 (スコア: 0.126)
#   - 良い, 台場 (スコア: 0.125)
#   - レインボー, ブリッジ (スコア: 0.114)
#   - 居心地, 良い (スコア: 0.093)
# --------------------
# 【THEキャラCAFE お台場デックス店】
#   - ラブ, ライブ (スコア: 0.419)
#   - 味, コラボレーション (スコア: 0.419)
#   - 高い, いい (スコア: 0.400)
#   - ランチョン, マット (スコア: 0.385)
#   - カフェ, する (スコア: 0.321)
#   - 特筆, する (スコア: 0.307)
#   - クオリティ, 高い (スコア: 0.245)
# --------------------
# 【The Cabaret】
#   - フォート (スコア: 0.410)
#   - イマーシブ (スコア: 0.397)
#   - フォート, 東京 (スコア: 0.309)
#   - イマーシブフォート, 東京 (スコア: 0.210)
#   - ショー, 見る (スコア: 0.205)
#   - 東京, 中 (スコア: 0.126)
#   - する, ショー (スコア: 0.122)
# --------------------
# 【The Grill on 30th】
#   - グランド, ニッコー (スコア: 0.395)
#   - 30, 階 (スコア: 0.337)
#   - ニッコー, 東京 (スコア: 0.290)
#   - 30, th (スコア: 0.207)
#   - 東京, 台場 (スコア: 0.198)
#   - on, 30 (スコア: 0.192)
#   - 台場, 30 (スコア: 0.184)
# --------------------
# 【The Lobby Cafe】
#   - アフタヌーン, ティー (スコア: 0.510)
#   - グランド, ニッコー (スコア: 0.384)
#   - ニッコー, 東京 (スコア: 0.327)
#   - 東京, 台場 (スコア: 0.189)
#   - the, lobby (スコア: 0.165)
#   - lobby, cafe (スコア: 0.165)
#   - アフタヌーン, ティーセット (スコア: 0.124)
# --------------------
# 【Tokyo 串家】
#   - 串, 家 (スコア: 0.512)
#   - フロンティア, ビル (スコア: 0.171)
#   - 台場, フロンティア (スコア: 0.163)
#   - タレ, 甘い (スコア: 0.138)
#   - 週, 替わり (スコア: 0.123)
#   - く, 夜 (スコア: 0.105)
#   - 丼, タレ (スコア: 0.098)
# --------------------
# 【Trattoria&Pizzeria LOGIC お台場】
#   - ピザ, 生地 (スコア: 0.154)
#   - パスタ, ピザ (スコア: 0.144)
#   - 予約, する (スコア: 0.126)
#   - ピザ, パスタ (スコア: 0.115)
#   - 焼く, ピザ (スコア: 0.104)
#   - ピザ, 美味しい (スコア: 0.103)
#   - バー, 付く (スコア: 0.090)
# --------------------
# 【WAGYU USHITOMI GINZA】
#   - 新富, 町 (スコア: 0.698)
#   - 八丁堀, 駅 (スコア: 0.233)
#   - 新富町, 駅 (スコア: 0.205)
#   - 割烹, 店 (スコア: 0.171)
#   - 黒毛, 和牛 (スコア: 0.164)
#   - 町, 駅 (スコア: 0.140)
#   - する, 割烹 (スコア: 0.112)
# --------------------
# 【WINESTAND TEO】
#   - 清澄, 白河 (スコア: 0.317)
#   - ナチュラル, ワイン (スコア: 0.296)
#   - 2, 階 (スコア: 0.180)
#   - サクッ, 行う (スコア: 0.133)
#   - 白河, 駅 (スコア: 0.133)
#   - ワイン, バー (スコア: 0.115)
#   - 1, 階 (スコア: 0.110)
# --------------------
# 【WOOD DESIGN PARK お台場店】
#   - 快適, 過ごす (スコア: 0.184)
#   - パワー, ワード (スコア: 0.184)
#   - の, 余裕 (スコア: 0.184)
#   - バーベキュー, セット (スコア: 0.184)
#   - 友達, いる (スコア: 0.184)
#   - よい, 最初 (スコア: 0.184)
#   - セット, ソフトドリンク (スコア: 0.184)
# --------------------
# 【YORIMICHI Odaiba】
#   - アフタヌーン, ティー (スコア: 0.397)
#   - レインボー, ブリッジ (スコア: 0.191)
#   - 創作, 和食 (スコア: 0.154)
#   - 台場, 夜景 (スコア: 0.124)
#   - 相談, する (スコア: 0.090)
#   - ブリッジ, 一望 (スコア: 0.088)
#   - ティー, 食べる (スコア: 0.080)
# --------------------
# 【Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉】
#   - 一, 枚 (スコア: 0.404)
#   - 焼肉, 屋 (スコア: 0.244)
#   - 1, 枚 (スコア: 0.207)
#   - 冷, 麺 (スコア: 0.191)
#   - 焼肉, 激戦 (スコア: 0.188)
#   - 焼肉, 店 (スコア: 0.176)
#   - 激戦, 区 (スコア: 0.172)
# --------------------
# 【bills お台場】
#   - 世界一, 朝食 (スコア: 0.315)
#   - bills, 台場 (スコア: 0.278)
#   - 台場, bills (スコア: 0.250)
#   - パンケーキ, 食べる (スコア: 0.242)
#   - 台場, 店 (スコア: 0.153)
#   - スクランブル, エッグ (スコア: 0.145)
#   - パンケーキ, 美味しい (スコア: 0.140)
# --------------------
# 【creperie kenny's ダイバーシティ店】
#   - ダイバー, シティ (スコア: 0.287)
#   - クレープ, 屋 (スコア: 0.284)
#   - チョコ, 生クリーム (スコア: 0.229)
#   - バナナ, チョコ (スコア: 0.198)
#   - シティ, 店 (スコア: 0.164)
#   - クレープ, 店 (スコア: 0.158)
#   - , s (スコア: 0.146)
# --------------------
# 【da pai dang 105 有明ガーデン店】
#   - 小籠, 包 (スコア: 0.687)
#   - フード, コート (スコア: 0.248)
#   - 焼く, 小籠 (スコア: 0.244)
#   - 包, セット (スコア: 0.166)
#   - 有明, ガーデン (スコア: 0.153)
#   - 焼き, 小籠 (スコア: 0.105)
#   - 階, フード (スコア: 0.089)
# --------------------
# 【mal D'amour】
#   - ベイ, コート (スコア: 0.599)
#   - 東京, ベイ (スコア: 0.359)
#   - コート, 倶楽部 (スコア: 0.333)
#   - 会員, 制 (スコア: 0.271)
#   - 24, 階 (スコア: 0.131)
#   - 倶楽部, 24 (スコア: 0.120)
#   - mal, d (スコア: 0.105)
# --------------------
# 【milky70 since1951 アクアシティお台場店】
#   - ミルキー, ソフトクリーム (スコア: 0.227)
#   - アイス, 屋 (スコア: 0.217)
#   - ペコ, ちゃん (スコア: 0.217)
#   - フード, コート (スコア: 0.199)
#   - アクアシティ, 台場 (スコア: 0.194)
#   - , ミルキー (スコア: 0.152)
#   - ソフトクリーム, ミックス (スコア: 0.152)
# --------------------
# 【mode super smoothie】
#   - アーバンスポーツパーク, 中 (スコア: 0.281)
#   - どれ, 千 (スコア: 0.281)
#   - 飲む, 価格 (スコア: 0.281)
#   - できる, きれい (スコア: 0.281)
#   - 暑い, 1 (スコア: 0.268)
#   - 有明, アーバンスポーツパーク (スコア: 0.268)
#   - もらう, できる (スコア: 0.258)
# --------------------
# 【root C 日本科学未来館 5Fロビー】
#   - バー, 1 (スコア: 0.315)
#   - にぎる, 頼む (スコア: 0.315)
#   - 美味しい, バー (スコア: 0.315)
#   - 感じ, 言う (スコア: 0.300)
#   - 試す, の (スコア: 0.280)
#   - 頼む, 食べる (スコア: 0.237)
#   - 日本, 科学 (スコア: 0.234)
# --------------------
# 【the BAR】
#   - プレ, オープン (スコア: 0.363)
#   - 眺める, れる (スコア: 0.225)
#   - 何, 情報 (スコア: 0.225)
#   - the, bar (スコア: 0.225)
#   - 貼る, おる (スコア: 0.225)
#   - オープン, ある (スコア: 0.215)
#   - , 2010 (スコア: 0.215)
# --------------------
# 【the open bakery】
#   - パン, 屋 (スコア: 0.550)
#   - カレー, パン (スコア: 0.211)
#   - 台場, 海浜 (スコア: 0.193)
#   - 海浜, 公園 (スコア: 0.188)
#   - ルー, ベン (スコア: 0.133)
#   - 公園, 駅 (スコア: 0.109)
#   - ベーカリー, カフェ (スコア: 0.106)
# --------------------
# 【あのり】
#   - 台場, 入る (スコア: 0.248)
#   - 台場, 海浜 (スコア: 0.213)
#   - 海浜, 公園 (スコア: 0.208)
#   - 手頃, 酒 (スコア: 0.144)
#   - ローカル, フード (スコア: 0.144)
#   - 店, 始まる (スコア: 0.144)
#   - 肴, 美味い (スコア: 0.144)
# --------------------
# 【あばら大根 西葛西店】
#   - 刺身, 盛り合わせ (スコア: 0.218)
#   - 西葛西, 駅 (スコア: 0.205)
#   - 飲む, 放題 (スコア: 0.100)
#   - 西葛西, 店 (スコア: 0.094)
#   - 美味しい, 刺身 (スコア: 0.088)
#   - 西葛西, 行く (スコア: 0.073)
#   - いらっしゃる,  (スコア: 0.073)
# --------------------
# 【いろり庵 きらく 国際展示場駅店】
#   - 立ち, 食い (スコア: 0.363)
#   - 券売, 機 (スコア: 0.199)
#   - 展示, 場 (スコア: 0.187)
#   - 国際, 展示 (スコア: 0.178)
#   - 場, 駅 (スコア: 0.178)
#   - 蕎麦, 屋 (スコア: 0.177)
#   - 食い, そば (スコア: 0.158)
# --------------------
# 【うなぎ 明月川 豊洲店】
#   - 食べる, 歩き (スコア: 0.275)
#   - 豊洲, 千客万来 (スコア: 0.219)
#   - 鰻, 屋 (スコア: 0.211)
#   - 豊洲, 市場 (スコア: 0.194)
#   - 白, 焼き (スコア: 0.188)
#   - 海鮮, 丼 (スコア: 0.166)
#   - 店, 千客万来 (スコア: 0.127)
# --------------------
# 【おいらんち 葛西駅前店】
#   - 葛西, 駅 (スコア: 0.249)
#   - 知人, 紹介 (スコア: 0.167)
#   - , 鮮度 (スコア: 0.138)
#   - 平日, 賑わう (スコア: 0.132)
#   - 洋食, ある (スコア: 0.132)
#   - 葛西, 駅前 (スコア: 0.116)
#   - , 葛西 (スコア: 0.116)
# --------------------
# 【おぼんdeごはん ダイバーシティ東京プラザ店】
#   - de, ごはん (スコア: 0.229)
#   - ぼん, de (スコア: 0.229)
#   - 味噌汁, かわり (スコア: 0.178)
#   - びん, ちょう (スコア: 0.172)
#   - ちょう, まぐろ (スコア: 0.172)
#   - ダイバー, シティ (スコア: 0.172)
#   - ごはん, 味噌汁 (スコア: 0.148)
# --------------------
# 【お食事処 ゆき】
#   - 台場, 海浜 (スコア: 0.240)
#   - 海浜, 公園 (スコア: 0.234)
#   - 焼き, 定食 (スコア: 0.194)
#   - 公園, 駅 (スコア: 0.180)
#   - 海, 家 (スコア: 0.179)
#   - 定食, 屋 (スコア: 0.167)
#   - 生姜, 焼き (スコア: 0.160)
# --------------------
# 【かつゑもん ダイバーシティ東京プラザ】
#   - フード, コート (スコア: 0.354)
#   - ダイバー, シティ (スコア: 0.273)
#   - カツ, 丼 (スコア: 0.234)
#   - シティ, 東京 (スコア: 0.226)
#   - チーズ, トマト (スコア: 0.199)
#   - 東京, プラザ (スコア: 0.178)
#   - 卵, とじる (スコア: 0.137)
# --------------------
# 【がぜん 有明】
#   - 海鮮, 丼 (スコア: 0.342)
#   - ビッグ, サイト (スコア: 0.264)
#   - ワシントン, ホテル (スコア: 0.230)
#   - パーク, ビル (スコア: 0.178)
#   - 有明, パーク (スコア: 0.158)
#   - 国際, 展示 (スコア: 0.151)
#   - 展示, 会 (スコア: 0.151)
# --------------------
# 【くいもの屋わん お台場デックス東京ビーチ店】
#   - わん, 台場 (スコア: 0.233)
#   - 牛, タン (スコア: 0.147)
#   - 夜, 仕事 (スコア: 0.140)
#   - ビーチ, 店 (スコア: 0.137)
#   - 店, 居酒屋 (スコア: 0.121)
#   - の, 早い (スコア: 0.096)
#   - 台場, デックス (スコア: 0.092)
# --------------------
# 【くずし割烹 天ぷら竹の庵 東銀座店】
#   - 東, 銀座 (スコア: 0.384)
#   - ビル, 地下 (スコア: 0.345)
#   - 天ぷら, 竹 (スコア: 0.200)
#   - 天ぷら, 膳 (スコア: 0.200)
#   - 天ぷら, 屋 (スコア: 0.161)
#   - 銀座, 店 (スコア: 0.113)
#   - 銀座, 駅 (スコア: 0.101)
# --------------------
# 【こだわりから揚げの酒処 くらふと】
#   - 唐, 揚げ (スコア: 0.572)
#   - 国際, 展示 (スコア: 0.185)
#   - 展示, 場 (スコア: 0.184)
#   - ハッピー, アワー (スコア: 0.154)
#   - 場, 駅 (スコア: 0.148)
#   - ビッグ, サイト (スコア: 0.102)
#   - 鴨, ユッケ (スコア: 0.095)
# --------------------
# 【こなな 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.361)
#   - 和風, パスタ (スコア: 0.341)
#   - こ, 有明 (スコア: 0.165)
#   - パスタ, 食べる (スコア: 0.118)
#   - パスタ, 屋 (スコア: 0.104)
#   - する, パスタ (スコア: 0.095)
#   - する, 有明 (スコア: 0.095)
# --------------------
# 【こめらく みんなで、お茶漬け日和。 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.313)
#   - フード, コート (スコア: 0.302)
#   - ガーデン, フード (スコア: 0.166)
#   - 丼, お茶漬け (スコア: 0.161)
#   - 出汁, かける (スコア: 0.154)
#   - 切り, 豚 (スコア: 0.154)
#   - コート, できる (スコア: 0.139)
# --------------------
# 【さち福や 台場アクアシティ店】
#   - 和, 定食 (スコア: 0.265)
#   - ちる, 福 (スコア: 0.157)
#   - 度, コスパ (スコア: 0.157)
#   - 有明, 店舗 (スコア: 0.157)
#   - 鶏, エリンギ (スコア: 0.157)
#   - 炊く, てる (スコア: 0.157)
#   - 和食, 台場 (スコア: 0.157)
# --------------------
# 【さち福やCAFE 有明ガーデン】
#   - 有明, ガーデン (スコア: 0.392)
#   - ちる, 福 (スコア: 0.258)
#   - チキン, 南蛮 (スコア: 0.180)
#   - 米, 選べる (スコア: 0.154)
#   - 五穀, 米 (スコア: 0.106)
#   - 牡蠣, フライ (スコア: 0.106)
#   - ガーデン, シアター (スコア: 0.106)
# --------------------
# 【しゃぶしゃぶ 吟半 お台場店】
#   - 半, 台場 (スコア: 0.306)
#   - デックス, 東京 (スコア: 0.252)
#   - 東京, ビーチ (スコア: 0.228)
#   - 上, ロース (スコア: 0.209)
#   - 国産, 牛 (スコア: 0.184)
#   - 贅沢, コース (スコア: 0.173)
#   - ビーチ, 1 (スコア: 0.173)
# --------------------
# 【しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場】
#   - 食べる, 放題 (スコア: 0.339)
#   - 飲茶, 食べる (スコア: 0.141)
#   - 6, 階 (スコア: 0.131)
#   - ゴマ, だれ (スコア: 0.119)
#   - アクアシティ, 台場 (スコア: 0.108)
#   - 景色, 綺麗 (スコア: 0.093)
#   - 予約, する (スコア: 0.093)
# --------------------
# 【しゃぶ食べ 有明ガーデン店】
#   - 食べる, 放題 (スコア: 0.455)
#   - 有明, ガーデン (スコア: 0.255)
#   - しゃぶしゃぶ, 屋 (スコア: 0.167)
#   - 豚, 食べる (スコア: 0.161)
#   - 三, 元 (スコア: 0.161)
#   - 元, 豚 (スコア: 0.161)
#   - しゃぶしゃぶ, 食べる (スコア: 0.140)
# --------------------
# 【しゅん】
#   - ヒレ, カツ (スコア: 0.146)
#   - 靴, 脱ぐ (スコア: 0.135)
#   - 隠れ家, 割烹 (スコア: 0.118)
#   - エリア, 東雲 (スコア: 0.118)
#   - 昔, 上司 (スコア: 0.118)
#   - できる, 割烹 (スコア: 0.118)
#   - 陸, 孤島 (スコア: 0.112)
# --------------------
# 【すき家 ワンザ有明店】
#   - すき, 家 (スコア: 0.615)
#   - 牛, 丼 (スコア: 0.378)
#   - ワンザ, 有明 (スコア: 0.175)
#   - フード, コート (スコア: 0.126)
#   - 展示, 場 (スコア: 0.125)
#   - する, すき (スコア: 0.112)
#   - 国際, 展示 (スコア: 0.094)
# --------------------
# 【すき家 東雲晴海通り店】
#   - すき, 家 (スコア: 0.565)
#   - 牛, 丼 (スコア: 0.280)
#   - 仕事場, 近く (スコア: 0.218)
#   - ふろ, ふき (スコア: 0.119)
#   - 牛, すき鍋 (スコア: 0.119)
#   - 白髪, ねぎ (スコア: 0.119)
#   - かける, 牛 (スコア: 0.119)
# --------------------
# 【すしざんまい 奥の院】
#   - すし, ざんまい (スコア: 0.875)
#   - 寿司, 屋 (スコア: 0.116)
#   - 築地, すし (スコア: 0.101)
#   - する, ざんまい (スコア: 0.087)
#   - 寿司, 食べる (スコア: 0.077)
#   - 築地, 寿司 (スコア: 0.075)
#   - 築地, 場外 (スコア: 0.068)
# --------------------
# 【すしざんまい 築地駅前店】
#   - すし, ざんまい (スコア: 0.805)
#   - 築地, 駅前 (スコア: 0.186)
#   - ざんまい, 築地 (スコア: 0.175)
#   - 築地, 駅 (スコア: 0.150)
#   - 駅前, 店 (スコア: 0.108)
#   - 築地, 本願寺 (スコア: 0.104)
#   - 店, 築地 (スコア: 0.078)
# --------------------
# 【すし処おかめ】
#   - 豊洲, 市場 (スコア: 0.504)
#   - 立ち, 食い (スコア: 0.180)
#   - 寿司, 屋 (スコア: 0.162)
#   - おまかせ, 握り (スコア: 0.156)
#   - 管理, 棟 (スコア: 0.148)
#   - 市場, 行く (スコア: 0.137)
#   - 市場, 見学 (スコア: 0.116)
# --------------------
# 【せきどうばなな】
#   - バナナ, 甘い (スコア: 0.483)
#   - , バナナ (スコア: 0.444)
#   - 頂く, 後 (スコア: 0.430)
#   - , アルコール (スコア: 0.418)
#   - チョイス,  (スコア: 0.370)
#   - 食, する (スコア: 0.272)
# --------------------
# 【そじ坊 ダイバーシティ東京プラザ店】
#   - す, 坊 (スコア: 0.475)
#   - ダイバー, シティ (スコア: 0.251)
#   - カレー, 南蛮 (スコア: 0.231)
#   - チキン, カツ (スコア: 0.155)
#   - カツ, 丼 (スコア: 0.150)
#   - 温かい, 蕎麦 (スコア: 0.141)
#   - 揚げる, 餅 (スコア: 0.133)
# --------------------
# 【そじ坊 ワンザ有明店】
#   - す, 坊 (スコア: 0.236)
#   - ワンザ, 有明 (スコア: 0.214)
#   - とろろ, そば (スコア: 0.204)
#   - 蕎麦, 屋 (スコア: 0.187)
#   - カツ, 丼 (スコア: 0.185)
#   - ビッグ, サイト (スコア: 0.175)
#   - 丼, 定食 (スコア: 0.132)
# --------------------
# 【そなエリア東京バーベキューガーデン】
#   - 防災, 公園 (スコア: 0.253)
#   - 臨海, 広域 (スコア: 0.253)
#   - そ, エリア (スコア: 0.253)
#   - 広域, 防災 (スコア: 0.253)
#   - bbq,  (スコア: 0.243)
#   - エリア, 東京 (スコア: 0.243)
#   - 東京, 臨海 (スコア: 0.175)
# --------------------
# 【たけぞー】
#   - ビッグ, サイト (スコア: 0.291)
#   - たけ, ー (スコア: 0.196)
#   - 有明, セントラルタワー (スコア: 0.183)
#   - かける, うどん (スコア: 0.173)
#   - 東京, ビッグ (スコア: 0.167)
#   - かける, そば (スコア: 0.131)
#   - セントラルタワー, 2 (スコア: 0.131)
# --------------------
# 【たこやきやの元祖 本家 会津屋 お台場店】
#   - たこ焼き, ミュージアム (スコア: 0.659)
#   - 台場, たこ焼き (スコア: 0.388)
#   - たこ焼き, 屋 (スコア: 0.125)
#   - 発祥, 店 (スコア: 0.120)
#   - 12, 個 (スコア: 0.108)
#   - ミュージアム, 中 (スコア: 0.102)
#   - 牛, すじ (スコア: 0.098)
# --------------------
# 【たこ家道頓堀くくる お台場たこ焼きミュージアム店】
#   - たこ焼き, ミュージアム (スコア: 0.643)
#   - 台場, たこ焼き (スコア: 0.326)
#   - たこ焼き, 屋 (スコア: 0.193)
#   - 明石, 焼き (スコア: 0.181)
#   - 道頓堀, くくる (スコア: 0.166)
#   - 8, 個 (スコア: 0.132)
#   - たこ焼き, 食べる (スコア: 0.123)
# --------------------
# 【つきじ丼匠】
#   - 豊洲, 市場 (スコア: 0.523)
#   - 海鮮, 丼 (スコア: 0.291)
#   - 豪快, 丼 (スコア: 0.197)
#   - 丼, 店 (スコア: 0.130)
#   - 管理, 棟 (スコア: 0.125)
#   - 街, 区 (スコア: 0.102)
#   - 寿司, 屋 (スコア: 0.100)
# --------------------
# 【つきぢ神楽寿司 豊洲市場店】
#   - 豊洲, 市場 (スコア: 0.447)
#   - 赤, 酢 (スコア: 0.428)
#   - つく, ぢ (スコア: 0.189)
#   - 寿司, 豊洲 (スコア: 0.174)
#   - 寿司, 屋 (スコア: 0.164)
#   - 市場, 店 (スコア: 0.114)
#   - 酢, シャリ (スコア: 0.102)
# --------------------
# 【つけ麺らーめん春樹 お台場店】
#   - つけ, 麺 (スコア: 0.591)
#   - 特, 盛 (スコア: 0.201)
#   - 麺, 特 (スコア: 0.163)
#   - 山, 盛 (スコア: 0.163)
#   - 豚, 骨 (スコア: 0.159)
#   - 麺, ら (スコア: 0.130)
#   - 太, 麺 (スコア: 0.117)
# --------------------
# 【つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店】
#   - つけ, 麺 (スコア: 0.525)
#   - 三田, 製 (スコア: 0.432)
#   - 麺, 所 (スコア: 0.340)
#   - 製, 麺 (スコア: 0.319)
#   - 特, 濃い (スコア: 0.170)
#   - つけ, 汁 (スコア: 0.160)
#   - つける, 麺 (スコア: 0.156)
# --------------------
# 【てしごとや ふくの鳥 木場店】
#   - 唐, 揚げ (スコア: 0.245)
#   - ふく, 鳥 (スコア: 0.222)
#   - １１月, １ (スコア: 0.166)
#   - チキン, 南蛮 (スコア: 0.154)
#   - 木場, 駅 (スコア: 0.144)
#   - 揚げ, 定食 (スコア: 0.113)
#   - いる, 木場 (スコア: 0.106)
# --------------------
# 【てっぱん屋台 ダイバーシティ東京プラザ店】
#   - ぱん, 屋台 (スコア: 0.375)
#   - フード, コート (スコア: 0.372)
#   - てる, ぱん (スコア: 0.331)
#   - ダイバー, シティ (スコア: 0.331)
#   - モダン, 焼き (スコア: 0.182)
#   - やく, そば (スコア: 0.177)
#   - シティ, 東京 (スコア: 0.151)
# --------------------
# 【とんかつ八千代】
#   - チャーシュー, エッグ (スコア: 0.663)
#   - 豊洲, 市場 (スコア: 0.372)
#   - アジ, フライ (スコア: 0.329)
#   - エッグ, 定食 (スコア: 0.252)
#   - とる, 八千代 (スコア: 0.172)
#   - とぶ, 八千代 (スコア: 0.105)
#   - 車, エビ (スコア: 0.105)
# --------------------
# 【どうとんぼり神座 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.546)
#   - フード, コート (スコア: 0.415)
#   - おいしい, ラーメン (スコア: 0.193)
#   - ガーデン, フード (スコア: 0.182)
#   - ん, ぼる (スコア: 0.179)
#   - ラーメン, 屋 (スコア: 0.149)
#   - ガーデン, 店 (スコア: 0.135)
# --------------------
# 【なんで、や お台場店】
#   - アクアシティ, 台場 (スコア: 0.229)
#   - 台場, 店 (スコア: 0.168)
#   - アクアシティ, １ (スコア: 0.163)
#   - 大衆, 居酒屋 (スコア: 0.129)
#   - 台場, 居酒屋 (スコア: 0.116)
#   - 大衆, 酒場 (スコア: 0.108)
#   - フード, コート (スコア: 0.107)
# --------------------
# 【にばん家 勝どき】
#   - 勝どき, 駅 (スコア: 0.350)
#   - 焼き, 弁当 (スコア: 0.273)
#   - 路地, 裏 (スコア: 0.257)
#   - 焼, 丼 (スコア: 0.191)
#   - 裏, 隠れ家 (スコア: 0.191)
#   - 仕事, 飲む (スコア: 0.095)
#   - 勧め, 日本 (スコア: 0.095)
# --------------------
# 【ねぎま屋 武蔵 葛西店】
#   - 焼き鳥, 屋 (スコア: 0.185)
#   - 葛西, 駅 (スコア: 0.169)
#   - ナポリ, タン (スコア: 0.130)
#   - 99,  (スコア: 0.117)
#   - 串, 美味しい (スコア: 0.117)
#   - いる, 焼き鳥 (スコア: 0.112)
#   - 来る, 焼き鳥 (スコア: 0.112)
# --------------------
# 【ねこねこチーズケーキ 有明ガーデンシティ店】
#   - チーズ, ケーキ (スコア: 0.464)
#   - ねこ, ねこ (スコア: 0.222)
#   - 有明, ガーデン (スコア: 0.216)
#   - 形, する (スコア: 0.173)
#   - する, チーズ (スコア: 0.153)
#   - 店, 可愛らしい (スコア: 0.148)
#   - 食, 濃厚 (スコア: 0.148)
# --------------------
# 【はなまるうどん ダイバーシティ東京店】
#   - なまる, うどん (スコア: 0.643)
#   - 冷, かける (スコア: 0.260)
#   - ダイバー, シティ (スコア: 0.259)
#   - フード, コート (スコア: 0.227)
#   - の, なまる (スコア: 0.182)
#   - うどん, 小 (スコア: 0.138)
#   - シティ, 東京 (スコア: 0.138)
# --------------------
# 【はなまる屋 アクアシティお台場店】
#   - なまる, うどん (スコア: 0.412)
#   - フード, コート (スコア: 0.214)
#   - 台場, フード (スコア: 0.209)
#   - アクアシティ, 台場 (スコア: 0.195)
#   - 大変, 目 (スコア: 0.095)
#   - 屋, 跡地 (スコア: 0.095)
#   - うどん, 卵 (スコア: 0.095)
# --------------------
# 【ふくの鳥 東陽町】
#   - チキン, 南蛮 (スコア: 0.395)
#   - メンチ, カツ (スコア: 0.279)
#   - ふく, 鳥 (スコア: 0.200)
#   - ひな, 鶏 (スコア: 0.191)
#   - 東陽, 町 (スコア: 0.185)
#   - カツ, 定食 (スコア: 0.156)
#   - 粗, 挽く (スコア: 0.127)
# --------------------
# 【ふぐ倶楽部ビルヂング】
#   - 店, ふぐ (スコア: 0.223)
#   - ふぐ, 専門 (スコア: 0.223)
#   - 新富, 町 (スコア: 0.176)
#   - 専門, 店 (スコア: 0.146)
#   - 00,  (スコア: 0.138)
#   - 店, 外 (スコア: 0.115)
#   - , ч (スコア: 0.111)
# --------------------
# 【ほおずきや】
#   - ワンザ, 有明 (スコア: 0.310)
#   - ビッグ, サイト (スコア: 0.248)
#   - 国際, 展示 (スコア: 0.192)
#   - 展示, 場 (スコア: 0.192)
#   - ら, ー (スコア: 0.162)
#   - ー, めん (スコア: 0.160)
#   - ベイ, モール (スコア: 0.159)
# --------------------
# 【ほっともっと 東雲店】
#   - 東雲, 1 (スコア: 0.196)
#   - 東雲, 店 (スコア: 0.180)
#   - 区, 東雲 (スコア: 0.174)
#   - てる, 弁当 (スコア: 0.098)
#   - する, すき焼き (スコア: 0.098)
#   - 近く, 東雲 (スコア: 0.098)
#   - 晴, 気温 (スコア: 0.098)
# --------------------
# 【ぼてや アクアシティお台場店】
#   - フード, コート (スコア: 0.340)
#   - アクアシティ, 台場 (スコア: 0.174)
#   - ひる, ぜん (スコア: 0.170)
#   - ぜん, 焼きそば (スコア: 0.170)
#   - モダン, 焼き (スコア: 0.156)
#   - 台場, フード (スコア: 0.124)
#   - 月見, 焼きそば (スコア: 0.113)
# --------------------
# 【まいばすけっと 台場1丁目店】
#   - 品数, 割 (スコア: 0.497)
#   - ipa, 探す (スコア: 0.497)
#   - 手, する (スコア: 0.474)
#   - 入口, 近い (スコア: 0.474)
#   - レインボー, ブリッジ (スコア: 0.235)
# --------------------
# 【まはらに】
#   - 居酒屋, 定食 (スコア: 0.188)
#   - とる, くれる (スコア: 0.167)
#   - 予約, とる (スコア: 0.163)
#   - 国際, 展示 (スコア: 0.157)
#   - 展示, 場 (スコア: 0.157)
#   - インド, 屋 (スコア: 0.149)
#   - 定食, 屋 (スコア: 0.129)
# --------------------
# 【むら田】
#   - ワシントン, ホテル (スコア: 0.361)
#   - 有明, ワシントン (スコア: 0.239)
#   - チキン, 南蛮 (スコア: 0.227)
#   - ビッグ, サイト (スコア: 0.198)
#   - むら, 田 (スコア: 0.195)
#   - 展示, 会 (スコア: 0.182)
#   - 展示, 場 (スコア: 0.136)
# --------------------
# 【やまちゃん お台場店】
#   - たこ焼き, ミュージアム (スコア: 0.657)
#   - 台場, たこ焼き (スコア: 0.305)
#   - たこ焼き, 屋 (スコア: 0.212)
#   - やむ, ちゃん (スコア: 0.194)
#   - 明石, 焼き (スコア: 0.141)
#   - デックス, 東京 (スコア: 0.116)
#   - 東京, ビーチ (スコア: 0.112)
# --------------------
# 【アイランド・ヴィンテージ・コーヒー 台場店】
#   - コーヒー (スコア: 0.261)
#   - アサイーボウル, 食べる (スコア: 0.184)
#   - コナ, コーヒー (スコア: 0.152)
#   - ハーフ, サイズ (スコア: 0.124)
#   - デックス, 東京 (スコア: 0.117)
#   - アサイー, 食べる (スコア: 0.116)
#   - 台場, 店 (スコア: 0.112)
# --------------------
# 【アニミル お台場店】
#   - エリア, テラス (スコア: 0.264)
#   - がる, てる (スコア: 0.264)
#   - する, ふる (スコア: 0.252)
#   - そう, 家族 (スコア: 0.252)
#   - 行く, 子供 (スコア: 0.243)
#   - decks, 東京 (スコア: 0.243)
#   - てる, 連れる (スコア: 0.243)
# --------------------
# 【アマラ ダイバーシティ東京店】
#   - ダイバー, シティ (スコア: 0.343)
#   - フード, コート (スコア: 0.297)
#   - シティ, フード (スコア: 0.218)
#   - スペシャル, セット (スコア: 0.188)
#   - 内, インド (スコア: 0.146)
#   - カレー, 屋 (スコア: 0.145)
#   - インド, ネパール (スコア: 0.141)
# --------------------
# 【アルポルト 東京ビッグサイト店】
#   - ビッグ, サイト (スコア: 0.493)
#   - 8, 階 (スコア: 0.271)
#   - 東京, ビッグ (スコア: 0.244)
#   - 会議, 棟 (スコア: 0.234)
#   - パスタ, ランチ (スコア: 0.220)
#   - 展示, 会 (スコア: 0.190)
#   - サイト, 会議 (スコア: 0.120)
# --------------------
# 【ア・タ・ゴール】
#   - 木場, 公園 (スコア: 0.466)
#   - 木場, 駅 (スコア: 0.349)
#   - ゴール (スコア: 0.202)
#   - オーナー, シェフ (スコア: 0.183)
#   - ランチ, コース (スコア: 0.107)
#   - なる, いる (スコア: 0.097)
#   - れる, 特別 (スコア: 0.093)
# --------------------
# 【イオンスタイル 有明ガーデン】
#   - t,  (スコア: 0.171)
#   - , t (スコア: 0.169)
#   - ７, 千 (スコア: 0.120)
#   - レジ, 袋 (スコア: 0.120)
#   - モール, １ (スコア: 0.120)
#   - する, 年末 (スコア: 0.120)
#   - 残す, ちゃう (スコア: 0.120)
# --------------------
# 【イタリアン酒場 パステーカ】
#   - ビッグ, サイト (スコア: 0.189)
#   - トマト, ソース (スコア: 0.153)
#   - 展示, 会 (スコア: 0.139)
#   - ホール, 一 (スコア: 0.138)
#   - ソース, パスタ (スコア: 0.123)
#   - , о (スコア: 0.123)
#   - о,  (スコア: 0.121)
# --------------------
# 【イマーシブ・フォート東京】
#   - ディ (スコア: 0.322)
#   - ペローニ (スコア: 0.169)
#   - 粉, チーズ (スコア: 0.169)
#   - 可能,  (スコア: 0.139)
#   - 具合,  (スコア: 0.131)
#   - 事, できる (スコア: 0.096)
#   - ショー, 合わせる (スコア: 0.084)
# --------------------
# 【インコントロ オステリア&グリル】
#   - ニッコー, 東京 (スコア: 0.210)
#   - グランド, ニッコー (スコア: 0.207)
#   - , グリル (スコア: 0.200)
#   - 台場, 駅 (スコア: 0.123)
#   - 予約, する (スコア: 0.115)
#   - ランチ, コース (スコア: 0.101)
#   - 記念, コース (スコア: 0.100)
# --------------------
# 【インドレストラン＆バー ムナル】
#   - チーズ, ナン (スコア: 0.377)
#   - インド, カレー (スコア: 0.250)
#   - カレー, 屋 (スコア: 0.250)
#   - インド, ネパール (スコア: 0.184)
#   - 西葛西, インド (スコア: 0.156)
#   - 西葛西, 駅 (スコア: 0.146)
#   - カレー, セット (スコア: 0.144)
# --------------------
# 【インド料理ムンバイ アクアシティお台場店】
#   - カレー, ナン (スコア: 0.240)
#   - アクアシティ, 台場 (スコア: 0.192)
#   - ナン, セット (スコア: 0.159)
#   - レインボー, ブリッジ (スコア: 0.138)
#   - インド, カレー (スコア: 0.123)
#   - 辛い, さ (スコア: 0.109)
#   - 娘, 達 (スコア: 0.108)
# --------------------
# 【ウイスキーボイス 台場】
#   - カツ, カレー (スコア: 0.238)
#   - 間接, 照明 (スコア: 0.177)
#   - ビル, 地下 (スコア: 0.170)
#   - , 1300 (スコア: 0.142)
#   - 漬け, 物 (スコア: 0.118)
#   - 階段, 降りる (スコア: 0.113)
#   - ダイニング, バー (スコア: 0.113)
# --------------------
# 【ウェンディーズ・ファーストキッチン アクアシティお台場店】
#   - アクアシティ, 台場 (スコア: 0.245)
#   - 台場, フード (スコア: 0.210)
#   - フード, コート (スコア: 0.179)
#   - セルフ, レジ (スコア: 0.154)
#   - 番号, 呼ぶ (スコア: 0.149)
#   - 呼ぶ, れる (スコア: 0.109)
#   - 台場, アクアシティ (スコア: 0.104)
# --------------------
# 【ウマミバーガー 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.680)
#   - ポテト, セット (スコア: 0.154)
#   - ガーデン, 店 (スコア: 0.110)
#   - ガーデン, 5 (スコア: 0.094)
#   - ハンバーガー, 屋 (スコア: 0.082)
#   - 店, 限定 (スコア: 0.079)
#   - 5, 階 (スコア: 0.077)
# --------------------
# 【エクセルシオール カフェ ダイバーシティ東京プラザ店】
#   - ダイバー, シティ (スコア: 0.365)
#   - 東京, プラザ (スコア: 0.327)
#   - シティ, 東京 (スコア: 0.312)
#   - プラザ, 店 (スコア: 0.186)
#   - ５, 階 (スコア: 0.108)
#   - テレポート, 駅 (スコア: 0.093)
#   - の, 空間 (スコア: 0.091)
# --------------------
# 【エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店】
#   - 探す, 見当たる (スコア: 0.181)
#   - 不思議, 思う (スコア: 0.181)
#   - , ほうじ茶 (スコア: 0.181)
#   - 思う, フロア (スコア: 0.181)
#   - 480, する (スコア: 0.181)
#   - フロア, マップ (スコア: 0.181)
#   - センター, カフェ (スコア: 0.181)
# --------------------
# 【エグゼクティブラウンジ】
#   - カクテル, タイム (スコア: 0.335)
#   - 東京, 台場 (スコア: 0.269)
#   - ヒルトン, 東京 (スコア: 0.252)
#   - 台場, エグゼクティブラウンジ (スコア: 0.251)
#   - ヒルトン, 台場 (スコア: 0.192)
#   - 2020,  (スコア: 0.148)
#   - １, 本 (スコア: 0.138)
# --------------------
# 【エスプレッソ アメリカーノ テレコムセンター店】
#   - テレコム, センター (スコア: 0.685)
#   - センター, 1 (スコア: 0.178)
#   - センター, 駅 (スコア: 0.139)
#   - オープン, カフェ (スコア: 0.128)
#   - オープン, スペース (スコア: 0.110)
#   - サンドイッチ, セット (スコア: 0.089)
#   - する, テレコム (スコア: 0.085)
# --------------------
# 【エッグスンシングス お台場店】
#   - パンケーキ, 食べる (スコア: 0.292)
#   - n, things (スコア: 0.147)
#   - パンケーキ,  (スコア: 0.140)
#   - , パンケーキ (スコア: 0.115)
#   - パンケーキ, 美味しい (スコア: 0.115)
#   - , n (スコア: 0.115)
#   - 天井, 高い (スコア: 0.108)
# --------------------
# 【エフアイランド】
#   - , パパ (スコア: 0.227)
#   - 階, ショップ (スコア: 0.227)
#   - ー, ２ (スコア: 0.216)
#   - by, bankara (スコア: 0.216)
#   - named, by (スコア: 0.216)
#   - bankara,  (スコア: 0.216)
#   - 常習犯,  (スコア: 0.208)
# --------------------
# 【エフカイビーチ】
#   - 海浜, 公園 (スコア: 0.448)
#   - 台場, 海浜 (スコア: 0.396)
#   - 犬, 連れる (スコア: 0.106)
#   - 台場, 賑わう (スコア: 0.084)
#   - 海沿い, 歩く (スコア: 0.084)
#   - 公園, 来る (スコア: 0.080)
#   - 品川, 台場 (スコア: 0.077)
# --------------------
# 【オイスターハウス お台場店】
#   - 牡蠣, 食べる (スコア: 0.263)
#   - パン, 食べる (スコア: 0.234)
#   - 食べる, 放題 (スコア: 0.196)
#   - レインボー, ブリッジ (スコア: 0.157)
#   - ランチ, パン (スコア: 0.148)
#   - 牡蠣, 牡蠣 (スコア: 0.141)
#   - , 牡蠣 (スコア: 0.128)
# --------------------
# 【オリジナルパンケーキハウス 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.502)
#   - パンケーキ, 食べる (スコア: 0.205)
#   - ある, パンケーキ (スコア: 0.164)
#   - パンケーキ, 屋 (スコア: 0.164)
#   - パンケーキ, 店 (スコア: 0.124)
#   - パンケーキ,  (スコア: 0.121)
#   - パンケーキ, 美味しい (スコア: 0.102)
# --------------------
# 【オーケー お台場店】
#   - 店, 新橋 (スコア: 0.166)
#   - カナダ, 産 (スコア: 0.166)
#   - チェーン, ある (スコア: 0.166)
#   - 探す, 参る (スコア: 0.166)
#   - 過ぎ, 東京 (スコア: 0.166)
#   - パック, 購入 (スコア: 0.166)
#   - 産, 三 (スコア: 0.166)
# --------------------
# 【オーケー 東雲店】
#   - いう, ピザ (スコア: 0.264)
#   - 購入, 食べる (スコア: 0.264)
#   - する, 299 (スコア: 0.264)
#   - 前, 買う (スコア: 0.264)
#   - おいしい, リーズナブル (スコア: 0.264)
#   - カツ, 重 (スコア: 0.252)
#   - 17, オープン (スコア: 0.243)
# --------------------
# 【オーシャンクラブビュッフェ デックス東京ビーチ店】
#   - デックス, 東京 (スコア: 0.319)
#   - 東京, ビーチ (スコア: 0.193)
#   - サラダ, コーナー (スコア: 0.137)
#   - 台場, デックス (スコア: 0.135)
#   - 和洋, 中 (スコア: 0.106)
#   - 内, ビュッフェ (スコア: 0.098)
#   - レインボー, ブリッジ (スコア: 0.081)
# --------------------
# 【オーシャン東九フェリー】
#   - 販売, 機 (スコア: 0.299)
#   - 揃える, 多い (スコア: 0.173)
#   - 00, 東京 (スコア: 0.173)
#   - カトラリー, 揃う (スコア: 0.173)
#   - 電子, レンジ (スコア: 0.173)
#   - フェリー, 乗り場 (スコア: 0.173)
#   - 現金, 以外 (スコア: 0.173)
# --------------------
# 【オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明)】
#   - 海鮮, 丼 (スコア: 0.248)
#   - 勝手, 丼 (スコア: 0.189)
#   - 就学, 児 (スコア: 0.163)
#   - 児, 無料 (スコア: 0.157)
#   - 有明, ガーデン (スコア: 0.138)
#   - ランチ, ビュッフェ (スコア: 0.135)
#   - ホテル, ビュッフェ (スコア: 0.127)
# --------------------
# 【カザーナ お台場店】
#   - 食べる, 放題 (スコア: 0.320)
#   - ランチ, バイキング (スコア: 0.289)
#   - インド, カレー (スコア: 0.274)
#   - カレー, 4 (スコア: 0.247)
#   - デックス, 東京 (スコア: 0.152)
#   - 4, カレー (スコア: 0.148)
#   - カレー, 屋 (スコア: 0.140)
# --------------------
# 【カツオたまご食堂】
#   - テレコム, センター (スコア: 0.361)
#   - たま, 定食 (スコア: 0.308)
#   - センター, 駅 (スコア: 0.144)
#   - スタミナ, 豚 (スコア: 0.123)
#   - 券売, 機 (スコア: 0.120)
#   - 青海, フロンティア (スコア: 0.113)
#   - 社員, 食堂 (スコア: 0.104)
# --------------------
# 【カフェ ラ・ボエム お台場】
#   - ボエム (スコア: 0.338)
#   - レインボー, ブリッジ (スコア: 0.239)
#   - グローバル, ダイニング (スコア: 0.150)
#   - 蒸す, 鶏 (スコア: 0.141)
#   - 予約, する (スコア: 0.135)
#   - 炭酸, 水 (スコア: 0.118)
#   - パスタ, ランチ (スコア: 0.108)
# --------------------
# 【カフェ&ミール ムジ 東京有明】
#   - 無印, 良品 (スコア: 0.623)
#   - 有明, ガーデン (スコア: 0.184)
#   - カフェ, する (スコア: 0.131)
#   - アイス, コーヒー (スコア: 0.112)
#   - 東京, 有明 (スコア: 0.107)
#   - ミール, ムジ (スコア: 0.103)
#   - 関東, 最大 (スコア: 0.095)
# --------------------
# 【カフェテラス　ロイヤル】
#   - ビッグ, サイト (スコア: 0.359)
#   - 西, 展示 (スコア: 0.285)
#   - サイト, 西 (スコア: 0.285)
#   - 東京, ビッグ (スコア: 0.244)
#   - 展示, 場 (スコア: 0.194)
#   - 展示, 会 (スコア: 0.189)
#   - エビ, フライ (スコア: 0.089)
# --------------------
# 【カフェ＆レストラン レインボー】
#   - がん, 研 (スコア: 0.380)
#   - 病院, 内 (スコア: 0.333)
#   - 有明, 病院 (スコア: 0.320)
#   - 有明, がん (スコア: 0.199)
#   - 研, 有明 (スコア: 0.199)
#   - 癌, 研 (スコア: 0.190)
#   - カフェ, レインボー (スコア: 0.190)
# --------------------
# 【カフェ･ベローチェ  有明店】
#   - 国際, 展示 (スコア: 0.346)
#   - 展示, 場 (スコア: 0.335)
#   - ビッグ, サイト (スコア: 0.237)
#   - 場, 駅 (スコア: 0.217)
#   - 有明, フロンティア (スコア: 0.185)
#   - フロンティア, ビル (スコア: 0.184)
#   - コーヒー, ゼリー (スコア: 0.164)
# --------------------
# 【カレス】
#   - トマト, ソース (スコア: 0.395)
#   - ランチ, 今日 (スコア: 0.229)
#   - 海浜, 公園 (スコア: 0.219)
#   - 台場, 海浜 (スコア: 0.218)
#   - コーヒー, 付き (スコア: 0.170)
#   - 公園, 駅 (スコア: 0.138)
#   - 予約, する (スコア: 0.131)
# --------------------
# 【カレーショップ C&Cダイニング 東京ビッグサイト店】
#   - c,  (スコア: 0.355)
#   - , c (スコア: 0.328)
#   - ビッグ, サイト (スコア: 0.299)
#   - 東京, ビッグ (スコア: 0.242)
#   - カツ, カレー (スコア: 0.238)
#   - ショップ, c (スコア: 0.195)
#   - カレー, ショップ (スコア: 0.186)
# --------------------
# 【カレー香房】
#   - フード, コート (スコア: 0.286)
#   - 香, 房 (スコア: 0.254)
#   - ビッグ, サイト (スコア: 0.231)
#   - カレー, 香 (スコア: 0.182)
#   - 東京, ビッグ (スコア: 0.169)
#   - 西, ホール (スコア: 0.165)
#   - 展示, 会 (スコア: 0.142)
# --------------------
# 【カンテボーレ イオンスタイル有明ガーデン】
#   - パン, 屋 (スコア: 0.443)
#   - 塩, パン (スコア: 0.367)
#   - 頂く, 物 (スコア: 0.293)
#   - イオン, スタイル (スコア: 0.160)
#   - リベイク, する (スコア: 0.152)
#   - パン, 多い (スコア: 0.142)
#   - チーズ,  (スコア: 0.142)
# --------------------
# 【カーサ・ディ・ペロー二】
#   - ディ (スコア: 0.287)
#   - フォート, 東京 (スコア: 0.239)
#   - フォート (スコア: 0.230)
#   - イマーシブ (スコア: 0.223)
#   - イマーシブフォート, 東京 (スコア: 0.217)
#   - 具合,  (スコア: 0.156)
#   - カーサ (スコア: 0.150)
# --------------------
# 【カールスジュニア ダイバーシティ東京 プラザレストラン】
#   - フード, コート (スコア: 0.412)
#   - ダイバー, シティ (スコア: 0.305)
#   - ハンバーガー, 屋 (スコア: 0.247)
#   - コート, 内 (スコア: 0.131)
#   - バーガー, キング (スコア: 0.130)
#   - ハンバーガー, チェーン (スコア: 0.127)
#   - シティ, 東京 (スコア: 0.111)
# --------------------
# 【ガルーバ】
#   - レインボー, ブリッジ (スコア: 0.267)
#   - 焼肉, 屋 (スコア: 0.236)
#   - 台場, 焼肉 (スコア: 0.147)
#   - アクアシティ, 台場 (スコア: 0.136)
#   - カルビ, ランチ (スコア: 0.112)
#   - 黒毛, 和牛 (スコア: 0.111)
#   - 夜景, 見える (スコア: 0.101)
# --------------------
# 【ガーデン ダイニング】
#   - グランド, ニッコー (スコア: 0.432)
#   - ニッコー, 東京 (スコア: 0.305)
#   - ロースト, ビーフ (スコア: 0.227)
#   - ランチ, ビュッフェ (スコア: 0.181)
#   - 東京, 台場 (スコア: 0.177)
#   - ニッコー, 台場 (スコア: 0.140)
#   - フェア, やる (スコア: 0.118)
# --------------------
# 【キッチン有明】
#   - 週, 替る (スコア: 0.457)
#   - 替る, ラーメン (スコア: 0.455)
#   - チン, 有明 (スコア: 0.229)
#   - 有明, 食堂 (スコア: 0.176)
#   - 味噌, ラーメン (スコア: 0.171)
#   - 食堂, 週 (スコア: 0.144)
#   - 職場, 近く (スコア: 0.112)
# --------------------
# 【キッチン青海珈琲】
#   - 11,  (スコア: 0.283)
#   - ハンバーグ, 定食 (スコア: 0.278)
#   - , 000 (スコア: 0.239)
#   - トマト, 酸味 (スコア: 0.230)
#   - 000, 11 (スコア: 0.214)
#   - 1,  (スコア: 0.182)
#   - 手作り, ハンバーグ (スコア: 0.161)
# --------------------
# 【キムカツ亭 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.502)
#   - フード, コート (スコア: 0.375)
#   - ガーデン, 店 (スコア: 0.179)
#   - ガーデン, フード (スコア: 0.166)
#   - カツ, 膳 (スコア: 0.164)
#   - カツ, 丼 (スコア: 0.162)
#   - コート, 内 (スコア: 0.111)
# --------------------
# 【キラキラドンキ ダイバーシティ東京 プラザ店】
#   - 会, 中核 (スコア: 0.337)
#   - てる, 購入 (スコア: 0.337)
#   - 会社, ショッピング (スコア: 0.337)
#   - 中核, 不動産 (スコア: 0.337)
#   - 購入, 味 (スコア: 0.337)
#   - 不動産, 会社 (スコア: 0.277)
#   - バー, ある (スコア: 0.267)
# --------------------
# 【キリンシティプラス 有明ガーデン店】
#   - キリン, シティ (スコア: 0.613)
#   - 有明, ガーデン (スコア: 0.199)
#   - ガーデン, シアター (スコア: 0.135)
#   - 注ぐ, 方 (スコア: 0.123)
#   - シティ, ある (スコア: 0.082)
#   - 飲む, 軽い (スコア: 0.082)
#   - シアター, 推す (スコア: 0.078)
# --------------------
# 【クアアイナ アクアシティお台場店】
#   - 台場, 店 (スコア: 0.219)
#   - ハンバーガー, 屋 (スコア: 0.189)
#   - アクアシティ, 台場 (スコア: 0.187)
#   - レインボー, ブリッジ (スコア: 0.167)
#   - 自由, 女神 (スコア: 0.163)
#   - ハンバーガー, 食べる (スコア: 0.156)
#   - 厚, 切り (スコア: 0.144)
# --------------------
# 【クルックス カフェオ ヨーロピアンリゾートカフェ】
#   - テレポート, 駅 (スコア: 0.154)
#   - オフィス, ビル (スコア: 0.152)
#   - フロンティア, ビル (スコア: 0.151)
#   - 台場, フロンティア (スコア: 0.144)
#   - 東京, テレポート (スコア: 0.126)
#   - 台場, 海浜 (スコア: 0.124)
#   - 海浜, 公園 (スコア: 0.122)
# --------------------
# 【クレープおじさん お台場店】
#   - , ジョイポリス (スコア: 0.268)
#   - クレープ, 屋 (スコア: 0.248)
#   - ジョイポリス, 中 (スコア: 0.201)
#   - おじさん, 焼く (スコア: 0.201)
#   - 誕生, 日月 (スコア: 0.191)
#   - , n (スコア: 0.178)
#   - , 9 (スコア: 0.101)
# --------------------
# 【グランディール 有明ガーデン店】
#   - パン, 屋 (スコア: 0.643)
#   - 有明, ガーデン (スコア: 0.271)
#   - ガーデン, 2 (スコア: 0.145)
#   - もち, もち (スコア: 0.141)
#   - ある, パン (スコア: 0.128)
#   - する, パン (スコア: 0.128)
#   - パン, ある (スコア: 0.093)
# --------------------
# 【グランドニッコー東京 台場】
#   - グランド, ニッコー (スコア: 0.462)
#   - ニッコー, 東京 (スコア: 0.343)
#   - 東京, 台場 (スコア: 0.232)
#   - アフタヌーン, ティー (スコア: 0.135)
#   - 会社, 行事 (スコア: 0.114)
#   - ルーム, サービス (スコア: 0.104)
#   - ニッコー, 台場 (スコア: 0.095)
# --------------------
# 【グランドニッコー東京 台場 エグゼクティブラウンジ】
#   - メロン, パフェ (スコア: 0.163)
#   - 宿泊, する (スコア: 0.143)
#   - ニッコー, 東京 (スコア: 0.138)
#   - グランド, ニッコー (スコア: 0.136)
#   - ホテル, 朝食 (スコア: 0.132)
#   - アフタヌーン, ティー (スコア: 0.129)
#   - 東京, 台場 (スコア: 0.098)
# --------------------
# 【グランブルー】
#   - 予約, 直後 (スコア: 0.279)
#   - プール, サイド (スコア: 0.279)
#   - ホテル, プール (スコア: 0.279)
#   - ホテルグランパシフィック, le (スコア: 0.266)
#   - 限定, ビアガーデン (スコア: 0.266)
#   - 予約, 確認 (スコア: 0.266)
#   - 参る, 何 (スコア: 0.256)
# --------------------
# 【グリロジー バー＆グリル】
#   - アフタヌーン, ティー (スコア: 0.416)
#   - ヒルトン, 東京 (スコア: 0.333)
#   - 東京, 台場 (スコア: 0.238)
#   - ヒルトン, 台場 (スコア: 0.198)
#   - 台場, ヒルトン (スコア: 0.117)
#   - ティー, 行く (スコア: 0.102)
#   - 台場, グリロジーバー (スコア: 0.074)
# --------------------
# 【グリーン アジア トウキョウ】
#   - サラダ, バー (スコア: 0.596)
#   - バー, スープ (スコア: 0.190)
#   - スープ, バー (スコア: 0.106)
#   - バー, つく (スコア: 0.103)
#   - バリュー, セット (スコア: 0.092)
#   - 台場, タイ (スコア: 0.092)
#   - エビ, 春巻き (スコア: 0.092)
# --------------------
# 【グリーンズシェフ】
#   - テレコム, センター (スコア: 0.412)
#   - 社, 食 (スコア: 0.201)
#   - 5, 階 (スコア: 0.146)
#   - 食堂, ある (スコア: 0.094)
#   - 残念, 量 (スコア: 0.094)
#   - する, 選択 (スコア: 0.094)
#   - 近辺, 食堂 (スコア: 0.094)
# --------------------
# 【グロー ジュース スタンド】
#   - 有明, ガーデン (スコア: 0.293)
#   - ガーデン, 5 (スコア: 0.143)
#   - ジュース, スタンド (スコア: 0.130)
#   - パッション, フルーツ (スコア: 0.124)
#   - 5, 階 (スコア: 0.118)
#   - 運営, する (スコア: 0.105)
#   - 飲む, やすい (スコア: 0.094)
# --------------------
# 【ゲンの中華そば 東京ビックサイト南展示棟店】
#   - 中華, そば (スコア: 0.643)
#   - ビッグ, サイト (スコア: 0.187)
#   - ゲン, 中華 (スコア: 0.165)
#   - 東京, ビッグ (スコア: 0.162)
#   - 展示, 会 (スコア: 0.148)
#   - サイト, 南 (スコア: 0.126)
#   - カレー, 飯 (スコア: 0.126)
# --------------------
# 【ココス 有明パークビル店】
#   - 有明, パーク (スコア: 0.319)
#   - パーク, ビル (スコア: 0.298)
#   - 国際, 展示 (スコア: 0.200)
#   - 展示, 場 (スコア: 0.199)
#   - 場, 駅 (スコア: 0.144)
#   - coco,  (スコア: 0.137)
#   - ワシントン, ホテル (スコア: 0.116)
# --------------------
# 【コムフォー アーバンドック ららぽーと豊洲店】
#   - グリーン, カレー (スコア: 0.354)
#   - 食べる, 放題 (スコア: 0.284)
#   - レッド, カレー (スコア: 0.259)
#   - 鶏, フォー (スコア: 0.247)
#   - カレー, 食べる (スコア: 0.229)
#   - 国産, 米 (スコア: 0.212)
#   - フォー, 専門 (スコア: 0.188)
# --------------------
# 【ゴクゴク ダイバーシティ東京プラザ店】
#   - バナナ, ミルク (スコア: 0.347)
#   - ダイバー, シティ (スコア: 0.217)
#   - バナナ, 入る (スコア: 0.174)
#   - 遊び, 疲れる (スコア: 0.174)
#   - 思う, フルーツ (スコア: 0.174)
#   - ジュース, 屋 (スコア: 0.174)
#   - 行く, 際 (スコア: 0.111)
# --------------------
# 【ゴンチャ アクアシティお台場店】
#   - ミルク, ティー (スコア: 0.280)
#   - タピオカ, トッピング (スコア: 0.202)
#   - 抹茶, ミルク (スコア: 0.180)
#   - 甘い, さ (スコア: 0.173)
#   - さ, 氷 (スコア: 0.152)
#   - 氷, 少なめ (スコア: 0.145)
#   - 飲む, なる (スコア: 0.111)
# --------------------
# 【サイゼリヤ 有明フロンティアビル店】
#   - ビッグ, サイト (スコア: 0.255)
#   - 展示, 会 (スコア: 0.243)
#   - 展示, 場 (スコア: 0.239)
#   - 国際, 展示 (スコア: 0.228)
#   - 有明, フロンティア (スコア: 0.169)
#   - ミラノ, 風 (スコア: 0.164)
#   - 休憩, lunch (スコア: 0.145)
# --------------------
# 【サザエさんのお店】
#   - 台場, フジテレビ (スコア: 0.322)
#   - 月島, もんじゃ (スコア: 0.203)
#   - , フジテレビ (スコア: 0.189)
#   - フジテレビ, 内 (スコア: 0.160)
#   - フジテレビ, 社屋 (スコア: 0.152)
#   - チョコ, クリーム (スコア: 0.146)
#   - 売る, いる (スコア: 0.146)
# --------------------
# 【サブウェイ TFT有明店】
#   - サブ, ウェイ (スコア: 0.710)
#   - tft, 有明 (スコア: 0.185)
#   - 復活, する (スコア: 0.156)
#   - エビ, アボカド (スコア: 0.115)
#   - ベイ, モール (スコア: 0.112)
#   - 有明, ベイ (スコア: 0.104)
#   - ワンザ, 有明 (スコア: 0.100)
# --------------------
# 【サーティワン エクスペリエンス ダイバーシティ東京プラザ店】
#   - ダイバー, シティ (スコア: 0.463)
#   - アイス, 食べる (スコア: 0.187)
#   - ３, １ (スコア: 0.187)
#   - 東京, プラザ (スコア: 0.173)
#   - シティ, 東京 (スコア: 0.165)
#   - , フレーバー (スコア: 0.116)
#   - 久しぶり, サーティーワン (スコア: 0.116)
# --------------------
# 【サーティワンアイスクリーム デックス東京ビーチ店】
#   - 東京, ビーチ (スコア: 0.160)
#   - デックス, 東京 (スコア: 0.156)
#   - スモール, ダブル (スコア: 0.142)
#   - なる, 更新 (スコア: 0.135)
#   - コメント, 励み (スコア: 0.135)
#   - レゴランド, 東京 (スコア: 0.135)
#   - イイネ, コメント (スコア: 0.135)
# --------------------
# 【サーティワンアイスクリーム 有明ガーデン店】
#   - スモール, ダブル (スコア: 0.252)
#   - 有明, ガーデン (スコア: 0.184)
#   - ガーデン, 2 (スコア: 0.180)
# ...
#   - タン, 定食 (スコア: 0.225)
#   - 有明, ガーデン (スコア: 0.211)
#   - テール, スープ (スコア: 0.184)
#   - ガーデン, シアター (スコア: 0.092)
#   - タン, 美味しい (スコア: 0.088)
# --------------------
# 【牛カツ京都勝牛 ダイバーシティ東京プラザ店】
#   - 牛, カツ (スコア: 0.845)
#   - カツ, 膳 (スコア: 0.173)
#   - 味, 変 (スコア: 0.116)
#   - 牛, サーロイン (スコア: 0.098)
#   - ロース, カツ (スコア: 0.079)
#   - 牛, ロース (スコア: 0.075)
#   - 山椒, 塩 (スコア: 0.068)
# --------------------
# 【牛和鹿 葛西店】
#   - 和, 鹿 (スコア: 0.354)
#   - 牛, 和 (スコア: 0.314)
#   - 葛西, 店 (スコア: 0.227)
#   - 近江, 牛 (スコア: 0.210)
#   - 門前仲, 町 (スコア: 0.194)
#   - ロース, ハラ (スコア: 0.136)
#   - ハラ, ミ (スコア: 0.130)
# --------------------
# 【牛若 葛西店】
#   - 焼肉, 屋 (スコア: 0.291)
#   - 葛西, 駅 (スコア: 0.284)
#   - 牛, 若 (スコア: 0.224)
#   - 5, 点 (スコア: 0.123)
#   - 焼肉, 食べる (スコア: 0.113)
#   - 大事, する (スコア: 0.112)
#   - 美味い, 焼肉 (スコア: 0.112)
# --------------------
# 【生粋 葛西駅前店】
#   - もつ, 鍋 (スコア: 0.172)
#   - 個室, 案内 (スコア: 0.156)
#   - 喫煙, 可 (スコア: 0.153)
#   - 飲む, 放題 (スコア: 0.152)
#   - 人数, 多い (スコア: 0.150)
#   - 2, 件 (スコア: 0.138)
#   - 件, 目 (スコア: 0.112)
# --------------------
# 【目利きの銀次 門前仲町駅前店】
#   - 飲む, 放題 (スコア: 0.172)
#   - ライス, 代わり (スコア: 0.167)
#   - チェーン, 店 (スコア: 0.166)
#   - 奥, カウンター (スコア: 0.151)
#   - 代わり, 無料 (スコア: 0.148)
#   - 行う, 参る (スコア: 0.128)
#   - 丼, する (スコア: 0.110)
# --------------------
# 【相鉄グランドフレッサ 東京ベイ有明】
#   - 朝食, 付き (スコア: 0.198)
#   - 朝食, バイキング (スコア: 0.191)
#   - 階, ビュッフェ (スコア: 0.147)
#   - ホテル, 2 (スコア: 0.123)
#   - 予約, 制 (スコア: 0.119)
#   - 期間, 中 (スコア: 0.100)
#   - , 3 (スコア: 0.091)
# --------------------
# 【眺遊楼】
#   - ベイ, コート (スコア: 0.722)
#   - 東京, ベイ (スコア: 0.279)
#   - コート, 倶楽部 (スコア: 0.266)
#   - フカ, ヒレ (スコア: 0.202)
#   - 会員, 制 (スコア: 0.155)
#   - コート, クラブ (スコア: 0.119)
#   - 北京, ダック (スコア: 0.104)
# --------------------
# 【石臼挽きそば 石楽】
#   - 蕎麦, 屋 (スコア: 0.354)
#   - 石臼, 挽く (スコア: 0.223)
#   - 豊洲, フロント (スコア: 0.198)
#   - 豊洲, 駅 (スコア: 0.174)
#   - せい, ろ (スコア: 0.168)
#   - 蕎麦, 食べる (スコア: 0.143)
#   - 蕎麦, セット (スコア: 0.125)
# --------------------
# 【磯寿司】
#   - 豊洲, 市場 (スコア: 0.564)
#   - 磯, 寿司 (スコア: 0.469)
#   - 寿司, 屋 (スコア: 0.157)
#   - 特, 上 (スコア: 0.142)
#   - 市場, 寿司 (スコア: 0.127)
#   - おまかせ, 15 (スコア: 0.117)
#   - 15, 貫 (スコア: 0.111)
# --------------------
# 【社食DELI】
#   - ビニール, 袋 (スコア: 0.281)
#   - 袋, 入れる (スコア: 0.281)
#   - 食堂, なる (スコア: 0.281)
#   - みそ, 汁 (スコア: 0.281)
#   - 内, 弁当 (スコア: 0.281)
#   - スペース, なる (スコア: 0.268)
#   - なる, オープン (スコア: 0.268)
# --------------------
# 【社食デリ】
#   - せる, 弁当 (スコア: 0.233)
#   - 洋, 中 (スコア: 0.233)
#   - 屋, 集合 (スコア: 0.233)
#   - 斜, 向かい (スコア: 0.233)
#   - 中, 他 (スコア: 0.222)
#   - 窓, 越し (スコア: 0.222)
#   - 店, 弁当 (スコア: 0.222)
# --------------------
# 【秀徳市場マルマサ】
#   - 店, やる (スコア: 0.142)
#   - 高い, テーブル (スコア: 0.106)
#   - 分ける, 提供 (スコア: 0.106)
#   - 妥当, する (スコア: 0.106)
#   - 前, 炭火 (スコア: 0.106)
#   - てる, 商品 (スコア: 0.106)
#   - 焼肉, たべる (スコア: 0.106)
# --------------------
# 【笑笑 お台場海浜公園駅前店】
#   - 笑, 笑 (スコア: 0.488)
#   - おろす, そば (スコア: 0.433)
#   - 公園, 駅前 (スコア: 0.146)
#   - 600,  (スコア: 0.107)
#   - そば,  (スコア: 0.098)
#   - 田舎, 蕎麦 (スコア: 0.090)
#   - 笑, 台場 (スコア: 0.087)
# --------------------
# 【笑笑 月島駅前店】
#   - 笑, 笑 (スコア: 0.357)
#   - ある, 月島 (スコア: 0.143)
#   - モンテローザ, 系列 (スコア: 0.143)
#   - 行く, 月島 (スコア: 0.136)
#   - 月島, 店 (スコア: 0.131)
#   - 分煙, する (スコア: 0.124)
#   - チェーン, 居酒屋 (スコア: 0.124)
# --------------------
# 【築地 すし Omakase】
#   - 血, 抜き (スコア: 0.268)
#   - 熟成, する (スコア: 0.256)
#   - 築地, すし (スコア: 0.188)
#   - 寿司, 屋 (スコア: 0.179)
#   - 予約, する (スコア: 0.144)
#   - する, れる (スコア: 0.132)
#   - 鮨, 屋 (スコア: 0.124)
# --------------------
# 【築地 挙母鮨】
#   - 15, 貫 (スコア: 0.202)
#   - 築地, 場外 (スコア: 0.185)
#   - 晴海, 通り (スコア: 0.168)
#   - 寿司, 屋 (スコア: 0.163)
#   - 上, 握り (スコア: 0.157)
#   - 7, 貫 (スコア: 0.157)
#   - 10, 貫 (スコア: 0.142)
# --------------------
# 【築地さらしなの里】
#   - 蕎麦, 屋 (スコア: 0.544)
#   - 十, 割 (スコア: 0.247)
#   - 築地, 駅 (スコア: 0.211)
#   - 三, 色 (スコア: 0.208)
#   - カレー, 南蛮 (スコア: 0.158)
#   - 新富, 町 (スコア: 0.147)
#   - 老舗, 蕎麦 (スコア: 0.131)
# --------------------
# 【築地玉寿司 晴海通り店】
#   - 晴海, 通り (スコア: 0.397)
#   - 寿司, 屋 (スコア: 0.281)
#   - 通り, 店 (スコア: 0.239)
#   - 寿司, 食べる (スコア: 0.143)
#   - 築地, 寿司 (スコア: 0.135)
#   - , 3 (スコア: 0.132)
#   - 通り, 沿い (スコア: 0.115)
# --------------------
# 【築地秀徳元祖】
#   - 赤, 酢 (スコア: 0.274)
#   - 築地, 場外 (スコア: 0.250)
#   - 号, 店 (スコア: 0.241)
#   - 寿司, 屋 (スコア: 0.232)
#   - 2, 号 (スコア: 0.161)
#   - 秀徳, 本店 (スコア: 0.158)
#   - 寿司, 食べる (スコア: 0.124)
# --------------------
# 【築地銀だこ ダイバーシティ東京プラザ店】
#   - 銀, だこ (スコア: 0.771)
#   - ダイバー, シティ (スコア: 0.237)
#   - 6, 個 (スコア: 0.187)
#   - フード, コート (スコア: 0.186)
#   - シティ, フード (スコア: 0.133)
#   - 個, 入り (スコア: 0.124)
#   - 8, 個 (スコア: 0.093)
# --------------------
# 【築地青空三代目 本店】
#   - 三, 代目 (スコア: 0.482)
#   - 青空, 三 (スコア: 0.414)
#   - 築地, 青空 (スコア: 0.362)
#   - 寿司, 屋 (スコア: 0.178)
#   - 築地, 場外 (スコア: 0.178)
#   - 予約, する (スコア: 0.131)
#   - 築地, 寿司 (スコア: 0.126)
# --------------------
# 【築地食堂 源ちゃん アクアシティお台場店】
#   - 源, ちゃん (スコア: 0.452)
#   - 築地, 食堂 (スコア: 0.319)
#   - 食堂, 源 (スコア: 0.265)
#   - アクアシティ, 台場 (スコア: 0.186)
#   - 海鮮, 丼 (スコア: 0.123)
#   - ちゃん, 丼 (スコア: 0.111)
#   - 刺身, 定食 (スコア: 0.093)
# --------------------
# 【築地食堂 源ちゃん 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.351)
#   - 源, ちゃん (スコア: 0.327)
#   - 築地, 食堂 (スコア: 0.231)
#   - 海鮮, 丼 (スコア: 0.223)
#   - ちゃん, 有明 (スコア: 0.187)
#   - 食堂, 源 (スコア: 0.177)
#   - 刺身, 定食 (スコア: 0.143)
# --------------------
# 【築地食堂 源ちゃん 東京ビックサイト店】
#   - 源, ちゃん (スコア: 0.379)
#   - ビッグ, サイト (スコア: 0.348)
#   - 東京, ビッグ (スコア: 0.248)
#   - 築地, 食堂 (スコア: 0.191)
#   - 展示, 会 (スコア: 0.186)
#   - 食堂, 源 (スコア: 0.176)
#   - しらす, 丼 (スコア: 0.150)
# --------------------
# 【築地食堂　源ちゃん TFT有明店】
#   - 源, ちゃん (スコア: 0.345)
#   - ビッグ, サイト (スコア: 0.245)
#   - 築地, 食堂 (スコア: 0.233)
#   - 海鮮, 丼 (スコア: 0.193)
#   - 食堂, 源 (スコア: 0.170)
#   - 東京, ビッグ (スコア: 0.143)
#   - アジ, フライ (スコア: 0.135)
# --------------------
# 【米三角】
#   - 豊洲, 千客万来 (スコア: 0.273)
#   - 千客万来, 2 (スコア: 0.210)
#   - 日本, 酒 (スコア: 0.187)
#   - 万葉, 倶楽部 (スコア: 0.158)
#   - 豊洲, 市場 (スコア: 0.151)
#   - 市場, 千客万来 (スコア: 0.145)
#   - 万, 来 (スコア: 0.140)
# --------------------
# 【翠苑】
#   - 刀, 削る (スコア: 0.193)
#   - 削る, 麺 (スコア: 0.193)
#   - ワンザ, 有明 (スコア: 0.174)
#   - tft, ビル (スコア: 0.145)
#   - 展示, 会 (スコア: 0.137)
#   - ビッグ, サイト (スコア: 0.136)
#   - 中華, 店 (スコア: 0.128)
# --------------------
# 【肉菜工房うしすけ 台場店】
#   - うし, すける (スコア: 0.300)
#   - 焼肉, 屋 (スコア: 0.283)
#   - わん, ちゃん (スコア: 0.230)
#   - わん, こ (スコア: 0.214)
#   - ワン, ちゃん (スコア: 0.204)
#   - 犬, 用 (スコア: 0.160)
#   - 食べる, 放題 (スコア: 0.134)
# --------------------
# 【自由が丘 蔭山 有明ガーデン店】
#   - 鶏, 白湯 (スコア: 0.649)
#   - 白湯, 塩 (スコア: 0.321)
#   - 塩, そば (スコア: 0.317)
#   - フード, コート (スコア: 0.304)
#   - 有明, ガーデン (スコア: 0.282)
#   - 味, 玉 (スコア: 0.200)
#   - ガーデン, フード (スコア: 0.127)
# --------------------
# 【芋蛸 お台場たこやきミュージアム店】
#   - たこ焼き, ミュージアム (スコア: 0.565)
#   - 芋, 蛸 (スコア: 0.392)
#   - たこ焼き, 屋 (スコア: 0.254)
#   - 台場, たこ焼き (スコア: 0.211)
#   - たこやき, ミュージアム (スコア: 0.174)
#   - ミュージアム, 内 (スコア: 0.117)
#   - ミュージアム, 中 (スコア: 0.114)
# --------------------
# 【花水木】
#   - 門前仲, 町 (スコア: 0.246)
#   - 不動尊, 参道 (スコア: 0.175)
#   - 深川, 不動尊 (スコア: 0.175)
#   - すき焼き, しゃぶしゃぶ (スコア: 0.175)
#   - しゃぶしゃぶ, 屋 (スコア: 0.167)
#   - すき焼き, 食べる (スコア: 0.167)
#   - 門前仲町, 駅 (スコア: 0.132)
# --------------------
# 【茂助だんご 豊洲市場】
#   - 茂助, ん (スコア: 0.645)
#   - 豊洲, 市場 (スコア: 0.501)
#   - 管理, 棟 (スコア: 0.143)
#   - 施設, 棟 (スコア: 0.132)
#   - 管理, 施設 (スコア: 0.129)
#   - あん, みつ (スコア: 0.125)
#   - ん, 豊洲 (スコア: 0.121)
# --------------------
# 【茶寮 伊藤園 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.498)
#   - 抹茶, ほうじ茶 (スコア: 0.249)
#   - 抹茶, ソフト (スコア: 0.186)
#   - 抹茶, ラテ (スコア: 0.176)
#   - ガーデン, 内 (スコア: 0.126)
#   - ガーデン, 店 (スコア: 0.125)
#   - 白玉, あずき (スコア: 0.124)
# --------------------
# 【菊屋】
#   - 町中, 華 (スコア: 0.326)
#   - 東雲, 駅 (スコア: 0.210)
#   - 線, 東雲 (スコア: 0.136)
#   - 東雲, 1 (スコア: 0.102)
#   - 東雲, 地区 (スコア: 0.102)
#   - 中華, 食堂 (スコア: 0.102)
#   - もやし, そば (スコア: 0.102)
# --------------------
# 【葛西ビアバー】
#   - 神, 泡 (スコア: 0.345)
#   - 一, 週間 (スコア: 0.205)
#   - オープン, 17 (スコア: 0.173)
#   - プレミアム (スコア: 0.159)
#   - ハッピー, アワー (スコア: 0.120)
#   - 1, 回 (スコア: 0.095)
#   - 泡, 飲む (スコア: 0.086)
# --------------------
# 【葛西臨海公園バーベキュー広場】
#   - 臨海, 公園 (スコア: 0.313)
#   - 葛西, 臨海 (スコア: 0.305)
#   - バーベキュー, する (スコア: 0.209)
#   - 公園, 内 (スコア: 0.209)
#   - 飲む, 放題 (スコア: 0.184)
#   - , 飲む (スコア: 0.148)
#   - 込み, 込み (スコア: 0.118)
# --------------------
# 【蔵乃ゑ】
#   - 内, 類 (スコア: 0.286)
#   - られる, 飲める (スコア: 0.286)
#   - くれる, 置く (スコア: 0.286)
#   - ここ, 勧め (スコア: 0.286)
#   - 一切, ある (スコア: 0.286)
#   - テーマパーク, 内 (スコア: 0.273)
#   - 温泉, 物語 (スコア: 0.273)
# --------------------
# 【親子丼 トリカイ エクスプレス ダイバーシティ東京店】
#   - 親子, 丼 (スコア: 0.683)
#   - ダイバー, シティ (スコア: 0.277)
#   - フード, コート (スコア: 0.257)
#   - 唐, 揚げ (スコア: 0.116)
#   - 丼, 店 (スコア: 0.098)
#   - する, 親子 (スコア: 0.093)
#   - チキン, 南蛮 (スコア: 0.091)
# --------------------
# 【豊洲市場 共同食堂】
#   - 棟, 5 (スコア: 0.241)
#   - 豊洲, 市場 (スコア: 0.145)
#   - 5, 階 (スコア: 0.131)
#   - 買い出し, 朝 (スコア: 0.126)
#   - 前, 中 (スコア: 0.126)
#   - 持つ, 厨房 (スコア: 0.126)
#   - 定食, 1150 (スコア: 0.126)
# --------------------
# 【豊海ワイン食堂】
#   - 作る, れる (スコア: 0.181)
#   - いただく, 水 (スコア: 0.165)
#   - 200, サラダ (スコア: 0.165)
#   - 価値, 店 (スコア: 0.165)
#   - たっぷり, ソース (スコア: 0.165)
#   - 今日, オープン (スコア: 0.165)
#   - 勝どき, マンション (スコア: 0.165)
# --------------------
# 【越後屋 竹千代】
#   - ビッグ, サイト (スコア: 0.335)
#   - 有明, セントラルタワー (スコア: 0.259)
#   - 展示, 会 (スコア: 0.226)
#   - セントラルタワー, 2 (スコア: 0.220)
#   - 東京, ビッグ (スコア: 0.205)
#   - 竹, 千 (スコア: 0.197)
#   - 千, 代 (スコア: 0.186)
# --------------------
# 【道頓堀 赤鬼】
#   - たこ焼き, ミュージアム (スコア: 0.462)
#   - 台場, たこ焼き (スコア: 0.249)
#   - 赤, 鬼 (スコア: 0.189)
#   - 明石, 焼き (スコア: 0.168)
#   - ミュージアム, 内 (スコア: 0.163)
#   - たこ焼き,  (スコア: 0.127)
#   - たこ焼き, 屋 (スコア: 0.127)
# --------------------
# 【都会の農園バーベキュー広場】
#   - バーベキュー, 広場 (スコア: 0.298)
#   - ダイバー, シティ (スコア: 0.273)
#   - シティ, 屋上 (スコア: 0.237)
#   - 風, 強い (スコア: 0.223)
#   - 飲む, 放題 (スコア: 0.214)
#   - 屋上, bbq (スコア: 0.189)
#   - 東京, プラザ (スコア: 0.148)
# --------------------
# 【都立潮風公園バーベキュー広場】
#   - 潮風, 公園 (スコア: 0.624)
#   - バーベキュー, 広場 (スコア: 0.312)
#   - 公園, バーベキュー (スコア: 0.312)
#   - 竹, 芝 (スコア: 0.156)
#   - エリア, エリア (スコア: 0.156)
#   - なる, 楽しい (スコア: 0.156)
#   - 気分, 予約 (スコア: 0.156)
# --------------------
# 【金澤濃厚豚骨ラーメン 神仙 アクアシティ店】
#   - 豚, 骨 (スコア: 0.569)
#   - 濃厚, 豚 (スコア: 0.416)
#   - ラーメン, 国技 (スコア: 0.261)
#   - 国技, 館 (スコア: 0.261)
#   - 骨, 醤油 (スコア: 0.258)
#   - 骨, ラーメン (スコア: 0.220)
#   - 特製, 濃厚 (スコア: 0.130)
# --------------------
# 【鉄板焼 銀杏】
#   - 鉄板, 焼き (スコア: 0.588)
#   - 30, 階 (スコア: 0.266)
#   - グランド, ニッコー (スコア: 0.165)
#   - レインボー, ブリッジ (スコア: 0.132)
#   - 階, 鉄板 (スコア: 0.130)
#   - ニッコー, 東京 (スコア: 0.112)
#   - ホテル, 最上階 (スコア: 0.106)
# --------------------
# 【銀座 深川玄庵】
#   - 門前仲, 町 (スコア: 0.243)
#   - 蕎麦, 前 (スコア: 0.164)
#   - 移転, する (スコア: 0.162)
#   - 門, 仲 (スコア: 0.118)
#   - 2, 年 (スコア: 0.095)
#   - 蕎麦, がき (スコア: 0.086)
#   - 検索, 引っかかる (スコア: 0.086)
# --------------------
# 【銀座 祭や】
#   - 日本, 酒 (スコア: 0.191)
#   - あん, 肝 (スコア: 0.127)
#   - 地下, 店 (スコア: 0.119)
#   - タバコ, 吸える (スコア: 0.113)
#   - 皆さん, 元気 (スコア: 0.107)
#   - 焼酎, 日本 (スコア: 0.102)
#   - 深夜, やる (スコア: 0.098)
# --------------------
# 【長寿韓酒房 ダイバーシティ東京プラザ店】
#   - 冷, 麺 (スコア: 0.469)
#   - みぞ, 冷 (スコア: 0.438)
#   - 長寿, 韓 (スコア: 0.345)
#   - 酒, 房 (スコア: 0.305)
#   - 韓, 酒 (スコア: 0.286)
#   - ダイバー, シティ (スコア: 0.171)
#   - スープ, 冷 (スコア: 0.157)
# --------------------
# 【長寿韓酒房 有明店】
#   - 韓, 酒 (スコア: 0.321)
#   - 酒, 房 (スコア: 0.321)
#   - 長寿, 韓 (スコア: 0.280)
#   - ビッグ, サイト (スコア: 0.227)
#   - 韓国, 食べる (スコア: 0.142)
#   - 石, 焼 (スコア: 0.135)
#   - 国際, 展示 (スコア: 0.134)
# --------------------
# 【長生庵】
#   - 蕎麦, 屋 (スコア: 0.455)
#   - 築地, 場外 (スコア: 0.291)
#   - 日本, 酒 (スコア: 0.245)
#   - 朝, 定食 (スコア: 0.235)
#   - 丼, そば (スコア: 0.159)
#   - 海鮮, 丼 (スコア: 0.146)
#   - しらす, 丼 (スコア: 0.144)
# --------------------
# 【門仲STAND】
#   - , 度 (スコア: 0.347)
#   - 自然, 派 (スコア: 0.270)
#   - 門, 仲 (スコア: 0.209)
#   - 派, ワイン (スコア: 0.207)
#   - 前菜, 盛り合わせ (スコア: 0.133)
#   - 日々, 記録 (スコア: 0.130)
#   - , 日々 (スコア: 0.130)
# --------------------
# 【門前仲町 らっきょう】
#   - かう, ぼう (スコア: 0.221)
#   - 揚げる, やつ (スコア: 0.140)
#   - 店, 移転 (スコア: 0.135)
#   - やつ, 美味しい (スコア: 0.127)
#   - 酒, つまむ (スコア: 0.105)
#   - の, よい (スコア: 0.092)
#   - 方面, 進む (スコア: 0.074)
# --------------------
# 【青海珈琲 青海本店】
#   - 青海, 珈琲 (スコア: 0.416)
#   - テレコム, センター (スコア: 0.261)
#   - 焙る, 煎る (スコア: 0.238)
#   - センター, 駅 (スコア: 0.231)
#   - 水, 出し (スコア: 0.170)
#   - 青海, フロンティア (スコア: 0.164)
#   - フロンティア, ビル (スコア: 0.134)
# --------------------
# 【青海食堂】
#   - 青海, 食堂 (スコア: 0.298)
#   - テレコム, センター (スコア: 0.259)
#   - ①, ① (スコア: 0.147)
#   - 定食, 650 (スコア: 0.147)
#   - センター, 駅 (スコア: 0.138)
#   - 天ぷら, そば (スコア: 0.127)
#   - 港湾, 関係 (スコア: 0.118)
# --------------------
# 【韓美膳 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.365)
#   - 石, 焼 (スコア: 0.330)
#   - 冷, 麺 (スコア: 0.317)
#   - フード, コート (スコア: 0.294)
#   - 焼, ビビンバ (スコア: 0.237)
#   - 韓国, 店 (スコア: 0.180)
#   - ガーデン, フード (スコア: 0.157)
# --------------------
# 【頑者NEXT LEVEL】
#   - つけ, 麺 (スコア: 0.708)
#   - ラーメン, 国技 (スコア: 0.352)
#   - 国技, 館 (スコア: 0.348)
#   - 海老, つけ (スコア: 0.187)
#   - つけ, めん (スコア: 0.155)
#   - 特製, つけ (スコア: 0.123)
#   - 豚, 骨 (スコア: 0.119)
# --------------------
# 【飛車角 有明ガーデン店】
#   - 有明, ガーデン (スコア: 0.333)
#   - ハラ, ミ (スコア: 0.280)
#   - 焼肉, 屋 (スコア: 0.190)
#   - 牛, タン (スコア: 0.137)
#   - カルビ, ハラ (スコア: 0.108)
#   - 冷, 麺 (スコア: 0.106)
#   - ビビンバ, 冷 (スコア: 0.098)
# --------------------
# 【餃子の王様 龍吟 ダイバーシティ店】
#   - ダイバー, シティ (スコア: 0.327)
#   - 餃子, 2 (スコア: 0.197)
#   - 町中, 華 (スコア: 0.172)
#   - 婆, 豆腐 (スコア: 0.129)
#   - 麻, 婆 (スコア: 0.125)
#   - レ, バニラ (スコア: 0.116)
#   - 2, 個 (スコア: 0.108)
# --------------------
# 【餃子酒家 築地店】
#   - 餃子, 酒家 (スコア: 0.440)
#   - 新富, 町 (スコア: 0.348)
#   - 新富町, 駅 (スコア: 0.242)
#   - 中華, 屋 (スコア: 0.174)
#   - 町, 中華 (スコア: 0.168)
#   - ラーメン, セット (スコア: 0.125)
#   - 16, ある (スコア: 0.117)
# --------------------
# 【香港飲茶楼 ル・パルク】
#   - ビッグ, サイト (スコア: 0.419)
#   - 東京, ビッグ (スコア: 0.279)
#   - 展示, 会 (スコア: 0.226)
#   - あん, かける (スコア: 0.171)
#   - 展示, 場 (スコア: 0.169)
#   - 東, 展示 (スコア: 0.158)
#   - 五目, あん (スコア: 0.140)
# --------------------
# 【魚とと 東京ビックサイトEat iT!店】
#   - ビッグ, サイト (スコア: 0.234)
#   - 東京, ビッグ (スコア: 0.228)
#   - ネギ, トロ (スコア: 0.203)
#   - サラダ, 丼 (スコア: 0.193)
#   - フード, コート (スコア: 0.193)
#   - 西, 棟 (スコア: 0.162)
#   - 海鮮, 健康 (スコア: 0.128)
# --------------------
# 【魚民 勝どき駅前店】
#   - 長居, する (スコア: 0.205)
#   - 為, 久々 (スコア: 0.136)
#   - 海老, ラーメン (スコア: 0.136)
#   - シェア, サイズ (スコア: 0.136)
#   - 全席, 個室 (スコア: 0.136)
#   - 満席, 為 (スコア: 0.136)
#   - 金曜日, 混む (スコア: 0.136)
# --------------------
# 【魚民 潮見駅前店】
#   - ０, 回 (スコア: 0.180)
#   - 位,  (スコア: 0.180)
#   - 室, 個室 (スコア: 0.180)
#   - 生ビール, キリン (スコア: 0.180)
#   - なる, 書く (スコア: 0.180)
#   - 言う, 難い (スコア: 0.180)
#   - 先週, 水曜日 (スコア: 0.180)
# --------------------
# 【魚河岸トミーナ 豊洲市場店】
#   - 豊洲, 市場 (スコア: 0.604)
#   - 海鮮, ピザ (スコア: 0.207)
#   - 市場, 内 (スコア: 0.181)
#   - ピザ, 食べる (スコア: 0.134)
#   - 管理, 棟 (スコア: 0.105)
#   - 茂助, ん (スコア: 0.093)
#   - ピザ, パスタ (スコア: 0.087)
# --------------------
# 【鮒忠 有明店】
#   - 鮒, 忠 (スコア: 0.452)
#   - チキン, 南蛮 (スコア: 0.296)
#   - ビッグ, サイト (スコア: 0.194)
#   - 南蛮, 定食 (スコア: 0.172)
#   - 有明, 店 (スコア: 0.124)
#   - 展示, 会 (スコア: 0.119)
#   - 国際, 展示 (スコア: 0.111)
# --------------------
# 【鮨 もりなり】
#   - ネタ, 大きい (スコア: 0.270)
#   - 寿司, 屋 (スコア: 0.237)
#   - 鮨, 屋 (スコア: 0.206)
#   - 絵画, 飾る (スコア: 0.128)
#   - 修行, する (スコア: 0.127)
#   - 帆, 立 (スコア: 0.117)
#   - 独立, する (スコア: 0.106)
# --------------------
# 【鮨 玉かがり 天ぷら 玉衣】
#   - グランド, ニッコー (スコア: 0.463)
#   - 30, 階 (スコア: 0.328)
#   - ニッコー, 東京 (スコア: 0.274)
#   - 寿司, 天ぷら (スコア: 0.167)
#   - 朝, 寿司 (スコア: 0.157)
#   - ニッコー, 台場 (スコア: 0.144)
#   - 東京, 台場 (スコア: 0.139)
# --------------------
# 【鮨 酒 肴 杉玉 新木場】
#   - 杉, 玉 (スコア: 0.447)
#   - 新木場, 駅 (スコア: 0.369)
#   - 寿司, 居酒屋 (スコア: 0.170)
#   - 肴, 杉 (スコア: 0.089)
#   - 創作, 系 (スコア: 0.089)
#   - 鮨, 酒 (スコア: 0.085)
#   - 寿司, セット (スコア: 0.085)
# --------------------
# 【鮨　宇田川】
#   - ワシントン, ホテル (スコア: 0.232)
#   - パーク, ビル (スコア: 0.232)
#   - 有明, パーク (スコア: 0.228)
#   - にぎる, 1 (スコア: 0.146)
#   - ビッグ, サイト (スコア: 0.138)
#   - 5, 人前 (スコア: 0.121)
#   - 展示, 会 (スコア: 0.109)
# --------------------
# 【鮨･酒･肴 杉玉 葛西店】
#   - 杉, 玉 (スコア: 0.266)
#   - 葛西, 駅前 (スコア: 0.149)
#   - ポテト, サラダ (スコア: 0.115)
#   - 赤, 酢 (スコア: 0.109)
#   - 美味しい, 寿司 (スコア: 0.102)
#   - ハッピー, アワー (スコア: 0.092)
#   - 肴, 杉 (スコア: 0.089)
# --------------------
# 【鮮魚旬菜 魚福】
#   - toc, 有明 (スコア: 0.248)
#   - ビッグ, サイト (スコア: 0.169)
#   - 国際, 展示 (スコア: 0.156)
#   - 展示, 場 (スコア: 0.155)
#   - 品, 選ぶ (スコア: 0.145)
#   - 1, 品 (スコア: 0.139)
#   - おかず, 2 (スコア: 0.124)
# --------------------
# 【鶏味座 ダイバーシティ東京プラザ店】
#   - 親子, 丼 (スコア: 0.863)
#   - 究極, 親子 (スコア: 0.317)
#   - ダイバー, シティ (スコア: 0.187)
#   - 鶏, 味 (スコア: 0.137)
#   - ら, ー (スコア: 0.052)
#   - ー, めん (スコア: 0.052)
#   - 丼, ラーメン (スコア: 0.046)
# --------------------
# 【鶏鬨はなれ 勝どき清澄通り店】
#   - 鶏, 鬨 (スコア: 0.510)
#   - ひつ, まぶしい (スコア: 0.468)
#   - 勝どき, 駅 (スコア: 0.257)
#   - 十, 割 (スコア: 0.136)
#   - 清澄, 通り (スコア: 0.108)
#   - 割, そば (スコア: 0.094)
#   - 焼き鳥, 屋 (スコア: 0.091)
# --------------------
# 【鶴橋風月 お台場店】
#   - モダン, 焼き (スコア: 0.347)
#   - お好み焼き, 食べる (スコア: 0.232)
#   - お好み焼き, 屋 (スコア: 0.232)
#   - 豚, 玉 (スコア: 0.224)
#   - 焼く, くれる (スコア: 0.170)
#   - 大阪, お好み焼き (スコア: 0.126)
#   - 台場, 6 (スコア: 0.125)
# --------------------
# 【黄金鉄鍋餃子 HUG】
#   - 鍋, 餃子 (スコア: 0.263)
#   - 鉄, 鍋 (スコア: 0.222)
#   - 餃子, 6 (スコア: 0.167)
#   - 焼き, 餃子 (スコア: 0.156)
#   - 塩, 塩 (スコア: 0.156)
#   - 味噌汁, 菜 (スコア: 0.131)
#   - 6, 個 (スコア: 0.127)
# --------------------
# 【龍記 お台場デックス東京ビーチ店】
#   - 削る, 麺 (スコア: 0.562)
#   - 刀, 削る (スコア: 0.521)
#   - 婆, 豆腐 (スコア: 0.181)
#   - 麻, 婆 (スコア: 0.175)
#   - エビ, チリ (スコア: 0.087)
#   - 四川, 風 (スコア: 0.079)
#   - 石鍋, 麻 (スコア: 0.072)
# --------------------
# 【＆ Ovo】
#   - 築地, 本願寺 (スコア: 0.579)
#   - 築地, 駅 (スコア: 0.275)
#   - モーニング, プレート (スコア: 0.180)
#   - 階, 2 (スコア: 0.154)
#   - 目, 前 (スコア: 0.142)
#   - カフェ,  (スコア: 0.130)
#   - ビス, トロ (スコア: 0.126)
# --------------------
