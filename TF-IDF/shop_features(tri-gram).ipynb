# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# CSVファイルを読み込む
try:
    df = pd.read_csv('/Users/dangararara/lecture/miraisouzou/csv/odaiba_reviews.csv')
except FileNotFoundError:
    print("エラー: 'odaiba_reviews.csv'が見つかりません。")
    df = pd.DataFrame()

# JanomeのTokenizerを準備
t = Tokenizer()

# ストップワード
stop_words = [
    'こと', 'もの', 'それ', 'これ', 'さん', 'よう', 'ため', '的', '的', '気', '感',
    'いる', 'する', 'なる', 'ある', 'ない', 'くる', 'いく', '思う', '言う',
    '美味しい', 'うまい', '普通', '良い', '悪い', '最高', '本当', '今回', '前回', 
    '初', '再訪', '人気', '有名', '定番', '満足', '好き', 'おすすめ', 'ごちそうさま', '様',
    '料理', '食事', 'メニュー', 'ドリンク', 'デザート', '一品', 'ご飯', 'ビール',  '肉', '魚', '野菜',
    '食べる', '飲む', '行く', '来る', '入る', '出る', '頼む', '注文', 
    '訪問', '利用', '頂く', 'いただく', '会計',
    '時間', '日', '時', '分', 
    'お店', 'レストラン', 'こちら', 'ところ', '場所', '雰囲気', '店内', 
    '外観', '席', 'スタッフ', '店員', 
    '自分', '私', '人',
    '一つ', 'たくさん', '少し', 'ちょっと', 'かなり', '非常', 'いろいろ', '色々', 
    '種類', '豊富', '一番', '円', '...',
]


# <--- 変更点：Tri-gram用のTokenizer関数 ---
def tokenize_for_trigrams(text):
    """テキストを形態素解析し、Tri-gramの文字列を返す"""
    # まずは単語に分解
    tokens = []
    for token in t.tokenize(text):
        part_of_speech = token.part_of_speech.split(',')[0]
        if part_of_speech in ['名詞', '動詞', '形容詞'] and token.surface not in stop_words:
            tokens.append(token.base_form)
    
    # 単語リストからTri-gramを作成
    trigrams = [f"{tokens[i]}_{tokens[i+1]}_{tokens[i+2]}" for i in range(len(tokens) - 2)]
    return ' '.join(trigrams)

if not df.empty:
    shop_docs = df.groupby('shop_name')['review_text'].apply(lambda x: ' '.join(x.dropna())).reset_index()
    
    print("各店舗の口コミをTri-gramに変換中...")
    # <--- 変更点：Tri-gram用の関数を適用 ---
    shop_docs['tokens'] = shop_docs['review_text'].apply(tokenize_for_trigrams)
    
    corpus = shop_docs['tokens'].tolist()
    shop_names = shop_docs['shop_name'].tolist()

    if corpus:
        print("Tri-gramのTF-IDFスコアを計算中...")
        vectorizer = TfidfVectorizer(min_df=2, max_df=0.95)
        tfidf_matrix = vectorizer.fit_transform(corpus)
        feature_names = vectorizer.get_feature_names_out()

        print("\n--- 店舗ごとの特徴語（Tri-gramスコア上位）---\n")
        
        for i, shop_name in enumerate(shop_names):
            print(f"【{shop_name}】")
            row = tfidf_matrix.toarray()[i]
            top_n_indices = row.argsort()[::-1][:7]
            
            for index in top_n_indices:
                if row[index] > 0:
                    # <--- 変更点：見やすいようにアンダースコアを置換 ---
                    display_name = feature_names[index].replace('_', ', ')
                    print(f"  - {display_name} (スコア: {row[index]:.3f})")
            print("-" * 20)
# Out:
# 各店舗の口コミをTri-gramに変換中...
# Tri-gramのTF-IDFスコアを計算中...
#
# --- 店舗ごとの特徴語（Tri-gramスコア上位）---
#
# 【1129 by Ogawa】
#   - デックス, 東京, ビーチ (スコア: 0.286)
#   - 東京, ビーチ, 6 (スコア: 0.279)
#   - 台場, 海浜, 公園 (スコア: 0.194)
#   - ビーチ, 6, 階 (スコア: 0.168)
#   - ハンバーグ, 200, g (スコア: 0.140)
#   - 海浜, 公園, 駅 (スコア: 0.126)
#   - 牛, タン, カレー (スコア: 0.107)
# --------------------
# 【82 築地店】
#   - 築地, 駅, 近く (スコア: 0.197)
#   - メトロ, 日比谷線, 築地 (スコア: 0.186)
#   - 東京, メトロ, 日比谷線 (スコア: 0.183)
#   - 日比谷線, 築地, 駅 (スコア: 0.177)
#   - 東, 銀座, 店 (スコア: 0.152)
#   - 00,  (スコア: 0.148)
#   - 一, 入る, やすい (スコア: 0.124)
# --------------------
# 【ABURI 百貫 有明ガーデン店】
#   - 回転, 寿司, 店 (スコア: 0.255)
#   - ガーデン, 回転, 寿司 (スコア: 0.200)
#   - 回転, 寿司, 屋 (スコア: 0.153)
#   - 有明, ガーデン, 内 (スコア: 0.136)
#   - 有明, ガーデン, 店 (スコア: 0.135)
#   - グルメ, 回転, 寿司 (スコア: 0.100)
#   - 有明, ガーデン, 寿司 (スコア: 0.100)
# --------------------
# 【ARIAKE ARENA CAFE】
#   - 有明, アリーナ, 行く (スコア: 0.274)
#   - ライブ, 有明, アリーナ (スコア: 0.261)
#   - 有明, アリーナ, イベント (スコア: 0.252)
#   - , 2, 日間 (スコア: 0.137)
#   - スチュワート, ライブ (スコア: 0.137)
#   - 暑い, さ, へとへと (スコア: 0.137)
#   - 書く, せる, いただく (スコア: 0.137)
# --------------------
# 【ARIAKE ARENA DINING MOON RIVER】
#   - 考え, 多い, の (スコア: 0.221)
#   - する, 先客, １ (スコア: 0.221)
#   - 列, できる, 混雑 (スコア: 0.221)
#   - 有明, アリーナ, 来る (スコア: 0.221)
#   - 店, 30, 待つ (スコア: 0.221)
#   - 30, 待つ, 広い (スコア: 0.221)
#   - する, 気持ち, いい (スコア: 0.221)
# --------------------
# 【AkeruE】
#   - 場, 駅, 出る (スコア: 0.572)
#   - ピザ,  (スコア: 0.506)
#   - , 700 (スコア: 0.382)
#   - 2, 階, ある (スコア: 0.358)
#   - 展示, 場, 駅 (スコア: 0.282)
#   - 国際, 展示, 場 (スコア: 0.251)
# --------------------
# 【Ariake Miraie】
#   - ディーラー, 中, カフェ (スコア: 0.346)
#   - 併設, する, カフェ (スコア: 0.173)
#   - スペース, 有明, ガーデン (スコア: 0.173)
#   - 近く, ランチ, する (スコア: 0.173)
#   - 内, カフェ, ある (スコア: 0.173)
#   - ある, 子供, 遊ぶ (スコア: 0.173)
#   - できる, 期待, する (スコア: 0.173)
# --------------------
# 【BBQ PLAY GROUND お台場デックス東京ビーチ店】
#   - 公園, 駅, 徒歩 (スコア: 0.196)
#   - 海浜, 公園, 駅 (スコア: 0.170)
#   - , 0 (スコア: 0.165)
#   - , 5 (スコア: 0.155)
#   - , 5,  (スコア: 0.120)
#   - 15,  (スコア: 0.103)
#   - 36,  (スコア: 0.100)
# --------------------
# 【BISTRO うしすけ】
#   - ビス, トロ, うし (スコア: 0.274)
#   - トロ, うし, すける (スコア: 0.274)
#   - 三, 元, 豚 (スコア: 0.236)
#   - うし, すける, さ (スコア: 0.206)
#   - すける, さ, ん (スコア: 0.137)
#   - 台場, 海浜, 公園 (スコア: 0.119)
#   - 焼肉, うし, すける (スコア: 0.103)
# --------------------
# 【BLUE TABLE Odaiba】
#   - 台場, 海浜, 公園 (スコア: 0.231)
#   - 海浜, 公園, 中 (スコア: 0.187)
#   - ラスト, オーダー, 後 (スコア: 0.093)
#   - 綺麗, 夜景, 眺める (スコア: 0.093)
#   - 綺麗, みえる, ロケーション (スコア: 0.093)
#   - サラダ, 台場, 夜 (スコア: 0.093)
#   - ぺてこ, 予約, tel (スコア: 0.093)
# --------------------
# 【Bistro961】
#   - 次回, 夜, する (スコア: 0.117)
#   - 店, ある, 静か (スコア: 0.117)
#   - 階, ビス, トロ (スコア: 0.117)
#   - 散策, 都営, 大江戸 (スコア: 0.117)
#   - 登る, 2, 階 (スコア: 0.117)
#   - しみる, いる, 美味しい (スコア: 0.117)
#   - 勝どき, 方面, 歩く (スコア: 0.117)
# --------------------
# 【Bomb! Dogs】
#   - ソース, つける, 食べる (スコア: 0.433)
#   - 細かい, 刻む, れる (スコア: 0.413)
#   - 合う, いる, 美味しい (スコア: 0.413)
#   - 新規, オープン, する (スコア: 0.336)
#   - ガーデン, 2, 階 (スコア: 0.321)
#   - 有明, ガーデン, 2 (スコア: 0.308)
#   - オープン, する, いる (スコア: 0.304)
# --------------------
# 【Brew33 Bar】
#   - カウンター, 夜景, 見る (スコア: 0.707)
#   - ダブル, ツリー, by (スコア: 0.707)
# --------------------
# 【CAFE TERIA BLUE】
#   - 代わり, 自由, の (スコア: 0.247)
#   - ある, カウンター, 前 (スコア: 0.247)
#   - 台場, 方面, 眺める (スコア: 0.247)
#   - の, 変わる, 感じ (スコア: 0.247)
#   - ナイフ, フォーク, 食べる (スコア: 0.247)
#   - フード, 充実, する (スコア: 0.247)
#   - 日本, 未来, 科学 (スコア: 0.235)
# --------------------
# 【Cha pi】
#   - 二, シェア, する (スコア: 0.156)
#   - 東京, ビーチ, 入る (スコア: 0.156)
#   - 甘い, さ, 良い (スコア: 0.156)
#   - 見える, 美味しい, そう (スコア: 0.156)
#   - 甘い, さ, 氷 (スコア: 0.156)
#   - シーサイド, ３, 階 (スコア: 0.156)
#   - する, 2020, 年 (スコア: 0.156)
# --------------------
# 【Chez コバラヘッタ 有明ガーデン店】
#   - 有明, ガーデン, 内 (スコア: 0.171)
#   - ガーデン, 5, 階 (スコア: 0.142)
#   - 有明, ガーデン, 5 (スコア: 0.139)
#   - ゆり, かもめ, 有明 (スコア: 0.135)
#   - 店, 有明, ガーデン (スコア: 0.134)
#   - 2024,  (スコア: 0.121)
#   - かもめ, 有明, 駅 (スコア: 0.092)
# --------------------
# 【CoCo壱番屋 ワンザ有明店】
#   - カレー, 食べる, なる (スコア: 0.254)
#   - 気温, 29,  (スコア: 0.147)
#   - , カレー, 食べる (スコア: 0.147)
#   - する, 源, ちゃん (スコア: 0.147)
#   - 辛い, さ, 上げる (スコア: 0.147)
#   - 外, 気温, 29 (スコア: 0.147)
#   - 有明, 勤務, 午前 (スコア: 0.147)
# --------------------
# 【Cuore】
#   - 東京, ベイ, サイド (スコア: 0.545)
#   - ホテルトラスティ, 東京, ベイ (スコア: 0.514)
#   - ベイ, コート, 倶楽部 (スコア: 0.181)
#   - , 当時,  (スコア: 0.102)
#   - 当時,  (スコア: 0.099)
#   - , 当時 (スコア: 0.094)
#   - 東京, ベイ, コート (スコア: 0.090)
# --------------------
# 【D-ラウンジ】
#   - ちゃう,  (スコア: 0.237)
#   - 2, 階, ある (スコア: 0.210)
#   - 東京, テレポート, 駅 (スコア: 0.179)
#   - 施設, 東京, ジョイポリス (スコア: 0.176)
#   - 左, 曲がる, 先 (スコア: 0.176)
#   - セルフ, 式, カフェ (スコア: 0.176)
#   - 階, ある, 目 (スコア: 0.176)
# --------------------
# 【DAIBA】
#   - 二, 回, 目 (スコア: 0.308)
#   - 多い, の, ここ (スコア: 0.236)
#   - 仕事, 来る, おる (スコア: 0.236)
#   - 者, 懇親, 会 (スコア: 0.236)
#   - 回, 目, 多い (スコア: 0.236)
#   - 行く, 社員, 食堂 (スコア: 0.236)
#   - 台場, 夢, 大陸 (スコア: 0.236)
# --------------------
# 【DOG DEPT お台場東京ビーチ店】
#   - 開店, 店, する (スコア: 0.536)
#   - １, ５, 年 (スコア: 0.481)
#   - ０, １, ５ (スコア: 0.471)
#   - , いただく (スコア: 0.402)
#   - ２, ０, １ (スコア: 0.312)
# --------------------
# 【DOLCE VITA】
#   - 3, 月, オープン (スコア: 0.274)
#   - , ドルチェ (スコア: 0.222)
#   - イマーシブフォート, 行く, くる (スコア: 0.222)
#   - オープン, する, イマーシブフォート (スコア: 0.211)
#   - 可能,  (スコア: 0.182)
#   - 2024, 年, 3 (スコア: 0.175)
#   - 具合,  (スコア: 0.172)
# --------------------
# 【Deli&Cafe Uran】
#   - 台場, 海浜, 公園 (スコア: 0.265)
#   - 海浜, 公園, 駅 (スコア: 0.202)
#   - , デミグラスソース,  (スコア: 0.179)
#   - , 平日, ランチタイム (スコア: 0.179)
#   - 海浜, 公園, 行く (スコア: 0.179)
#   - 絶対, 食べる, 方 (スコア: 0.179)
#   - 賃貸, 住宅, 下 (スコア: 0.179)
# --------------------
# 【Domino's Pizza  ARIAKE GARDEN】
#   - 向かい, 有明, ガーデン (スコア: 0.276)
#   - ガーデン, シアター, 開催 (スコア: 0.276)
#   - シアター, 開催, する (スコア: 0.276)
#   - ガーデン, 店, フード (スコア: 0.276)
#   - オーダー, する, 有明 (スコア: 0.263)
#   - フード, コート, 到着 (スコア: 0.263)
#   - 20, 頃, フード (スコア: 0.263)
# --------------------
# 【Eat it! 東京ビッグサイト店】
#   - 東京, ビッグ, サイト (スコア: 0.403)
#   - 国際, 展示, 場 (スコア: 0.155)
#   - , 東京, ビッグ (スコア: 0.138)
#   - 棟, フード, コート (スコア: 0.118)
#   - it,  (スコア: 0.110)
#   - eat, it,  (スコア: 0.110)
#   - ビッグ, サイト, 西 (スコア: 0.104)
# --------------------
# 【FARMS' KITCHEN MIKIKE TOKYO ODAIBA】
#   - ん, 感動, する (スコア: 0.246)
#   - 店, 窓, 景色 (スコア: 0.246)
#   - ランチ, コース, 店 (スコア: 0.246)
#   - もらう, ランチタイム, 終わる (スコア: 0.246)
#   - 美味しい, 見た目, 美しい (スコア: 0.246)
#   - ランチタイム, 終わる, ギリギリ (スコア: 0.246)
#   - 素材, 良い, 美味しい (スコア: 0.235)
# --------------------
# 【GODIVA アクアシティお台場店】
#   - godiva,  (スコア: 0.374)
#   - , 購入 (スコア: 0.188)
#   - 台場, 遊び, 来る (スコア: 0.174)
#   - , ダーク, チョコレート (スコア: 0.125)
#   - 3, f, godiva (スコア: 0.125)
#   - なる, いる, アクアシティ (スコア: 0.125)
#   - する, 感激, する (スコア: 0.125)
# --------------------
# 【GODIVA ダイバーシティ東京プラザ店】
#   - ダイバー, シティ, 東京 (スコア: 0.337)
#   - シティ, 東京, プラザ (スコア: 0.269)
#   - , ショコリキサー (スコア: 0.222)
#   - ダイバー, シティ, する (スコア: 0.197)
#   - godiva, ダーク, チョコレート (スコア: 0.148)
#   - 発売, する, れる (スコア: 0.148)
#   - ある, ダイバー, シティ (スコア: 0.117)
# --------------------
# 【GOKUGOKU 有明ガーデン店】
#   - 完熟, バナナ, ミルク (スコア: 0.284)
#   - l, サイズ, 選べる (スコア: 0.142)
#   - コロシアム, 行く, 帰り (スコア: 0.142)
#   - 甘い, さ, 酸味 (スコア: 0.142)
#   - 美味しい, そう, 寄る (スコア: 0.142)
#   - め, く, ちる (スコア: 0.142)
#   - さ, 酸味, バランス (スコア: 0.142)
# --------------------
# 【GREAT STEAK】
#   - 店, ある, する (スコア: 0.365)
#   - ある, する, みる (スコア: 0.348)
#   - 抜,  (スコア: 0.325)
#   - 税, 抜,  (スコア: 0.325)
#   - フード, コート, 見る (スコア: 0.316)
#   - , 1280 (スコア: 0.316)
#   - ブザー, 渡す, れる (スコア: 0.308)
# --------------------
# 【GUNDAM Café　キッチンカー】
#   - 販売, する, れる (スコア: 0.887)
#   - する, れる, いる (スコア: 0.461)
# --------------------
# 【Green×Green】
#   - 台場, フード, コート (スコア: 0.394)
#   - green,  (スコア: 0.265)
#   - , green (スコア: 0.265)
#   - アクアシティ, 台場, フード (スコア: 0.218)
#   - する, 安い, の (スコア: 0.133)
#   - 専門, 店, 波 (スコア: 0.133)
#   - 店, する, 安い (スコア: 0.133)
# --------------------
# 【H.B.GRILL】
#   - h,  (スコア: 0.478)
#   - , b (スコア: 0.362)
#   - , b,  (スコア: 0.340)
#   - , grill (スコア: 0.322)
#   - b,  (スコア: 0.306)
#   - 街, 海, 側 (スコア: 0.072)
#   - 本日, 紹介, する (スコア: 0.072)
# --------------------
# 【HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店】
#   - ダイバー, シティ, 東京 (スコア: 0.354)
#   - シティ, 東京, プラザ (スコア: 0.209)
#   - 商業, 施設, ダイバー (スコア: 0.175)
#   - 施設, ダイバー, シティ (スコア: 0.167)
#   - , 甘い (スコア: 0.146)
#   - 東京, 2, f (スコア: 0.132)
#   - シティ, 東京, 2 (スコア: 0.127)
# --------------------
# 【HIRO ダイバーシティ東京店】
#   - ダイバー, シティ, 東京 (スコア: 0.225)
#   - , ハンバーグ (スコア: 0.205)
#   - g,  (スコア: 0.161)
#   - , ライス (スコア: 0.117)
#   - シティ, 6, 階 (スコア: 0.106)
#   - 台場, ダイバー, シティ (スコア: 0.105)
#   - ダイバー, シティ, 6 (スコア: 0.104)
# --------------------
# 【HUNZA】
#   - 葛西, 駅, 徒歩 (スコア: 0.248)
#   - ビリ, ヤニ, 食べる (スコア: 0.234)
#   - インド, カレー, 屋 (スコア: 0.169)
#   - インド, カレー, 店 (スコア: 0.143)
#   - , 葛西 (スコア: 0.131)
#   - 東西線, 葛西, 駅 (スコア: 0.123)
#   - カレー, 2, 種 (スコア: 0.119)
# --------------------
# 【Hobson’s アクアシティお台場】
#   - hobson,  (スコア: 0.232)
#   - , ホブソンズ (スコア: 0.155)
#   - , s (スコア: 0.148)
#   - 食べる, なる, フード (スコア: 0.142)
#   - アクアシティ, 1, 階 (スコア: 0.142)
#   - なる, フード, コート (スコア: 0.127)
#   - アクアシティ, フード, コート (スコア: 0.122)
# --------------------
# 【KING OF THE PIRATES】
#   - オブ (スコア: 0.323)
#   - レインボー, ブリッジ, 見える (スコア: 0.175)
#   - アクアシティ, 台場, 5 (スコア: 0.160)
#   - 台場, 5, 階 (スコア: 0.120)
#   - 飲む, 放題, 付き (スコア: 0.094)
#   - 予約, する, 来店 (スコア: 0.089)
#   - パ, エリア, 美味しい (スコア: 0.077)
# --------------------
# 【L'Agréable Esprit de GAMIN】
#   - l,  (スコア: 0.185)
#   - 伺い, する, の (スコア: 0.183)
#   - 門前仲町, 駅, 徒歩 (スコア: 0.144)
#   - トマト, 冷, 製 (スコア: 0.123)
#   - 訪,  (スコア: 0.123)
#   - 振り, 伺い, する (スコア: 0.123)
#   - ﾟ,  (スコア: 0.122)
# --------------------
# 【LAWSON Tokyoビッグベイ店】
#   - ガーリック,  (スコア: 0.549)
#   - 2, 月, 14 (スコア: 0.504)
#   - , 黒 (スコア: 0.504)
#   - ステーキ,  (スコア: 0.435)
# --------------------
# 【LAWSON お台場店】
#   - , 禁断 (スコア: 0.292)
#   - ー,  (スコア: 0.183)
#   - 東京, テレポート, 駅 (スコア: 0.162)
#   - チェーン, 店,  (スコア: 0.159)
#   - 抜ける, 右, エスカレーター (スコア: 0.159)
#   - 隊,  (スコア: 0.159)
#   - 先, コンビニエンスストア, チェーン (スコア: 0.159)
# --------------------
# 【LAWSON しののめ店】
#   - 1, 月, 31 (スコア: 0.490)
#   - 東雲, 駅, 豊洲 (スコア: 0.490)
#   - 2023, 年, 1 (スコア: 0.467)
#   - ガ, テン, 系 (スコア: 0.467)
#   - 年, 1, 月 (スコア: 0.290)
# --------------------
# 【LAWSON りんかい線東雲駅店】
#   - 茨城, 県, 産 (スコア: 0.724)
#   - する, 食, 楽しめる (スコア: 0.690)
# --------------------
# 【LAWSON アクアシティお台場】
#   - ー,  (スコア: 0.213)
#   - 場, ヒルトン, 台場 (スコア: 0.185)
#   - 後, 甘い, 欲しい (スコア: 0.185)
#   - 近, 場, ヒルトン (スコア: 0.185)
#   - アクアシティ, 台場, できる (スコア: 0.185)
#   - 夕食, 後, 甘い (スコア: 0.185)
#   - お盆, 休み, 遠出 (スコア: 0.176)
# --------------------
# 【LAWSON フジテレビ店】
#   - 8, 月, 台場 (スコア: 0.492)
#   - 台場, 観光, する (スコア: 0.246)
#   - 3, 月, 8 (スコア: 0.246)
#   - , ３, １ (スコア: 0.246)
#   - , 軽い, 思う (スコア: 0.246)
#   - １, ０,  (スコア: 0.246)
#   - 台場, 夢, 大陸 (スコア: 0.246)
# --------------------
# 【LAWSON ポートストア有明】
#   - 財団, 法人, 東京 (スコア: 0.385)
#   - 法人, 東京, 港湾 (スコア: 0.385)
#   - 一般, 財団, 法人 (スコア: 0.385)
#   - 有明, サービス, センター (スコア: 0.385)
#   - 港湾, 福利, 厚生 (スコア: 0.368)
#   - 福利, 厚生, 協会 (スコア: 0.368)
#   - 東京, 港湾, 福利 (スコア: 0.368)
# --------------------
# 【LAWSON 国際展示場駅前店】
#   - 国際, 展示, 場 (スコア: 0.305)
#   - 展示, 場, 駅 (スコア: 0.229)
#   - , 国際 (スコア: 0.189)
#   - 展示, 場, 駅前 (スコア: 0.189)
#   - , 国際, 展示 (スコア: 0.189)
#   - , t,  (スコア: 0.181)
#   - t,  (スコア: 0.174)
# --------------------
# 【LAWSON 有明コロシアム前店】
#   - 駐車, 場, 広い (スコア: 0.634)
#   - , 地元 (スコア: 0.575)
#   - ラッキー,  (スコア: 0.517)
# --------------------
# 【LAWSON 有明セントラルタワー店】
#   - どっち,  (スコア: 0.373)
#   - マヨ,  (スコア: 0.373)
#   - 有明, セントラルタワー, 1 (スコア: 0.373)
#   - 無い, 見つける, の (スコア: 0.373)
#   - かな,  (スコア: 0.332)
#   - 1, 階, 入る (スコア: 0.332)
#   - , パン (スコア: 0.315)
# --------------------
# 【LAWSON 東京テレポート駅前店】
#   - 江東, 区, 店 (スコア: 0.527)
#   - する, 店名, 変更 (スコア: 0.527)
#   - オープン, する, おる (スコア: 0.527)
#   - 新規, オープン, する (スコア: 0.410)
# --------------------
# 【LAWSON 東京ビッグサイトエントランス】
#   - 東京, ビッグ, サイト (スコア: 0.296)
#   - 狭い, の, 難点 (スコア: 0.166)
#   - テーブル, ある, ランチ (スコア: 0.166)
#   - , ビックリ, する (スコア: 0.166)
#   - , ビックリ (スコア: 0.166)
#   - 為, 久しぶり, 東京 (スコア: 0.166)
#   - の, 取引, 先 (スコア: 0.166)
# --------------------
# 【LAWSON 東雲一丁目店】
#   - ７, 年, 以上 (スコア: 0.425)
#   - 東雲, 一, 丁目 (スコア: 0.425)
#   - 47,  (スコア: 0.425)
#   - 食べる, ログ, コメント (スコア: 0.406)
#   - 2, 月, 7 (スコア: 0.406)
#   - マンション, 一, 階 (スコア: 0.358)
# --------------------
# 【LAWSON 相鉄グランドフレッサ有明店】
#   - 2, 階, 位置 (スコア: 0.442)
#   - グランドフレッサ, 東京, ベイ (スコア: 0.422)
#   - 相鉄, グランドフレッサ, 東京 (スコア: 0.422)
#   - 有明, 2, 階 (スコア: 0.393)
#   - ホテル, 2, 階 (スコア: 0.357)
#   - 東京, ベイ, 有明 (スコア: 0.319)
#   - 充実, する, いる (スコア: 0.257)
# --------------------
# 【LAWSON Ｈ台場駅前店】
#   - 店名, 頭文字, h (スコア: 0.318)
#   - ググ, 出自, 示す (スコア: 0.318)
#   - 頭文字, h, なる (スコア: 0.318)
#   - h, なる, ググ (スコア: 0.318)
#   - ２, 軒, １つ (スコア: 0.318)
#   - なる, ググ, 出自 (スコア: 0.318)
#   - 出自, 示す, 推測 (スコア: 0.318)
# --------------------
# 【Louis Hamburger Restaurant】
#   - バーガー, 専門, 店 (スコア: 0.402)
#   - 紹介, する, れる (スコア: 0.171)
#   - 東陽町, 駅, 徒歩 (スコア: 0.166)
#   - 2022, 年, 11 (スコア: 0.163)
#   - マツコ, 知る, 世界 (スコア: 0.147)
#   - ハンバーガー, 専門, 店 (スコア: 0.109)
#   - 駅, 4, 番 (スコア: 0.109)
# --------------------
# 【MOMI&TOY'S 有明ガーデン店】
#   - 有明, ガーデン, 寄る (スコア: 0.174)
#   - 甘い, 食べる, なる (スコア: 0.153)
#   - 有明, ガーデン, 店 (スコア: 0.110)
#   - フード, コート, 内 (スコア: 0.105)
#   - 00, 頃, 大人 (スコア: 0.095)
#   - 後, 一息, つく (スコア: 0.095)
#   - 枚, 1, 枚 (スコア: 0.095)
# --------------------
# 【MONPAL 8】
#   - 2, 軒, 目 (スコア: 0.159)
#   - 飲む, 放題, コース (スコア: 0.148)
#   - , 638 (スコア: 0.125)
#   - れる, 出る, くる (スコア: 0.119)
#   - 飲む, 放題, アラカルト (スコア: 0.119)
#   - ここ, 日本, 酒 (スコア: 0.119)
#   - 飲む, 放題, 付き (スコア: 0.109)
# --------------------
# 【N．Y．Kカフェ お台場・デックス東京ビーチ】
#   - 甘い, 食べる, なる (スコア: 0.356)
#   - 入る, 右側, ある (スコア: 0.220)
#   - 香り, 誘う, れる (スコア: 0.220)
#   - , 他, お客 (スコア: 0.220)
#   - , y,  (スコア: 0.220)
#   - 16, 午後, 夫 (スコア: 0.220)
#   - , y (スコア: 0.220)
# --------------------
# 【OEDO ARIAKE STYLE】
#   - 2, 階, フード (スコア: 0.319)
#   - いる, なる, 寿司 (スコア: 0.280)
#   - 丼, 専門, 店 (スコア: 0.271)
#   - 階, フード, コート (スコア: 0.234)
#   - ガーデン, 2, 階 (スコア: 0.226)
#   - 有明, ガーデン, 2 (スコア: 0.218)
#   - 有明, ガーデン, 内 (スコア: 0.177)
# --------------------
# 【OSMIC DISH】
#   - 220,  (スコア: 0.228)
#   - , 220,  (スコア: 0.228)
#   - , 220 (スコア: 0.203)
#   - , 1100,  (スコア: 0.188)
#   - 1100,  (スコア: 0.178)
#   - , 1100 (スコア: 0.157)
#   - 側, レインボー, ブリッジ (スコア: 0.114)
# --------------------
# 【Ozgur Kitchen Kebab】
#   - 東京, ビーチ, アイランドモール (スコア: 0.498)
#   - 徒歩, 4, 東京 (スコア: 0.457)
#   - かもめ, 台場, 海浜 (スコア: 0.375)
#   - 公園, 駅, 徒歩 (スコア: 0.326)
#   - 駅, 徒歩, 4 (スコア: 0.291)
#   - 海浜, 公園, 駅 (スコア: 0.282)
#   - ゆり, かもめ, 台場 (スコア: 0.267)
# --------------------
# 【PATISSERIE L11S】
#   - いる, ケーキ, 美味しい (スコア: 0.417)
#   - 一, 階, カフェ (スコア: 0.417)
#   - カフェ, なる, いる (スコア: 0.417)
#   - なる, いる, ケーキ (スコア: 0.417)
#   - マンション, 一, 階 (スコア: 0.351)
#   - , 広い (スコア: 0.324)
#   - する, せる, もらう (スコア: 0.227)
# --------------------
# 【PERFECT BEER STAND MONNAKA】
#   - 門前仲町, 駅, 徒歩 (スコア: 0.307)
#   - 1, 軒, 目 (スコア: 0.209)
#   - 19,  (スコア: 0.132)
#   - 店, 階段, 上がる (スコア: 0.132)
#   - 評価, 以下, 通り (スコア: 0.132)
#   - 感じる, 雰, 囲 (スコア: 0.132)
#   - , 24,  (スコア: 0.132)
# --------------------
# 【PHO365】
#   - フォー, 専門, 店 (スコア: 0.491)
#   - 葛西, 麺類, 探訪 (スコア: 0.301)
#   - フォー (スコア: 0.301)
#   - ガー (スコア: 0.164)
#   - 生, 春巻き, セット (スコア: 0.164)
#   - フォー, 春巻き, セット (スコア: 0.164)
#   - フォー,  (スコア: 0.150)
# --------------------
# 【PIZZA SALVATORE CUOMO 豊洲】
#   - , サラダ (スコア: 0.130)
#   - , ピザ (スコア: 0.115)
#   - 豊洲, 駅, 徒歩 (スコア: 0.109)
#   - , ﾟ (スコア: 0.108)
#   - ピザ,  (スコア: 0.106)
#   - , ﾟ,  (スコア: 0.099)
#   - 1, f, 入る (スコア: 0.084)
# --------------------
# 【PIZZA&WINE カヤバール 有明ガーデン店】
#   - 有明, ガーデン, 店 (スコア: 0.176)
#   - , ピザ (スコア: 0.140)
#   - 店, 有明, ガーデン (スコア: 0.123)
#   - 有明, ガーデン, 内 (スコア: 0.118)
#   - 友達, 連れる, いく (スコア: 0.102)
#   - いる, 味, 薄い (スコア: 0.102)
#   - 良い, 有明, ガーデン (スコア: 0.097)
# --------------------
# 【PLANT LOVE】
#   - ２, 年, ２月 (スコア: 0.274)
#   - ない, 最初, 最後 (スコア: 0.274)
#   - 待ち, 待ち, ない (スコア: 0.274)
#   - 来る, 待ち, 待ち (スコア: 0.274)
#   - １, ０, 東京 (スコア: 0.274)
#   - ０, 東京, 都 (スコア: 0.274)
#   - 投稿, する, いる (スコア: 0.262)
# --------------------
# 【Pacific PICKLE CLUB】
#   - する, いる, うち (スコア: 0.194)
#   - れる, おる, アルコール (スコア: 0.194)
#   - お茶, 楽しむ, できる (スコア: 0.194)
#   - できる, タコ, ライス (スコア: 0.194)
#   - new, open,  (スコア: 0.194)
#   - 店, 有明, テニス (スコア: 0.194)
#   - の, ワン, ちゃん (スコア: 0.194)
# --------------------
# 【R's Cafe】
#   - 紙, タバコ, 吸える (スコア: 0.287)
#   - 最後, 1, 杯 (スコア: 0.287)
#   - , バー,  (スコア: 0.287)
#   - 落ち着く, 飲める, 店 (スコア: 0.287)
#   - 3, 次, 会 (スコア: 0.274)
#   - , バー (スコア: 0.248)
#   - 唐, 揚げ, 食べる (スコア: 0.242)
# --------------------
# 【RESTAURANT WHITE ART】
#   - ランチ, いただく, くる (スコア: 0.846)
#   - 有明, テニス, 森 (スコア: 0.534)
# --------------------
# 【RIN&GOカレー 東京有明セントラルタワー店】
#   - 好み, 味, なる (スコア: 0.707)
#   - カツ, カレー, いただく (スコア: 0.707)
# --------------------
# 【RISTORANTE OZIO】
#   - 東京, ベイ, コート (スコア: 0.668)
#   - ベイ, コート, 倶楽部 (スコア: 0.505)
#   - コート, 倶楽部, ホテル (スコア: 0.120)
#   - ベイ, コート, クラブ (スコア: 0.108)
#   - ベイ, コート, 中 (スコア: 0.083)
#   - コート, 倶楽部, 内 (スコア: 0.083)
#   - 会員, 制, ホテル (スコア: 0.077)
# --------------------
# 【SAUS】
#   - ダブル, ツリー, by (スコア: 0.410)
#   - 国際, 展示, 場 (スコア: 0.172)
#   - , 1,  (スコア: 0.157)
#   - ビッグ, サイト, 有明 (スコア: 0.137)
#   - ガーデン, ランチ, する (スコア: 0.137)
#   - つく, くる, 食べる (スコア: 0.137)
#   - 昨年, 12, 月 (スコア: 0.137)
# --------------------
# 【SONAE CAFE】
#   - 広域, 防災, 公園 (スコア: 0.380)
#   - 防災, 公園, そ (スコア: 0.380)
#   - 公園, そ, エリア (スコア: 0.380)
#   - 東京, 臨海, 広域 (スコア: 0.380)
#   - 臨海, 広域, 防災 (スコア: 0.380)
#   - そ, エリア, 東京 (スコア: 0.253)
#   - 国営, 東京, 臨海 (スコア: 0.253)
# --------------------
# 【STONE FACTORY Jr.】
#   - 国産, 牛, ステーキ (スコア: 0.526)
#   - u, x, u (スコア: 0.175)
#   - する, 目, 留まる (スコア: 0.175)
#   - ３, 夕食, 食べる (スコア: 0.175)
#   - そう, 思う, 食べる (スコア: 0.175)
#   - 分かる, 石, 焼 (スコア: 0.175)
#   - 邪魔, する, 目 (スコア: 0.175)
# --------------------
# 【SWITCH STAND ODAIBA】
#   - 良い, さ, ある (スコア: 0.357)
#   - 優しい, 丁寧, 説明 (スコア: 0.357)
#   - ランチ, パスタ, カレー (スコア: 0.357)
#   - 違う, 良い, さ (スコア: 0.341)
#   - 何, 回, かわり (スコア: 0.328)
#   - 回, かわり, する (スコア: 0.318)
#   - かわり, する, しまう (スコア: 0.301)
# --------------------
# 【Seaside Café SOLARIS】
#   - 水上, バス, 乗り場 (スコア: 0.391)
#   - 公園, 水上, バス (スコア: 0.293)
#   - 海浜, 公園, 水上 (スコア: 0.293)
#   - 台場, 海浜, 公園 (スコア: 0.290)
#   - なる, 天気, 晴 (スコア: 0.098)
#   - 頼む, どく, 港 (スコア: 0.098)
#   - 月, 休日, 昼食 (スコア: 0.098)
# --------------------
# 【Sky Restaurant シーガル】
#   - , 3,  (スコア: 0.344)
#   - タイム, 24, ビル (スコア: 0.332)
#   - , 3 (スコア: 0.330)
#   - , 1, 点 (スコア: 0.261)
#   - 3,  (スコア: 0.234)
#   - , 3, 点 (スコア: 0.166)
#   - 舞, 茸, 天ぷら (スコア: 0.155)
# --------------------
# 【TGI FRIDAYS 有明ガーデン店】
#   - 目, 前, 作る (スコア: 0.118)
#   - 有明, ガーデン, 内 (スコア: 0.103)
#   - 有明, ガーデン, 店 (スコア: 0.102)
#   - 有明, ガーデン, ディナー (スコア: 0.089)
#   - , フライデーズ (スコア: 0.089)
#   - かわり, できる, の (スコア: 0.089)
#   - 2,  (スコア: 0.084)
# --------------------
# 【TGIフライデーズ お台場アクアシティ店】
#   - , i (スコア: 0.150)
#   - レインボー, ブリッジ, 見える (スコア: 0.119)
#   - g,  (スコア: 0.110)
#   - t,  (スコア: 0.107)
#   - i,  (スコア: 0.096)
#   - , g (スコア: 0.096)
#   - 土曜日, 予約, する (スコア: 0.096)
# --------------------
# 【THE BBQ BEACH in AQUA CITY ODAIBA】
#   - 綺麗, 居心地, 良い (スコア: 0.189)
#   - 台場, 駅, 1 (スコア: 0.189)
#   - 辿る, 着ける, 店 (スコア: 0.189)
#   - , 1, か月 (スコア: 0.189)
#   - 女神, 像, 見える (スコア: 0.189)
#   - 外, 中, ジューシー (スコア: 0.189)
#   - 台場, 素敵, 景色 (スコア: 0.189)
# --------------------
# 【THEキャラCAFE お台場デックス店】
# --------------------
# 【The Cabaret】
#   - フォート (スコア: 0.506)
#   - イマーシブ (スコア: 0.490)
#   - フォート, 東京 (スコア: 0.382)
#   - フォート, 東京, 中 (スコア: 0.150)
#   - 2024, 年, 3 (スコア: 0.119)
#   - 没入, 体験, テーマパーク (スコア: 0.100)
#   - 完全, 没入, 体験 (スコア: 0.100)
# --------------------
# 【The Grill on 30th】
#   - グランド, ニッコー, 東京 (スコア: 0.432)
#   - ニッコー, 東京, 台場 (スコア: 0.399)
#   - the, grill, on (スコア: 0.265)
#   - grill, on, 30 (スコア: 0.265)
#   - on, 30, th (スコア: 0.265)
#   - 台場, 30, 階 (スコア: 0.196)
#   - 東京, 台場, 30 (スコア: 0.162)
# --------------------
# 【The Lobby Cafe】
#   - グランド, ニッコー, 東京 (スコア: 0.501)
#   - ニッコー, 東京, 台場 (スコア: 0.401)
#   - the, lobby, cafe (スコア: 0.266)
#   - 台場, グランド, ニッコー (スコア: 0.137)
#   - アフタヌーン, ティー, 行く (スコア: 0.122)
#   - , グランド (スコア: 0.115)
#   - , グランド, ニッコー (スコア: 0.115)
# --------------------
# 【Tokyo 串家】
#   - 台場, フロンティア, ビル (スコア: 0.276)
#   - 丼, タレ, 甘い (スコア: 0.193)
#   - 1,  (スコア: 0.164)
#   - タレ, 甘い, め (スコア: 0.162)
#   - ランチ, 1,  (スコア: 0.134)
#   - , 300 (スコア: 0.109)
#   - 商業, フロア, ある (スコア: 0.096)
# --------------------
# 【Trattoria&Pizzeria LOGIC お台場】
#   - ピザ, 生地, モチ (スコア: 0.129)
#   - デックス, 東京, ビーチ (スコア: 0.128)
#   - ビーチ, 3, 階 (スコア: 0.124)
#   - 生地, モチ, モチ (スコア: 0.124)
#   - サラダ, バー, バー (スコア: 0.124)
#   - , ピザ (スコア: 0.124)
#   - 東京, ビーチ, 3 (スコア: 0.120)
# --------------------
# 【WAGYU USHITOMI GINZA】
#   - 新富, 町, 駅 (スコア: 0.374)
#   - 2022, 年, 6 (スコア: 0.232)
#   - 麻布, 十, 番 (スコア: 0.200)
#   - , 黒毛 (スコア: 0.194)
#   - , 黒毛, 和牛 (スコア: 0.194)
#   - 6, 月, オープン (スコア: 0.179)
#   - タン, ハラ, ミ (スコア: 0.179)
# --------------------
# 【WINESTAND TEO】
#   - 清澄, 白河, 駅 (スコア: 0.274)
#   - 2, 軒, 目 (スコア: 0.174)
#   - れる, ワイン, 提供 (スコア: 0.137)
#   - 半額, グラス, ワイン (スコア: 0.137)
#   - 飲む, やすい, ワイン (スコア: 0.137)
#   - 週末,  (スコア: 0.137)
#   - 店, オレンジ, ワイン (スコア: 0.137)
# --------------------
# 【WOOD DESIGN PARK お台場店】
#   - 食器, 用意, する (スコア: 0.430)
#   - する, てる, すごい (スコア: 0.430)
#   - できる, 子供, 用 (スコア: 0.430)
#   - 過ごす, できる, 行く (スコア: 0.430)
#   - 用意, する, いただく (スコア: 0.362)
#   - アルコール, 飲む, 放題 (スコア: 0.362)
# --------------------
# 【YORIMICHI Odaiba】
#   - レインボー, ブリッジ, 一望 (スコア: 0.154)
#   - アフタヌーン, ティー, 食べる (スコア: 0.140)
#   - アフタヌーン, ティー,  (スコア: 0.134)
#   - する, 台場, 景色 (スコア: 0.134)
#   - 方, 対応, 良い (スコア: 0.124)
#   - ティー,  (スコア: 0.121)
#   - 目, 前, 広がる (スコア: 0.121)
# --------------------
# 【Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉】
#   - 焼肉, 激戦, 区 (スコア: 0.327)
#   - 厚, 切り, タン (スコア: 0.236)
#   - 激戦, 区, 月島 (スコア: 0.178)
#   - 一, 枚, 頼める (スコア: 0.140)
#   - 月島, 焼肉, 店 (スコア: 0.134)
#   - オープン, する, 焼肉 (スコア: 0.134)
#   - 月島, 駅, 徒歩 (スコア: 0.121)
# --------------------
# 【bills お台場】
#   - デックス, 東京, ビーチ (スコア: 0.151)
#   - パンケーキ, 食べる, なる (スコア: 0.136)
#   - , 00 (スコア: 0.119)
#   - 台場, 海浜, 公園 (スコア: 0.101)
#   - レインボー, ブリッジ, 見える (スコア: 0.097)
#   - , パンケーキ (スコア: 0.091)
#   - 練る, 込む, れる (スコア: 0.082)
# --------------------
# 【creperie kenny's ダイバーシティ店】
#   - バナナ, チョコ, 生クリーム (スコア: 0.359)
#   - ダイバー, シティ, 店 (スコア: 0.267)
#   - , s (スコア: 0.229)
#   - 使用, する, 自家製 (スコア: 0.180)
#   - シティ, 東京, プラザ (スコア: 0.163)
#   - ダイバー, シティ, 東京 (スコア: 0.153)
#   - 東京, プラザ, 2 (スコア: 0.148)
# --------------------
# 【da pai dang 105 有明ガーデン店】
#   - 焼く, 小籠, 包 (スコア: 0.452)
#   - 小籠, 包, セット (スコア: 0.308)
#   - 焼き, 小籠, 包 (スコア: 0.194)
#   - 2, 階, フード (スコア: 0.180)
#   - 階, フード, コート (スコア: 0.165)
#   - フード, コート, 内 (スコア: 0.143)
#   - 小籠, 包, 店 (スコア: 0.129)
# --------------------
# 【mal D'amour】
#   - 東京, ベイ, コート (スコア: 0.648)
#   - ベイ, コート, 倶楽部 (スコア: 0.480)
#   - , amour (スコア: 0.152)
#   - コート, 倶楽部, 24 (スコア: 0.145)
#   - 倶楽部, 24, 階 (スコア: 0.116)
#   - 会員, 制, リゾート (スコア: 0.105)
#   - ベイ, コート, クラブ (スコア: 0.100)
# --------------------
# 【milky70 since1951 アクアシティお台場店】
#   - , ミルキー (スコア: 0.261)
#   - 気付く,  (スコア: 0.261)
#   - 相性, 良い, 美味しい (スコア: 0.226)
#   - アクアシティ, フード, コート (スコア: 0.207)
#   - アクアシティ, 台場, 店 (スコア: 0.158)
#   - フード, コート, 内 (スコア: 0.144)
#   - 店舗, アクアシティ, 台場 (スコア: 0.131)
# --------------------
# 【mode super smoothie】
#   - できる, 有明, アーバンスポーツパーク (スコア: 0.491)
#   - できる, する, せる (スコア: 0.491)
#   - 新しい, できる, 有明 (スコア: 0.451)
#   - 体, 良い, さ (スコア: 0.437)
#   - する, せる, もらう (スコア: 0.268)
#   - 良い, さ, そう (スコア: 0.226)
# --------------------
# 【root C 日本科学未来館 5Fロビー】
#   - ある, ここ, する (スコア: 0.629)
#   - 応え, ある, 美味しい (スコア: 0.518)
#   - 日本, 科学, 来館 (スコア: 0.466)
#   - 食べる, 応え, ある (スコア: 0.345)
# --------------------
# 【the BAR】
#   - 良い, 窓, 大きい (スコア: 0.314)
#   - ある, ん,  (スコア: 0.314)
#   - プレ, オープン, オープン (スコア: 0.314)
#   - 見える, 景色, 良い (スコア: 0.314)
#   - 座る, いる, 外 (スコア: 0.314)
#   - , 2010, 年 (スコア: 0.314)
#   - , 2010 (スコア: 0.300)
# --------------------
# 【the open bakery】
#   - 台場, 海浜, 公園 (スコア: 0.347)
#   - 海浜, 公園, 駅 (スコア: 0.213)
#   - 公園, 駅, 徒歩 (スコア: 0.141)
#   - 賃貸, 住宅, １ (スコア: 0.108)
#   - パン, ハード, 系 (スコア: 0.108)
#   - セット, サラダ, スープ (スコア: 0.103)
#   - , 台場 (スコア: 0.095)
# --------------------
# 【あのり】
#   - 台場, 海浜, 公園 (スコア: 0.352)
#   - レインボー, ブリッジ, 徒歩 (スコア: 0.237)
#   - 値段, 手頃, 酒 (スコア: 0.237)
#   - いい, 店, ん (スコア: 0.237)
#   - する, いる, 刺身 (スコア: 0.237)
#   - 台場, 入る, やすい (スコア: 0.237)
#   - 買い物, 帰り, 台場 (スコア: 0.237)
# --------------------
# 【あばら大根 西葛西店】
#   - 西葛西, 駅, 徒歩 (スコア: 0.158)
#   - いらっしゃる,  (スコア: 0.128)
#   - 美味しい, アジ, フライ (スコア: 0.122)
#   - する, どれ, 美味しい (スコア: 0.094)
#   - コス, パ, よい (スコア: 0.081)
#   - 高い, どれ, おいしい (スコア: 0.064)
#   - ５, ２, ０ (スコア: 0.064)
# --------------------
# 【いろり庵 きらく 国際展示場駅店】
#   - 国際, 展示, 場 (スコア: 0.313)
#   - 展示, 場, 駅 (スコア: 0.313)
#   - 立ち, 食い, そば (スコア: 0.278)
#   - 立ち, 食い, 蕎麦 (スコア: 0.222)
#   - 食い, 蕎麦, 屋 (スコア: 0.208)
#   - 東京, ビッグ, サイト (スコア: 0.186)
#   - 番号, 呼ぶ, れる (スコア: 0.165)
# --------------------
# 【うなぎ 明月川 豊洲店】
#   - 豊洲, 千客万来, 2 (スコア: 0.164)
#   - てる, 豊洲, 市場 (スコア: 0.157)
#   - 食べる, 歩き, する (スコア: 0.146)
#   - する, れる,  (スコア: 0.119)
#   - 焼き,  (スコア: 0.114)
#   - , 300 (スコア: 0.093)
#   - 2024,  (スコア: 0.090)
# --------------------
# 【おいらんち 葛西駅前店】
#   - , 鮮度 (スコア: 0.211)
#   - , 葛西, 駅 (スコア: 0.202)
#   - , 葛西 (スコア: 0.178)
#   - 葛西, 駅, 徒歩 (スコア: 0.157)
#   - 飲む, 会, する (スコア: 0.153)
#   - 伺い, する, せる (スコア: 0.151)
#   - 何, 度, する (スコア: 0.117)
# --------------------
# 【おぼんdeごはん ダイバーシティ東京プラザ店】
#   - ぼん, de, ごはん (スコア: 0.335)
#   - びん, ちょう, まぐろ (スコア: 0.251)
#   - ごはん, 味噌汁, かわり (スコア: 0.240)
#   - , 定食 (スコア: 0.167)
#   - 味噌汁, かわり, 自由 (スコア: 0.141)
#   - , 来店 (スコア: 0.130)
#   - シティ, 東京, プラザ (スコア: 0.101)
# --------------------
# 【お食事処 ゆき】
#   - 台場, 海浜, 公園 (スコア: 0.331)
#   - 海浜, 公園, 駅 (スコア: 0.275)
#   - 生姜, 焼き, 定食 (スコア: 0.250)
#   - かもめ, 台場, 海浜 (スコア: 0.183)
#   - 定食, 食べる, られる (スコア: 0.154)
#   - ゆり, かもめ, 台場 (スコア: 0.130)
#   - お願い, する, 10 (スコア: 0.122)
# --------------------
# 【かつゑもん ダイバーシティ東京プラザ】
#   - ダイバー, シティ, 東京 (スコア: 0.340)
#   - シティ, 東京, プラザ (スコア: 0.271)
#   - 三, 元, 豚 (スコア: 0.171)
#   - 東京, プラザ, フード (スコア: 0.126)
#   - プラザ, フード, コート (スコア: 0.126)
#   - フード, コート, 内 (スコア: 0.123)
#   - 東京, グルメ, スタジアム (スコア: 0.120)
# --------------------
# 【がぜん 有明】
#   - 有明, パーク, ビル (スコア: 0.249)
#   - 国際, 展示, 場 (スコア: 0.234)
#   - 東京, ビッグ, サイト (スコア: 0.218)
#   - 有明, ワシントン, ホテル (スコア: 0.154)
#   - 展示, 場, 駅 (スコア: 0.148)
#   - パーク, ビル, 内 (スコア: 0.129)
#   - パーク, ビル, 2 (スコア: 0.115)
# --------------------
# 【くいもの屋わん お台場デックス東京ビーチ店】
#   - 東京, ビーチ, 店 (スコア: 0.225)
#   - 台場, デックス, 東京 (スコア: 0.172)
#   - デックス, 東京, ビーチ (スコア: 0.152)
#   - チェーン, 牛, 丼 (スコア: 0.134)
#   - いい, 感じ, 落ち着く (スコア: 0.134)
#   - , 000, いう (スコア: 0.134)
#   - ビーチ, 店, 潜入 (スコア: 0.134)
# --------------------
# 【くずし割烹 天ぷら竹の庵 東銀座店】
#   - 東, 銀座, 店 (スコア: 0.292)
#   - 東, 銀座, 駅 (スコア: 0.215)
#   - ビル, 地下, ある (スコア: 0.204)
#   - サラダ, かける, ドレッシング (スコア: 0.102)
#   - 閉店, する, ちゃう (スコア: 0.102)
#   - 白米, 玄米, 選べる (スコア: 0.102)
#   - 晴海, 通り, 晴海 (スコア: 0.097)
# --------------------
# 【こだわりから揚げの酒処 くらふと】
#   - 国際, 展示, 場 (スコア: 0.337)
#   - 展示, 場, 駅 (スコア: 0.270)
#   - 唐, 揚げ, 唐 (スコア: 0.165)
#   - 唐, 揚げ, 定食 (スコア: 0.156)
#   - 場, 駅, 近辺 (スコア: 0.115)
#   - 45, 予約, する (スコア: 0.115)
#   - いる, 唐, 揚げ (スコア: 0.115)
# --------------------
# 【こなな 有明ガーデン店】
#   - する, 有明, ガーデン (スコア: 0.153)
#   - 有明, ガーデン, 中 (スコア: 0.153)
#   - 有明, ガーデン, 内 (スコア: 0.138)
#   - ガーデン, 内, 店 (スコア: 0.127)
#   - 有明, ガーデン, フロア (スコア: 0.127)
#   - 飲む, 放題, の (スコア: 0.127)
#   - ガーデン, 店, 有明 (スコア: 0.107)
# --------------------
# 【こめらく みんなで、お茶漬け日和。 有明ガーデン店】
#   - 有明, ガーデン, フード (スコア: 0.246)
#   - ガーデン, フード, コート (スコア: 0.246)
#   - 厚, 切り, 豚 (スコア: 0.227)
#   - フード, コート, できる (スコア: 0.206)
#   - フード, コート, 内 (スコア: 0.197)
#   - ある, フード, コート (スコア: 0.174)
#   - 5, 階, フード (スコア: 0.168)
# --------------------
# 【さち福や 台場アクアシティ店】
#   - 定食, 1000, 唐 (スコア: 0.231)
#   - 台場, アクアシティ, ちる (スコア: 0.231)
#   - 和, 定食, 店 (スコア: 0.231)
#   - 中, 店, 最近 (スコア: 0.231)
#   - オープン, する, 和 (スコア: 0.231)
#   - お客, 少ない, 思う (スコア: 0.231)
#   - かわり, できる, の (スコア: 0.231)
# --------------------
# 【さち福やCAFE 有明ガーデン】
#   - 牡蠣, フライ, 定食 (スコア: 0.162)
#   - 有明, ガーデン, 内 (スコア: 0.136)
#   - 定食,  (スコア: 0.134)
#   - 有明, ガーデン, ランチ (スコア: 0.127)
#   - 有明, ガーデン, シアター (スコア: 0.121)
#   - フライ, 定食,  (スコア: 0.112)
#   - 片付ける, られる, いる (スコア: 0.112)
# --------------------
# 【しゃぶしゃぶ 吟半 お台場店】
#   - デックス, 東京, ビーチ (スコア: 0.365)
#   - 東京, ビーチ, 1 (スコア: 0.274)
#   - ビーチ, 1, 階 (スコア: 0.265)
#   - 台場, 海浜, 公園 (スコア: 0.251)
#   - 特, 上, ロース (スコア: 0.221)
#   - 8,  (スコア: 0.170)
#   - 海浜, 公園, 駅 (スコア: 0.137)
# --------------------
# 【しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場】
#   - 飲茶, 食べる, 放題 (スコア: 0.223)
#   - 良い, 景色, 綺麗 (スコア: 0.111)
#   - 景色, 一望, 出来る (スコア: 0.111)
#   - でる, くる, 食べる (スコア: 0.111)
#   - 予約, ない, ギリギリ (スコア: 0.111)
#   - 食べる, 放題, いただける (スコア: 0.111)
#   - 制, ラスト, オーダー (スコア: 0.111)
# --------------------
# 【しゃぶ食べ 有明ガーデン店】
#   - 三, 元, 豚 (スコア: 0.298)
#   - 食べる, 放題, 店 (スコア: 0.206)
#   - アルコール, 飲む, 放題 (スコア: 0.164)
#   - 食べる, 放題, チェーン (スコア: 0.130)
#   - カレー, 牛, 丼 (スコア: 0.130)
#   - れる, コース, する (スコア: 0.130)
#   - 牛, 食べる, れる (スコア: 0.124)
# --------------------
# 【しゅん】
#   - 調理, する, れる (スコア: 0.194)
#   - さ, そう, 所 (スコア: 0.129)
#   - 豊洲, 東雲, 方面 (スコア: 0.129)
#   - 酒, どれ, 美味しい (スコア: 0.129)
#   - 5, 6, 年 (スコア: 0.129)
#   - 豊洲, 有明, エリア (スコア: 0.129)
#   - 年, 振り, する (スコア: 0.129)
# --------------------
# 【すき家 ワンザ有明店】
#   - する, すき, 家 (スコア: 0.239)
#   - 国際, 展示, 場 (スコア: 0.200)
#   - 牛, 丼, 並 (スコア: 0.159)
#   - 丼, チェーン, 店 (スコア: 0.152)
#   - 牛, 丼, チェーン (スコア: 0.152)
#   - 場, 正門, 駅 (スコア: 0.102)
#   - 内, フード, コート (スコア: 0.102)
# --------------------
# 【すき家 東雲晴海通り店】
#   - ふろ, ふき, 大根 (スコア: 0.280)
#   - かける, 牛, 丼 (スコア: 0.280)
#   - なる, する, みる (スコア: 0.140)
#   - 旨味, 引き出す, れる (スコア: 0.140)
#   - 店, 外, 8 (スコア: 0.140)
#   - 位, 待つ, 入れる (スコア: 0.140)
#   - 清潔, ある, 良い (スコア: 0.140)
# --------------------
# 【すしざんまい 奥の院】
#   - 築地, すし, ざんまい (スコア: 0.374)
#   - する, すし, ざんまい (スコア: 0.173)
#   - すし, ざんまい, 店舗 (スコア: 0.173)
#   - 店, すし, ざんまい (スコア: 0.165)
#   - すし, ざんまい, 本店 (スコア: 0.144)
#   - すし, ざんまい, 築地 (スコア: 0.144)
#   - すし, ざんまい, ある (スコア: 0.144)
# --------------------
# 【すしざんまい 築地駅前店】
#   - すし, ざんまい, 築地 (スコア: 0.447)
#   - 築地, 駅前, 店 (スコア: 0.387)
#   - 築地, すし, ざんまい (スコア: 0.119)
#   - 歩く, そば, ある (スコア: 0.119)
#   - 駅, 歩く, そば (スコア: 0.119)
#   - ある, すし, ざんまい (スコア: 0.119)
#   - 日比谷線, 築地, 駅 (スコア: 0.111)
# --------------------
# 【すし処おかめ】
#   - 豊洲, 市場, 行く (スコア: 0.260)
#   - 立ち, 食い, 寿司 (スコア: 0.177)
#   - 豊洲, 市場, 見学 (スコア: 0.163)
#   - 食べる, 歩く, ツアー (スコア: 0.129)
#   - 多い, 豊洲, 市場 (スコア: 0.129)
#   - , 2000 (スコア: 0.111)
#   - 寿司, 屋, 築地 (スコア: 0.111)
# --------------------
# 【せきどうばなな】
#   - , バナナ (スコア: 0.623)
#   - , アルコール (スコア: 0.586)
#   - チョイス,  (スコア: 0.519)
# --------------------
# 【そじ坊 ダイバーシティ東京プラザ店】
#   - チキン, カツ, 丼 (スコア: 0.316)
#   - 坊さん, 行く, くる (スコア: 0.251)
#   - カツ, 丼, セット (スコア: 0.193)
#   - 蕎麦, 蕎麦, コシ (スコア: 0.151)
#   - カレー, 南蛮, そば (スコア: 0.151)
#   - ダイバー, シティ, 東京 (スコア: 0.120)
#   - 茸, 天ぷら, 揚げる (スコア: 0.105)
# --------------------
# 【そじ坊 ワンザ有明店】
#   - ワンザ, 有明, 店 (スコア: 0.181)
#   - 国際, 展示, 場 (スコア: 0.165)
#   - 東京, ビッグ, サイト (スコア: 0.147)
#   - 月見, とろろ, そば (スコア: 0.132)
#   - 系, 蕎麦, 屋 (スコア: 0.132)
#   - 大人, ポテト, サラダ (スコア: 0.132)
#   - ワンザ, 有明, 2 (スコア: 0.126)
# --------------------
# 【そなエリア東京バーベキューガーデン】
#   - 広域, 防災, 公園 (スコア: 0.290)
#   - 東京, 臨海, 広域 (スコア: 0.290)
#   - 臨海, 広域, 防災 (スコア: 0.290)
#   - そ, エリア, 東京 (スコア: 0.290)
#   - bbq,  (スコア: 0.279)
#   - かう, 線, 国際 (スコア: 0.175)
#   - 線, 国際, 展示 (スコア: 0.170)
# --------------------
# 【たけぞー】
#   - 東京, ビッグ, サイト (スコア: 0.283)
#   - 有明, セントラルタワー, 2 (スコア: 0.220)
#   - セントラルタワー, 2, f (スコア: 0.165)
#   - ビッグ, サイト, 展示 (スコア: 0.123)
#   - 国際, 展示, 場 (スコア: 0.121)
#   - ビッグ, サイト, 近く (スコア: 0.116)
#   - する, 有明, セントラルタワー (スコア: 0.115)
# --------------------
# 【たこやきやの元祖 本家 会津屋 お台場店】
#   - 台場, たこ焼き, ミュージアム (スコア: 0.710)
#   - たこ焼き, ミュージアム, 中 (スコア: 0.193)
#   - デックス, 東京, ビーチ (スコア: 0.110)
#   - たこ焼き, ミュージアム, 内 (スコア: 0.104)
#   - , たこ焼き (スコア: 0.102)
#   - たこ焼き, ミュージアム, たこ焼き (スコア: 0.083)
#   - ビーチ, たこ焼き, ミュージアム (スコア: 0.072)
# --------------------
# 【たこ家道頓堀くくる お台場たこ焼きミュージアム店】
#   - 台場, たこ焼き, ミュージアム (スコア: 0.562)
#   - たこ焼き, ミュージアム, たこ焼き (スコア: 0.202)
#   - デックス, 東京, ビーチ (スコア: 0.163)
#   - 8, 個, 入り (スコア: 0.119)
#   - 台場, デックス, 東京 (スコア: 0.100)
#   - たこ焼き, 8, 個 (スコア: 0.096)
#   - たこ焼き, ミュージアム, 店 (スコア: 0.093)
# --------------------
# 【つきじ丼匠】
#   - 海鮮, 丼, 店 (スコア: 0.194)
#   - 豊洲, 市場, 海鮮 (スコア: 0.169)
#   - 丼,  (スコア: 0.161)
#   - 7, 街, 区 (スコア: 0.159)
#   - 豊洲, 市場, 内 (スコア: 0.152)
#   - いくら, サーモン, 丼 (スコア: 0.138)
#   - 市場, 海鮮, 丼 (スコア: 0.138)
# --------------------
# 【つきぢ神楽寿司 豊洲市場店】
#   - 寿司, 豊洲, 市場 (スコア: 0.268)
#   - 豊洲, 市場, 店 (スコア: 0.222)
#   - 赤, 酢, シャリ (スコア: 0.180)
#   - おまかせ, 3,  (スコア: 0.125)
#   - する, 赤, 酢 (スコア: 0.125)
#   - , 赤, 酢 (スコア: 0.125)
#   - 先客, 万, 来 (スコア: 0.111)
# --------------------
# 【つけ麺らーめん春樹 お台場店】
#   - 麺, 特, 盛 (スコア: 0.305)
#   - つけ, 麺, ら (スコア: 0.244)
#   - つけ, 麺, 特 (スコア: 0.233)
#   - 麺, ら, ー (スコア: 0.233)
#   - ら, ー, めん (スコア: 0.163)
#   - ラーメン, つけ, 麺 (スコア: 0.158)
#   - 豚, 骨, ラーメン (スコア: 0.138)
# --------------------
# 【つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店】
#   - 三田, 製, 麺 (スコア: 0.649)
#   - 製, 麺, 所 (スコア: 0.550)
#   - 濃厚, つけ, 麺 (スコア: 0.115)
#   - 麺,  (スコア: 0.089)
#   - 4, 月, 28 (スコア: 0.088)
#   - つけ, 麺, 食べる (スコア: 0.078)
#   - , 050 (スコア: 0.069)
# --------------------
# 【てしごとや ふくの鳥 木場店】
#   - 唐, 揚げ, 定食 (スコア: 0.185)
#   - 東西線, 木場, 駅 (スコア: 0.166)
#   - コース, 予約, する (スコア: 0.097)
#   - チョイス, チェーン, 店 (スコア: 0.090)
#   - スープ, サラダ, 小鉢 (スコア: 0.090)
#   - 南蛮, 唐, 揚げ (スコア: 0.090)
#   - 唐, 揚げ, 一 (スコア: 0.090)
# --------------------
# 【てっぱん屋台 ダイバーシティ東京プラザ店】
#   - てる, ぱん, 屋台 (スコア: 0.551)
#   - ダイバー, シティ, 東京 (スコア: 0.251)
#   - シティ, 東京, プラザ (スコア: 0.200)
#   - フード, コート, 内 (スコア: 0.142)
#   - 東京, プラザ, 店 (スコア: 0.125)
#   - 階, フード, コート (スコア: 0.113)
#   - フード, コート, 店 (スコア: 0.109)
# --------------------
# 【とんかつ八千代】
#   - チャーシュー, エッグ, 定食 (スコア: 0.640)
#   - 管理, 施設, 棟 (スコア: 0.184)
#   - 八千代, チャーシュー, エッグ (スコア: 0.160)
#   - チャーシュー, エッグ, 食べる (スコア: 0.151)
#   - 定食,  (スコア: 0.137)
#   - , アジ (スコア: 0.130)
#   - アジ, フライ, 定食 (スコア: 0.127)
# --------------------
# 【どうとんぼり神座 有明ガーデン店】
#   - ガーデン, フード, コート (スコア: 0.339)
#   - 有明, ガーデン, フード (スコア: 0.319)
#   - 有明, ガーデン, 店 (スコア: 0.250)
#   - フード, コート, 内 (スコア: 0.224)
#   - 有明, ガーデン, 内 (スコア: 0.151)
#   - 階, フード, コート (スコア: 0.119)
#   - ガーデン, 内, フード (スコア: 0.115)
# --------------------
# 【なんで、や お台場店】
#   - アクアシティ, 台場, 店 (スコア: 0.196)
#   - アクアシティ, 台場, 1 (スコア: 0.163)
#   - アクアシティ, １, 階 (スコア: 0.129)
#   - 夜, 居酒屋, する (スコア: 0.129)
#   - ⁰,  (スコア: 0.129)
#   - , ⁰ (スコア: 0.129)
#   - , ⁰,  (スコア: 0.129)
# --------------------
# 【にばん家 勝どき】
#   - 路地, 裏, 隠れ家 (スコア: 0.319)
#   - 日本, 酒, つまむ (スコア: 0.159)
#   - 値段, する, コス (スコア: 0.159)
#   - ランチ, 勝どき, 駅 (スコア: 0.159)
#   - 分かる, にくい, 思う (スコア: 0.159)
#   - 大江戸, 線, 勝どき (スコア: 0.159)
#   - 入る, みる, カウンター (スコア: 0.159)
# --------------------
# 【ねぎま屋 武蔵 葛西店】
#   - 葛西, 駅, 徒歩 (スコア: 0.210)
#   - line, 登録, する (スコア: 0.188)
#   - 99,  (スコア: 0.188)
#   - 駅, 徒歩, 圏内 (スコア: 0.152)
#   - コス, パ, 抜群 (スコア: 0.149)
#   - 近, 場, 行う (スコア: 0.094)
#   - 行う, 無い, 店 (スコア: 0.094)
# --------------------
# 【ねこねこチーズケーキ 有明ガーデンシティ店】
#   - 形, する, チーズ (スコア: 0.245)
#   - 有明, ガーデン, シティ (スコア: 0.225)
#   - する, チーズ, ケーキ (スコア: 0.218)
#   - , о,  (スコア: 0.194)
#   - , о (スコア: 0.194)
#   - о,  (スコア: 0.191)
#   - 州, 大井, 町 (スコア: 0.123)
# --------------------
# 【はなまるうどん ダイバーシティ東京店】
#   - ダイバー, シティ, 東京 (スコア: 0.334)
#   - の, なまる, うどん (スコア: 0.251)
#   - フード, コート, 内 (スコア: 0.185)
#   - うどん,  (スコア: 0.173)
#   - 階, フード, コート (スコア: 0.150)
#   - ダイバー, シティ, フード (スコア: 0.115)
#   - シティ, フード, コート (スコア: 0.115)
# --------------------
# 【はなまる屋 アクアシティお台場店】
#   - アクアシティ, 台場, フード (スコア: 0.333)
#   - 台場, フード, コート (スコア: 0.300)
#   - 丼, 吉野家, 系 (スコア: 0.135)
#   - リーズナブル, お腹, いっぱい (スコア: 0.135)
#   - 買い出し,  (スコア: 0.135)
#   - 飲食, 店, 中央 (スコア: 0.135)
#   - の, なまる, うどん (スコア: 0.135)
# --------------------
# 【ふくの鳥 東陽町】
#   - メンチ, カツ, 定食 (スコア: 0.407)
#   - , 850 (スコア: 0.204)
#   - チキン, 南蛮, 定食 (スコア: 0.168)
#   - 厚, 切り, ハムカツ (スコア: 0.136)
#   - ひな, 鶏, 唐 (スコア: 0.136)
#   - サラダ, 温, 玉 (スコア: 0.136)
#   - , チキン, 南蛮 (スコア: 0.129)
# --------------------
# 【ふぐ倶楽部ビルヂング】
#   - ふぐ, 専門, 店 (スコア: 0.297)
#   - , 00,  (スコア: 0.200)
#   - 00,  (スコア: 0.184)
#   - 溢れる, 素敵, 店 (スコア: 0.148)
#   - , ふぐ (スコア: 0.148)
#   - さ, 唐, 揚げ (スコア: 0.148)
#   - , 10000,  (スコア: 0.148)
# --------------------
# 【ほおずきや】
#   - 国際, 展示, 場 (スコア: 0.274)
#   - ら, ー, めん (スコア: 0.233)
#   - 有明, ベイ, モール (スコア: 0.227)
#   - ワンザ, 有明, ベイ (スコア: 0.227)
#   - 東京, ビッグ, サイト (スコア: 0.215)
#   - 唐, 揚げ, 定食 (スコア: 0.119)
#   - 3,  (スコア: 0.118)
# --------------------
# 【ほっともっと 東雲店】
#   - 江東, 区, 東雲 (スコア: 0.233)
#   - する, できる, する (スコア: 0.131)
#   - ある, 安心, する (スコア: 0.131)
#   - 駅, 出る, 晴海 (スコア: 0.131)
#   - 作る, 置く, する (スコア: 0.131)
#   - 打ち合わせ, 帰り, 見つける (スコア: 0.131)
#   - 休憩, 中, する (スコア: 0.131)
# --------------------
# 【ぼてや アクアシティお台場店】
#   - ひる, ぜん, 焼きそば (スコア: 0.279)
#   - アクアシティ, 台場, フード (スコア: 0.229)
#   - 台場, フード, コート (スコア: 0.207)
#   - しまう, 台場, 有る (スコア: 0.093)
#   - サラダ, 付き, セット (スコア: 0.093)
#   - 成る, しまう, 台場 (スコア: 0.093)
#   - , ビックリ (スコア: 0.093)
# --------------------
# 【まいばすけっと 台場1丁目店】
# --------------------
# 【まはらに】
#   - 予約, とる, くれる (スコア: 0.306)
#   - 国際, 展示, 場 (スコア: 0.256)
#   - ビル, 2, 階 (スコア: 0.184)
#   - , インド, 店 (スコア: 0.153)
#   - 忘れる, られる, てる (スコア: 0.153)
#   - いる, 店, 12 (スコア: 0.153)
#   - の, 忘れる, られる (スコア: 0.153)
# --------------------
# 【むら田】
#   - 有明, ワシントン, ホテル (スコア: 0.352)
#   - ワシントン, ホテル, 2 (スコア: 0.198)
#   - 国際, 展示, 場 (スコア: 0.176)
#   - 東京, ビッグ, サイト (スコア: 0.161)
#   - ホテル, 2, f (スコア: 0.160)
#   - チキン, 南蛮, 定食 (スコア: 0.148)
#   - ベイ, 有明, ワシントン (スコア: 0.136)
# --------------------
# 【やまちゃん お台場店】
#   - 台場, たこ焼き, ミュージアム (スコア: 0.587)
#   - デックス, 東京, ビーチ (スコア: 0.232)
#   - たこ焼き, ミュージアム, 内 (スコア: 0.164)
#   - たこ焼き, ミュージアム, 中 (スコア: 0.145)
#   - 台場, デックス, 東京 (スコア: 0.122)
#   - たこ焼き, ミュージアム, 行く (スコア: 0.100)
#   - 8, 個, 入り (スコア: 0.100)
# --------------------
# 【アイランド・ヴィンテージ・コーヒー 台場店】
#   - コーヒー (スコア: 0.416)
#   - , レギュラー (スコア: 0.139)
#   - デックス, 東京, ビーチ (スコア: 0.138)
#   - ハーフ, サイズ, する (スコア: 0.097)
#   - アサイーボウル,  (スコア: 0.097)
#   - ラテ (スコア: 0.097)
#   - 台場, 海浜, 公園 (スコア: 0.096)
# --------------------
# 【アニミル お台場店】
#   - 子供, 行く, がる (スコア: 0.520)
#   - 日本, 最大, 級 (スコア: 0.520)
#   - てる, 連れる, 行く (スコア: 0.496)
#   - 連れる, 行く, あげる (スコア: 0.462)
# --------------------
# 【アマラ ダイバーシティ東京店】
#   - シティ, フード, コート (スコア: 0.335)
#   - ダイバー, シティ, フード (スコア: 0.335)
#   - ダイバー, シティ, 東京 (スコア: 0.185)
#   - フード, コート, 内 (スコア: 0.135)
#   - 日本, 科学, 来館 (スコア: 0.121)
#   - 台場, ダイバー, シティ (スコア: 0.097)
#   - フード, コート, 店 (スコア: 0.096)
# --------------------
# 【アルポルト 東京ビッグサイト店】
#   - 東京, ビッグ, サイト (スコア: 0.411)
#   - ビッグ, サイト, 会議 (スコア: 0.201)
#   - サイト, 会議, 棟 (スコア: 0.201)
#   - ビッグ, サイト, 店 (スコア: 0.159)
#   - , 0,  (スコア: 0.154)
#   - 0,  (スコア: 0.129)
#   - 3,  (スコア: 0.126)
# --------------------
# 【ア・タ・ゴール】
#   - ゴール (スコア: 0.402)
#   - 木場, 駅, 徒歩 (スコア: 0.206)
#   - 東西線, 木場, 駅 (スコア: 0.142)
#   - 以前, なる, いる (スコア: 0.139)
#   - メトロ, 東西線, 木場 (スコア: 0.124)
#   - なる, いる, 店 (スコア: 0.096)
#   - , ジビエ (スコア: 0.093)
# --------------------
# 【イオンスタイル 有明ガーデン】
#   - , t,  (スコア: 0.272)
#   - t,  (スコア: 0.261)
#   - , t (スコア: 0.258)
#   - ２, ０, ごろ (スコア: 0.183)
#   - ガーリック,  (スコア: 0.183)
#   - モール, １, 階 (スコア: 0.183)
#   - 注意, する, 下さる (スコア: 0.183)
# --------------------
# 【イタリアン酒場 パステーカ】
#   - トマト, ソース, パスタ (スコア: 0.206)
#   - , о (スコア: 0.163)
#   - , о,  (スコア: 0.163)
#   - о,  (スコア: 0.160)
#   - ビッグ, サイト, イベント (スコア: 0.159)
#   - イベント, 参加, の (スコア: 0.103)
#   - いる, 仕事, 帰り (スコア: 0.103)
# --------------------
# 【イマーシブ・フォート東京】
#   - ディ (スコア: 0.573)
#   - ペローニ (スコア: 0.200)
#   - 可能,  (スコア: 0.165)
#   - 具合,  (スコア: 0.156)
#   - てる, する,  (スコア: 0.100)
#   - ドルチェ (スコア: 0.100)
#   - get,  (スコア: 0.100)
# --------------------
# 【インコントロ オステリア&グリル】
#   - , グリル (スコア: 0.284)
#   - グランド, ニッコー, 東京 (スコア: 0.262)
#   - ニッコー, 東京, 台場 (スコア: 0.187)
#   - かもめ, 台場, 駅 (スコア: 0.115)
#   - 台場, 駅, 直結 (スコア: 0.114)
#   - ゆり, かもめ, 台場 (スコア: 0.107)
#   - 感動, する, サービス (スコア: 0.099)
# --------------------
# 【インドレストラン＆バー ムナル】
#   - インド, カレー, 屋 (スコア: 0.251)
#   - インド, カレー, 店 (スコア: 0.228)
#   - インド, ネパール, 屋 (スコア: 0.199)
#   - インド, ネパール, 店 (スコア: 0.149)
#   - ランチ, 頂く, の (スコア: 0.149)
#   - セット,  (スコア: 0.139)
#   - , カレー (スコア: 0.137)
# --------------------
# 【インド料理ムンバイ アクアシティお台場店】
#   - カレー, ナン, セット (スコア: 0.199)
#   - インド, カレー, 屋 (スコア: 0.168)
#   - 辛い, さ, 美味しい (スコア: 0.127)
#   - レインボー, ブリッジ, 目 (スコア: 0.103)
#   - ブリッジ, 目, 前 (スコア: 0.103)
#   - カレー,  (スコア: 0.082)
#   - アクアシティ, 台場, 店 (スコア: 0.081)
# --------------------
# 【ウイスキーボイス 台場】
#   - , 1300 (スコア: 0.236)
#   - , 1300,  (スコア: 0.178)
#   - 1300,  (スコア: 0.170)
#   - 1,  (スコア: 0.117)
#   - , 300 (スコア: 0.117)
#   - 付く,  (スコア: 0.103)
#   - マンション, 買う, 昔 (スコア: 0.103)
# --------------------
# 【ウェンディーズ・ファーストキッチン アクアシティお台場店】
#   - アクアシティ, 台場, フード (スコア: 0.308)
#   - 台場, フード, コート (スコア: 0.277)
#   - 番号, 呼ぶ, れる (スコア: 0.197)
#   - ０, 日曜日, 事 (スコア: 0.125)
#   - 年, ６月, ３ (スコア: 0.125)
#   - 観覧, する, 行く (スコア: 0.125)
#   - ヒャダ, こじらせる, ライブ (スコア: 0.125)
# --------------------
# 【ウマミバーガー 有明ガーデン店】
#   - 有明, ガーデン, 店 (スコア: 0.214)
#   - 有明, ガーデン, 5 (スコア: 0.182)
#   - , ポテト (スコア: 0.130)
#   - ベーコン (スコア: 0.123)
#   - 有明, 店, 限定 (スコア: 0.123)
#   - オニオン (スコア: 0.123)
#   - ガーデン, 5, f (スコア: 0.114)
# --------------------
# 【エクセルシオール カフェ ダイバーシティ東京プラザ店】
#   - シティ, 東京, プラザ (スコア: 0.467)
#   - ダイバー, シティ, 東京 (スコア: 0.439)
#   - 東京, プラザ, 店 (スコア: 0.262)
#   - 東京, テレポート, 駅 (スコア: 0.131)
#   - 空く, てる, 助かる (スコア: 0.128)
#   - 広い, 空く, てる (スコア: 0.128)
#   - テレポート, 駅, ダイバシティ (スコア: 0.128)
# --------------------
# 【エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店】
#   - 空く, いる, 着席 (スコア: 0.275)
#   - , 480, する (スコア: 0.275)
#   - 海外, 旅行, 客 (スコア: 0.275)
#   - , ほうじ茶 (スコア: 0.275)
#   - カヌレ,  (スコア: 0.262)
#   - でる, 思う, 空く (スコア: 0.262)
#   - フロア, ある, 店 (スコア: 0.262)
# --------------------
# 【エグゼクティブラウンジ】
#   - ヒルトン, 東京, 台場 (スコア: 0.380)
#   - 東京, 台場, エグゼクティブラウンジ (スコア: 0.244)
#   - 2020,  (スコア: 0.215)
#   - , 11,  (スコア: 0.185)
#   - , 11 (スコア: 0.158)
#   - 11,  (スコア: 0.129)
#   - 晩, 飯, なる (スコア: 0.122)
# --------------------
# 【エスプレッソ アメリカーノ テレコムセンター店】
#   - テレコム, センター, 駅 (スコア: 0.301)
#   - センター, 1, 階 (スコア: 0.194)
#   - する, テレコム, センター (スコア: 0.185)
#   - ゆり, かもめ, テレコム (スコア: 0.167)
#   - かもめ, テレコム, センター (スコア: 0.167)
#   - 一, 階, ある (スコア: 0.138)
#   - いる, なる, いる (スコア: 0.136)
# --------------------
# 【エッグスンシングス お台場店】
#   - パンケーキ,  (スコア: 0.253)
#   - , n (スコア: 0.208)
#   - , パンケーキ (スコア: 0.208)
#   - , n, things (スコア: 0.200)
#   - , ガーリックシュリンプ (スコア: 0.100)
#   - , パンケーキ,  (スコア: 0.100)
#   - 照り, 焼き, チキン (スコア: 0.087)
# --------------------
# 【エフアイランド】
#   - １, ６, 年 (スコア: 0.249)
#   - , パパ (スコア: 0.249)
#   - ０, １, ６ (スコア: 0.249)
#   - bankara,  (スコア: 0.238)
#   - by, bankara,  (スコア: 0.238)
#   - named, by, bankara (スコア: 0.238)
#   - 禁断, なる, 常習犯 (スコア: 0.229)
# --------------------
# 【エフカイビーチ】
#   - 台場, 海浜, 公園 (スコア: 0.661)
#   - 何, 度, 行う (スコア: 0.087)
#   - 海浜, 公園, 駅 (スコア: 0.079)
#   - いい, ここ, いい (スコア: 0.070)
#   - , ビーチ (スコア: 0.070)
#   - 久々, 台場, くる (スコア: 0.070)
#   - 1, 泊, する (スコア: 0.070)
# --------------------
# 【オイスターハウス お台場店】
#   - パン, 食べる, 放題 (スコア: 0.435)
#   - , 牡蠣 (スコア: 0.197)
#   - クリーム, パスタ, 美味しい (スコア: 0.114)
#   - ランチ, パン, 食べる (スコア: 0.114)
#   - 食べる, 放題, 付き (スコア: 0.109)
#   - する, ランチ, セット (スコア: 0.101)
#   - 日本, 科学, 来館 (スコア: 0.084)
# --------------------
# 【オリジナルパンケーキハウス 有明ガーデン店】
#   - パンケーキ,  (スコア: 0.234)
#   - 有明, ガーデン, 内 (スコア: 0.161)
#   - , パンケーキ (スコア: 0.148)
#   - 店, パンケーキ, 食べる (スコア: 0.111)
#   - 有明, ガーデン, シティ (スコア: 0.102)
#   - 有明, ガーデン, 店 (スコア: 0.096)
#   - 食べる, 応え, ある (スコア: 0.091)
# --------------------
# 【オーケー お台場店】
#   - チェーン, 牛, 丼 (スコア: 0.278)
#   - テレポート, 駅, 到着 (スコア: 0.278)
#   - ２, ９, ９ (スコア: 0.278)
#   - する, れる, 当店 (スコア: 0.278)
#   - 元, 豚, 使用 (スコア: 0.278)
#   - いる, 値段, 設定 (スコア: 0.278)
#   - 考える, いる, 店 (スコア: 0.265)
# --------------------
# 【オーケー 東雲店】
#   - , 17, オープン (スコア: 0.394)
#   - 7, 8, 年 (スコア: 0.394)
#   - 東雲, 駅, 徒歩 (スコア: 0.376)
#   - 店, 4,  (スコア: 0.362)
#   - 17, オープン, する (スコア: 0.362)
#   - 8, 年, 前 (スコア: 0.362)
#   - 駅, 徒歩, 6 (スコア: 0.265)
# --------------------
# 【オーシャンクラブビュッフェ デックス東京ビーチ店】
#   - デックス, 東京, ビーチ (スコア: 0.282)
#   - ない, 不可, ない (スコア: 0.115)
#   - 可, ない, 不可 (スコア: 0.113)
#   - 2016, 年, 6 (スコア: 0.110)
#   - 食べる, れる, ビュッフェ (スコア: 0.110)
#   - 広い, レインボー, ブリッジ (スコア: 0.110)
#   - 台場, デックス, 東京 (スコア: 0.106)
# --------------------
# 【オーシャン東九フェリー】
#   - 品, 揃える, 多い (スコア: 0.392)
#   - 250, 1, 番 (スコア: 0.392)
#   - , 00, 東京 (スコア: 0.392)
#   - , 有明,  (スコア: 0.349)
#   - 1, 番, の (スコア: 0.323)
#   - 有明,  (スコア: 0.287)
#   - 販売, する, れる (スコア: 0.280)
# --------------------
# 【オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明)】
#   - 就学, 児, 無料 (スコア: 0.274)
#   - ビュッフェ,  (スコア: 0.185)
#   - ヴィラフォンテーヌグランド, 東京, 有明 (スコア: 0.146)
#   - 海鮮, 丼, 作れる (スコア: 0.110)
#   - 海鮮, 食べる, 放題 (スコア: 0.110)
#   - 美味しい, 海鮮, 丼 (スコア: 0.110)
#   - 祝日, ランチ, 来訪 (スコア: 0.110)
# --------------------
# 【カザーナ お台場店】
#   - ナン (スコア: 0.311)
#   - タンドリーチキン (スコア: 0.228)
#   - カレー, 食べる, 放題 (スコア: 0.210)
#   - サフランライス (スコア: 0.196)
#   - デックス, 東京, ビーチ (スコア: 0.186)
#   - サラダ (スコア: 0.169)
#   - カレー, 4, 種 (スコア: 0.163)
# --------------------
# 【カツオたまご食堂】
#   - テレコム, センター, 駅 (スコア: 0.232)
#   - 青海, フロンティア, ビル (スコア: 0.183)
#   - フロンティア, ビル, 1 (スコア: 0.183)
#   - 機, 食券, 購入 (スコア: 0.158)
#   - 券売, 機, 食券 (スコア: 0.150)
#   - ビル, 1, 階 (スコア: 0.139)
#   - 定食,  (スコア: 0.113)
# --------------------
# 【カフェ ラ・ボエム お台場】
#   - ボエム (スコア: 0.536)
#   - レインボー, ブリッジ, 見える (スコア: 0.167)
#   - 就労, 者, 割引 (スコア: 0.151)
#   - 近隣, 就労, 者 (スコア: 0.149)
#   - カフェ, ラ (スコア: 0.124)
#   - , パスタ (スコア: 0.101)
#   - 水, 炭酸, 水 (スコア: 0.086)
# --------------------
# 【カフェ&ミール ムジ 東京有明】
#   - カフェ,  (スコア: 0.168)
#   - 無印, 良品, 東京 (スコア: 0.122)
#   - 無印, 良品, カフェ (スコア: 0.122)
#   - 級, 無印, 良品 (スコア: 0.122)
#   - 有明, 無印, 良品 (スコア: 0.122)
#   - 良品, 東京, 有明 (スコア: 0.122)
#   - 東京, 有明, 無印 (スコア: 0.122)
# --------------------
# 【カフェテラス　ロイヤル】
#   - ビッグ, サイト, 西 (スコア: 0.416)
#   - 東京, ビッグ, サイト (スコア: 0.358)
#   - 西, 展示, 場 (スコア: 0.320)
#   - 東京, 国際, 展示 (スコア: 0.130)
#   - 西, 展示, 棟 (スコア: 0.123)
#   - 展示, 会場, 内 (スコア: 0.107)
#   - 国際, 展示, 場 (スコア: 0.103)
# --------------------
# 【カフェ＆レストラン レインボー】
#   - 研, 有明, 病院 (スコア: 0.376)
#   - がん, 研, 有明 (スコア: 0.188)
#   - 癌, 研, 病院 (スコア: 0.179)
#   - 展示, 場, 駅 (スコア: 0.177)
#   - 場, 駅, 有明 (スコア: 0.173)
#   - 駅, 有明, 駅 (スコア: 0.162)
#   - 国際, 展示, 場 (スコア: 0.157)
# --------------------
# 【カフェ･ベローチェ  有明店】
#   - 国際, 展示, 場 (スコア: 0.454)
#   - 展示, 場, 駅 (スコア: 0.294)
#   - 有明, フロンティア, ビル (スコア: 0.250)
#   - 線, 国際, 展示 (スコア: 0.221)
#   - かう, 線, 国際 (スコア: 0.209)
#   - 東京, ビッグ, サイト (スコア: 0.176)
#   - フロンティア, ビル, １ (スコア: 0.165)
# --------------------
# 【カレス】
#   - 台場, 海浜, 公園 (スコア: 0.408)
#   - 海浜, 公園, 駅 (スコア: 0.262)
#   - トマト, ソース, パスタ (スコア: 0.180)
#   - 公園, 駅, 近く (スコア: 0.104)
#   - する, ホット, コーヒー (スコア: 0.103)
#   - , 1000 (スコア: 0.099)
#   - ホット, コーヒー, する (スコア: 0.098)
# --------------------
# 【カレーショップ C&Cダイニング 東京ビッグサイト店】
#   - c,  (スコア: 0.465)
#   - , c (スコア: 0.430)
#   - 東京, ビッグ, サイト (スコア: 0.319)
#   - カレー, ショップ, c (スコア: 0.255)
#   - ショップ, c,  (スコア: 0.255)
#   - ビッグ, サイト, 内 (スコア: 0.128)
#   - 東, 展示, 棟 (スコア: 0.105)
# --------------------
# 【カレー香房】
#   - カレー, 香, 房 (スコア: 0.296)
#   - 東京, ビッグ, サイト (スコア: 0.264)
#   - フード, コート, カレー (スコア: 0.181)
#   - カレー, 専門, 店 (スコア: 0.175)
#   - ビッグ, サイト, 会議 (スコア: 0.166)
#   - サイト, 会議, 棟 (スコア: 0.166)
#   - ビックサイト, 展示, 会 (スコア: 0.117)
# --------------------
# 【カンテボーレ イオンスタイル有明ガーデン】
#   - チーズ,  (スコア: 0.339)
#   - 有明, ガーデン, イオン (スコア: 0.191)
#   - パン, 焼き, たて (スコア: 0.191)
#   - の, 開催, する (スコア: 0.191)
#   - ショッピング, センター, 開業 (スコア: 0.191)
#   - 別, パン, 屋 (スコア: 0.191)
#   - 購入, する, 購入 (スコア: 0.191)
# --------------------
# 【カーサ・ディ・ペロー二】
#   - ディ (スコア: 0.491)
#   - フォート, 東京 (スコア: 0.273)
#   - フォート (スコア: 0.263)
#   - イマーシブ (スコア: 0.254)
#   - 具合,  (スコア: 0.178)
#   - カーサ (スコア: 0.172)
#   - ごろ, 混雑, 状況 (スコア: 0.109)
# --------------------
# 【カールスジュニア ダイバーシティ東京 プラザレストラン】
#   - フード, コート, 内 (スコア: 0.234)
#   - ダイバー, シティ, フード (スコア: 0.175)
#   - シティ, フード, コート (スコア: 0.175)
#   - ダイバー, シティ, 東京 (スコア: 0.169)
#   - 内, ハンバーガー, 屋 (スコア: 0.127)
#   - コート, 内, ハンバーガー (スコア: 0.127)
#   - 飲み物, 飲む, 放題 (スコア: 0.121)
# --------------------
# 【ガルーバ】
#   - 黒毛, 和牛, ロース (スコア: 0.158)
#   - アクアシティ, 台場, 6 (スコア: 0.130)
#   - レインボー, ブリッジ, 見える (スコア: 0.125)
#   - 台場, 焼肉, 食べる (スコア: 0.105)
#   - ６, 階, 焼肉 (スコア: 0.105)
#   - いい, 焼肉, 屋 (スコア: 0.101)
#   - , 台場 (スコア: 0.093)
# --------------------
# 【ガーデン ダイニング】
#   - グランド, ニッコー, 東京 (スコア: 0.494)
#   - ニッコー, 東京, 台場 (スコア: 0.370)
#   - グランド, ニッコー, 台場 (スコア: 0.162)
#   - フェア, やる, いる (スコア: 0.138)
#   - ランチ, ビュッフェ, 行く (スコア: 0.123)
#   - ビュッフェ, 行く, くる (スコア: 0.117)
#   - 東京, 台場, 1 (スコア: 0.113)
# --------------------
# 【キッチン有明】
#   - 週, 替る, ラーメン (スコア: 0.756)
#   - 食堂, 週, 替る (スコア: 0.239)
#   - 2025, 年, 2 (スコア: 0.131)
#   - 有明, 食堂, 週 (スコア: 0.119)
#   - 有明, サービス, センター (スコア: 0.119)
#   - 福利, 厚生, 協会 (スコア: 0.114)
#   - 江東, 区, 有明 (スコア: 0.110)
# --------------------
# 【キッチン青海珈琲】
#   - 11,  (スコア: 0.384)
#   - , 000 (スコア: 0.324)
#   - 000, 11,  (スコア: 0.300)
#   - , 000, 11 (スコア: 0.291)
#   - 1,  (スコア: 0.247)
#   - ハンバーグ, 1,  (スコア: 0.218)
#   - 名, 券売, 機 (スコア: 0.218)
# --------------------
# 【キムカツ亭 有明ガーデン店】
#   - 有明, ガーデン, 店 (スコア: 0.271)
#   - ガーデン, フード, コート (スコア: 0.251)
#   - 有明, ガーデン, フード (スコア: 0.251)
#   - フード, コート, 内 (スコア: 0.173)
#   - 有明, ガーデン, 5 (スコア: 0.165)
#   - チーズ (スコア: 0.149)
#   - フード, コート, する (スコア: 0.110)
# --------------------
# 【キラキラドンキ ダイバーシティ東京 プラザ店】
#   - 中核, 不動産, 会社 (スコア: 0.422)
#   - 会社, ショッピング, センター (スコア: 0.422)
#   - 会, 中核, 不動産 (スコア: 0.422)
#   - 不動産, 会社, ショッピング (スコア: 0.422)
#   - ある, 前, なる (スコア: 0.355)
#   - 前, なる, てる (スコア: 0.313)
#   - 江東, 区, 青海 (スコア: 0.255)
# --------------------
# 【キリンシティプラス 有明ガーデン店】
#   - シアター, 推す, ライブ (スコア: 0.182)
#   - ガーデン, シアター, 推す (スコア: 0.182)
#   - 東京, ガーデン, シアター (スコア: 0.162)
#   - 店, 有明, ガーデン (スコア: 0.110)
#   - 有明, ガーデン, 店 (スコア: 0.105)
#   - 2, 階, オープン (スコア: 0.091)
#   - ライブ, 前, 予約 (スコア: 0.091)
# --------------------
# 【クアアイナ アクアシティお台場店】
#   - アクアシティ, 台場, 店 (スコア: 0.148)
#   - ハンバーガー,  (スコア: 0.135)
#   - 1,  (スコア: 0.120)
#   - ハンバーガー, 食べる, なる (スコア: 0.099)
#   - ブリッジ, 自由, 女神 (スコア: 0.096)
#   - レインボー, ブリッジ, 自由 (スコア: 0.096)
#   - , o,  (スコア: 0.091)
# --------------------
# 【クルックス カフェオ ヨーロピアンリゾートカフェ】
#   - 2, 階, カフェ (スコア: 0.206)
#   - 台場, フロンティア, ビル (スコア: 0.206)
#   - 東京, テレポート, 駅 (スコア: 0.184)
#   - 台場, 海浜, 公園 (スコア: 0.178)
#   - フロンティア, ビル, 2 (スコア: 0.132)
#   - テレポート, 駅, 台場 (スコア: 0.125)
#   - アイス, コーヒー, いただく (スコア: 0.119)
# --------------------
# 【クレープおじさん お台場店】
#   - , ジョイポリス (スコア: 0.379)
#   - , n (スコア: 0.253)
#   - , 9,  (スコア: 0.168)
#   - , 9 (スコア: 0.143)
#   - 台場, くる, とき (スコア: 0.142)
#   - 生クリーム, たっぷり, 美味しい (スコア: 0.142)
#   - 内, クレープ, 屋 (スコア: 0.142)
# --------------------
# 【グランディール 有明ガーデン店】
#   - 有明, ガーデン, 2 (スコア: 0.301)
#   - ガーデン, 2, 階 (スコア: 0.235)
#   - する, パン, 屋 (スコア: 0.202)
#   - , 230 (スコア: 0.188)
#   - 使う, 有明, ガーデン (スコア: 0.106)
#   - 2, 階, 新しい (スコア: 0.106)
#   - 見れる, の, 残念 (スコア: 0.106)
# --------------------
# 【グランドニッコー東京 台場】
#   - グランド, ニッコー, 東京 (スコア: 0.492)
#   - ニッコー, 東京, 台場 (スコア: 0.383)
#   - グランド, ニッコー, 台場 (スコア: 0.144)
#   - 年, 4, 月 (スコア: 0.129)
#   - , 朝食 (スコア: 0.113)
#   - , 部屋 (スコア: 0.097)
#   - , 今日 (スコア: 0.094)
# --------------------
# 【グランドニッコー東京 台場 エグゼクティブラウンジ】
#   - ニッコー, 東京, 台場 (スコア: 0.223)
#   - グランド, ニッコー, 東京 (スコア: 0.223)
#   - する, 宿泊, する (スコア: 0.148)
#   - ピンク, アフタヌーン, ティー (スコア: 0.148)
#   - 目, 宿泊, 先 (スコア: 0.148)
#   - 先, グランド, ニッコー (スコア: 0.148)
#   - する, 空く, おる (スコア: 0.148)
# --------------------
# 【グランブルー】
#   - する, する, 予約 (スコア: 0.589)
#   - ホテルグランパシフィック, le, daiba (スコア: 0.589)
#   - 予約, する, する (スコア: 0.403)
#   - いる, 予約, する (スコア: 0.380)
# --------------------
# 【グリロジー バー＆グリル】
#   - ヒルトン, 東京, 台場 (スコア: 0.529)
#   - アフタヌーン, ティー, 行く (スコア: 0.156)
#   - 東京, 台場, グリロジーバー (スコア: 0.113)
#   - ヒルトン, 台場, アフタヌーン (スコア: 0.113)
#   - , グリル (スコア: 0.108)
#   - 台場, アフタヌーン, ティー (スコア: 0.108)
#   - , ヒルトン (スコア: 0.098)
# --------------------
# 【グリーン アジア トウキョウ】
#   - する, サラダ, バー (スコア: 0.218)
#   - ランチ, する, サラダ (スコア: 0.164)
#   - サラダ, バー, つく (スコア: 0.164)
#   - サラダ, バー, 付き (スコア: 0.164)
#   - , スープ (スコア: 0.157)
#   - , エビ (スコア: 0.133)
#   - スープ,  (スコア: 0.124)
# --------------------
# 【グリーンズシェフ】
#   - 5, 階, 入る (スコア: 0.173)
#   - 技術, 研究, センター (スコア: 0.173)
#   - 方, する, れる (スコア: 0.173)
#   - 屋, 店舗, 数 (スコア: 0.173)
#   - 少なめ, 感じる, コスパ (スコア: 0.173)
#   - 量, 少なめ, 感じる (スコア: 0.173)
# ...
#   - ベイ, コート, クラブ (スコア: 0.212)
#   - 台場, ベイ, コート (スコア: 0.111)
#   - ホテル, 東京, ベイ (スコア: 0.106)
#   - 会員, 制, リゾート (スコア: 0.093)
#   - 制, リゾート, ホテル (スコア: 0.093)
# --------------------
# 【石臼挽きそば 石楽】
#   - 天, せい, ろ (スコア: 0.203)
#   - 丼, 蕎麦, セット (スコア: 0.122)
#   - , 豊洲 (スコア: 0.122)
#   - 蕎麦, 食べる, なる (スコア: 0.118)
#   - 鴨, せい, ろ (スコア: 0.112)
#   - 点,  (スコア: 0.102)
#   - 日本, 酒, 美味しい (スコア: 0.089)
# --------------------
# 【磯寿司】
#   - おまかせ, 15, 貫 (スコア: 0.264)
#   - 豊洲, 市場, 寿司 (スコア: 0.223)
#   - 豊洲, 市場, 内 (スコア: 0.145)
#   - 豊洲, 市場, 行く (スコア: 0.142)
#   - , 豊洲 (スコア: 0.141)
#   - , 豊洲, 市場 (スコア: 0.139)
#   - 寿司, 豊洲, 市場 (スコア: 0.135)
# --------------------
# 【社食DELI】
#   - オープン, スペース, なる (スコア: 0.516)
#   - 弁当, 購入, する (スコア: 0.516)
#   - フロンティア, ビル, 内 (スコア: 0.492)
#   - 青海, フロンティア, ビル (スコア: 0.474)
# --------------------
# 【社食デリ】
#   - 値上げ, する, の (スコア: 0.398)
#   - 屋, 集合, する (スコア: 0.398)
#   - 和, 洋, 中 (スコア: 0.398)
#   - 店, 飲食, 店 (スコア: 0.379)
#   - 弁当, 売る, いる (スコア: 0.379)
#   - オフィス, ビル, 1 (スコア: 0.335)
#   - ビル, 1, 階 (スコア: 0.277)
# --------------------
# 【秀徳市場マルマサ】
#   - ある, てる, の (スコア: 0.166)
#   - ログ, 探す, いる (スコア: 0.166)
#   - 炭火, 焼く, くれる (スコア: 0.166)
#   - 食う, 後, 一 (スコア: 0.166)
#   - お通し, マグロ, 中落ち (スコア: 0.166)
#   - 号, 店, 3 (スコア: 0.166)
#   - おでん, 味, 染みる (スコア: 0.166)
# --------------------
# 【笑笑 お台場海浜公園駅前店】
#   - 海浜, 公園, 駅前 (スコア: 0.280)
#   - , 600,  (スコア: 0.231)
#   - 600,  (スコア: 0.205)
#   - 笑, 笑, 笑 (スコア: 0.187)
#   - そば,  (スコア: 0.187)
#   - , 600 (スコア: 0.156)
#   - 台場, 海浜, 公園 (スコア: 0.139)
# --------------------
# 【笑笑 月島駅前店】
#   - 笑, 笑, 笑 (スコア: 0.260)
#   - する, 笑, 笑 (スコア: 0.239)
#   - 20, 代, 前半 (スコア: 0.130)
#   - する, れる, 笑 (スコア: 0.130)
#   - 揚げ, 美味しい, する (スコア: 0.130)
#   - , 月島, 店 (スコア: 0.130)
#   - 若い, 子, 達 (スコア: 0.130)
# --------------------
# 【築地 すし Omakase】
#   - 2, 階, テーブル (スコア: 0.218)
#   - , 築地 (スコア: 0.183)
#   - 熟成, する, れる (スコア: 0.141)
#   - , 000 (スコア: 0.132)
#   - 6,  (スコア: 0.125)
#   - 15,  (スコア: 0.113)
#   - 2, 階, 個室 (スコア: 0.109)
# --------------------
# 【築地 挙母鮨】
#   - 晴海, 通り, 沿い (スコア: 0.213)
#   - 築地, 場外, 市場 (スコア: 0.175)
#   - 8,  (スコア: 0.163)
#   - , モーニング (スコア: 0.152)
#   - 目, 前, 握る (スコア: 0.138)
#   - 特, 上, 握り (スコア: 0.120)
#   - , 30 (スコア: 0.117)
# --------------------
# 【築地さらしなの里】
#   - 老舗, 蕎麦, 屋 (スコア: 0.316)
#   - 十, 割, そば (スコア: 0.201)
#   - そば,  (スコア: 0.187)
#   - 十, 割, 蕎麦 (スコア: 0.151)
#   - , 築地 (スコア: 0.142)
#   - , 新富 (スコア: 0.140)
#   - , 新富, 町 (スコア: 0.140)
# --------------------
# 【築地玉寿司 晴海通り店】
#   - 晴海, 通り, 店 (スコア: 0.484)
#   - 晴海, 通り, 沿い (スコア: 0.239)
#   - , 3 (スコア: 0.204)
#   - , 3,  (スコア: 0.200)
#   - 3,  (スコア: 0.145)
#   - 階, 案内, する (スコア: 0.091)
#   - 日比谷線, 築地, 駅 (スコア: 0.080)
# --------------------
# 【築地秀徳元祖】
#   - 2, 号, 店 (スコア: 0.326)
#   - 3, 号, 店 (スコア: 0.157)
#   - , 500 (スコア: 0.127)
#   - 築地, 寿司, 食べる (スコア: 0.122)
#   - , 500, コース (スコア: 0.116)
#   - 築地, 場外, 市場 (スコア: 0.100)
#   - 赤, 酢, 寿司 (スコア: 0.098)
# --------------------
# 【築地銀だこ ダイバーシティ東京プラザ店】
#   - シティ, フード, コート (スコア: 0.364)
#   - ダイバー, シティ, フード (スコア: 0.323)
#   - 6, 個, 入り (スコア: 0.237)
#   - ダイバー, シティ, 東京 (スコア: 0.134)
#   - , 明太 (スコア: 0.118)
#   - ライブ, 見る, 来る (スコア: 0.118)
#   - 九, 条, ねぎ (スコア: 0.108)
# --------------------
# 【築地青空三代目 本店】
#   - 青空, 三, 代目 (スコア: 0.661)
#   - 築地, 青空, 三 (スコア: 0.545)
#   - , 築地 (スコア: 0.122)
#   - 築地, 寿司, 屋 (スコア: 0.093)
#   - 築地, 場外, 市場 (スコア: 0.089)
#   - 予約, する, 伺う (スコア: 0.041)
#   - 5,  (スコア: 0.039)
# --------------------
# 【築地食堂 源ちゃん アクアシティお台場店】
#   - 食堂, 源, ちゃん (スコア: 0.414)
#   - 築地, 食堂, 源 (スコア: 0.414)
#   - 源, ちゃん, 丼 (スコア: 0.173)
#   - アクアシティ, 台場, 店 (スコア: 0.160)
#   - アクアシティ, 台場, 5 (スコア: 0.084)
#   - 唐, 揚げ, 定食 (スコア: 0.077)
#   - f, 築地, 食堂 (スコア: 0.076)
# --------------------
# 【築地食堂 源ちゃん 有明ガーデン店】
#   - 源, ちゃん, 有明 (スコア: 0.306)
#   - 築地, 食堂, 源 (スコア: 0.290)
#   - 食堂, 源, ちゃん (スコア: 0.290)
#   - 有明, ガーデン, 5 (スコア: 0.169)
#   - 有明, ガーデン, 店 (スコア: 0.155)
#   - ガーデン, 5, 階 (スコア: 0.123)
#   - 魚河岸, フライ, 定食 (スコア: 0.115)
# --------------------
# 【築地食堂 源ちゃん 東京ビックサイト店】
#   - 東京, ビッグ, サイト (スコア: 0.383)
#   - 食堂, 源, ちゃん (スコア: 0.272)
#   - 築地, 食堂, 源 (スコア: 0.272)
#   - ネギ, トロ, しらす (スコア: 0.171)
#   - 唐, 揚げ, セット (スコア: 0.142)
#   - ビッグ, サイト, 東 (スコア: 0.137)
#   - 東, 展示, 棟 (スコア: 0.118)
# --------------------
# 【築地食堂　源ちゃん TFT有明店】
#   - 築地, 食堂, 源 (スコア: 0.276)
#   - 食堂, 源, ちゃん (スコア: 0.248)
#   - 東京, ビッグ, サイト (スコア: 0.233)
#   - 国際, 展示, 場 (スコア: 0.137)
#   - 丼, 鶏, 唐 (スコア: 0.131)
#   - 唐, 揚げ, セット (スコア: 0.104)
#   - トロ, さば, 定食 (スコア: 0.098)
# --------------------
# 【米三角】
#   - 千客万来, 2, 階 (スコア: 0.243)
#   - 豊洲, 市場, 千客万来 (スコア: 0.224)
#   - 先客, 万, 来 (スコア: 0.216)
#   - 笑, 日本, 酒 (スコア: 0.162)
#   - 商業, 施設, 豊洲 (スコア: 0.162)
#   - 豊洲, 先客, 万 (スコア: 0.162)
#   - 施設, 豊洲, 千客万来 (スコア: 0.162)
# --------------------
# 【翠苑】
#   - 刀, 削る, 麺 (スコア: 0.278)
#   - 展示, 場, 正門 (スコア: 0.172)
#   - 国際, 展示, 場 (スコア: 0.168)
#   - 東京, ビッグ, サイト (スコア: 0.144)
#   - 有明, ベイ, モール (スコア: 0.139)
#   - ワンザ, 有明, ベイ (スコア: 0.139)
#   - ベイ, モール, 2 (スコア: 0.115)
# --------------------
# 【肉菜工房うしすけ 台場店】
#   - 入れる, 焼肉, 屋 (スコア: 0.205)
#   - ワン, コメ, ニュー (スコア: 0.171)
#   - うし, すける, さ (スコア: 0.143)
#   - 一緒, 食べる, られる (スコア: 0.137)
#   - うし, すける, 台場 (スコア: 0.108)
#   - 行ける, 焼肉, 屋 (スコア: 0.108)
#   - わん, ちゃん, 用 (スコア: 0.103)
# --------------------
# 【自由が丘 蔭山 有明ガーデン店】
#   - 鶏, 白湯, 塩 (スコア: 0.673)
#   - ガーデン, フード, コート (スコア: 0.272)
#   - 有明, ガーデン, フード (スコア: 0.272)
#   - 鶏, 白湯, ラーメン (スコア: 0.188)
#   - オブ (スコア: 0.169)
#   - フード, コート, ラーメン (スコア: 0.148)
#   - 店, 鶏, 白湯 (スコア: 0.108)
# --------------------
# 【芋蛸 お台場たこやきミュージアム店】
#   - 台場, たこ焼き, ミュージアム (スコア: 0.385)
#   - 台場, たこやき, ミュージアム (スコア: 0.204)
#   - たこ焼き, ミュージアム, 中 (スコア: 0.198)
#   - たこ焼き, ミュージアム, 内 (スコア: 0.192)
#   - デックス, 東京, ビーチ (スコア: 0.181)
#   - , たこ焼き (スコア: 0.161)
#   - 台場, デックス, 東京 (スコア: 0.143)
# --------------------
# 【花水木】
#   - 深川, 不動尊, 参道 (スコア: 0.215)
#   - 門前仲町, 駅, 1 (スコア: 0.215)
#   - 1, 番, 出口 (スコア: 0.186)
#   - 駅, 1, 番 (スコア: 0.181)
#   - 食べる, 放題, コース (スコア: 0.165)
#   - の, わかる, する (スコア: 0.108)
#   - , しゃぶしゃぶ (スコア: 0.108)
# --------------------
# 【茂助だんご 豊洲市場】
#   - 管理, 施設, 棟 (スコア: 0.386)
#   - 豊洲, 市場, 管理 (スコア: 0.292)
#   - 市場, 管理, 施設 (スコア: 0.228)
#   - 施設, 棟, 3 (スコア: 0.165)
#   - 7, 街, 区 (スコア: 0.150)
#   - 物販, 店, 買い物 (スコア: 0.149)
#   - 豊洲, 市場, 内 (スコア: 0.143)
# --------------------
# 【茶寮 伊藤園 有明ガーデン店】
#   - 有明, ガーデン, 店 (スコア: 0.234)
#   - , 抹茶 (スコア: 0.206)
#   - 有明, ガーデン, 内 (スコア: 0.202)
#   - 甘い, さ, 控えめ (スコア: 0.120)
#   - 抹茶, 白玉, あずき (スコア: 0.116)
#   - , ほうじ茶 (スコア: 0.116)
#   - ほうじ茶,  (スコア: 0.116)
# --------------------
# 【菊屋】
#   - かう, 線, 東雲 (スコア: 0.226)
#   - 線, 東雲, 駅 (スコア: 0.226)
#   - 店, かう, 線 (スコア: 0.156)
#   - 江東, 区, 東雲 (スコア: 0.151)
#   - チャーハン,  (スコア: 0.134)
#   - , チャーハン (スコア: 0.132)
#   - 平日, 12,  (スコア: 0.113)
# --------------------
# 【葛西ビアバー】
#   - プレミアム (スコア: 0.417)
#   - 前, なる, いる (スコア: 0.164)
#   - 惹く, れる, ランチ (スコア: 0.152)
#   - 新た, 店, 発見 (スコア: 0.152)
#   - 週, 2, 回 (スコア: 0.152)
#   - 小腹, 空く, 軽い (スコア: 0.152)
#   - ある, 感動, 美味しい (スコア: 0.152)
# --------------------
# 【葛西臨海公園バーベキュー広場】
#   - 葛西, 臨海, 公園 (スコア: 0.491)
#   - 臨海, 公園, 内 (スコア: 0.368)
#   - , 飲む (スコア: 0.232)
#   - 本日, 葛西, 臨海 (スコア: 0.184)
#   - 準備, する, くれる (スコア: 0.184)
#   - する, 値段, 割 (スコア: 0.184)
#   - ある, 子供, 達 (スコア: 0.184)
# --------------------
# 【蔵乃ゑ】
#   - する, くれる, 置く (スコア: 0.454)
#   - 行く, 提供, する (スコア: 0.454)
#   - 食べる, られる, 飲める (スコア: 0.454)
#   - 大江戸, 温泉, 物語 (スコア: 0.433)
#   - フード, コート, 行く (スコア: 0.337)
#   - 提供, する, くれる (スコア: 0.284)
# --------------------
# 【親子丼 トリカイ エクスプレス ダイバーシティ東京店】
#   - する, 親子, 丼 (スコア: 0.183)
#   - 親子, 丼, 店 (スコア: 0.183)
#   - 親子, 丼,  (スコア: 0.168)
#   - シティ, 東京, 店 (スコア: 0.142)
#   - ダイバー, シティ, フード (スコア: 0.126)
#   - 唐, 揚げ, 定食 (スコア: 0.124)
#   - 揚げ, チキン, 南蛮 (スコア: 0.122)
# --------------------
# 【豊洲市場 共同食堂】
#   - 棟, 5, 階 (スコア: 0.346)
#   - 社, 食, スタイル (スコア: 0.173)
#   - 客, 向け, 店 (スコア: 0.173)
#   - ４, ０, ８ (スコア: 0.173)
#   - なる, 水産, 仲 (スコア: 0.173)
#   - 営業, 開始, する (スコア: 0.173)
#   - ２, ０, ４ (スコア: 0.173)
# --------------------
# 【豊海ワイン食堂】
#   - センター, ビル, 1 (スコア: 0.501)
#   - 一, 手間, かける (スコア: 0.501)
#   - スパークリングワイン, 乾杯, する (スコア: 0.501)
#   - 会社, 飲む, 会 (スコア: 0.353)
#   - ビル, 1, 階 (スコア: 0.349)
# --------------------
# 【越後屋 竹千代】
#   - 有明, セントラルタワー, 2 (スコア: 0.347)
#   - 東京, ビッグ, サイト (スコア: 0.325)
#   - 竹, 千, 代 (スコア: 0.312)
#   - セントラルタワー, 2, 階 (スコア: 0.301)
#   - 国際, 展示, 場 (スコア: 0.132)
#   - 三, 元, 豚 (スコア: 0.130)
#   - 定食,  (スコア: 0.124)
# --------------------
# 【道頓堀 赤鬼】
#   - 台場, たこ焼き, ミュージアム (スコア: 0.360)
#   - たこ焼き,  (スコア: 0.201)
#   - たこ焼き, ミュージアム, 内 (スコア: 0.154)
#   - 区, 台場, たこ焼き (スコア: 0.119)
#   - 三, 年, 連続 (スコア: 0.119)
#   - 年, 連続, 選出 (スコア: 0.119)
#   - 連続, 選出, する (スコア: 0.119)
# --------------------
# 【都会の農園バーベキュー広場】
#   - ダイバー, シティ, 屋上 (スコア: 0.370)
#   - ダイバー, シティ, 東京 (スコア: 0.276)
#   - シティ, 東京, プラザ (スコア: 0.235)
#   - シティ, 屋上, bbq (スコア: 0.194)
#   - やってくる, ダイバー, シティ (スコア: 0.185)
#   - 台場, ダイバー, シティ (スコア: 0.174)
#   - アルコール, 飲む, 放題 (スコア: 0.164)
# --------------------
# 【都立潮風公園バーベキュー広場】
#   - 団体, する, せる (スコア: 0.331)
#   - できる, そう, 感じ (スコア: 0.331)
#   - 購入, できる, そう (スコア: 0.331)
#   - 気分, 予約, する (スコア: 0.331)
#   - エリア, エリア, の (スコア: 0.331)
#   - 予約, する, ある (スコア: 0.279)
#   - , 今年 (スコア: 0.272)
# --------------------
# 【金澤濃厚豚骨ラーメン 神仙 アクアシティ店】
#   - 濃厚, 豚, 骨 (スコア: 0.595)
#   - 豚, 骨, 醤油 (スコア: 0.368)
#   - ラーメン, 国技, 館 (スコア: 0.361)
#   - 豚, 骨, ラーメン (スコア: 0.314)
#   - 骨, 醤油, ラーメン (スコア: 0.170)
#   - ら, ー, めん (スコア: 0.154)
#   - 骨, 醤油, ら (スコア: 0.123)
# --------------------
# 【鉄板焼 銀杏】
#   - グランド, ニッコー, 東京 (スコア: 0.224)
#   - 階, 鉄板, 焼き (スコア: 0.223)
#   - ３, ０, 階 (スコア: 0.213)
#   - 鉄板, 焼き, 屋 (スコア: 0.198)
#   - ニッコー, 東京, 台場 (スコア: 0.168)
#   - 鉄板, 焼き, 店 (スコア: 0.165)
#   - 眺める, 鉄板, 焼き (スコア: 0.149)
# --------------------
# 【銀座 深川玄庵】
#   - 蕎麦, 食べる, 店 (スコア: 0.134)
#   - の, 残念, 酒 (スコア: 0.134)
#   - ボトル,  (スコア: 0.134)
#   - 風味, 豊か, 味わい (スコア: 0.134)
#   - 特別, コース, 予約 (スコア: 0.134)
#   - 出る, くる, 本格 (スコア: 0.134)
#   - やすい, ある, 店 (スコア: 0.134)
# --------------------
# 【銀座 祭や】
#   - 焼酎, 日本, 酒 (スコア: 0.146)
#   - 酒, 日本, 酒 (スコア: 0.132)
#   - する, せる, いただく (スコア: 0.112)
#   - 同僚, 送別, 会 (スコア: 0.102)
#   - 朝, 5, やる (スコア: 0.102)
#   - 5, やる, てる (スコア: 0.102)
#   - 朝, 空く, てる (スコア: 0.102)
# --------------------
# 【長寿韓酒房 ダイバーシティ東京プラザ店】
#   - みぞ, 冷, 麺 (スコア: 0.625)
#   - 韓, 酒, 房 (スコア: 0.408)
#   - 長寿, 韓, 酒 (スコア: 0.408)
#   - 冷, 麺,  (スコア: 0.141)
#   - 麺,  (スコア: 0.134)
#   - 冷, 麺, 食べる (スコア: 0.117)
#   - 参, 鶏, 湯 (スコア: 0.100)
# --------------------
# 【長寿韓酒房 有明店】
#   - 韓, 酒, 房 (スコア: 0.458)
#   - 長寿, 韓, 酒 (スコア: 0.420)
#   - 国際, 展示, 場 (スコア: 0.192)
#   - 石, 焼, ビビンバ (スコア: 0.154)
#   - 東京, ビッグ, サイト (スコア: 0.136)
#   - ジャー, ジャー, 麺 (スコア: 0.102)
#   - 展示, 場, 正門 (スコア: 0.093)
# --------------------
# 【長生庵】
#   - 築地, 場外, 市場 (スコア: 0.210)
#   - 老舗, 蕎麦, 屋 (スコア: 0.168)
#   - 鮪, 中, トロ (スコア: 0.154)
#   - 中, トロ, 赤身 (スコア: 0.144)
#   - 築地, 駅, 徒歩 (スコア: 0.142)
#   - , 築地 (スコア: 0.137)
#   - 丼, 蕎麦, セット (スコア: 0.132)
# --------------------
# 【門仲STAND】
#   - , 度 (スコア: 0.499)
#   - 自然, 派, ワイン (スコア: 0.297)
#   - , 日々 (スコア: 0.187)
#   - 日々, 記録, 用 (スコア: 0.187)
#   - , 日々, 記録 (スコア: 0.187)
#   - 記録, 用,  (スコア: 0.187)
#   - 絶品,  (スコア: 0.174)
# --------------------
# 【門前仲町 らっきょう】
#   - 吸い込む, れる, みる (スコア: 0.138)
#   - , 定食 (スコア: 0.138)
#   - どれ, 丁寧, 美味しい (スコア: 0.138)
#   - 移転, する, の (スコア: 0.138)
#   - 見つける, 吸い込む, れる (スコア: 0.138)
#   - ランチ, 850,  (スコア: 0.138)
#   - 女将, 素敵, 方 (スコア: 0.138)
# --------------------
# 【青海珈琲 青海本店】
#   - テレコム, センター, 駅 (スコア: 0.399)
#   - 青海, フロンティア, ビル (スコア: 0.283)
#   - 技術, 研究, センター (スコア: 0.205)
#   - 産業, 技術, 研究 (スコア: 0.205)
#   - 水, 出し, アイス (スコア: 0.196)
#   - 出し, アイス, コーヒー (スコア: 0.196)
#   - ビル, １, 階 (スコア: 0.152)
# --------------------
# 【青海食堂】
#   - テレコム, センター, 駅 (スコア: 0.255)
#   - 11,  (スコア: 0.116)
#   - 港湾, 関係, 者 (スコア: 0.109)
#   - , 20, 客 (スコア: 0.109)
#   - 客, ３, 割 (スコア: 0.109)
#   - 食堂, テレコム, センター (スコア: 0.109)
#   - 者, 向け, 食堂 (スコア: 0.109)
# --------------------
# 【韓美膳 有明ガーデン店】
#   - 石, 焼, ビビンバ (スコア: 0.381)
#   - ガーデン, フード, コート (スコア: 0.253)
#   - 有明, ガーデン, フード (スコア: 0.253)
#   - フード, コート, 韓国 (スコア: 0.210)
#   - , ハーフ (スコア: 0.190)
#   - フード, コート, ランチ (スコア: 0.125)
#   - 有明, ガーデン, 店 (スコア: 0.121)
# --------------------
# 【頑者NEXT LEVEL】
#   - ラーメン, 国技, 館 (スコア: 0.657)
#   - 海老, つけ, 麺 (スコア: 0.263)
#   - 東京, ラーメン, 国技 (スコア: 0.219)
#   - 台場, ラーメン, 国技 (スコア: 0.204)
#   - 特製, つけ, 麺 (スコア: 0.201)
#   - つけ, 麺,  (スコア: 0.145)
#   - 豚, 骨, 魚介 (スコア: 0.138)
# --------------------
# 【飛車角 有明ガーデン店】
#   - カルビ, ハラ, ミ (スコア: 0.178)
#   - ビビンバ, 冷, 麺 (スコア: 0.162)
#   - 有明, ガーデン, 店 (スコア: 0.156)
#   - 上, タン, 塩 (スコア: 0.131)
#   - 個室, 案内, する (スコア: 0.131)
#   - 冷, 麺, セット (スコア: 0.108)
#   - できる, ランチ, セット (スコア: 0.103)
# --------------------
# 【餃子の王様 龍吟 ダイバーシティ店】
#   - 麻, 婆, 豆腐 (スコア: 0.218)
#   - 6, 階, 街 (スコア: 0.184)
#   - ダイバー, シティ, 6 (スコア: 0.138)
#   - 持つ, くる, テーブル (スコア: 0.116)
#   - チャーハン, セット, 1100 (スコア: 0.116)
#   - 1250,  (スコア: 0.111)
#   - 餃子, 6, 個 (スコア: 0.111)
# --------------------
# 【餃子酒家 築地店】
#   - 町, 中華, 屋 (スコア: 0.269)
#   - 町, 餃子, 酒家 (スコア: 0.215)
#   - 新富, 町, 餃子 (スコア: 0.215)
#   - チャーハン, ラーメン, セット (スコア: 0.205)
#   - 向け, コスパ, 良い (スコア: 0.161)
#   - 中華, 屋, 餃子 (スコア: 0.161)
#   - セット, ランチ, セット (スコア: 0.154)
# --------------------
# 【香港飲茶楼 ル・パルク】
#   - 東京, ビッグ, サイト (スコア: 0.456)
#   - 五目, あん, かける (スコア: 0.228)
#   - 国際, 展示, 場 (スコア: 0.207)
#   - ビッグ, サイト, 内 (スコア: 0.165)
#   - 青, 椒, 絲 (スコア: 0.151)
#   - 東, 展示, 棟 (スコア: 0.136)
#   - ビッグ, サイト, 東 (スコア: 0.126)
# --------------------
# 【魚とと 東京ビックサイトEat iT!店】
#   - 東京, ビッグ, サイト (スコア: 0.299)
#   - トロ, 二色, 丼 (スコア: 0.168)
#   - 海鮮, 健康, 丼 (スコア: 0.168)
#   - ネギ, トロ, 二色 (スコア: 0.168)
#   - トロ, 鉄火, 丼 (スコア: 0.160)
#   - サイト, 西, 棟 (スコア: 0.160)
#   - ネギ, トロ, 鉄火 (スコア: 0.160)
# --------------------
# 【魚民 勝どき駅前店】
#   - 長居, する, しまう (スコア: 0.348)
#   - 思う, 1, 品 (スコア: 0.220)
#   - 日曜日, 20,  (スコア: 0.220)
#   - ラーメン, 頼む, みる (スコア: 0.220)
#   - 載る, いる, の (スコア: 0.220)
#   - 人目, する, 楽しめる (スコア: 0.220)
#   - 丁寧, 気持ちよい, 過ごせる (スコア: 0.220)
# --------------------
# 【魚民 潮見駅前店】
#   - 回, 以上, お世話 (スコア: 0.360)
#   - 生ビール, キリン, 搾る (スコア: 0.360)
#   - の, 先週, 水曜日 (スコア: 0.360)
#   - 位,  (スコア: 0.360)
#   - 以上, お世話, なる (スコア: 0.360)
#   - ０, 回, 以上 (スコア: 0.360)
#   - 毎日, 更新, する (スコア: 0.360)
# --------------------
# 【魚河岸トミーナ 豊洲市場店】
#   - 豊洲, 市場, 内 (スコア: 0.286)
#   - 市場, 内, 唯一 (スコア: 0.173)
#   - 行う, くる,  (スコア: 0.172)
#   - 豊洲, 市場, 管理 (スコア: 0.146)
#   - 市場, 管理, 棟 (スコア: 0.146)
#   - , 30 (スコア: 0.113)
#   - クリーム, パスタ, する (スコア: 0.106)
# --------------------
# 【鮒忠 有明店】
#   - チキン, 南蛮, 定食 (スコア: 0.313)
#   - 国際, 展示, 場 (スコア: 0.199)
#   - 東京, ビッグ, サイト (スコア: 0.191)
#   - 唐, 揚げ, 定食 (スコア: 0.162)
#   - ランチ, チキン, 南蛮 (スコア: 0.136)
#   - , 焼き鳥 (スコア: 0.127)
#   - 展示, 場, 正門 (スコア: 0.116)
# --------------------
# 【鮨 もりなり】
#   - 修行, する, れる (スコア: 0.207)
#   - ネタ, 大きい, 食べる (スコア: 0.148)
#   - 予約, する, ポイント (スコア: 0.148)
#   - , 000 (スコア: 0.128)
#   - お腹, いっぱい, なる (スコア: 0.126)
#   - 前, 予約, する (スコア: 0.123)
#   - 大きい, 食べる, 応え (スコア: 0.113)
# --------------------
# 【鮨 玉かがり 天ぷら 玉衣】
#   - グランド, ニッコー, 東京 (スコア: 0.466)
#   - ニッコー, 東京, 台場 (スコア: 0.333)
#   - グランド, ニッコー, 台場 (スコア: 0.245)
#   - ホテル, 30, 階 (スコア: 0.203)
#   - 台場, 30, 階 (スコア: 0.157)
#   - 台場, グランド, ニッコー (スコア: 0.146)
#   - 江戸, 朝, 寿司 (スコア: 0.133)
# --------------------
# 【鮨 酒 肴 杉玉 新木場】
#   - 肴, 杉, 玉 (スコア: 0.191)
#   - 酒, 肴, 杉 (スコア: 0.191)
#   - 鮨, 酒, 肴 (スコア: 0.191)
#   - 限定, 10, 食 (スコア: 0.170)
#   - 創作, 系, 多い (スコア: 0.128)
#   - , 新木場 (スコア: 0.128)
#   - 魅力,  (スコア: 0.113)
# --------------------
# 【鮨　宇田川】
#   - 有明, パーク, ビル (スコア: 0.323)
#   - にぎる, 1,  (スコア: 0.204)
#   - , 5, 人前 (スコア: 0.176)
#   - 有明, ワシントン, ホテル (スコア: 0.149)
#   - , ,  (スコア: 0.142)
#   - 展示, 会, 昼食 (スコア: 0.117)
#   - 昼, 御飯,  (スコア: 0.115)
# --------------------
# 【鮨･酒･肴 杉玉 葛西店】
#   - , ポテト, サラダ (スコア: 0.144)
#   - 限定, 10, 食 (スコア: 0.128)
#   - 赤, 酢, シャリ (スコア: 0.125)
#   - , ポテト (スコア: 0.114)
#   - , 990 (スコア: 0.101)
#   - 丼,  (スコア: 0.084)
#   - コース, 予約, する (スコア: 0.077)
# --------------------
# 【鮮魚旬菜 魚福】
#   - 国際, 展示, 場 (スコア: 0.236)
#   - 東京, ビッグ, サイト (スコア: 0.157)
#   - 平日, 11, 50 (スコア: 0.141)
#   - toc, 有明, 3 (スコア: 0.141)
#   - toc, 有明, ビル (スコア: 0.135)
#   - 50, 頃, 到着 (スコア: 0.135)
#   - 展示, 場, 駅 (スコア: 0.133)
# --------------------
# 【鶏味座 ダイバーシティ東京プラザ店】
#   - 究極, 親子, 丼 (スコア: 0.794)
#   - 親子, 丼,  (スコア: 0.182)
#   - ら, ー, めん (スコア: 0.132)
#   - 親子, 丼, 食べる (スコア: 0.128)
#   - 丼,  (スコア: 0.115)
#   - 親子, 丼, する (スコア: 0.090)
#   - ー, めん, セット (スコア: 0.090)
# --------------------
# 【鶏鬨はなれ 勝どき清澄通り店】
#   - 勝どき, 駅, 徒歩 (スコア: 0.330)
#   - 十, 割, そば (スコア: 0.197)
#   - 十, 割, 蕎麦 (スコア: 0.157)
#   - , 鶏 (スコア: 0.133)
#   - , 勝どき (スコア: 0.124)
#   - 大江戸, 線, 勝どき (スコア: 0.124)
#   - 徒歩, 5, 清澄 (スコア: 0.124)
# --------------------
# 【鶴橋風月 お台場店】
#   - アクアシティ, 台場, 6 (スコア: 0.195)
#   - 台場, 6, 階 (スコア: 0.150)
#   - 思う, いる, 台場 (スコア: 0.119)
#   - , 焼きそば (スコア: 0.113)
#   - 台場, 6, f (スコア: 0.109)
#   - 2025, 年, 3 (スコア: 0.109)
#   - 前, 焼く, くれる (スコア: 0.098)
# --------------------
# 【黄金鉄鍋餃子 HUG】
#   - 鉄, 鍋, 餃子 (スコア: 0.420)
#   - 餃子, 6, 個 (スコア: 0.267)
#   - 銀座, 築地, 方面 (スコア: 0.140)
#   - , ﾟ (スコア: 0.136)
#   - 築地, 4, 丁目 (スコア: 0.133)
#   - 4, 丁目, 交差点 (スコア: 0.133)
#   - 東, 銀座, 築地 (スコア: 0.124)
# --------------------
# 【龍記 お台場デックス東京ビーチ店】
#   - 刀, 削る, 麺 (スコア: 0.785)
#   - 麻, 婆, 豆腐 (スコア: 0.273)
#   - 石鍋, 麻, 婆 (スコア: 0.109)
#   - 麻, 辣刀削, 麺 (スコア: 0.104)
#   - 来る, 今日, 日替わり (スコア: 0.073)
#   - だれ, 鶏, 定食 (スコア: 0.073)
#   - 削る, 麺,  (スコア: 0.073)
# --------------------
# 【＆ Ovo】
#   - 1, 階, 2 (スコア: 0.230)
#   - カフェ,  (スコア: 0.222)
#   - 階, 2, 階 (スコア: 0.220)
#   - 4, 月, 28 (スコア: 0.211)
#   - 築地, 本願寺, 前 (スコア: 0.205)
#   - ソムリエ, 厳選, ワイン (スコア: 0.184)
#   - , モーニング (スコア: 0.176)
# --------------------
