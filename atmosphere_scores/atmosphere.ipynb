# %%
import pandas as pd
from janome.tokenizer import Tokenizer

# --- 準備 ---
# 上記の atmosphere_dictionary をここに貼り付け
atmosphere_dictionary = {
    'quiet': ['静か', '落ち着く', '穏やか', '静寂', 'ゆっくり', 'ひっそり'],
    'lively': ['賑やか', 'にぎやか', 'ガヤガヤ', '活気', 'ワイワイ', '盛り上がる'],
    'stylish': ['おしゃれ', 'オシャレ', 'スタイリッシュ', 'モダン', '洗練', 'デザイン'],
    'cozy': ['アットホーム', '隠れ家', 'こぢんまり', 'アットホーム', '温かい'],
    'formal': ['高級', 'ラグジュアリー', 'フォーマル', '贅沢', '記念日', '接待'],
}

try:
    df = pd.read_csv('/Users/dangararara/lecture/miraisouzou/csv/odaiba_reviews.csv')
except FileNotFoundError:
    print("エラー: 'odaiba_reviews.csv'が見つかりません。")
    exit()

# --- メイン処理 ---
if __name__ == '__main__':
    # 店舗ごとに口コミを一つの文章にまとめる
    shop_docs = df.groupby('shop_name')['review_text'].apply(lambda x: ' '.join(x.dropna())).reset_index()

    # スコアを格納するためのリストを準備
    atmosphere_scores = []
    total_shops = len(shop_docs)
    
    print("各店舗の雰囲気スコアを計算中...")

    # 1店舗ずつ処理
    for index, row in shop_docs.iterrows():
        shop_name = row['shop_name']
        review_text = row['review_text']
        
        # この店舗のスコアを記録する辞書
        scores = {'shop_name': shop_name}
        
        # レビューの総文字数を計算（スコアの正規化のため）
        total_length = len(review_text)
        if total_length == 0:
            total_length = 1 # ゼロ除算を避ける

        # atmosphere_dictionaryの各カテゴリについてスコアを計算
        for category, keywords in atmosphere_dictionary.items():
            count = 0
            # カテゴリ内の各キーワードが、口コミに何回出現するかを数える
            for keyword in keywords:
                count += review_text.count(keyword)
            
            # 出現回数を総文字数で割り、スコアとする（出現密度）
            # 1000を掛けて、スコアの桁を分かりやすく調整
            scores[category + '_score'] = (count / total_length) * 1000

        atmosphere_scores.append(scores)
        print(f"  [{index + 1}/{total_shops}] {shop_name} のスコア計算完了．")

    # 結果を新しいDataFrameに変換
    df_atmosphere = pd.DataFrame(atmosphere_scores)

    print("\n--- 雰囲気スコア計算結果（上位5店舗）---")
    print(df_atmosphere.head())

    # 結果をCSVに保存
    df_atmosphere.to_csv('csv/shop_atmosphere_scores.csv', index=False, encoding='utf-8-sig')
    print("\n計算結果を「shop_atmosphere_scores.csv」に保存しました。")
# Out:
# 各店舗の雰囲気スコアを計算中...
#   [1/563] 1129 by Ogawa のスコア計算完了．
#   [2/563] 82 築地店 のスコア計算完了．
#   [3/563] ABURI 百貫 有明ガーデン店 のスコア計算完了．
#   [4/563] ARIAKE ARENA CAFE のスコア計算完了．
#   [5/563] ARIAKE ARENA DINING MOON RIVER のスコア計算完了．
#   [6/563] AkeruE のスコア計算完了．
#   [7/563] Ariake Miraie のスコア計算完了．
#   [8/563] BBQ PLAY GROUND お台場デックス東京ビーチ店 のスコア計算完了．
#   [9/563] BISTRO うしすけ のスコア計算完了．
#   [10/563] BLUE TABLE Odaiba のスコア計算完了．
#   [11/563] Bistro961 のスコア計算完了．
#   [12/563] Bomb! Dogs のスコア計算完了．
#   [13/563] Brew33 Bar のスコア計算完了．
#   [14/563] CAFE TERIA BLUE のスコア計算完了．
#   [15/563] Cha pi のスコア計算完了．
#   [16/563] Chez コバラヘッタ 有明ガーデン店 のスコア計算完了．
#   [17/563] CoCo壱番屋 ワンザ有明店 のスコア計算完了．
#   [18/563] Cuore のスコア計算完了．
#   [19/563] D-ラウンジ のスコア計算完了．
#   [20/563] DAIBA のスコア計算完了．
#   [21/563] DOG DEPT お台場東京ビーチ店 のスコア計算完了．
#   [22/563] DOLCE VITA のスコア計算完了．
#   [23/563] Deli&Cafe Uran のスコア計算完了．
#   [24/563] Domino's Pizza  ARIAKE GARDEN のスコア計算完了．
#   [25/563] Eat it! 東京ビッグサイト店 のスコア計算完了．
#   [26/563] FARMS' KITCHEN MIKIKE TOKYO ODAIBA のスコア計算完了．
#   [27/563] GODIVA アクアシティお台場店 のスコア計算完了．
#   [28/563] GODIVA ダイバーシティ東京プラザ店 のスコア計算完了．
#   [29/563] GOKUGOKU 有明ガーデン店 のスコア計算完了．
#   [30/563] GREAT STEAK のスコア計算完了．
#   [31/563] GUNDAM Café　キッチンカー のスコア計算完了．
#   [32/563] Green×Green のスコア計算完了．
#   [33/563] H.B.GRILL のスコア計算完了．
#   [34/563] HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [35/563] HIRO ダイバーシティ東京店 のスコア計算完了．
#   [36/563] HUNZA のスコア計算完了．
#   [37/563] Hobson’s アクアシティお台場 のスコア計算完了．
#   [38/563] KING OF THE PIRATES のスコア計算完了．
#   [39/563] L'Agréable Esprit de GAMIN のスコア計算完了．
#   [40/563] LAWSON Tokyoビッグベイ店 のスコア計算完了．
#   [41/563] LAWSON お台場店 のスコア計算完了．
#   [42/563] LAWSON しののめ店 のスコア計算完了．
#   [43/563] LAWSON りんかい線東雲駅店 のスコア計算完了．
#   [44/563] LAWSON アクアシティお台場 のスコア計算完了．
#   [45/563] LAWSON フジテレビ店 のスコア計算完了．
#   [46/563] LAWSON ポートストア有明 のスコア計算完了．
#   [47/563] LAWSON 国際展示場駅前店 のスコア計算完了．
#   [48/563] LAWSON 有明コロシアム前店 のスコア計算完了．
#   [49/563] LAWSON 有明セントラルタワー店 のスコア計算完了．
#   [50/563] LAWSON 東京テレポート駅前店 のスコア計算完了．
#   [51/563] LAWSON 東京ビッグサイトエントランス のスコア計算完了．
#   [52/563] LAWSON 東雲一丁目店 のスコア計算完了．
#   [53/563] LAWSON 相鉄グランドフレッサ有明店 のスコア計算完了．
#   [54/563] LAWSON Ｈ台場駅前店 のスコア計算完了．
#   [55/563] Louis Hamburger Restaurant のスコア計算完了．
#   [56/563] MOMI&TOY'S 有明ガーデン店 のスコア計算完了．
#   [57/563] MONPAL 8 のスコア計算完了．
#   [58/563] N．Y．Kカフェ お台場・デックス東京ビーチ のスコア計算完了．
#   [59/563] OEDO ARIAKE STYLE のスコア計算完了．
#   [60/563] OSMIC DISH のスコア計算完了．
#   [61/563] Ozgur Kitchen Kebab のスコア計算完了．
#   [62/563] PATISSERIE L11S のスコア計算完了．
#   [63/563] PERFECT BEER STAND MONNAKA のスコア計算完了．
#   [64/563] PHO365 のスコア計算完了．
#   [65/563] PIZZA SALVATORE CUOMO 豊洲 のスコア計算完了．
#   [66/563] PIZZA&WINE カヤバール 有明ガーデン店 のスコア計算完了．
#   [67/563] PLANT LOVE のスコア計算完了．
#   [68/563] Pacific PICKLE CLUB のスコア計算完了．
#   [69/563] R's Cafe のスコア計算完了．
#   [70/563] RESTAURANT WHITE ART のスコア計算完了．
#   [71/563] RIN&GOカレー 東京有明セントラルタワー店 のスコア計算完了．
#   [72/563] RISTORANTE OZIO のスコア計算完了．
#   [73/563] SAUS のスコア計算完了．
#   [74/563] SONAE CAFE のスコア計算完了．
#   [75/563] STONE FACTORY Jr. のスコア計算完了．
#   [76/563] SWITCH STAND ODAIBA のスコア計算完了．
#   [77/563] Seaside Café SOLARIS のスコア計算完了．
#   [78/563] Sky Restaurant シーガル のスコア計算完了．
#   [79/563] TGI FRIDAYS 有明ガーデン店 のスコア計算完了．
#   [80/563] TGIフライデーズ お台場アクアシティ店 のスコア計算完了．
#   [81/563] THE BBQ BEACH in AQUA CITY ODAIBA のスコア計算完了．
#   [82/563] THEキャラCAFE お台場デックス店 のスコア計算完了．
#   [83/563] The Cabaret のスコア計算完了．
#   [84/563] The Grill on 30th のスコア計算完了．
#   [85/563] The Lobby Cafe のスコア計算完了．
#   [86/563] Tokyo 串家 のスコア計算完了．
#   [87/563] Trattoria&Pizzeria LOGIC お台場 のスコア計算完了．
#   [88/563] WAGYU USHITOMI GINZA のスコア計算完了．
#   [89/563] WINESTAND TEO のスコア計算完了．
#   [90/563] WOOD DESIGN PARK お台場店 のスコア計算完了．
#   [91/563] YORIMICHI Odaiba のスコア計算完了．
#   [92/563] Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉 のスコア計算完了．
#   [93/563] bills お台場 のスコア計算完了．
#   [94/563] creperie kenny's ダイバーシティ店 のスコア計算完了．
#   [95/563] da pai dang 105 有明ガーデン店 のスコア計算完了．
#   [96/563] mal D'amour のスコア計算完了．
#   [97/563] milky70 since1951 アクアシティお台場店 のスコア計算完了．
#   [98/563] mode super smoothie のスコア計算完了．
#   [99/563] root C 日本科学未来館 5Fロビー のスコア計算完了．
#   [100/563] the BAR のスコア計算完了．
#   [101/563] the open bakery のスコア計算完了．
#   [102/563] あのり のスコア計算完了．
#   [103/563] あばら大根 西葛西店 のスコア計算完了．
#   [104/563] いろり庵 きらく 国際展示場駅店 のスコア計算完了．
#   [105/563] うなぎ 明月川 豊洲店 のスコア計算完了．
#   [106/563] おいらんち 葛西駅前店 のスコア計算完了．
#   [107/563] おぼんdeごはん ダイバーシティ東京プラザ店 のスコア計算完了．
#   [108/563] お食事処 ゆき のスコア計算完了．
#   [109/563] かつゑもん ダイバーシティ東京プラザ のスコア計算完了．
#   [110/563] がぜん 有明 のスコア計算完了．
#   [111/563] くいもの屋わん お台場デックス東京ビーチ店 のスコア計算完了．
#   [112/563] くずし割烹 天ぷら竹の庵 東銀座店 のスコア計算完了．
#   [113/563] こだわりから揚げの酒処 くらふと のスコア計算完了．
#   [114/563] こなな 有明ガーデン店 のスコア計算完了．
#   [115/563] こめらく みんなで、お茶漬け日和。 有明ガーデン店 のスコア計算完了．
#   [116/563] さち福や 台場アクアシティ店 のスコア計算完了．
#   [117/563] さち福やCAFE 有明ガーデン のスコア計算完了．
#   [118/563] しゃぶしゃぶ 吟半 お台場店 のスコア計算完了．
#   [119/563] しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場 のスコア計算完了．
#   [120/563] しゃぶ食べ 有明ガーデン店 のスコア計算完了．
#   [121/563] しゅん のスコア計算完了．
#   [122/563] すき家 ワンザ有明店 のスコア計算完了．
#   [123/563] すき家 東雲晴海通り店 のスコア計算完了．
#   [124/563] すしざんまい 奥の院 のスコア計算完了．
#   [125/563] すしざんまい 築地駅前店 のスコア計算完了．
#   [126/563] すし処おかめ のスコア計算完了．
#   [127/563] せきどうばなな のスコア計算完了．
#   [128/563] そじ坊 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [129/563] そじ坊 ワンザ有明店 のスコア計算完了．
#   [130/563] そなエリア東京バーベキューガーデン のスコア計算完了．
#   [131/563] たけぞー のスコア計算完了．
#   [132/563] たこやきやの元祖 本家 会津屋 お台場店 のスコア計算完了．
#   [133/563] たこ家道頓堀くくる お台場たこ焼きミュージアム店 のスコア計算完了．
#   [134/563] つきじ丼匠 のスコア計算完了．
#   [135/563] つきぢ神楽寿司 豊洲市場店 のスコア計算完了．
#   [136/563] つけ麺らーめん春樹 お台場店 のスコア計算完了．
#   [137/563] つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店 のスコア計算完了．
#   [138/563] てしごとや ふくの鳥 木場店 のスコア計算完了．
#   [139/563] てっぱん屋台 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [140/563] とんかつ八千代 のスコア計算完了．
#   [141/563] どうとんぼり神座 有明ガーデン店 のスコア計算完了．
#   [142/563] なんで、や お台場店 のスコア計算完了．
#   [143/563] にばん家 勝どき のスコア計算完了．
#   [144/563] ねぎま屋 武蔵 葛西店 のスコア計算完了．
#   [145/563] ねこねこチーズケーキ 有明ガーデンシティ店 のスコア計算完了．
#   [146/563] はなまるうどん ダイバーシティ東京店 のスコア計算完了．
#   [147/563] はなまる屋 アクアシティお台場店 のスコア計算完了．
#   [148/563] ふくの鳥 東陽町 のスコア計算完了．
#   [149/563] ふぐ倶楽部ビルヂング のスコア計算完了．
#   [150/563] ほおずきや のスコア計算完了．
#   [151/563] ほっともっと 東雲店 のスコア計算完了．
#   [152/563] ぼてや アクアシティお台場店 のスコア計算完了．
#   [153/563] まいばすけっと 台場1丁目店 のスコア計算完了．
#   [154/563] まはらに のスコア計算完了．
#   [155/563] むら田 のスコア計算完了．
#   [156/563] やまちゃん お台場店 のスコア計算完了．
#   [157/563] アイランド・ヴィンテージ・コーヒー 台場店 のスコア計算完了．
#   [158/563] アニミル お台場店 のスコア計算完了．
#   [159/563] アマラ ダイバーシティ東京店 のスコア計算完了．
#   [160/563] アルポルト 東京ビッグサイト店 のスコア計算完了．
#   [161/563] ア・タ・ゴール のスコア計算完了．
#   [162/563] イオンスタイル 有明ガーデン のスコア計算完了．
#   [163/563] イタリアン酒場 パステーカ のスコア計算完了．
#   [164/563] イマーシブ・フォート東京 のスコア計算完了．
#   [165/563] インコントロ オステリア&グリル のスコア計算完了．
#   [166/563] インドレストラン＆バー ムナル のスコア計算完了．
#   [167/563] インド料理ムンバイ アクアシティお台場店 のスコア計算完了．
#   [168/563] ウイスキーボイス 台場 のスコア計算完了．
#   [169/563] ウェンディーズ・ファーストキッチン アクアシティお台場店 のスコア計算完了．
#   [170/563] ウマミバーガー 有明ガーデン店 のスコア計算完了．
#   [171/563] エクセルシオール カフェ ダイバーシティ東京プラザ店 のスコア計算完了．
#   [172/563] エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店 のスコア計算完了．
#   [173/563] エグゼクティブラウンジ のスコア計算完了．
#   [174/563] エスプレッソ アメリカーノ テレコムセンター店 のスコア計算完了．
#   [175/563] エッグスンシングス お台場店 のスコア計算完了．
#   [176/563] エフアイランド のスコア計算完了．
#   [177/563] エフカイビーチ のスコア計算完了．
#   [178/563] オイスターハウス お台場店 のスコア計算完了．
#   [179/563] オリジナルパンケーキハウス 有明ガーデン店 のスコア計算完了．
#   [180/563] オーケー お台場店 のスコア計算完了．
#   [181/563] オーケー 東雲店 のスコア計算完了．
#   [182/563] オーシャンクラブビュッフェ デックス東京ビーチ店 のスコア計算完了．
#   [183/563] オーシャン東九フェリー のスコア計算完了．
#   [184/563] オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明) のスコア計算完了．
#   [185/563] カザーナ お台場店 のスコア計算完了．
#   [186/563] カツオたまご食堂 のスコア計算完了．
#   [187/563] カフェ ラ・ボエム お台場 のスコア計算完了．
#   [188/563] カフェ&ミール ムジ 東京有明 のスコア計算完了．
#   [189/563] カフェテラス　ロイヤル のスコア計算完了．
#   [190/563] カフェ＆レストラン レインボー のスコア計算完了．
#   [191/563] カフェ･ベローチェ  有明店 のスコア計算完了．
#   [192/563] カレス のスコア計算完了．
#   [193/563] カレーショップ C&Cダイニング 東京ビッグサイト店 のスコア計算完了．
#   [194/563] カレー香房 のスコア計算完了．
#   [195/563] カンテボーレ イオンスタイル有明ガーデン のスコア計算完了．
#   [196/563] カーサ・ディ・ペロー二 のスコア計算完了．
#   [197/563] カールスジュニア ダイバーシティ東京 プラザレストラン のスコア計算完了．
#   [198/563] ガルーバ のスコア計算完了．
#   [199/563] ガーデン ダイニング のスコア計算完了．
#   [200/563] キッチン有明 のスコア計算完了．
#   [201/563] キッチン青海珈琲 のスコア計算完了．
#   [202/563] キムカツ亭 有明ガーデン店 のスコア計算完了．
#   [203/563] キラキラドンキ ダイバーシティ東京 プラザ店 のスコア計算完了．
#   [204/563] キリンシティプラス 有明ガーデン店 のスコア計算完了．
#   [205/563] クアアイナ アクアシティお台場店 のスコア計算完了．
#   [206/563] クルックス カフェオ ヨーロピアンリゾートカフェ のスコア計算完了．
#   [207/563] クレープおじさん お台場店 のスコア計算完了．
#   [208/563] グランディール 有明ガーデン店 のスコア計算完了．
#   [209/563] グランドニッコー東京 台場 のスコア計算完了．
#   [210/563] グランドニッコー東京 台場 エグゼクティブラウンジ のスコア計算完了．
#   [211/563] グランブルー のスコア計算完了．
#   [212/563] グリロジー バー＆グリル のスコア計算完了．
#   [213/563] グリーン アジア トウキョウ のスコア計算完了．
#   [214/563] グリーンズシェフ のスコア計算完了．
#   [215/563] グロー ジュース スタンド のスコア計算完了．
#   [216/563] ゲンの中華そば 東京ビックサイト南展示棟店 のスコア計算完了．
#   [217/563] ココス 有明パークビル店 のスコア計算完了．
#   [218/563] コムフォー アーバンドック ららぽーと豊洲店 のスコア計算完了．
#   [219/563] ゴクゴク ダイバーシティ東京プラザ店 のスコア計算完了．
#   [220/563] ゴンチャ アクアシティお台場店 のスコア計算完了．
#   [221/563] サイゼリヤ 有明フロンティアビル店 のスコア計算完了．
#   [222/563] サザエさんのお店 のスコア計算完了．
#   [223/563] サブウェイ TFT有明店 のスコア計算完了．
#   [224/563] サーティワン エクスペリエンス ダイバーシティ東京プラザ店 のスコア計算完了．
#   [225/563] サーティワンアイスクリーム デックス東京ビーチ店 のスコア計算完了．
#   [226/563] サーティワンアイスクリーム 有明ガーデン店 のスコア計算完了．
#   [227/563] ザ バー&ラウンジ のスコア計算完了．
#   [228/563] ザ・コルトーナシーサイド台場 のスコア計算完了．
#   [229/563] ザ・台場 のスコア計算完了．
#   [230/563] シズラー アクアシティ店 のスコア計算完了．
#   [231/563] シュマッツ 有明ガーデン のスコア計算完了．
#   [232/563] シースケープ スイーツ＆コーヒー のスコア計算完了．
#   [233/563] シースケープ テラス・ダイニング のスコア計算完了．
#   [234/563] シーフードキッチン ピチ のスコア計算完了．
#   [235/563] シーフードレストラン メヒコ 東京ベイ有明店 のスコア計算完了．
#   [236/563] シーフードレストランネプチューン のスコア計算完了．
#   [237/563] ジ オーブン アメリカン ビュッフェ のスコア計算完了．
#   [238/563] ジューシーパパ のスコア計算完了．
#   [239/563] ジューススタンド のスコア計算完了．
#   [240/563] ジョナサン 台場デックス東京ビーチ店 のスコア計算完了．
#   [241/563] ジョンノ屋台村＆ネネチキン 有明ガーデン のスコア計算完了．
#   [242/563] ジョージタウン のスコア計算完了．
#   [243/563] ジー＆ジー のスコア計算完了．
#   [244/563] スターバックス コーヒー ダイバーシティ東京プラザ店 のスコア計算完了．
#   [245/563] スターバックスコーヒー 東京ビッグサイト店 のスコア計算完了．
#   [246/563] スターバックス・コーヒー アクアシティお台場店 のスコア計算完了．
#   [247/563] スモール ワールズ トウキョウ のスコア計算完了．
#   [248/563] セブンイレブン DR東京有明ダイワロイネットホテル店 のスコア計算完了．
#   [249/563] セブンイレブン ROYALビッグサイト店 のスコア計算完了．
#   [250/563] セブンイレブン タイム24ビル店 のスコア計算完了．
#   [251/563] セブンイレブン ダイバーシティ東京プラザ店 のスコア計算完了．
#   [252/563] セブンイレブン ＴＦＴ有明店 のスコア計算完了．
#   [253/563] ゼスト キャンティーナ お台場 のスコア計算完了．
#   [254/563] ゼッテリア TFT有明店 のスコア計算完了．
#   [255/563] タコベル アクアシティお台場店 のスコア計算完了．
#   [256/563] タコベル 有明ガーデン店 のスコア計算完了．
#   [257/563] タラキッチン 東陽町イースト21店 のスコア計算完了．
#   [258/563] タリーズコーヒー がん研有明病院店 のスコア計算完了．
#   [259/563] タリーズコーヒー ダイバーシティ東京プラザ店 のスコア計算完了．
#   [260/563] タリーズコーヒー フジテレビ店 のスコア計算完了．
#   [261/563] タリーズコーヒー 有明ガーデン店 のスコア計算完了．
#   [262/563] タリーズコーヒー 東京ガーデンシアター店 のスコア計算完了．
#   [263/563] タリーズコーヒー 東京テレポート駅店 のスコア計算完了．
#   [264/563] タリーズコーヒー 東京ビッグサイト店 のスコア計算完了．
#   [265/563] タヴェルナ・エ・ピッツェリア　サルーテ のスコア計算完了．
#   [266/563] タールムビアンコ お台場店 のスコア計算完了．
#   [267/563] ダブルティー アリアケ のスコア計算完了．
#   [268/563] チムニー 東京ビックサイト前店 のスコア計算完了．
#   [269/563] チャイナグリーン のスコア計算完了．
#   [270/563] ディッピンドッツ・アイスクリーム 東京ジョイポリス のスコア計算完了．
#   [271/563] ディップガーデン テラス 有明ガーデン店 のスコア計算完了．
#   [272/563] デコラクリーマリー ダイバーシティ東京プラザ店 のスコア計算完了．
#   [273/563] デンバー プレミアム 有明ガーデン店 のスコア計算完了．
#   [274/563] トゥ・ザ・ハーブズ アクアシティーお台場店 のスコア計算完了．
#   [275/563] トウキョウ・クッキー・ファクトリー ラオックス デックス東京ビーチ台場店 のスコア計算完了．
#   [276/563] トモズ 有明ガーデン店 のスコア計算完了．
#   [277/563] ドッグデプトカフェ お台場東京ビーチ店 のスコア計算完了．
#   [278/563] ドトールコーヒーショップ 国際展示場駅店 のスコア計算完了．
#   [279/563] ドトールコーヒーショップ 有明セントラルタワー店 のスコア計算完了．
#   [280/563] ドミノ・ピザ 台場店 のスコア計算完了．
#   [281/563] ナチュラルクレープ 有明ガーデン店 のスコア計算完了．
#   [282/563] ニイチク のスコア計算完了．
#   [283/563] ニャーベトナム フォー&バインミー 有明店 のスコア計算完了．
#   [284/563] ニューデイズ 東京テレポート店 のスコア計算完了．
#   [285/563] ニューヤマザキデイリーストア 青海流通センター店 のスコア計算完了．
#   [286/563] ニルワナム 有明店 のスコア計算完了．
#   [287/563] ニルワナム 東京ビッグサイト店 のスコア計算完了．
#   [288/563] ノイタミナSHOP のスコア計算完了．
#   [289/563] ハイカラ横丁 のスコア計算完了．
#   [290/563] バイロンベイミートパイ  有明店 のスコア計算完了．
#   [291/563] バウムクーヘン専門店アニバウム 有明ガーデン店 のスコア計算完了．
#   [292/563] バニヤンツリーカフェ のスコア計算完了．
#   [293/563] バンクサンドイッチ アクアシティお台場店 のスコア計算完了．
#   [294/563] バーガーキング  有明ガーデン店 のスコア計算完了．
#   [295/563] バーベキューテラス　「アブレイズ」 ヒルトン東京お台場 のスコア計算完了．
#   [296/563] パティスリー ピネード 有明ガーデンシティ店 のスコア計算完了．
#   [297/563] パパスバル のスコア計算完了．
#   [298/563] パパトリア 門前仲町本店 のスコア計算完了．
#   [299/563] パンドクレム のスコア計算完了．
#   [300/563] ヒルトン東京お台場 のスコア計算完了．
#   [301/563] ヒーローフィールド のスコア計算完了．
#   [302/563] ビオラル 有明ガーデン店 のスコア計算完了．
#   [303/563] ビオラルカフェ 有明ガーデン店 のスコア計算完了．
#   [304/563] ビッグシェフ お台場・デックス東京ビーチ のスコア計算完了．
#   [305/563] ビューラウンジ グランドニッコー東京 台場 のスコア計算完了．
#   [306/563] ビーエムダブリューグループトーキョーベイ のスコア計算完了．
#   [307/563] ピザーラ 有明 のスコア計算完了．
#   [308/563] ピザ＆パスタ マリノステリア 葛西店 のスコア計算完了．
#   [309/563] ピッツェリア ドォーロ ローマ 台場店 のスコア計算完了．
#   [310/563] ファミリーマート BSガレリア店 のスコア計算完了．
#   [311/563] ファミリーマート お台場東京ビーチ店 のスコア計算完了．
#   [312/563] ファミリーマート お台場海浜公園店 のスコア計算完了．
#   [313/563] ファミリーマート がん研有明病院店 のスコア計算完了．
#   [314/563] ファミリーマート テレコムセンター店 のスコア計算完了．
#   [315/563] ファミリーマート トレードピアお台場店 のスコア計算完了．
#   [316/563] ファミリーマート 有明フロンティア店 のスコア計算完了．
#   [317/563] ファミリーマート 東京湾岸警察署前店 のスコア計算完了．
#   [318/563] ファミリーマート 青海フロンティア店 のスコア計算完了．
#   [319/563] ファーイーストビレッジホテル 東京有明 のスコア計算完了．
#   [320/563] フォーシーズンズカフェ のスコア計算完了．
#   [321/563] フレームカフェ のスコア計算完了．
#   [322/563] ブリッジ のスコア計算完了．
#   [323/563] プロント ワンザ有明店 のスコア計算完了．
#   [324/563] プロント 東京ビッグサイト店 のスコア計算完了．
#   [325/563] ベジテジや ダイバーシティ東京プラザ店 のスコア計算完了．
#   [326/563] ベビーカステラ専門店 KUTSUROGI のスコア計算完了．
#   [327/563] ベーカリー&ペストリー・ショップ のスコア計算完了．
#   [328/563] ベーカリーレストランサンマルク 有明ガーデン店 のスコア計算完了．
#   [329/563] ペコちゃんmilkyドーナツ 有明ガーデン のスコア計算完了．
#   [330/563] ホップ＆ステップ カフェ のスコア計算完了．
#   [331/563] ホテルトラスティ 東京駅ベイサイド のスコア計算完了．
#   [332/563] ホブソンズ アイスクリームパーラー 有明ガーデン店 のスコア計算完了．
#   [333/563] ホルモン焼肉 しまちゃん のスコア計算完了．
#   [334/563] ポムの樹 アクアシティお台場店 のスコア計算完了．
#   [335/563] ポートストア 青海 のスコア計算完了．
#   [336/563] マクドナルド お台場デックス店 のスコア計算完了．
#   [337/563] マクドナルド ダイバーシティ東京プラザ店 のスコア計算完了．
#   [338/563] マクドナルド 有明パークビル店 のスコア計算完了．
#   [339/563] マグロスタンダード 門前仲町店 のスコア計算完了．
#   [340/563] マジカレー 有明ガーデン店 のスコア計算完了．
#   [341/563] マジソン プレミアム バーガー のスコア計算完了．
#   [342/563] マダムドリュック 有明ガーデン店 のスコア計算完了．
#   [343/563] マディソンラウンジ のスコア計算完了．
#   [344/563] マルエツ お台場店 のスコア計算完了．
#   [345/563] マルユ のスコア計算完了．
#   [346/563] マロリーポークステーキ お台場店 のスコア計算完了．
#   [347/563] マロリーポークステーキ 南砂町SUNAMO店 のスコア計算完了．
#   [348/563] マーメイド のスコア計算完了．
#   [349/563] ミスタードーナツ ダイバーシティ東京プラザショップ のスコア計算完了．
#   [350/563] ミニストップ WANZA有明店 のスコア計算完了．
#   [351/563] ミニストップ シティタワーズ東京ベイ店 のスコア計算完了．
#   [352/563] ミート酒場 ぼいす のスコア計算完了．
#   [353/563] ムジベーカリー 東京有明店 のスコア計算完了．
#   [354/563] メインバー「キャプテンズバー」 ヒルトン東京お台場 のスコア計算完了．
#   [355/563] メーピン のスコア計算完了．
#   [356/563] モナークバー のスコア計算完了．
#   [357/563] モミアンドトイズ デックス東京ビーチ店 のスコア計算完了．
#   [358/563] モンスーンカフェ お台場 のスコア計算完了．
#   [359/563] ユナイテッド・シネマ アクアシティお台場 のスコア計算完了．
#   [360/563] ヨゴリーノ　 お台場デックス東京ビーチ店 のスコア計算完了．
#   [361/563] ラ ヴィーニャ のスコア計算完了．
#   [362/563] ラムと豪州ジビエバル プラスアルファキッチン のスコア計算完了．
#   [363/563] ランチタイム のスコア計算完了．
#   [364/563] ラ・オハナ ダイバーシティ東京店 のスコア計算完了．
#   [365/563] リンガーハット アクアシティお台場店 のスコア計算完了．
#   [366/563] レゴカフェ のスコア計算完了．
#   [367/563] レゴランド ディスカバリー センターショップ のスコア計算完了．
#   [368/563] レストラン　シー・マインド のスコア計算完了．
#   [369/563] レストランシーサイド のスコア計算完了．
#   [370/563] レッドロブスター アクアシティお台場店 のスコア計算完了．
#   [371/563] ロイヤルキャフェテリア のスコア計算完了．
#   [372/563] ロジウラ のスコア計算完了．
#   [373/563] ロハスカフェARIAKE のスコア計算完了．
#   [374/563] ロングボード・カフェ のスコア計算完了．
#   [375/563] ローソン Hお台場海浜公園前店 のスコア計算完了．
#   [376/563] ワフーズ　タコス&モア のスコア計算完了．
#   [377/563] ヴィラフォンテーヌ グランド 東京有明 のスコア計算完了．
#   [378/563] ヴィレッジヴァンガードダイナー 豊洲フォレシア のスコア計算完了．
#   [379/563] 三代目 博多 だるま のスコア計算完了．
#   [380/563] 三代目文治 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [381/563] 中国料理 桃李 のスコア計算完了．
#   [382/563] 中国料理居酒屋 珍味館 築地店 のスコア計算完了．
#   [383/563] 中國料理 跳龍門 のスコア計算完了．
#   [384/563] 中華そば専門 田中そば店 ダイバーシティ東京店 のスコア計算完了．
#   [385/563] 中華居酒屋料理 餃子屋 のスコア計算完了．
#   [386/563] 中華料理 阿里城 アクアシティお台場店 のスコア計算完了．
#   [387/563] 中葛西 ごっさん のスコア計算完了．
#   [388/563] 串家物語 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [389/563] 久臨 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [390/563] 京都きん家 のスコア計算完了．
#   [391/563] 京鼎樓 アクアシティお台場店 のスコア計算完了．
#   [392/563] 仕立屋 甚五郎 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [393/563] 代官山 炭火焼肉 猿楽 豊洲店 のスコア計算完了．
#   [394/563] 伊勢元 のスコア計算完了．
#   [395/563] 伊吹や製麺 東京ビックサイトEat iT!店 のスコア計算完了．
#   [396/563] 伍之伍之 十六夜 のスコア計算完了．
#   [397/563] 伝説のすた丼屋 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [398/563] 倭料理 築地伊八 弐號 のスコア計算完了．
#   [399/563] 健康中華 青蓮 TOC有明店 のスコア計算完了．
#   [400/563] 元祖やきとり串八珍 築地本店 のスコア計算完了．
#   [401/563] 元祖セルフうどんの店 竹清 有明ガーデン店 のスコア計算完了．
#   [402/563] 六右衛門 のスコア計算完了．
#   [403/563] 創菜Patio のスコア計算完了．
#   [404/563] 勝鬨UNIqUE のスコア計算完了．
#   [405/563] 北京ダック専門店 嘉園 お台場店 のスコア計算完了．
#   [406/563] 北海道うまいもの館 ダイバーシティ東京店 のスコア計算完了．
#   [407/563] 北陸富山回転寿司　プレミアム 海王 ダイバーシティ東京店 のスコア計算完了．
#   [408/563] 十割蕎麦 さがたに 有明ガーデン店 のスコア計算完了．
#   [409/563] 千房 有明ガーデン支店 のスコア計算完了．
#   [410/563] 南砂餃子坊 のスコア計算完了．
#   [411/563] 南風花 アクアシティお台場店 のスコア計算完了．
#   [412/563] 博多うどん呑処 一㐂 下町居酒屋 台場店 のスコア計算完了．
#   [413/563] 博多もつ鍋 やまや 豊洲店 のスコア計算完了．
#   [414/563] 双麺 門前仲町店 のスコア計算完了．
#   [415/563] 吉野家 お台場 デックス店 のスコア計算完了．
#   [416/563] 味な店なかちゃん のスコア計算完了．
#   [417/563] 和カフェ Tsumugi 有明ガーデン店 のスコア計算完了．
#   [418/563] 和彩 よし川 のスコア計算完了．
#   [419/563] 和菜365 のスコア計算完了．
#   [420/563] 和風ダイニング 喜楽 のスコア計算完了．
#   [421/563] 和風居酒屋 豊洲酒場 のスコア計算完了．
#   [422/563] 和食ダイニング 田久井 のスコア計算完了．
#   [423/563] 唐苑 のスコア計算完了．
#   [424/563] 喫茶フラワー のスコア計算完了．
#   [425/563] 地鶏×鮮魚 個室居酒屋 もみじ屋 デックス東京ビーチ店 のスコア計算完了．
#   [426/563] 塩らーめん専門 ひるがお アクアシティお台場店 のスコア計算完了．
#   [427/563] 大衆酒場 有頂天 のスコア計算完了．
#   [428/563] 大衆酒場かんぱい家 葛西店 のスコア計算完了．
#   [429/563] 天天有 お台場デックス東京ビーチ店 のスコア計算完了．
#   [430/563] 家系らーめん 金井家 のスコア計算完了．
#   [431/563] 小樽ザンギとサケ 半身揚げのジョニー のスコア計算完了．
#   [432/563] 居酒屋いっき 有明別邸 のスコア計算完了．
#   [433/563] 屋台DELi のスコア計算完了．
#   [434/563] 山下本気うどん デックス東京ビーチ のスコア計算完了．
#   [435/563] 山形山　月島店 のスコア計算完了．
#   [436/563] 成都 陳麻婆豆腐 有明ガーデン店 のスコア計算完了．
#   [437/563] 成都担々 のスコア計算完了．
#   [438/563] 手打ち中華 玉 アクアシティお台場店 のスコア計算完了．
#   [439/563] 文化堂 有明店 のスコア計算完了．
#   [440/563] 日本料理 「さくら」   ヒルトン東京お台場 のスコア計算完了．
#   [441/563] 日本料理 紫水 のスコア計算完了．
#   [442/563] 日本料理　時宜 のスコア計算完了．
#   [443/563] 日本橋 天丼 金子半之助 ダイバーシティ東京店 のスコア計算完了．
#   [444/563] 日比谷松本楼 東京ビッグサイト店 のスコア計算完了．
#   [445/563] 春華秋実 のスコア計算完了．
#   [446/563] 月島焼肉ハラミ屋兎月 月島店 のスコア計算完了．
#   [447/563] 木村家 のスコア計算完了．
#   [448/563] 本格四川料理 麻辣先生 豊洲店 のスコア計算完了．
#   [449/563] 札幌 みその アクアシティお台場店 のスコア計算完了．
#   [450/563] 東京 焼肉エイト 木場本店 のスコア計算完了．
#   [451/563] 東京29寿司 のスコア計算完了．
#   [452/563] 東京ビッグサイト のスコア計算完了．
#   [453/563] 東京ベイキッチン 東京ビッグサイト店 のスコア計算完了．
#   [454/563] 東京ベイコート倶楽部 のスコア計算完了．
#   [455/563] 東京ベイ有明ワシントンホテル のスコア計算完了．
#   [456/563] 東京寿司 ITAMAE SUSHI アクアシティお台場店 のスコア計算完了．
#   [457/563] 東京恋テラス のスコア計算完了．
#   [458/563] 東京焼肉 平城苑 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [459/563] 東京麻辣湯 アクアシティお台場店 のスコア計算完了．
#   [460/563] 杵屋麦丸 有明ワンザ店 のスコア計算完了．
#   [461/563] 松屋 武蔵野大学有明CP店 のスコア計算完了．
#   [462/563] 楽苑 のスコア計算完了．
#   [463/563] 権八 お台場 のスコア計算完了．
#   [464/563] 横濱炸鶏排 お台場店 のスコア計算完了．
#   [465/563] 永利 豊洲3号店 のスコア計算完了．
#   [466/563] 江戸湾直送 回転 東京すし街道by ITAMAE SUSHI アクアシティお台場店 のスコア計算完了．
#   [467/563] 泉天空の湯 有明キッチン のスコア計算完了．
#   [468/563] 浅草 草津亭 有明店 のスコア計算完了．
#   [469/563] 海のYey のスコア計算完了．
#   [470/563] 清澄白河 フジマル醸造所 のスコア計算完了．
#   [471/563] 潤や のスコア計算完了．
#   [472/563] 潮見スキッパーズ 有明店 のスコア計算完了．
#   [473/563] 激旨ホルモン魂 のスコア計算完了．
#   [474/563] 炭火串焼き ふく屋 のスコア計算完了．
#   [475/563] 炭火焼肉 牛和鹿 本店 のスコア計算完了．
#   [476/563] 炭火焼肉・韓国料理 KollaBo アクアシティお台場店 のスコア計算完了．
#   [477/563] 無印良品 東京有明店 のスコア計算完了．
#   [478/563] 焼うお いし川 のスコア計算完了．
#   [479/563] 焼きとんと旨い魚 甚四郎 本店 のスコア計算完了．
#   [480/563] 焼肉 平城苑 アクアシティお台場店 のスコア計算完了．
#   [481/563] 焼肉ここから 東陽町店 のスコア計算完了．
#   [482/563] 焼肉と夜景 醍醐 お台場店 のスコア計算完了．
#   [483/563] 焼鳥トリフク食堂 のスコア計算完了．
#   [484/563] 焼鶏ばんちょう のスコア計算完了．
#   [485/563] 牛たん炭焼利久 有明ガーデン店 のスコア計算完了．
#   [486/563] 牛カツ京都勝牛 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [487/563] 牛和鹿 葛西店 のスコア計算完了．
#   [488/563] 牛若 葛西店 のスコア計算完了．
#   [489/563] 生粋 葛西駅前店 のスコア計算完了．
#   [490/563] 目利きの銀次 門前仲町駅前店 のスコア計算完了．
#   [491/563] 相鉄グランドフレッサ 東京ベイ有明 のスコア計算完了．
#   [492/563] 眺遊楼 のスコア計算完了．
#   [493/563] 石臼挽きそば 石楽 のスコア計算完了．
#   [494/563] 磯寿司 のスコア計算完了．
#   [495/563] 社食DELI のスコア計算完了．
#   [496/563] 社食デリ のスコア計算完了．
#   [497/563] 秀徳市場マルマサ のスコア計算完了．
#   [498/563] 笑笑 お台場海浜公園駅前店 のスコア計算完了．
#   [499/563] 笑笑 月島駅前店 のスコア計算完了．
#   [500/563] 築地 すし Omakase のスコア計算完了．
#   [501/563] 築地 挙母鮨 のスコア計算完了．
#   [502/563] 築地さらしなの里 のスコア計算完了．
#   [503/563] 築地玉寿司 晴海通り店 のスコア計算完了．
#   [504/563] 築地秀徳元祖 のスコア計算完了．
#   [505/563] 築地銀だこ ダイバーシティ東京プラザ店 のスコア計算完了．
#   [506/563] 築地青空三代目 本店 のスコア計算完了．
#   [507/563] 築地食堂 源ちゃん アクアシティお台場店 のスコア計算完了．
#   [508/563] 築地食堂 源ちゃん 有明ガーデン店 のスコア計算完了．
#   [509/563] 築地食堂 源ちゃん 東京ビックサイト店 のスコア計算完了．
#   [510/563] 築地食堂　源ちゃん TFT有明店 のスコア計算完了．
#   [511/563] 米三角 のスコア計算完了．
#   [512/563] 翠苑 のスコア計算完了．
#   [513/563] 肉菜工房うしすけ 台場店 のスコア計算完了．
#   [514/563] 自由が丘 蔭山 有明ガーデン店 のスコア計算完了．
#   [515/563] 芋蛸 お台場たこやきミュージアム店 のスコア計算完了．
#   [516/563] 花水木 のスコア計算完了．
#   [517/563] 茂助だんご 豊洲市場 のスコア計算完了．
#   [518/563] 茶寮 伊藤園 有明ガーデン店 のスコア計算完了．
#   [519/563] 菊屋 のスコア計算完了．
#   [520/563] 葛西ビアバー のスコア計算完了．
#   [521/563] 葛西臨海公園バーベキュー広場 のスコア計算完了．
#   [522/563] 蔵乃ゑ のスコア計算完了．
#   [523/563] 親子丼 トリカイ エクスプレス ダイバーシティ東京店 のスコア計算完了．
#   [524/563] 豊洲市場 共同食堂 のスコア計算完了．
#   [525/563] 豊海ワイン食堂 のスコア計算完了．
#   [526/563] 越後屋 竹千代 のスコア計算完了．
#   [527/563] 道頓堀 赤鬼 のスコア計算完了．
#   [528/563] 都会の農園バーベキュー広場 のスコア計算完了．
#   [529/563] 都立潮風公園バーベキュー広場 のスコア計算完了．
#   [530/563] 金澤濃厚豚骨ラーメン 神仙 アクアシティ店 のスコア計算完了．
#   [531/563] 鉄板焼 銀杏 のスコア計算完了．
#   [532/563] 銀座 深川玄庵 のスコア計算完了．
#   [533/563] 銀座 祭や のスコア計算完了．
#   [534/563] 長寿韓酒房 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [535/563] 長寿韓酒房 有明店 のスコア計算完了．
#   [536/563] 長生庵 のスコア計算完了．
#   [537/563] 門仲STAND のスコア計算完了．
#   [538/563] 門前仲町 らっきょう のスコア計算完了．
#   [539/563] 青海珈琲 青海本店 のスコア計算完了．
#   [540/563] 青海食堂 のスコア計算完了．
#   [541/563] 韓美膳 有明ガーデン店 のスコア計算完了．
#   [542/563] 頑者NEXT LEVEL のスコア計算完了．
#   [543/563] 飛車角 有明ガーデン店 のスコア計算完了．
#   [544/563] 餃子の王様 龍吟 ダイバーシティ店 のスコア計算完了．
#   [545/563] 餃子酒家 築地店 のスコア計算完了．
#   [546/563] 香港飲茶楼 ル・パルク のスコア計算完了．
#   [547/563] 魚とと 東京ビックサイトEat iT!店 のスコア計算完了．
#   [548/563] 魚民 勝どき駅前店 のスコア計算完了．
#   [549/563] 魚民 潮見駅前店 のスコア計算完了．
#   [550/563] 魚河岸トミーナ 豊洲市場店 のスコア計算完了．
#   [551/563] 鮒忠 有明店 のスコア計算完了．
#   [552/563] 鮨 もりなり のスコア計算完了．
#   [553/563] 鮨 玉かがり 天ぷら 玉衣 のスコア計算完了．
#   [554/563] 鮨 酒 肴 杉玉 新木場 のスコア計算完了．
#   [555/563] 鮨　宇田川 のスコア計算完了．
#   [556/563] 鮨･酒･肴 杉玉 葛西店 のスコア計算完了．
#   [557/563] 鮮魚旬菜 魚福 のスコア計算完了．
#   [558/563] 鶏味座 ダイバーシティ東京プラザ店 のスコア計算完了．
#   [559/563] 鶏鬨はなれ 勝どき清澄通り店 のスコア計算完了．
#   [560/563] 鶴橋風月 お台場店 のスコア計算完了．
#   [561/563] 黄金鉄鍋餃子 HUG のスコア計算完了．
#   [562/563] 龍記 お台場デックス東京ビーチ店 のスコア計算完了．
#   [563/563] ＆ Ovo のスコア計算完了．
#
# --- 雰囲気スコア計算結果（上位5店舗）---
#                         shop_name  quiet_score  lively_score  stylish_score  \
# 0                   1129 by Ogawa     0.152683           0.0       0.203578
# 1                          82 築地店     0.234797           0.0       0.000000
# 2                ABURI 百貫 有明ガーデン店     0.000000           0.0       0.000000
# 3               ARIAKE ARENA CAFE     0.000000           0.0       0.000000
# 4  ARIAKE ARENA DINING MOON RIVER     0.000000           0.0       0.000000
#
#    cozy_score  formal_score
# 0    0.050894      0.101789
# 1    0.000000      0.000000
# 2    0.000000      0.130081
# 3    0.000000      0.000000
# 4    0.000000      0.000000
#
# 計算結果を「shop_atmosphere_scores.csv」に保存しました。
