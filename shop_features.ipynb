# %% [markdown]
# ## 頻出単語計算

# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from collections import Counter

# --- 準備 ---
# CSVファイルを読み込む
try:
    df = pd.read_csv('odaiba_reviews.csv')
except FileNotFoundError:
    print("エラー: 'odaiba_reviews.csv'が見つかりません。")
    df = pd.DataFrame()

# JanomeのTokenizerを準備
t = Tokenizer()

# ストップワード（分析に不要な一般的な単語）を定義
stop_words = ['こと', 'もの', 'それ', 'これ', 'さん', 'よう', 'ため', 'こちら', 'ところ', '感じ','...']

# --- 実行 ---
if not df.empty:
    # 1. 店舗名でグループ分け
    grouped = df.groupby('shop_name')

    # 各店舗ごとに処理
    for shop_name, group in grouped:
        print(f"\n--- 【{shop_name}】の頻出名詞 TOP 5 ---")

        # 2. その店舗の全口コミを一つに連結
        all_reviews_text = ' '.join(group['review_text'].dropna())

        # 3. 形態素解析で名詞を抽出
        nouns = []
        for token in t.tokenize(all_reviews_text):
            # 品詞が名詞で、ストップワードに含まれていない単語のみを抽出
            if token.part_of_speech.startswith('名詞') and token.surface not in stop_words:
                nouns.append(token.surface)
        
        # 4. 単語の出現回数をカウントし、ランキングを作成
        word_counts = Counter(nouns)
        
        # 最も多く出現した5つの単語を表示
        for word, count in word_counts.most_common(5):
            print(f"{word}: {count}回")
# Out:
# --- 【1129 by Ogawa】の頻出名詞 TOP 5 ---
# ...: 355回
# ハンバーグ: 210回
# 台場: 192回
# 店: 180回
# 席: 142回
#
# --- 【82 築地店】の頻出名詞 TOP 5 ---
# 築地: 45回
# ...: 42回
# 店: 40回
# ビール: 14回
# パブ: 12回
#
# --- 【ABURI 百貫 有明ガーデン店】の頻出名詞 TOP 5 ---
# 寿司: 142回
# ...: 134回
# 回転: 85回
# 店: 76回
# 有明: 63回
#
# --- 【ARIAKE ARENA CAFE】の頻出名詞 TOP 5 ---
# アリーナ: 15回
# ...: 12回
# 有明: 11回
# ライブ: 9回
# の: 6回
#
# --- 【ARIAKE ARENA DINING MOON RIVER】の頻出名詞 TOP 5 ---
# ...: 8回
# アリーナ: 7回
# 店: 6回
# 有明: 6回
# カフェ: 5回
#
# --- 【AkeruE】の頻出名詞 TOP 5 ---
# 国際: 1回
# 展示: 1回
# 場: 1回
# 駅: 1回
# 左手: 1回
#
# --- 【Ariake Miraie】の頻出名詞 TOP 5 ---
# ...: 9回
# カフェ: 7回
# 中: 7回
# トヨタ: 5回
# ディーラー: 5回
#
# --- 【BBQ PLAY GROUND お台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 20回
# 台場: 11回
# BBQ: 11回
# 持ち込み: 8回
# の: 8回
#
# --- 【BISTRO うしすけ】の頻出名詞 TOP 5 ---
# ...: 110回
# 店: 79回
# 犬: 63回
# 台場: 53回
# ランチ: 47回
#
# --- 【BLUE TABLE Odaiba】の頻出名詞 TOP 5 ---
# ...: 23回
# 台場: 11回
# 店: 10回
# 海: 8回
# ランチ: 8回
#
# --- 【Bistro961】の頻出名詞 TOP 5 ---
# ...: 18回
# 店: 15回
# ワイン: 14回
# 階: 11回
# 2: 9回
#
# --- 【Bomb! Dogs】の頻出名詞 TOP 5 ---
# ポテト: 2回
# ソース: 2回
# 店: 2回
# ランチ: 1回
# 飛び込み: 1回
#
# --- 【Brew33 Bar】の頻出名詞 TOP 5 ---
# ダイニング: 1回
# レストラン: 1回
# 様: 1回
# カジュアル: 1回
# ファミリー: 1回
#
# --- 【CAFE TERIA BLUE】の頻出名詞 TOP 5 ---
# ...: 8回
# 平日: 4回
# チ: 3回
# 特別: 3回
# 展: 3回
#
# --- 【Cha pi】の頻出名詞 TOP 5 ---
# ...: 16回
# ミルク: 8回
# 台場: 6回
# 抹茶: 6回
# ほうじ茶: 5回
#
# --- 【Chez コバラヘッタ 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 40回
# 有明: 33回
# ガーデン: 25回
# 店: 22回
# メニュー: 16回
#
# --- 【CoCo壱番屋 ワンザ有明店】の頻出名詞 TOP 5 ---
# ...: 11回
# カレー: 10回
# 店: 9回
# CoCo: 8回
# の: 5回
#
# --- 【Cuore】の頻出名詞 TOP 5 ---
# ...: 36回
# ホテル: 26回
# ランチ: 15回
# 東京: 15回
# 利用: 14回
#
# --- 【D-ラウンジ】の頻出名詞 TOP 5 ---
# 東京: 10回
# ジョイポリス: 8回
# ...: 6回
# ホットドッグ: 4回
# 2: 4回
#
# --- 【DAIBA】の頻出名詞 TOP 5 ---
# 社員: 5回
# 食堂: 5回
# フジテレビ: 4回
# ...: 4回
# テレビ局: 3回
#
# --- 【DOG DEPT お台場東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 2回
# 大型: 1回
# 連休: 1回
# 真ん中: 1回
# 開店: 1回
#
# --- 【DOLCE VITA】の頻出名詞 TOP 5 ---
# ...: 12回
# イマーシブフォート: 6回
# パフェ: 6回
# 東京: 4回
# メロン: 4回
#
# --- 【Deli&Cafe Uran】の頻出名詞 TOP 5 ---
# ...: 10回
# 店: 10回
# 円: 6回
# 台場: 6回
# おかず: 5回
#
# --- 【Domino's Pizza  ARIAKE GARDEN】の頻出名詞 TOP 5 ---
# ピザ: 5回
# ガーデン: 4回
# ...: 3回
# 有明: 3回
# フード: 2回
#
# --- 【Eat it! 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 56回
# フード: 37回
# コート: 37回
# ビッグ: 36回
# サイト: 35回
#
# --- 【FARMS' KITCHEN MIKIKE TOKYO ODAIBA】の頻出名詞 TOP 5 ---
# ...: 5回
# 台場: 3回
# レストラン: 3回
# 観光: 2回
# 地: 2回
#
# --- 【GODIVA アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 23回
# GODIVA: 17回
# ショコリキサー: 12回
# の: 12回
# チョコレート: 12回
#
# --- 【GODIVA ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 41回
# ダイバー: 20回
# シティ: 20回
# ショコリキサー: 19回
# チョコレート: 19回
#
# --- 【GOKUGOKU 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 14回
# 有明: 7回
# ガーデン: 6回
# バナナ: 6回
# 購入: 5回
#
# --- 【GREAT STEAK】の頻出名詞 TOP 5 ---
# 店: 2回
# ステーキ: 2回
# ダイバー: 1回
# シティ: 1回
# フード: 1回
#
# --- 【GUNDAM Café　キッチンカー】の頻出名詞 TOP 5 ---
# アニメ: 1回
# 放送: 1回
# 中: 1回
# ジークアクス: 1回
# テーマ: 1回
#
# --- 【Green×Green】の頻出名詞 TOP 5 ---
# サラダ: 18回
# ...: 15回
# 店: 8回
# 台場: 7回
# ドレッシング: 7回
#
# --- 【H.B.GRILL】の頻出名詞 TOP 5 ---
# ...: 66回
# 台場: 39回
# 店: 36回
# ランチ: 27回
# .: 26回
#
# --- 【HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 39回
# 店: 25回
# キティちゃん: 19回
# 東京: 17回
# ダイバー: 17回
#
# --- 【HIRO ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# ...: 88回
# ハンバーグ: 75回
# 店: 47回
# ステーキ: 45回
# ダイバー: 39回
#
# --- 【HUNZA】の頻出名詞 TOP 5 ---
# ...: 255回
# カレー: 193回
# 葛西: 142回
# 店: 142回
# インド: 133回
#
# --- 【Hobson’s アクアシティお台場】の頻出名詞 TOP 5 ---
# ...: 30回
# アイス: 15回
# 台場: 15回
# フード: 15回
# クレープ: 14回
#
# --- 【KING OF THE PIRATES】の頻出名詞 TOP 5 ---
# ...: 234回
# 店: 126回
# 海賊: 119回
# 台場: 113回
# 席: 95回
#
# --- 【L'Agréable Esprit de GAMIN】の頻出名詞 TOP 5 ---
# ...: 61回
# 料理: 32回
# 店: 30回
# フレンチ: 24回
# コース: 21回
#
# --- 【LAWSON Tokyoビッグベイ店】の頻出名詞 TOP 5 ---
# 2: 1回
# 月: 1回
# 14: 1回
# 日: 1回
# 発売: 1回
#
# --- 【LAWSON お台場店】の頻出名詞 TOP 5 ---
# (: 3回
# 東京: 2回
# テレポート: 2回
# 駅: 2回
# コンビニ: 2回
#
# --- 【LAWSON しののめ店】の頻出名詞 TOP 5 ---
# ローソン: 2回
# ...: 2回
# 栃木: 2回
# 県: 2回
# 産: 2回
#
# --- 【LAWSON りんかい線東雲駅店】の頻出名詞 TOP 5 ---
# 芋: 3回
# 紅: 2回
# 天使: 2回
# カスタード: 2回
# クリーム: 2回
#
# --- 【LAWSON アクアシティお台場】の頻出名詞 TOP 5 ---
# ...: 4回
# ローソン: 4回
# 台場: 3回
# 方: 3回
# 禁断: 2回
#
# --- 【LAWSON フジテレビ店】の頻出名詞 TOP 5 ---
# 月: 3回
# １: 3回
# 8: 2回
# 台場: 2回
# 中: 2回
#
# --- 【LAWSON ポートストア有明】の頻出名詞 TOP 5 ---
# 有明: 2回
# チン: 1回
# 隣: 1回
# 一般: 1回
# 財団: 1回
#
# --- 【LAWSON 国際展示場駅前店】の頻出名詞 TOP 5 ---
# ...: 9回
# 国際: 6回
# 展示: 6回
# 場: 6回
# 店: 6回
#
# --- 【LAWSON 有明コロシアム前店】の頻出名詞 TOP 5 ---
# ローソン: 3回
# ...: 2回
# 車: 2回
# バーガー: 1回
# キング: 1回
#
# --- 【LAWSON 有明セントラルタワー店】の頻出名詞 TOP 5 ---
# ローソン: 5回
# ...: 4回
# 屋: 3回
# 桔梗: 3回
# 近く: 2回
#
# --- 【LAWSON 東京テレポート駅前店】の頻出名詞 TOP 5 ---
# 店: 2回
# コンビニ: 2回
# 江東: 1回
# 区: 1回
# コード: 1回
#
# --- 【LAWSON 東京ビッグサイトエントランス】の頻出名詞 TOP 5 ---
# ...: 9回
# 東京: 6回
# ビッグ: 5回
# サイト: 5回
# の: 5回
#
# --- 【LAWSON 東雲一丁目店】の頻出名詞 TOP 5 ---
# 前: 3回
# ローソン: 3回
# 東雲: 2回
# 一: 2回
# マンション: 2回
#
# --- 【LAWSON 相鉄グランドフレッサ有明店】の頻出名詞 TOP 5 ---
# ホテル: 2回
# 2: 2回
# 階: 2回
# ...: 2回
# 1930: 1回
#
# --- 【LAWSON Ｈ台場駅前店】の頻出名詞 TOP 5 ---
# 駅: 2回
# スイーツ: 2回
# 台場: 1回
# ホテル: 1回
# ２: 1回
#
# --- 【Louis Hamburger Restaurant】の頻出名詞 TOP 5 ---
# ...: 296回
# ハンバーガー: 149回
# 店: 143回
# バーガー: 88回
# 町: 83回
#
# --- 【MOMI&TOY'S 有明ガーデン店】の頻出名詞 TOP 5 ---
# クレープ: 29回
# ...: 21回
# の: 15回
# 有明: 11回
# ガーデン: 9回
#
# --- 【MONPAL 8】の頻出名詞 TOP 5 ---
# ...: 44回
# 酒: 34回
# 料理: 26回
# 放題: 21回
# 店: 20回
#
# --- 【N．Y．Kカフェ お台場・デックス東京ビーチ】の頻出名詞 TOP 5 ---
# ...: 5回
# クレープ: 4回
# .: 3回
# 台場: 2回
# デックス: 2回
#
# --- 【OEDO ARIAKE STYLE】の頻出名詞 TOP 5 ---
# 店: 8回
# フード: 7回
# 有明: 6回
# 2: 5回
# ...: 5回
#
# --- 【OSMIC DISH】の頻出名詞 TOP 5 ---
# トマト: 21回
# ...: 15回
# 台場: 11回
# 店: 10回
# 円: 9回
#
# --- 【Ozgur Kitchen Kebab】の頻出名詞 TOP 5 ---
# Ozgur: 1回
# Kitchen: 1回
# Kebab: 1回
# ケバブ: 1回
# どんぶり: 1回
#
# --- 【PATISSERIE L11S】の頻出名詞 TOP 5 ---
# ...: 2回
# ケーキ: 2回
# 1929: 1回
# 件: 1回
# 目: 1回
#
# --- 【PERFECT BEER STAND MONNAKA】の頻出名詞 TOP 5 ---
# ...: 18回
# ビール: 16回
# 店: 8回
# 目: 8回
# 時: 6回
#
# --- 【PHO365】の頻出名詞 TOP 5 ---
# フォー: 36回
# ...: 25回
# 春巻き: 21回
# 店: 19回
# ベトナム: 10回
#
# --- 【PIZZA SALVATORE CUOMO 豊洲】の頻出名詞 TOP 5 ---
# ...: 129回
# ピザ: 76回
# ランチ: 68回
# 豊洲: 65回
# 店: 65回
#
# --- 【PIZZA&WINE カヤバール 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 71回
# 有明: 43回
# 店: 41回
# ピザ: 41回
# パスタ: 40回
#
# --- 【PLANT LOVE】の頻出名詞 TOP 5 ---
# ０: 3回
# ２: 3回
# 待ち: 2回
# ...: 2回
# ベジカフェ: 2回
#
# --- 【Pacific PICKLE CLUB】の頻出名詞 TOP 5 ---
# 店: 9回
# ...: 8回
# パシフィック: 4回
# 有明: 4回
# タコ: 4回
#
# --- 【R's Cafe】の頻出名詞 TOP 5 ---
# カラオケ: 4回
# 個室: 4回
# 店内: 3回
# 店: 3回
# ♪: 3回
#
# --- 【RESTAURANT WHITE ART】の頻出名詞 TOP 5 ---
# 有明: 2回
# レストラン: 2回
# ...: 2回
# SMALL: 2回
# RESTAURANT: 1回
#
# --- 【RIN&GOカレー 東京有明セントラルタワー店】の頻出名詞 TOP 5 ---
# カレー: 4回
# カツ: 2回
# 小麦粉: 2回
# ルー: 2回
# ...: 2回
#
# --- 【RISTORANTE OZIO】の頻出名詞 TOP 5 ---
# ...: 159回
# ベイ: 77回
# コート: 75回
# 東京: 58回
# 料理: 55回
#
# --- 【SAUS】の頻出名詞 TOP 5 ---
# ...: 10回
# 1: 6回
# 有明: 5回
# SAUS: 5回
# ランチ: 4回
#
# --- 【SONAE CAFE】の頻出名詞 TOP 5 ---
# 東京: 5回
# 防災: 4回
# そ: 4回
# エリア: 4回
# 臨海: 3回
#
# --- 【STONE FACTORY Jr.】の頻出名詞 TOP 5 ---
# ステーキ: 6回
# 石: 5回
# フード: 5回
# コート: 5回
# ...: 5回
#
# --- 【SWITCH STAND ODAIBA】の頻出名詞 TOP 5 ---
# パスタ: 2回
# カレー: 2回
# ランチ: 1回
# サンド: 1回
# 3: 1回
#
# --- 【Seaside Café SOLARIS】の頻出名詞 TOP 5 ---
# ...: 18回
# 台場: 16回
# バス: 9回
# 前: 9回
# 乗り場: 8回
#
# --- 【Sky Restaurant シーガル】の頻出名詞 TOP 5 ---
# ...: 20回
# ビル: 12回
# 3: 12回
# :: 9回
# 11: 8回
#
# --- 【TGI FRIDAYS 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 244回
# 有明: 92回
# ランチ: 82回
# 店: 82回
# の: 78回
#
# --- 【TGIフライデーズ お台場アクアシティ店】の頻出名詞 TOP 5 ---
# ...: 174回
# 台場: 80回
# 店: 70回
# ランチ: 64回
# 席: 48回
#
# --- 【THE BBQ BEACH in AQUA CITY ODAIBA】の頻出名詞 TOP 5 ---
# ...: 13回
# BBQ: 10回
# 人: 8回
# 台場: 7回
# 階: 7回
#
# --- 【THEキャラCAFE お台場デックス店】の頻出名詞 TOP 5 ---
# コラボレーション: 2回
# カフェ: 2回
# ラブ: 1回
# ライブ: 1回
# シリーズ: 1回
#
# --- 【The Cabaret】の頻出名詞 TOP 5 ---
# ショー: 35回
# ...: 34回
# レストラン: 18回
# 東京: 18回
# 食事: 16回
#
# --- 【The Grill on 30th】の頻出名詞 TOP 5 ---
# ...: 281回
# 台場: 132回
# 30: 108回
# 東京: 106回
# 料理: 88回
#
# --- 【The Lobby Cafe】の頻出名詞 TOP 5 ---
# ...: 88回
# 台場: 53回
# アフタヌーン: 42回
# ティー: 36回
# グランド: 26回
#
# --- 【Tokyo 串家】の頻出名詞 TOP 5 ---
# ...: 21回
# ランチ: 14回
# 台場: 12回
# 円: 11回
# 串: 11回
#
# --- 【Trattoria&Pizzeria LOGIC お台場】の頻出名詞 TOP 5 ---
# ...: 90回
# ピザ: 56回
# 台場: 49回
# パスタ: 35回
# 店: 34回
#
# --- 【WAGYU USHITOMI GINZA】の頻出名詞 TOP 5 ---
# ...: 174回
# 肉: 161回
# 店: 123回
# 割烹: 93回
# 新富: 92回
#
# --- 【WINESTAND TEO】の頻出名詞 TOP 5 ---
# ワイン: 26回
# ...: 18回
# 階: 14回
# 店: 11回
# 2: 10回
#
# --- 【WOOD DESIGN PARK お台場店】の頻出名詞 TOP 5 ---
# ...: 3回
# バーベキュー: 3回
# 最高: 3回
# BBQ: 2回
# 子供: 2回
#
# --- 【YORIMICHI Odaiba】の頻出名詞 TOP 5 ---
# ...: 49回
# 店: 28回
# 台場: 27回
# の: 16回
# 席: 15回
#
# --- 【Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉】の頻出名詞 TOP 5 ---
# ...: 63回
# 焼肉: 51回
# 店: 47回
# 肉: 43回
# 枚: 36回
#
# --- 【bills お台場】の頻出名詞 TOP 5 ---
# ...: 489回
# パンケーキ: 307回
# 台場: 226回
# 店: 180回
# bills: 169回
#
# --- 【creperie kenny's ダイバーシティ店】の頻出名詞 TOP 5 ---
# クレープ: 30回
# ...: 28回
# 生クリーム: 14回
# ダイバー: 11回
# 店: 10回
#
# --- 【da pai dang 105 有明ガーデン店】の頻出名詞 TOP 5 ---
# 包: 29回
# 小籠: 28回
# ...: 26回
# フード: 19回
# コート: 19回
#
# --- 【mal D'amour】の頻出名詞 TOP 5 ---
# ...: 71回
# 東京: 39回
# フレンチ: 39回
# ベイ: 37回
# コート: 36回
#
# --- 【milky70 since1951 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ミルキー: 17回
# 店: 14回
# 台場: 12回
# ...: 12回
# アクアシティ: 8回
#
# --- 【mode super smoothie】の頻出名詞 TOP 5 ---
# 価格: 2回
# ...: 2回
# 店内: 2回
# どれ: 1回
# 千: 1回
#
# --- 【root C 日本科学未来館 5Fロビー】の頻出名詞 TOP 5 ---
# 肉: 3回
# ドリンク: 2回
# ...: 2回
# root: 2回
# C: 2回
#
# --- 【the BAR】の頻出名詞 TOP 5 ---
# ...: 3回
# オープン: 3回
# SOHO: 2回
# バー: 2回
# プレ: 2回
#
# --- 【the open bakery】の頻出名詞 TOP 5 ---
# パン: 93回
# ...: 73回
# 台場: 44回
# 屋: 25回
# 店: 23回
#
# --- 【あのり】の頻出名詞 TOP 5 ---
# 店: 7回
# 台場: 5回
# ...: 5回
# 居酒屋: 4回
# 海浜: 3回
#
# --- 【あばら大根 西葛西店】の頻出名詞 TOP 5 ---
# ...: 58回
# 店: 47回
# 料理: 27回
# 席: 21回
# 西葛西: 20回
#
# --- 【いろり庵 きらく 国際展示場駅店】の頻出名詞 TOP 5 ---
# ...: 77回
# そば: 68回
# 蕎麦: 51回
# 駅: 46回
# 展示: 33回
#
# --- 【うなぎ 明月川 豊洲店】の頻出名詞 TOP 5 ---
# ...: 41回
# 店: 32回
# 鰻: 31回
# うなぎ: 28回
# 豊洲: 25回
#
# --- 【おいらんち 葛西駅前店】の頻出名詞 TOP 5 ---
# ...: 19回
# 店: 13回
# メニュー: 12回
# 料理: 11回
# 利用: 9回
#
# --- 【おぼんdeごはん ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 22回
# 店: 13回
# 定食: 13回
# ランチ: 10回
# ごはん: 10回
#
# --- 【お食事処 ゆき】の頻出名詞 TOP 5 ---
# ...: 40回
# 台場: 38回
# 定食: 31回
# 店: 26回
# ゆき: 19回
#
# --- 【かつゑもん ダイバーシティ東京プラザ】の頻出名詞 TOP 5 ---
# ...: 26回
# カツ: 20回
# フード: 19回
# コート: 19回
# めし: 15回
#
# --- 【がぜん 有明】の頻出名詞 TOP 5 ---
# ...: 93回
# ランチ: 48回
# 店: 45回
# 丼: 42回
# 海鮮: 37回
#
# --- 【くいもの屋わん お台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 13回
# 台場: 10回
# 店: 8回
# わん: 7回
# 屋: 6回
#
# --- 【くずし割烹 天ぷら竹の庵 東銀座店】の頻出名詞 TOP 5 ---
# ...: 79回
# 天ぷら: 79回
# 店: 56回
# ランチ: 43回
# 個室: 31回
#
# --- 【こだわりから揚げの酒処 くらふと】の頻出名詞 TOP 5 ---
# ...: 50回
# 揚げ: 46回
# 唐: 46回
# 店: 24回
# 駅: 21回
#
# --- 【こなな 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 41回
# パスタ: 36回
# -: 26回
# 有明: 24回
# 店: 21回
#
# --- 【こめらく みんなで、お茶漬け日和。 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 15回
# お茶漬け: 11回
# 有明: 10回
# フード: 10回
# コート: 10回
#
# --- 【さち福や 台場アクアシティ店】の頻出名詞 TOP 5 ---
# 店: 5回
# ...: 4回
# の: 4回
# アクアシティ: 3回
# 台場: 3回
#
# --- 【さち福やCAFE 有明ガーデン】の頻出名詞 TOP 5 ---
# ...: 52回
# 定食: 39回
# 有明: 34回
# 店: 29回
# ガーデン: 29回
#
# --- 【しゃぶしゃぶ 吟半 お台場店】の頻出名詞 TOP 5 ---
# 台場: 164回
# ...: 154回
# 店: 101回
# しゃぶしゃぶ: 88回
# コース: 68回
#
# --- 【しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場】の頻出名詞 TOP 5 ---
# 台場: 19回
# ...: 17回
# 店: 12回
# 放題: 11回
# 肉: 10回
#
# --- 【しゃぶ食べ 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 45回
# 放題: 32回
# 肉: 22回
# 店: 22回
# 野菜: 20回
#
# --- 【しゅん】の頻出名詞 TOP 5 ---
# ...: 29回
# 店: 19回
# 東雲: 17回
# 割烹: 14回
# ランチ: 12回
#
# --- 【すき家 ワンザ有明店】の頻出名詞 TOP 5 ---
# ...: 27回
# 家: 20回
# 店: 20回
# すき: 19回
# 丼: 17回
#
# --- 【すき家 東雲晴海通り店】の頻出名詞 TOP 5 ---
# ...: 13回
# すき: 11回
# 家: 11回
# 牛: 10回
# 人: 9回
#
# --- 【すしざんまい 奥の院】の頻出名詞 TOP 5 ---
# ...: 182回
# ざんまい: 137回
# すし: 122回
# 寿司: 120回
# 築地: 101回
#
# --- 【すしざんまい 築地駅前店】の頻出名詞 TOP 5 ---
# ...: 128回
# 築地: 117回
# 店: 98回
# ざんまい: 90回
# すし: 86回
#
# --- 【すし処おかめ】の頻出名詞 TOP 5 ---
# ...: 40回
# 豊洲: 37回
# 市場: 30回
# 店: 28回
# 寿司: 28回
#
# --- 【せきどうばなな】の頻出名詞 TOP 5 ---
# バナナ: 3回
# ドリンク: 1回
# 食: 1回
# 初心者: 1回
# 種類: 1回
#
# --- 【そじ坊 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 57回
# 蕎麦: 51回
# そば: 37回
# 店: 28回
# 円: 24回
#
# --- 【そじ坊 ワンザ有明店】の頻出名詞 TOP 5 ---
# ...: 40回
# そば: 27回
# 店: 23回
# 蕎麦: 17回
# ランチ: 17回
#
# --- 【そなエリア東京バーベキューガーデン】の頻出名詞 TOP 5 ---
# 駅: 4回
# 東京: 4回
# BBQ: 4回
# 有明: 3回
# ...: 3回
#
# --- 【たけぞー】の頻出名詞 TOP 5 ---
# ...: 52回
# 店: 42回
# 蕎麦: 27回
# うどん: 26回
# そば: 22回
#
# --- 【たこやきやの元祖 本家 会津屋 お台場店】の頻出名詞 TOP 5 ---
# たこ焼き: 227回
# ...: 125回
# 台場: 78回
# ミュージアム: 72回
# 元祖: 60回
#
# --- 【たこ家道頓堀くくる お台場たこ焼きミュージアム店】の頻出名詞 TOP 5 ---
# たこ焼き: 202回
# ...: 119回
# 台場: 96回
# ミュージアム: 74回
# 店: 53回
#
# --- 【つきじ丼匠】の頻出名詞 TOP 5 ---
# 丼: 79回
# ...: 55回
# 豊洲: 53回
# 市場: 52回
# 店: 49回
#
# --- 【つきぢ神楽寿司 豊洲市場店】の頻出名詞 TOP 5 ---
# ...: 59回
# 寿司: 56回
# 豊洲: 53回
# 店: 47回
# 市場: 45回
#
# --- 【つけ麺らーめん春樹 お台場店】の頻出名詞 TOP 5 ---
# 麺: 46回
# つけ: 32回
# ...: 32回
# ラーメン: 24回
# 台場: 20回
#
# --- 【つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店】の頻出名詞 TOP 5 ---
# 麺: 132回
# つけ: 65回
# ...: 59回
# 三田: 31回
# 製: 28回
#
# --- 【てしごとや ふくの鳥 木場店】の頻出名詞 TOP 5 ---
# ...: 22回
# メニュー: 13回
# 揚げ: 12回
# 唐: 11回
# ランチ: 10回
#
# --- 【てっぱん屋台 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 62回
# 店: 50回
# フード: 46回
# コート: 45回
# ダイバー: 34回
#
# --- 【とんかつ八千代】の頻出名詞 TOP 5 ---
# ...: 395回
# フライ: 290回
# 豊洲: 285回
# 市場: 284回
# チャーシュー: 279回
#
# --- 【どうとんぼり神座 有明ガーデン店】の頻出名詞 TOP 5 ---
# ラーメン: 119回
# ...: 111回
# 有明: 92回
# ガーデン: 75回
# フード: 71回
#
# --- 【なんで、や お台場店】の頻出名詞 TOP 5 ---
# 台場: 48回
# ...: 46回
# アクアシティ: 22回
# 居酒屋: 21回
# 店: 20回
#
# --- 【にばん家 勝どき】の頻出名詞 TOP 5 ---
# ...: 8回
# きじ: 7回
# 店: 6回
# 路地: 5回
# 勝どき: 5回
#
# --- 【ねぎま屋 武蔵 葛西店】の頻出名詞 TOP 5 ---
# ...: 23回
# ねぎま: 15回
# 焼き鳥: 13回
# 店: 9回
# 時: 8回
#
# --- 【ねこねこチーズケーキ 有明ガーデンシティ店】の頻出名詞 TOP 5 ---
# ...: 15回
# ケーキ: 13回
# チーズ: 12回
# 有明: 10回
# ねこ: 10回
#
# --- 【はなまるうどん ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# うどん: 118回
# ...: 68回
# 円: 58回
# フード: 36回
# コート: 35回
#
# --- 【はなまる屋 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 9回
# 台場: 8回
# うどん: 8回
# フード: 6回
# コート: 6回
#
# --- 【ふくの鳥 東陽町】の頻出名詞 TOP 5 ---
# ...: 41回
# チキン: 24回
# 南蛮: 21回
# ランチ: 20回
# 日替わり: 20回
#
# --- 【ふぐ倶楽部ビルヂング】の頻出名詞 TOP 5 ---
# ふぐ: 20回
# 店: 11回
# 料理: 9回
# 倶楽部: 9回
# ...: 9回
#
# --- 【ほおずきや】の頻出名詞 TOP 5 ---
# ...: 106回
# 店: 66回
# 展示: 54回
# ランチ: 40回
# 定食: 40回
#
# --- 【ほっともっと 東雲店】の頻出名詞 TOP 5 ---
# 弁当: 12回
# ...: 11回
# 東雲: 9回
# 店: 6回
# 1: 4回
#
# --- 【ぼてや アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 24回
# 焼きそば: 17回
# フード: 16回
# コート: 16回
# 台場: 14回
#
# --- 【まいばすけっと 台場1丁目店】の頻出名詞 TOP 5 ---
# IPA: 2回
# レインボー: 1回
# ブリッジ: 1回
# 歩道: 1回
# 入口: 1回
#
# --- 【まはらに】の頻出名詞 TOP 5 ---
# 店: 14回
# ...: 12回
# 料理: 7回
# 展示: 5回
# 場: 5回
#
# --- 【むら田】の頻出名詞 TOP 5 ---
# ...: 35回
# 店: 34回
# 展示: 19回
# ランチ: 15回
# ホテル: 14回
#
# --- 【やまちゃん お台場店】の頻出名詞 TOP 5 ---
# たこ焼き: 204回
# ...: 113回
# 台場: 79回
# ミュージアム: 78回
# 店: 57回
#
# --- 【アイランド・ヴィンテージ・コーヒー 台場店】の頻出名詞 TOP 5 ---
# ...: 89回
# 店: 50回
# 台場: 49回
# アサイーボウル: 34回
# ハワイ: 34回
#
# --- 【アニミル お台場店】の頻出名詞 TOP 5 ---
# エリア: 5回
# アドベンチャー: 2回
# ...: 2回
# DECKS: 2回
# 東京: 2回
#
# --- 【アマラ ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# ...: 24回
# カレー: 24回
# フード: 15回
# コート: 15回
# ダイバー: 14回
#
# --- 【アルポルト 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 97回
# ビッグ: 60回
# サイト: 60回
# ランチ: 57回
# 店: 55回
#
# --- 【ア・タ・ゴール】の頻出名詞 TOP 5 ---
# ...: 205回
# 木場: 102回
# 店: 98回
# オリエント: 82回
# 急行: 78回
#
# --- 【イオンスタイル 有明ガーデン】の頻出名詞 TOP 5 ---
# ...: 5回
# 休日: 4回
# 時: 4回
# (: 3回
# ): 3回
#
# --- 【イタリアン酒場 パステーカ】の頻出名詞 TOP 5 ---
# パスタ: 14回
# ...: 12回
# ランチ: 8回
# の: 7回
# ビッグ: 6回
#
# --- 【イマーシブ・フォート東京】の頻出名詞 TOP 5 ---
# ...: 13回
# の: 7回
# (: 6回
# 円: 5回
# 体験: 4回
#
# --- 【インコントロ オステリア&グリル】の頻出名詞 TOP 5 ---
# ...: 71回
# 台場: 43回
# ランチ: 30回
# 店: 27回
# 料理: 26回
#
# --- 【インドレストラン＆バー ムナル】の頻出名詞 TOP 5 ---
# ...: 82回
# カレー: 76回
# 店: 47回
# インド: 43回
# ナン: 40回
#
# --- 【インド料理ムンバイ アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 44回
# カレー: 37回
# インド: 30回
# 店: 27回
# 台場: 25回
#
# --- 【ウイスキーボイス 台場】の頻出名詞 TOP 5 ---
# ...: 23回
# ランチ: 17回
# 雰囲気: 15回
# 店: 14回
# 台場: 12回
#
# --- 【ウェンディーズ・ファーストキッチン アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 13回
# 台場: 10回
# アクアシティ: 6回
# ウェンディーズ: 6回
# 円: 5回
#
# --- 【ウマミバーガー 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 105回
# 有明: 90回
# ガーデン: 70回
# 店: 54回
# バーガー: 48回
#
# --- 【エクセルシオール カフェ ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 東京: 11回
# ダイバー: 9回
# ...: 9回
# シティ: 8回
# 時間: 7回
#
# --- 【エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 4回
# 店: 3回
# フロア: 3回
# エクセルシオールカフェ: 2回
# チーズ: 2回
#
# --- 【エグゼクティブラウンジ】の頻出名詞 TOP 5 ---
# ...: 12回
# 台場: 11回
# ヒルトン: 8回
# 東京: 8回
# ラウンジ: 7回
#
# --- 【エスプレッソ アメリカーノ テレコムセンター店】の頻出名詞 TOP 5 ---
# ...: 28回
# テレコム: 21回
# センター: 21回
# カフェ: 16回
# 利用: 13回
#
# --- 【エッグスンシングス お台場店】の頻出名詞 TOP 5 ---
# ...: 217回
# パンケーキ: 182回
# 店: 89回
# 台場: 71回
# の: 55回
#
# --- 【エフアイランド】の頻出名詞 TOP 5 ---
# ): 2回
# 禁断: 2回
# その他: 2回
# ...: 2回
# 日: 2回
#
# --- 【エフカイビーチ】の頻出名詞 TOP 5 ---
# 台場: 45回
# ...: 39回
# 公園: 23回
# 海浜: 22回
# 店: 17回
#
# --- 【オイスターハウス お台場店】の頻出名詞 TOP 5 ---
# 牡蠣: 87回
# ...: 53回
# 店: 31回
# ランチ: 30回
# 席: 27回
#
# --- 【オリジナルパンケーキハウス 有明ガーデン店】の頻出名詞 TOP 5 ---
# パンケーキ: 84回
# ...: 81回
# 店: 47回
# 有明: 43回
# ガーデン: 37回
#
# --- 【オーケー お台場店】の頻出名詞 TOP 5 ---
# ...: 5回
# ロース: 3回
# 台場: 3回
# 時半: 2回
# 店: 2回
#
# --- 【オーケー 東雲店】の頻出名詞 TOP 5 ---
# 東雲: 3回
# オーケー: 2回
# 店: 2回
# 定番: 2回
# 駅: 1回
#
# --- 【オーシャンクラブビュッフェ デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 75回
# 台場: 32回
# ビュッフェ: 28回
# 店: 27回
# 東京: 25回
#
# --- 【オーシャン東九フェリー】の頻出名詞 TOP 5 ---
# フェリー: 6回
# ...: 6回
# 自販機: 5回
# 東京: 4回
# 徳島: 4回
#
# --- 【オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明)】の頻出名詞 TOP 5 ---
# ...: 74回
# ビュッフェ: 29回
# 料理: 25回
# 丼: 25回
# 海鮮: 23回
#
# --- 【カザーナ お台場店】の頻出名詞 TOP 5 ---
# カレー: 300回
# ...: 244回
# ランチ: 120回
# 台場: 116回
# バイキング: 110回
#
# --- 【カツオたまご食堂】の頻出名詞 TOP 5 ---
# ...: 17回
# カツオ: 14回
# 食堂: 12回
# 店: 11回
# 定食: 10回
#
# --- 【カフェ ラ・ボエム お台場】の頻出名詞 TOP 5 ---
# ...: 256回
# 店: 144回
# 台場: 144回
# パスタ: 100回
# 席: 86回
#
# --- 【カフェ&ミール ムジ 東京有明】の頻出名詞 TOP 5 ---
# ...: 40回
# 無印: 27回
# カフェ: 25回
# 有明: 22回
# 良品: 21回
#
# --- 【カフェテラス　ロイヤル】の頻出名詞 TOP 5 ---
# ...: 39回
# 展示: 27回
# サイト: 22回
# ビッグ: 21回
# 東京: 20回
#
# --- 【カフェ＆レストラン レインボー】の頻出名詞 TOP 5 ---
# ...: 29回
# レストラン: 24回
# 病院: 20回
# 有明: 19回
# 東京會舘: 19回
#
# --- 【カフェ･ベローチェ  有明店】の頻出名詞 TOP 5 ---
# ...: 78回
# 展示: 41回
# 国際: 34回
# 場: 33回
# コーヒー: 32回
#
# --- 【カレス】の頻出名詞 TOP 5 ---
# ...: 242回
# 台場: 169回
# ランチ: 123回
# 店: 122回
# パスタ: 93回
#
# --- 【カレーショップ C&Cダイニング 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# カレー: 105回
# ...: 74回
# C: 51回
# 店: 47回
# 東京: 46回
#
# --- 【カレー香房】の頻出名詞 TOP 5 ---
# カレー: 24回
# ...: 19回
# 東京: 12回
# フード: 12回
# コート: 12回
#
# --- 【カンテボーレ イオンスタイル有明ガーデン】の頻出名詞 TOP 5 ---
# パン: 17回
# イオン: 9回
# ...: 9回
# 屋: 7回
# 購入: 5回
#
# --- 【カーサ・ディ・ペロー二】の頻出名詞 TOP 5 ---
# ...: 27回
# 東京: 13回
# イマーシブフォート: 12回
# レストラン: 11回
# 円: 10回
#
# --- 【カールスジュニア ダイバーシティ東京 プラザレストラン】の頻出名詞 TOP 5 ---
# ...: 105回
# ハンバーガー: 57回
# フード: 47回
# コート: 45回
# の: 40回
#
# --- 【ガルーバ】の頻出名詞 TOP 5 ---
# ...: 61回
# 台場: 49回
# 焼肉: 40回
# 肉: 28回
# ランチ: 27回
#
# --- 【ガーデン ダイニング】の頻出名詞 TOP 5 ---
# ...: 190回
# ビュッフェ: 82回
# 台場: 76回
# ホテル: 66回
# ニッコー: 54回
#
# --- 【キッチン有明】の頻出名詞 TOP 5 ---
# ...: 65回
# ラーメン: 43回
# 食堂: 40回
# 有明: 32回
# 定食: 24回
#
# --- 【キッチン青海珈琲】の頻出名詞 TOP 5 ---
# :: 11回
# 11: 10回
# ...: 9回
# ハンバーグ: 9回
# 1: 8回
#
# --- 【キムカツ亭 有明ガーデン店】の頻出名詞 TOP 5 ---
# カツ: 51回
# ...: 44回
# 有明: 42回
# キム: 35回
# ガーデン: 31回
#
# --- 【キラキラドンキ ダイバーシティ東京 プラザ店】の頻出名詞 TOP 5 ---
# ワッフル: 3回
# 中: 2回
# キラキラドンキ: 2回
# ...: 2回
# チョコ: 1回
#
# --- 【キリンシティプラス 有明ガーデン店】の頻出名詞 TOP 5 ---
# ビール: 46回
# ...: 38回
# キリン: 24回
# 店: 18回
# 有明: 16回
#
# --- 【クアアイナ アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 354回
# 台場: 249回
# ハンバーガー: 208回
# 店: 199回
# クアアイナ: 136回
#
# --- 【クルックス カフェオ ヨーロピアンリゾートカフェ】の頻出名詞 TOP 5 ---
# ...: 36回
# 台場: 28回
# カフェ: 23回
# 店: 13回
# ビル: 13回
#
# --- 【クレープおじさん お台場店】の頻出名詞 TOP 5 ---
# クレープ: 8回
# ...: 8回
# .: 7回
# ジョイポリス: 5回
# 日: 5回
#
# --- 【グランディール 有明ガーデン店】の頻出名詞 TOP 5 ---
# パン: 39回
# ...: 19回
# 屋: 16回
# 有明: 12回
# ガーデン: 11回
#
# --- 【グランドニッコー東京 台場】の頻出名詞 TOP 5 ---
# ...: 83回
# 台場: 51回
# ホテル: 31回
# ニッコー: 30回
# 東京: 29回
#
# --- 【グランドニッコー東京 台場 エグゼクティブラウンジ】の頻出名詞 TOP 5 ---
# ...: 13回
# の: 5回
# 宿泊: 5回
# 時: 4回
# ホテル: 4回
#
# --- 【グランブルー】の頻出名詞 TOP 5 ---
# プール: 3回
# 予約: 3回
# ...: 2回
# ホテル: 2回
# ビアガーデン: 2回
#
# --- 【グリロジー バー＆グリル】の頻出名詞 TOP 5 ---
# ...: 52回
# 台場: 35回
# ヒルトン: 30回
# アフタヌーン: 16回
# ティー: 16回
#
# --- 【グリーン アジア トウキョウ】の頻出名詞 TOP 5 ---
# ...: 56回
# サラダ: 37回
# バー: 32回
# 料理: 31回
# ランチ: 30回
#
# --- 【グリーンズシェフ】の頻出名詞 TOP 5 ---
# ...: 10回
# センター: 7回
# テレコム: 6回
# 食堂: 5回
# 東京: 4回
#
# --- 【グロー ジュース スタンド】の頻出名詞 TOP 5 ---
# ...: 17回
# スムージー: 10回
# 有明: 9回
# ガーデン: 8回
# アサイーボウル: 7回
#
# --- 【ゲンの中華そば 東京ビックサイト南展示棟店】の頻出名詞 TOP 5 ---
# ...: 30回
# 中華: 26回
# ラーメン: 25回
# そば: 25回
# 東京: 21回
#
# --- 【ココス 有明パークビル店】の頻出名詞 TOP 5 ---
# ...: 55回
# ココス: 37回
# 有明: 26回
# ランチ: 22回
# の: 18回
#
# --- 【コムフォー アーバンドック ららぽーと豊洲店】の頻出名詞 TOP 5 ---
# フォー: 105回
# ...: 75回
# カレー: 57回
# 店: 52回
# パクチー: 28回
#
# --- 【ゴクゴク ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 13回
# バナナ: 12回
# ジュース: 10回
# ミルク: 5回
# ダイバー: 5回
#
# --- 【ゴンチャ アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 37回
# タピオカ: 33回
# ゴンチャ: 23回
# の: 16回
# さ: 14回
#
# --- 【サイゼリヤ 有明フロンティアビル店】の頻出名詞 TOP 5 ---
# ...: 79回
# 展示: 39回
# サイゼリヤ: 38回
# ランチ: 36回
# 店: 27回
#
# --- 【サザエさんのお店】の頻出名詞 TOP 5 ---
# サザエさん: 50回
# ...: 35回
# フジテレビ: 31回
# 焼き: 28回
# 味: 20回
#
# --- 【サブウェイ TFT有明店】の頻出名詞 TOP 5 ---
# ...: 13回
# サブ: 12回
# ウェイ: 11回
# の: 8回
# 久しぶり: 7回
#
# --- 【サーティワン エクスペリエンス ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 26回
# ダイバー: 16回
# シティ: 16回
# サーティワン: 12回
# アイス: 11回
#
# --- 【サーティワンアイスクリーム デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 21回
# 台場: 12回
# サーティーワン: 8回
# アイスクリーム: 7回
# 東京: 7回
#
# --- 【サーティワンアイスクリーム 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 7回
# 有明: 6回
# の: 4回
# アイス: 4回
# 私: 3回
#
# --- 【ザ バー&ラウンジ】の頻出名詞 TOP 5 ---
# ...: 23回
# 東京: 15回
# 台場: 12回
# バー: 11回
# ホテル: 10回
#
# --- 【ザ・コルトーナシーサイド台場】の頻出名詞 TOP 5 ---
# ...: 9回
# 結婚式: 5回
# クリスマス: 5回
# コース: 3回
# の: 3回
#
# --- 【ザ・台場】の頻出名詞 TOP 5 ---
# 土産: 5回
# 東京: 4回
# ...: 4回
# 台場: 4回
# 店: 3回
#
# --- 【シズラー アクアシティ店】の頻出名詞 TOP 5 ---
# ...: 137回
# サラダ: 102回
# シズラー: 88回
# バー: 73回
# 店: 70回
#
# --- 【シュマッツ 有明ガーデン】の頻出名詞 TOP 5 ---
# ...: 179回
# ビール: 168回
# 店: 95回
# 有明: 91回
# ガーデン: 75回
#
# --- 【シースケープ スイーツ＆コーヒー】の頻出名詞 TOP 5 ---
# ...: 6回
# ケーキ: 4回
# 値段: 3回
# 購入: 3回
# ヒルトン: 2回
#
# --- 【シースケープ テラス・ダイニング】の頻出名詞 TOP 5 ---
# ...: 192回
# 台場: 102回
# ビュッフェ: 77回
# ヒルトン: 76回
# 料理: 62回
#
# --- 【シーフードキッチン ピチ】の頻出名詞 TOP 5 ---
# 店: 26回
# ...: 26回
# 葛西: 10回
# 駅: 8回
# メニュー: 8回
#
# --- 【シーフードレストラン メヒコ 東京ベイ有明店】の頻出名詞 TOP 5 ---
# ...: 276回
# ピラフ: 211回
# カニ: 208回
# 店: 139回
# メヒコ: 101回
#
# --- 【シーフードレストランネプチューン】の頻出名詞 TOP 5 ---
# ...: 177回
# 店: 107回
# 東雲: 70回
# レストラン: 61回
# シーフード: 59回
#
# --- 【ジ オーブン アメリカン ビュッフェ】の頻出名詞 TOP 5 ---
# ...: 124回
# 台場: 66回
# 店: 61回
# 料理: 45回
# の: 34回
#
# --- 【ジューシーパパ】の頻出名詞 TOP 5 ---
# ...: 12回
# フード: 11回
# コート: 11回
# ビッグ: 9回
# サイト: 9回
#
# --- 【ジューススタンド】の頻出名詞 TOP 5 ---
# 無印: 2回
# 関東: 1回
# 最大: 1回
# 級: 1回
# 有明: 1回
#
# --- 【ジョナサン 台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 19回
# 台場: 16回
# 時: 10回
# 店: 9回
# ランチ: 7回
#
# --- 【ジョンノ屋台村＆ネネチキン 有明ガーデン】の頻出名詞 TOP 5 ---
# ...: 9回
# 有明: 8回
# フード: 8回
# ガーデン: 7回
# 韓国: 7回
#
# --- 【ジョージタウン】の頻出名詞 TOP 5 ---
# ...: 52回
# ホテル: 42回
# ワシントン: 26回
# 有明: 23回
# 朝食: 22回
#
# --- 【ジー＆ジー】の頻出名詞 TOP 5 ---
# 集まり: 2回
# ...: 2回
# 製: 2回
# 料理: 2回
# 年: 1回
#
# --- 【スターバックス コーヒー ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 45回
# スタバ: 26回
# ダイバー: 19回
# シティ: 17回
# の: 14回
#
# --- 【スターバックスコーヒー 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 82回
# 東京: 45回
# スタバ: 44回
# ビッグ: 38回
# サイト: 37回
#
# --- 【スターバックス・コーヒー アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 93回
# 台場: 73回
# アクアシティ: 37回
# スタバ: 35回
# 席: 33回
#
# --- 【スモール ワールズ トウキョウ】の頻出名詞 TOP 5 ---
# ...: 18回
# スモールワールズ: 9回
# 香: 8回
# 薫: 7回
# 世界: 6回
#
# --- 【セブンイレブン DR東京有明ダイワロイネットホテル店】の頻出名詞 TOP 5 ---
# スープ: 3回
# 一: 2回
# ...: 2回
# 本日: 2回
# ランチ: 2回
#
# --- 【セブンイレブン ROYALビッグサイト店】の頻出名詞 TOP 5 ---
# 店: 2回
# セブン: 2回
# イレブン: 2回
# おにぎり: 2回
# イベント: 1回
#
# --- 【セブンイレブン タイム24ビル店】の頻出名詞 TOP 5 ---
# 購入: 4回
# パン: 3回
# 円: 3回
# 寿司: 3回
# 日: 2回
#
# --- 【セブンイレブン ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 2回
# 玄米: 2回
# おにぎり: 2回
# 朝: 2回
# 自宅: 1回
#
# --- 【セブンイレブン ＴＦＴ有明店】の頻出名詞 TOP 5 ---
# 飲食: 2回
# 店: 2回
# 久々: 1回
# ビッグ: 1回
# サイト: 1回
#
# --- 【ゼスト キャンティーナ お台場】の頻出名詞 TOP 5 ---
# ...: 190回
# 店: 124回
# 台場: 100回
# ランチ: 64回
# 雰囲気: 62回
#
# --- 【ゼッテリア TFT有明店】の頻出名詞 TOP 5 ---
# ロッテリア: 21回
# ...: 20回
# 絶品: 13回
# の: 10回
# ゼッテリア: 10回
#
# --- 【タコベル アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 75回
# タコ: 50回
# 台場: 46回
# ベル: 45回
# 店: 42回
#
# --- 【タコベル 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 32回
# 有明: 20回
# タコ: 17回
# ガーデン: 16回
# 円: 15回
#
# --- 【タラキッチン 東陽町イースト21店】の頻出名詞 TOP 5 ---
# ...: 33回
# カレー: 24回
# 店: 22回
# インド: 17回
# 町: 17回
#
# --- 【タリーズコーヒー がん研有明病院店】の頻出名詞 TOP 5 ---
# 病院: 24回
# ...: 22回
# コーヒー: 11回
# タリーズ: 11回
# 有明: 10回
#
# --- 【タリーズコーヒー ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 19回
# 店: 12回
# ガン: 12回
# ダム: 12回
# ダイバー: 11回
#
# --- 【タリーズコーヒー フジテレビ店】の頻出名詞 TOP 5 ---
# ...: 4回
# 台場: 3回
# フジテレビ: 3回
# １: 2回
# 階: 2回
#
# --- 【タリーズコーヒー 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 34回
# 有明: 28回
# ガーデン: 18回
# コーヒー: 14回
# 店: 14回
#
# --- 【タリーズコーヒー 東京ガーデンシアター店】の頻出名詞 TOP 5 ---
# ...: 11回
# 有明: 9回
# ガーデン: 8回
# シアター: 6回
# コーヒー: 5回
#
# --- 【タリーズコーヒー 東京テレポート駅店】の頻出名詞 TOP 5 ---
# 駅: 7回
# ...: 6回
# 改札: 4回
# 席: 4回
# 内: 3回
#
# --- 【タリーズコーヒー 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 93回
# サイト: 58回
# ビッグ: 57回
# 東京: 52回
# 展示: 38回
#
# --- 【タヴェルナ・エ・ピッツェリア　サルーテ】の頻出名詞 TOP 5 ---
# ...: 31回
# ピザ: 20回
# 店: 19回
# ランチ: 17回
# パスタ: 16回
#
# --- 【タールムビアンコ お台場店】の頻出名詞 TOP 5 ---
# ...: 89回
# 店: 77回
# 台場: 62回
# の: 25回
# 海浜: 22回
#
# --- 【ダブルティー アリアケ】の頻出名詞 TOP 5 ---
# ...: 12回
# 有明: 11回
# カフェ: 10回
# 店: 9回
# コーヒー: 9回
#
# --- 【チムニー 東京ビックサイト前店】の頻出名詞 TOP 5 ---
# ...: 29回
# ランチ: 20回
# ビッグ: 16回
# サイト: 16回
# 東京: 15回
#
# --- 【チャイナグリーン】の頻出名詞 TOP 5 ---
# ...: 44回
# 店: 26回
# の: 17回
# ランチ: 16回
# 時: 15回
#
# --- 【ディッピンドッツ・アイスクリーム 東京ジョイポリス】の頻出名詞 TOP 5 ---
# ...: 38回
# アイス: 30回
# ジョイポリス: 21回
# 台場: 17回
# の: 15回
#
# --- 【ディップガーデン テラス 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 157回
# 料理: 106回
# 店: 94回
# 有明: 91回
# カレー: 85回
#
# --- 【デコラクリーマリー ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 29回
# 店: 24回
# 綿: 18回
# ダイバー: 17回
# シティ: 16回
#
# --- 【デンバー プレミアム 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 44回
# フード: 30回
# コート: 30回
# カレー: 28回
# 有明: 28回
#
# --- 【トゥ・ザ・ハーブズ アクアシティーお台場店】の頻出名詞 TOP 5 ---
# ...: 140回
# 台場: 99回
# 店: 79回
# 席: 78回
# テラス: 60回
#
# --- 【トウキョウ・クッキー・ファクトリー ラオックス デックス東京ビーチ台場店】の頻出名詞 TOP 5 ---
# 日: 1回
# やつ: 1回
# 西武: 1回
# 高槻: 1回
# 店: 1回
#
# --- 【トモズ 有明ガーデン店】の頻出名詞 TOP 5 ---
# ０: 2回
# (>_<): 2回
# 店: 2回
# サンガ: 1回
# リア: 1回
#
# --- 【ドッグデプトカフェ お台場東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 19回
# 台場: 16回
# 店: 15回
# 犬: 15回
# カフェ: 8回
#
# --- 【ドトールコーヒーショップ 国際展示場駅店】の頻出名詞 TOP 5 ---
# ...: 51回
# 駅: 43回
# 展示: 36回
# 国際: 31回
# 場: 31回
#
# --- 【ドトールコーヒーショップ 有明セントラルタワー店】の頻出名詞 TOP 5 ---
# ...: 12回
# ドトール: 6回
# 有明: 5回
# オフィス: 4回
# の: 4回
#
# --- 【ドミノ・ピザ 台場店】の頻出名詞 TOP 5 ---
# ピザ: 6回
# 分: 4回
# ...: 4回
# 台場: 3回
# ドミノ: 3回
#
# --- 【ナチュラルクレープ 有明ガーデン店】の頻出名詞 TOP 5 ---
# クレープ: 41回
# ...: 41回
# 有明: 24回
# ガーデン: 22回
# 生地: 21回
#
# --- 【ニイチク】の頻出名詞 TOP 5 ---
# 肉: 2回
# 月: 1回
# 卸: 1回
# 屋: 1回
# 直売: 1回
#
# --- 【ニャーベトナム フォー&バインミー 有明店】の頻出名詞 TOP 5 ---
# ...: 25回
# 有明: 24回
# フォー: 24回
# フード: 21回
# コート: 21回
#
# --- 【ニューデイズ 東京テレポート店】の頻出名詞 TOP 5 ---
# 駅: 2回
# ...: 2回
# 東京: 1回
# テレポート: 1回
# 改札: 1回
#
# --- 【ニューヤマザキデイリーストア 青海流通センター店】の頻出名詞 TOP 5 ---
# 青海: 2回
# 弁当: 2回
# 埠頭: 1回
# 流通: 1回
# センター: 1回
#
# --- 【ニルワナム 有明店】の頻出名詞 TOP 5 ---
# カレー: 35回
# ...: 34回
# 店: 18回
# マトン: 14回
# 有明: 13回
#
# --- 【ニルワナム 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 32回
# カレー: 28回
# 店: 24回
# ランチ: 17回
# 円: 14回
#
# --- 【ノイタミナSHOP】の頻出名詞 TOP 5 ---
# ...: 8回
# アニメ: 8回
# 点: 7回
# 5: 5回
# ノイタミナ: 4回
#
# --- 【ハイカラ横丁】の頻出名詞 TOP 5 ---
# 駄菓子: 6回
# 屋: 4回
# 台場: 4回
# ...: 4回
# .: 3回
#
# --- 【バイロンベイミートパイ  有明店】の頻出名詞 TOP 5 ---
# パイ: 19回
# ...: 9回
# ミート: 7回
# 店: 7回
# 2: 6回
#
# --- 【バウムクーヘン専門店アニバウム 有明ガーデン店】の頻出名詞 TOP 5 ---
# 有明: 6回
# ...: 5回
# 店: 5回
# ガーデン: 4回
# 際: 3回
#
# --- 【バニヤンツリーカフェ】の頻出名詞 TOP 5 ---
# メニュー: 6回
# ...: 4回
# ホテル: 3回
# ランチ: 3回
# 料理: 3回
#
# --- 【バンクサンドイッチ アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 19回
# 店: 13回
# サンドイッチ: 11回
# 台場: 10回
# 円: 8回
#
# --- 【バーガーキング  有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 18回
# 有明: 16回
# バーガー: 14回
# キング: 12回
# ガーデン: 11回
#
# --- 【バーベキューテラス　「アブレイズ」 ヒルトン東京お台場】の頻出名詞 TOP 5 ---
# ...: 22回
# 台場: 14回
# ヒルトン: 13回
# バーベキュー: 12回
# 東京: 11回
#
# --- 【パティスリー ピネード 有明ガーデンシティ店】の頻出名詞 TOP 5 ---
# ケーキ: 26回
# 有明: 24回
# ...: 23回
# ガーデン: 17回
# 店: 10回
#
# --- 【パパスバル】の頻出名詞 TOP 5 ---
# ...: 107回
# カレー: 99回
# 沖縄: 50回
# 店: 48回
# 訪問: 46回
#
# --- 【パパトリア 門前仲町本店】の頻出名詞 TOP 5 ---
# ...: 37回
# 店: 23回
# パスタ: 18回
# ランチ: 16回
# 料理: 13回
#
# --- 【パンドクレム】の頻出名詞 TOP 5 ---
# パン: 30回
# ...: 14回
# 屋: 8回
# 店員: 5回
# 前: 5回
#
# --- 【ヒルトン東京お台場】の頻出名詞 TOP 5 ---
# ...: 88回
# 台場: 57回
# ヒルトン: 49回
# 東京: 40回
# ホテル: 35回
#
# --- 【ヒーローフィールド】の頻出名詞 TOP 5 ---
# BBQ: 4回
# 東京: 3回
# エリア: 2回
# 駅: 2回
# 公園: 2回
#
# --- 【ビオラル 有明ガーデン店】の頻出名詞 TOP 5 ---
# ビオラル: 3回
# 中: 2回
# 野菜: 2回
# ...: 2回
# 健康: 1回
#
# --- 【ビオラルカフェ 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 33回
# カフェ: 19回
# 有明: 19回
# ガーデン: 18回
# 品: 13回
#
# --- 【ビッグシェフ お台場・デックス東京ビーチ】の頻出名詞 TOP 5 ---
# ...: 70回
# 店: 51回
# 台場: 46回
# の: 23回
# 席: 22回
#
# --- 【ビューラウンジ グランドニッコー東京 台場】の頻出名詞 TOP 5 ---
# ...: 7回
# ビュッフェ: 4回
# ここ: 3回
# の: 3回
# コース: 3回
#
# --- 【ビーエムダブリューグループトーキョーベイ】の頻出名詞 TOP 5 ---
# ...: 11回
# カフェ: 6回
# BMW: 5回
# コーヒー: 5回
# ドリンク: 4回
#
# --- 【ピザーラ 有明】の頻出名詞 TOP 5 ---
# 番組: 2回
# テレビ東京: 1回
# 系列: 1回
# 平日: 1回
# 夕方: 1回
#
# --- 【ピザ＆パスタ マリノステリア 葛西店】の頻出名詞 TOP 5 ---
# ...: 81回
# パスタ: 57回
# 店: 50回
# 葛西: 46回
# ランチ: 43回
#
# --- 【ピッツェリア ドォーロ ローマ 台場店】の頻出名詞 TOP 5 ---
# ...: 57回
# ピザ: 50回
# 店: 36回
# 台場: 22回
# の: 22回
#
# --- 【ファミリーマート BSガレリア店】の頻出名詞 TOP 5 ---
# T: 2回
# 東京: 1回
# ビックサイト: 1回
# 内: 1回
# 東: 1回
#
# --- 【ファミリーマート お台場東京ビーチ店】の頻出名詞 TOP 5 ---
# 台場: 1回
# デックス: 1回
# コンビニ: 1回
# サンクス: 1回
# ファミリーマート: 1回
#
# --- 【ファミリーマート お台場海浜公園店】の頻出名詞 TOP 5 ---
# とき: 3回
# ...: 3回
# (: 3回
# 途中: 2回
# 一服: 2回
#
# --- 【ファミリーマート がん研有明病院店】の頻出名詞 TOP 5 ---
# 病院: 5回
# ...: 3回
# がん: 3回
# 患者: 2回
# 見舞い: 2回
#
# --- 【ファミリーマート テレコムセンター店】の頻出名詞 TOP 5 ---
# ジャン: 2回
# キー: 2回
# おむすび: 1回
# ガーリック: 1回
# ごはん: 1回
#
# --- 【ファミリーマート トレードピアお台場店】の頻出名詞 TOP 5 ---
# ファミマ: 2回
# おにぎり: 2回
# 昼: 2回
# 朝: 1回
# パン: 1回
#
# --- 【ファミリーマート 有明フロンティア店】の頻出名詞 TOP 5 ---
# 1: 2回
# F: 2回
# コンビニ: 2回
# ...: 2回
# .: 2回
#
# --- 【ファミリーマート 東京湾岸警察署前店】の頻出名詞 TOP 5 ---
# アップ: 2回
# の: 2回
# 現場: 2回
# ...: 2回
# 日頃: 1回
#
# --- 【ファミリーマート 青海フロンティア店】の頻出名詞 TOP 5 ---
# 時間: 2回
# 江東: 1回
# 区: 1回
# テレコム: 1回
# センター: 1回
#
# --- 【ファーイーストビレッジホテル 東京有明】の頻出名詞 TOP 5 ---
# /: 2回
# 東京: 2回
# 2024: 1回
# 11: 1回
# 15: 1回
#
# --- 【フォーシーズンズカフェ】の頻出名詞 TOP 5 ---
# ...: 361回
# パフェ: 223回
# 店: 146回
# 西葛西: 104回
# の: 95回
#
# --- 【フレームカフェ】の頻出名詞 TOP 5 ---
# ...: 21回
# ジョイポリス: 17回
# カフェ: 10回
# 内: 7回
# 台場: 7回
#
# --- 【ブリッジ】の頻出名詞 TOP 5 ---
# 有明: 41回
# ...: 39回
# フード: 32回
# ガーデン: 31回
# コート: 29回
#
# --- 【プロント ワンザ有明店】の頻出名詞 TOP 5 ---
# ...: 37回
# 展示: 24回
# プロント: 19回
# 場: 15回
# 店: 14回
#
# --- 【プロント 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 72回
# ビッグ: 48回
# サイト: 47回
# 東京: 38回
# プロント: 30回
#
# --- 【ベジテジや ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 42回
# フード: 28回
# コート: 28回
# ダイバー: 22回
# 丼: 22回
#
# --- 【ベビーカステラ専門店 KUTSUROGI】の頻出名詞 TOP 5 ---
# カステラ: 16回
# ベビー: 14回
# ...: 11回
# 店内: 6回
# 注文: 4回
#
# --- 【ベーカリー&ペストリー・ショップ】の頻出名詞 TOP 5 ---
# ...: 62回
# ケーキ: 43回
# 台場: 42回
# パン: 28回
# 店: 25回
#
# --- 【ベーカリーレストランサンマルク 有明ガーデン店】の頻出名詞 TOP 5 ---
# パン: 58回
# ...: 54回
# 放題: 29回
# 店: 23回
# サンマルク: 21回
#
# --- 【ペコちゃんmilkyドーナツ 有明ガーデン】の頻出名詞 TOP 5 ---
# ドーナツ: 38回
# ...: 29回
# クリーム: 19回
# 店: 13回
# ペコ: 13回
#
# --- 【ホップ＆ステップ カフェ】の頻出名詞 TOP 5 ---
# 駅: 10回
# テレポート: 9回
# 東京: 8回
# ...: 8回
# カフェ: 7回
#
# --- 【ホテルトラスティ 東京駅ベイサイド】の頻出名詞 TOP 5 ---
# ...: 15回
# ランチ: 8回
# 東京: 7回
# 宿泊: 5回
# パン: 5回
#
# --- 【ホブソンズ アイスクリームパーラー 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 61回
# パフェ: 54回
# 有明: 48回
# ガーデン: 34回
# ": 32回
#
# --- 【ホルモン焼肉 しまちゃん】の頻出名詞 TOP 5 ---
# 放題: 211回
# タン: 203回
# ...: 168回
# 牛: 131回
# 焼肉: 103回
#
# --- 【ポムの樹 アクアシティお台場店】の頻出名詞 TOP 5 ---
# オムライス: 90回
# ...: 74回
# 台場: 49回
# 店: 47回
# ポム: 29回
#
# --- 【ポートストア 青海】の頻出名詞 TOP 5 ---
# ①: 2回
# /: 2回
# 湘南: 2回
# 青海: 1回
# 食堂: 1回
#
# --- 【マクドナルド お台場デックス店】の頻出名詞 TOP 5 ---
# ...: 51回
# 台場: 34回
# 円: 28回
# マック: 19回
# 東京: 17回
#
# --- 【マクドナルド ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 20回
# 台場: 12回
# シティ: 11回
# ダイバー: 10回
# マック: 6回
#
# --- 【マクドナルド 有明パークビル店】の頻出名詞 TOP 5 ---
# ...: 76回
# 有明: 51回
# 展示: 41回
# マック: 33回
# 場: 32回
#
# --- 【マグロスタンダード 門前仲町店】の頻出名詞 TOP 5 ---
# マグロ: 304回
# ...: 175回
# 店: 126回
# お通し: 61回
# の: 52回
#
# --- 【マジカレー 有明ガーデン店】の頻出名詞 TOP 5 ---
# カレー: 101回
# ...: 56回
# 有明: 42回
# フード: 34回
# コート: 34回
#
# --- 【マジソン プレミアム バーガー】の頻出名詞 TOP 5 ---
# ...: 28回
# 東京: 18回
# 展示: 16回
# 円: 13回
# サイト: 12回
#
# --- 【マダムドリュック 有明ガーデン店】の頻出名詞 TOP 5 ---
# チョコ: 20回
# ...: 18回
# チョコレート: 15回
# の: 10回
# 2: 10回
#
# --- 【マディソンラウンジ】の頻出名詞 TOP 5 ---
# ...: 35回
# ラウンジ: 27回
# ベイ: 22回
# 東京: 22回
# コート: 21回
#
# --- 【マルエツ お台場店】の頻出名詞 TOP 5 ---
# 近く: 2回
# ...: 2回
# スーパー: 2回
# 品: 2回
# ホテル: 1回
#
# --- 【マルユ】の頻出名詞 TOP 5 ---
# 酒: 43回
# ...: 39回
# 店: 31回
# 日本: 28回
# 立ち: 23回
#
# --- 【マロリーポークステーキ お台場店】の頻出名詞 TOP 5 ---
# ...: 34回
# 店: 21回
# 台場: 18回
# g: 17回
# ステーキ: 14回
#
# --- 【マロリーポークステーキ 南砂町SUNAMO店】の頻出名詞 TOP 5 ---
# ...: 80回
# ステーキ: 50回
# 店: 49回
# ポーク: 47回
# g: 39回
#
# --- 【マーメイド】の頻出名詞 TOP 5 ---
# ...: 46回
# 東京: 21回
# 展示: 20回
# 店: 20回
# ビッグ: 19回
#
# --- 【ミスタードーナツ ダイバーシティ東京プラザショップ】の頻出名詞 TOP 5 ---
# ...: 14回
# の: 10回
# ドーナツ: 6回
# ミスド: 6回
# 購入: 5回
#
# --- 【ミニストップ WANZA有明店】の頻出名詞 TOP 5 ---
# ソフト: 2回
# ハロ: 2回
# 感: 2回
# ...: 2回
# 期間: 1回
#
# --- 【ミニストップ シティタワーズ東京ベイ店】の頻出名詞 TOP 5 ---
# ...: 3回
# 前: 2回
# 店員: 2回
# レジ: 2回
# 東京: 2回
#
# --- 【ミート酒場 ぼいす】の頻出名詞 TOP 5 ---
# 肉: 19回
# ...: 13回
# 串: 9回
# 料理: 9回
# 店: 8回
#
# --- 【ムジベーカリー 東京有明店】の頻出名詞 TOP 5 ---
# パン: 58回
# ...: 44回
# 有明: 39回
# 無印: 36回
# カレー: 30回
#
# --- 【メインバー「キャプテンズバー」 ヒルトン東京お台場】の頻出名詞 TOP 5 ---
# ...: 34回
# バー: 24回
# 台場: 13回
# ホテル: 13回
# 日航: 11回
#
# --- 【メーピン】の頻出名詞 TOP 5 ---
# タイ: 69回
# ...: 59回
# 料理: 52回
# 店: 39回
# カレー: 33回
#
# --- 【モナークバー】の頻出名詞 TOP 5 ---
# 会員: 6回
# ...: 5回
# バー: 5回
# 時: 3回
# 東京: 3回
#
# --- 【モミアンドトイズ デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 18回
# クレープ: 13回
# 台場: 12回
# の: 10回
# 注文: 6回
#
# --- 【モンスーンカフェ お台場】の頻出名詞 TOP 5 ---
# ...: 165回
# 台場: 82回
# モンスーン: 76回
# カフェ: 66回
# 店: 66回
#
# --- 【ユナイテッド・シネマ アクアシティお台場】の頻出名詞 TOP 5 ---
# ポップコーン: 7回
# 台場: 5回
# 映画: 5回
# ...: 5回
# 購入: 4回
#
# --- 【ヨゴリーノ　 お台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 32回
# たこ焼き: 17回
# ヨーグルト: 15回
# 台場: 13回
# ヨゴリーノ: 13回
#
# --- 【ラ ヴィーニャ】の頻出名詞 TOP 5 ---
# ...: 49回
# 店: 35回
# 料理: 28回
# スペイン: 27回
# 月島: 21回
#
# --- 【ラムと豪州ジビエバル プラスアルファキッチン】の頻出名詞 TOP 5 ---
# ...: 83回
# 肉: 62回
# ラム: 48回
# 店: 48回
# ジビエ: 47回
#
# --- 【ランチタイム】の頻出名詞 TOP 5 ---
# カレー: 9回
# ランチ: 7回
# ...: 6回
# センター: 5回
# おかず: 5回
#
# --- 【ラ・オハナ ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# ...: 86回
# 店: 49回
# ランチ: 33回
# ダイバー: 26回
# 時: 26回
#
# --- 【リンガーハット アクアシティお台場店】の頻出名詞 TOP 5 ---
# ちゃんぽん: 48回
# リンガーハット: 45回
# ...: 42回
# 円: 26回
# 長崎: 26回
#
# --- 【レゴカフェ】の頻出名詞 TOP 5 ---
# ...: 10回
# レゴランド: 7回
# カフェ: 7回
# の: 6回
# 東京: 6回
#
# --- 【レゴランド ディスカバリー センターショップ】の頻出名詞 TOP 5 ---
# ...: 23回
# レゴランド: 20回
# カレー: 16回
# レゴ: 16回
# ランチ: 12回
#
# --- 【レストラン　シー・マインド】の頻出名詞 TOP 5 ---
# 会社: 2回
# ...: 2回
# 展示: 2回
# 通り: 1回
# 沿い: 1回
#
# --- 【レストランシーサイド】の頻出名詞 TOP 5 ---
# ...: 50回
# 葛西: 44回
# 公園: 43回
# レストラン: 43回
# 臨海: 42回
#
# --- 【レッドロブスター アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 248回
# ロブスター: 198回
# 台場: 150回
# 店: 126回
# レッドロブスター: 110回
#
# --- 【ロイヤルキャフェテリア】の頻出名詞 TOP 5 ---
# ...: 59回
# 展示: 37回
# ビッグ: 34回
# サイト: 34回
# 東京: 31回
#
# --- 【ロジウラ】の頻出名詞 TOP 5 ---
# ...: 56回
# 店: 52回
# 木場: 20回
# 雰囲気: 18回
# ワイン: 17回
#
# --- 【ロハスカフェARIAKE】の頻出名詞 TOP 5 ---
# ...: 96回
# 大学: 69回
# 学: 53回
# カフェ: 51回
# 食: 51回
#
# --- 【ロングボード・カフェ】の頻出名詞 TOP 5 ---
# ...: 71回
# 台場: 55回
# 店: 37回
# 席: 29回
# 店内: 28回
#
# --- 【ローソン Hお台場海浜公園前店】の頻出名詞 TOP 5 ---
# 台場: 1回
# 海浜: 1回
# 公園: 1回
# 駅: 1回
# レインボー: 1回
#
# --- 【ワフーズ　タコス&モア】の頻出名詞 TOP 5 ---
# ...: 30回
# 店: 22回
# ダイバー: 18回
# シティ: 17回
# 階: 14回
#
# --- 【ヴィラフォンテーヌ グランド 東京有明】の頻出名詞 TOP 5 ---
# ...: 18回
# 海鮮: 13回
# 丼: 10回
# ランチ: 8回
# :: 8回
#
# --- 【ヴィレッジヴァンガードダイナー 豊洲フォレシア】の頻出名詞 TOP 5 ---
# ...: 225回
# ハンバーガー: 124回
# 豊洲: 112回
# 店: 107回
# ランチ: 83回
#
# --- 【三代目 博多 だるま】の頻出名詞 TOP 5 ---
# ラーメン: 416回
# ...: 307回
# 台場: 187回
# 博多: 182回
# 豚: 167回
#
# --- 【三代目文治 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 牛: 86回
# タン: 76回
# ...: 56回
# 店: 37回
# おでん: 28回
#
# --- 【中国料理 桃李】の頻出名詞 TOP 5 ---
# ...: 40回
# 料理: 21回
# 台場: 19回
# ランチ: 19回
# ホテル: 18回
#
# --- 【中国料理居酒屋 珍味館 築地店】の頻出名詞 TOP 5 ---
# ...: 20回
# ランチ: 17回
# 店: 16回
# 築地: 16回
# ラーメン: 7回
#
# --- 【中國料理 跳龍門】の頻出名詞 TOP 5 ---
# ...: 46回
# 店: 30回
# 台場: 28回
# 飲茶: 26回
# 中華: 24回
#
# --- 【中華そば専門 田中そば店 ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# そば: 80回
# ...: 78回
# ラーメン: 70回
# 店: 55回
# 中華: 44回
#
# --- 【中華居酒屋料理 餃子屋】の頻出名詞 TOP 5 ---
# 餃子: 40回
# ...: 37回
# 店: 26回
# 屋: 21回
# 築地: 20回
#
# --- 【中華料理 阿里城 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 25回
# 台場: 22回
# フード: 18回
# コート: 17回
# 店: 16回
#
# --- 【中葛西 ごっさん】の頻出名詞 TOP 5 ---
# 店: 23回
# ...: 22回
# 料理: 15回
# 席: 12回
# 秋田: 11回
#
# --- 【串家物語 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 48回
# 串: 44回
# 放題: 29回
# 店: 29回
# 自分: 24回
#
# --- 【久臨 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 麺: 379回
# つけ: 377回
# ...: 337回
# フード: 252回
# コート: 249回
#
# --- 【京都きん家】の頻出名詞 TOP 5 ---
# ...: 114回
# お好み焼き: 84回
# 店: 74回
# 焼き: 49回
# 西葛西: 45回
#
# --- 【京鼎樓 アクアシティお台場店】の頻出名詞 TOP 5 ---
# 小籠: 81回
# 包: 81回
# ...: 57回
# 台場: 27回
# 店: 25回
#
# --- 【仕立屋 甚五郎 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 手羽: 2回
# 先: 2回
# 江東: 1回
# 区: 1回
# 青海: 1回
#
# --- 【代官山 炭火焼肉 猿楽 豊洲店】の頻出名詞 TOP 5 ---
# ...: 66回
# 焼肉: 40回
# 店: 36回
# ランチ: 33回
# 豊洲: 33回
#
# --- 【伊勢元】の頻出名詞 TOP 5 ---
# ...: 30回
# 店: 16回
# 伊勢: 13回
# 元: 13回
# 料理: 13回
#
# --- 【伊吹や製麺 東京ビックサイトEat iT!店】の頻出名詞 TOP 5 ---
# うどん: 21回
# ...: 12回
# 丼: 10回
# セット: 10回
# フード: 6回
#
# --- 【伍之伍之 十六夜】の頻出名詞 TOP 5 ---
# 店: 14回
# ...: 14回
# 料理: 7回
# 何: 6回
# 西葛西: 5回
#
# --- 【伝説のすた丼屋 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 丼: 103回
# 円: 64回
# ごちそうさま: 42回
# ...: 39回
# 塩: 31回
#
# --- 【倭料理 築地伊八 弐號】の頻出名詞 TOP 5 ---
# 築地: 12回
# ...: 9回
# 5: 5回
# 料理: 5回
# 時間: 5回
#
# --- 【健康中華 青蓮 TOC有明店】の頻出名詞 TOP 5 ---
# ...: 42回
# 中華: 29回
# 店: 25回
# ランチ: 22回
# の: 18回
#
# --- 【元祖やきとり串八珍 築地本店】の頻出名詞 TOP 5 ---
# 店: 8回
# ...: 7回
# 八: 6回
# 魚: 5回
# メニュー: 4回
#
# --- 【元祖セルフうどんの店 竹清 有明ガーデン店】の頻出名詞 TOP 5 ---
# うどん: 115回
# ...: 88回
# 有明: 80回
# 店: 59回
# フード: 56回
#
# --- 【六右衛門】の頻出名詞 TOP 5 ---
# 円: 21回
# ...: 20回
# ランチ: 13回
# 定食: 12回
# カレー: 9回
#
# --- 【創菜Patio】の頻出名詞 TOP 5 ---
# ...: 68回
# ランチ: 28回
# 有明: 28回
# 円: 23回
# ホテル: 21回
#
# --- 【勝鬨UNIqUE】の頻出名詞 TOP 5 ---
# ...: 10回
# 店: 9回
# 料理: 7回
# 階: 7回
# 2: 5回
#
# --- 【北京ダック専門店 嘉園 お台場店】の頻出名詞 TOP 5 ---
# 放題: 33回
# 北京: 29回
# ダック: 27回
# ...: 26回
# 店: 21回
#
# --- 【北海道うまいもの館 ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# ソフトクリーム: 11回
# ...: 9回
# 北海道: 7回
# ダイバー: 6回
# シティ: 6回
#
# --- 【北陸富山回転寿司　プレミアム 海王 ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# ...: 162回
# 寿司: 130回
# 店: 91回
# 回転: 86回
# ダイバー: 60回
#
# --- 【十割蕎麦 さがたに 有明ガーデン店】の頻出名詞 TOP 5 ---
# 蕎麦: 39回
# ...: 37回
# 有明: 26回
# フード: 25回
# コート: 25回
#
# --- 【千房 有明ガーデン支店】の頻出名詞 TOP 5 ---
# ...: 48回
# お好み焼き: 33回
# 有明: 28回
# 焼き: 26回
# ガーデン: 21回
#
# --- 【南砂餃子坊】の頻出名詞 TOP 5 ---
# 餃子: 62回
# ...: 62回
# 南砂: 25回
# 店: 23回
# セット: 21回
#
# --- 【南風花 アクアシティお台場店】の頻出名詞 TOP 5 ---
# 沖縄: 116回
# ...: 111回
# 料理: 87回
# 台場: 63回
# 店: 61回
#
# --- 【博多うどん呑処 一㐂 下町居酒屋 台場店】の頻出名詞 TOP 5 ---
# うどん: 27回
# 店: 18回
# ...: 17回
# ランチ: 12回
# 台場: 12回
#
# --- 【博多もつ鍋 やまや 豊洲店】の頻出名詞 TOP 5 ---
# ...: 95回
# 明太子: 84回
# 店: 64回
# ランチ: 57回
# やまや: 54回
#
# --- 【双麺 門前仲町店】の頻出名詞 TOP 5 ---
# ラーメン: 319回
# 麺: 311回
# ...: 271回
# 店: 156回
# 醤油: 143回
#
# --- 【吉野家 お台場 デックス店】の頻出名詞 TOP 5 ---
# 牛: 75回
# ...: 59回
# 吉野家: 54回
# 丼: 51回
# カレー: 40回
#
# --- 【味な店なかちゃん】の頻出名詞 TOP 5 ---
# ...: 27回
# 店: 20回
# 予約: 19回
# 訪問: 16回
# お好み焼き: 13回
#
# --- 【和カフェ Tsumugi 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 40回
# 有明: 32回
# 店: 25回
# ガーデン: 24回
# 和: 23回
#
# --- 【和彩 よし川】の頻出名詞 TOP 5 ---
# ...: 18回
# 店: 14回
# 料理: 9回
# 蕎麦: 9回
# 酒: 7回
#
# --- 【和菜365】の頻出名詞 TOP 5 ---
# カレー: 6回
# 人: 5回
# ランチ: 5回
# カツ: 5回
# ...: 5回
#
# --- 【和風ダイニング 喜楽】の頻出名詞 TOP 5 ---
# ...: 28回
# 店: 27回
# ランチ: 20回
# 新木場: 20回
# 駅: 18回
#
# --- 【和風居酒屋 豊洲酒場】の頻出名詞 TOP 5 ---
# ...: 29回
# 豊洲: 25回
# 居酒屋: 18回
# 駅: 12回
# ランチ: 11回
#
# --- 【和食ダイニング 田久井】の頻出名詞 TOP 5 ---
# ...: 27回
# 店: 19回
# 有明: 13回
# ビル: 12回
# 2: 10回
#
# --- 【唐苑】の頻出名詞 TOP 5 ---
# ...: 55回
# 店: 48回
# ランチ: 38回
# テレコム: 36回
# センター: 36回
#
# --- 【喫茶フラワー】の頻出名詞 TOP 5 ---
# 東京: 10回
# ...: 10回
# 卍: 7回
# 服: 6回
# の: 6回
#
# --- 【地鶏×鮮魚 個室居酒屋 もみじ屋 デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 15回
# 台場: 11回
# 個室: 9回
# もみじ: 8回
# 店: 8回
#
# --- 【塩らーめん専門 ひるがお アクアシティお台場店】の頻出名詞 TOP 5 ---
# ラーメン: 130回
# 塩: 109回
# ...: 81回
# 台場: 47回
# 麺: 40回
#
# --- 【大衆酒場 有頂天】の頻出名詞 TOP 5 ---
# ...: 17回
# ランチ: 13回
# 店: 13回
# 定食: 9回
# 展示: 8回
#
# --- 【大衆酒場かんぱい家 葛西店】の頻出名詞 TOP 5 ---
# ...: 22回
# 円: 18回
# 葛西: 14回
# 駅: 14回
# 店: 13回
#
# --- 【天天有 お台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ラーメン: 57回
# ...: 48回
# 鶏: 36回
# 天: 31回
# 白湯: 31回
#
# --- 【家系らーめん 金井家】の頻出名詞 TOP 5 ---
# ...: 22回
# ラーメン: 20回
# 豚: 12回
# 骨: 12回
# 醤油: 11回
#
# --- 【小樽ザンギとサケ 半身揚げのジョニー】の頻出名詞 TOP 5 ---
# ...: 12回
# 台場: 9回
# 店: 6回
# 揚げ: 6回
# 円: 6回
#
# --- 【居酒屋いっき 有明別邸】の頻出名詞 TOP 5 ---
# ...: 34回
# 2: 26回
# 品: 22回
# ランチ: 20回
# 店: 17回
#
# --- 【屋台DELi】の頻出名詞 TOP 5 ---
# 弁当: 8回
# ...: 4回
# 2: 3回
# 店: 3回
# F: 3回
#
# --- 【山下本気うどん デックス東京ビーチ】の頻出名詞 TOP 5 ---
# うどん: 194回
# ...: 116回
# 山下: 56回
# 店: 56回
# 天: 52回
#
# --- 【山形山　月島店】の頻出名詞 TOP 5 ---
# ...: 178回
# 山形: 172回
# 焼肉: 136回
# 月島: 113回
# 肉: 103回
#
# --- 【成都 陳麻婆豆腐 有明ガーデン店】の頻出名詞 TOP 5 ---
# 麻: 241回
# 婆: 235回
# 豆腐: 222回
# ...: 162回
# 店: 129回
#
# --- 【成都担々】の頻出名詞 TOP 5 ---
# 店: 3回
# 麺: 2回
# 屋: 2回
# ルリカケス: 2回
# 担々麺: 2回
#
# --- 【手打ち中華 玉 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ラーメン: 80回
# ...: 62回
# 麺: 46回
# 店: 37回
# 台場: 31回
#
# --- 【文化堂 有明店】の頻出名詞 TOP 5 ---
# 有明: 3回
# ...: 3回
# 月: 2回
# スーパー: 2回
# 1: 2回
#
# --- 【日本料理 「さくら」   ヒルトン東京お台場】の頻出名詞 TOP 5 ---
# ...: 183回
# 台場: 81回
# 料理: 76回
# ヒルトン: 64回
# 店: 63回
#
# --- 【日本料理 紫水】の頻出名詞 TOP 5 ---
# 築地: 63回
# ...: 54回
# 本願寺: 50回
# 円: 32回
# 料理: 25回
#
# --- 【日本料理　時宜】の頻出名詞 TOP 5 ---
# ...: 166回
# コート: 89回
# ベイ: 88回
# 料理: 88回
# 東京: 75回
#
# --- 【日本橋 天丼 金子半之助 ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# 天丼: 214回
# ...: 205回
# フード: 165回
# コート: 164回
# 店: 110回
#
# --- 【日比谷松本楼 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 166回
# 店: 107回
# ビッグ: 102回
# サイト: 102回
# 東京: 86回
#
# --- 【春華秋実】の頻出名詞 TOP 5 ---
# ...: 114回
# 店: 69回
# ランチ: 61回
# 麺: 52回
# 展示: 51回
#
# --- 【月島焼肉ハラミ屋兎月 月島店】の頻出名詞 TOP 5 ---
# 店: 31回
# 焼肉: 28回
# ハラ: 28回
# ミ: 26回
# ...: 26回
#
# --- 【木村家】の頻出名詞 TOP 5 ---
# 市場: 31回
# 豊洲: 21回
# ...: 21回
# 店: 15回
# 棟: 14回
#
# --- 【本格四川料理 麻辣先生 豊洲店】の頻出名詞 TOP 5 ---
# ...: 210回
# 麻: 205回
# 婆: 128回
# 豆腐: 127回
# さ: 107回
#
# --- 【札幌 みその アクアシティお台場店】の頻出名詞 TOP 5 ---
# ラーメン: 159回
# 味噌: 117回
# ...: 96回
# 味: 41回
# スープ: 37回
#
# --- 【東京 焼肉エイト 木場本店】の頻出名詞 TOP 5 ---
# ...: 28回
# 焼肉: 21回
# 店: 21回
# 肉: 15回
# 牛: 15回
#
# --- 【東京29寿司】の頻出名詞 TOP 5 ---
# ...: 119回
# 寿司: 116回
# 千客万来: 100回
# 豊洲: 84回
# セット: 58回
#
# --- 【東京ビッグサイト】の頻出名詞 TOP 5 ---
# ビッグ: 3回
# サイト: 3回
# まんじゅう: 2回
# 記念: 1回
# シンプル: 1回
#
# --- 【東京ベイキッチン 東京ビッグサイト店】の頻出名詞 TOP 5 ---
# ...: 56回
# ビッグ: 35回
# サイト: 35回
# 店: 33回
# 東京: 32回
#
# --- 【東京ベイコート倶楽部】の頻出名詞 TOP 5 ---
# ...: 83回
# 東京: 47回
# ベイ: 43回
# コート: 39回
# ホテル: 34回
#
# --- 【東京ベイ有明ワシントンホテル】の頻出名詞 TOP 5 ---
# ...: 35回
# ホテル: 31回
# 東京: 25回
# 朝食: 22回
# 有明: 21回
#
# --- 【東京寿司 ITAMAE SUSHI アクアシティお台場店】の頻出名詞 TOP 5 ---
# 寿司: 48回
# ...: 36回
# 店: 26回
# 台場: 21回
# 板前: 20回
#
# --- 【東京恋テラス】の頻出名詞 TOP 5 ---
# ...: 4回
# カフェ: 4回
# 台場: 3回
# おし: 3回
# ゅし: 3回
#
# --- 【東京焼肉 平城苑 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 176回
# 肉: 108回
# 焼肉: 90回
# 店: 90回
# ダイバー: 84回
#
# --- 【東京麻辣湯 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 47回
# 麻: 40回
# 具: 31回
# 辣湯: 29回
# 材: 26回
#
# --- 【杵屋麦丸 有明ワンザ店】の頻出名詞 TOP 5 ---
# ...: 40回
# うどん: 39回
# 円: 21回
# 東京: 19回
# 店: 18回
#
# --- 【松屋 武蔵野大学有明CP店】の頻出名詞 TOP 5 ---
# 大学: 4回
# 中: 2回
# 松屋: 2回
# 学: 2回
# 食: 2回
#
# --- 【楽苑】の頻出名詞 TOP 5 ---
# ...: 61回
# 店: 36回
# 有明: 26回
# ランチ: 25回
# ホテル: 25回
#
# --- 【権八 お台場】の頻出名詞 TOP 5 ---
# ...: 165回
# 台場: 121回
# 店: 110回
# 権八: 72回
# 蕎麦: 65回
#
# --- 【横濱炸鶏排 お台場店】の頻出名詞 TOP 5 ---
# 唐: 10回
# 台湾: 7回
# ...: 5回
# 揚げ: 5回
# 揚: 4回
#
# --- 【永利 豊洲3号店】の頻出名詞 TOP 5 ---
# ...: 90回
# 店: 78回
# 豊洲: 58回
# ランチ: 52回
# の: 46回
#
# --- 【江戸湾直送 回転 東京すし街道by ITAMAE SUSHI アクアシティお台場店】の頻出名詞 TOP 5 ---
# 寿司: 62回
# ...: 51回
# 回転: 46回
# 台場: 30回
# 店: 26回
#
# --- 【泉天空の湯 有明キッチン】の頻出名詞 TOP 5 ---
# ...: 36回
# 有明: 19回
# サウナ: 17回
# 中: 14回
# 施設: 12回
#
# --- 【浅草 草津亭 有明店】の頻出名詞 TOP 5 ---
# 店: 14回
# ...: 14回
# の: 8回
# 丼: 8回
# ランチ: 7回
#
# --- 【海のYey】の頻出名詞 TOP 5 ---
# ...: 42回
# 店: 31回
# 料理: 23回
# 利用: 15回
# 葛西: 15回
#
# --- 【清澄白河 フジマル醸造所】の頻出名詞 TOP 5 ---
# ワイン: 294回
# ...: 283回
# 店: 147回
# 料理: 134回
# 醸造: 112回
#
# --- 【潤や】の頻出名詞 TOP 5 ---
# つけ: 47回
# 麺: 47回
# コート: 32回
# ...: 30回
# フード: 30回
#
# --- 【潮見スキッパーズ 有明店】の頻出名詞 TOP 5 ---
# ...: 21回
# 店: 16回
# 有明: 11回
# スキッパーズエッグチーズ: 7回
# ポテト: 7回
#
# --- 【激旨ホルモン魂】の頻出名詞 TOP 5 ---
# ホルモン: 121回
# ...: 96回
# 店: 81回
# 木場: 50回
# 魂: 31回
#
# --- 【炭火串焼き ふく屋】の頻出名詞 TOP 5 ---
# ...: 18回
# 店: 17回
# 鍋: 13回
# 葛西: 11回
# 焼き鳥: 11回
#
# --- 【炭火焼肉 牛和鹿 本店】の頻出名詞 TOP 5 ---
# ...: 283回
# 牛: 198回
# 焼肉: 159回
# タン: 158回
# 店: 141回
#
# --- 【炭火焼肉・韓国料理 KollaBo アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 136回
# 店: 104回
# 韓国: 56回
# 台場: 54回
# 料理: 50回
#
# --- 【無印良品 東京有明店】の頻出名詞 TOP 5 ---
# ...: 24回
# 無印: 19回
# 有明: 12回
# 良品: 9回
# 円: 8回
#
# --- 【焼うお いし川】の頻出名詞 TOP 5 ---
# ...: 692回
# 魚: 422回
# 店: 394回
# 築地: 304回
# 焼肉: 234回
#
# --- 【焼きとんと旨い魚 甚四郎 本店】の頻出名詞 TOP 5 ---
# 円: 11回
# 刺身: 7回
# ...: 7回
# コース: 6回
# 料理: 6回
#
# --- 【焼肉 平城苑 アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 168回
# 台場: 118回
# 店: 114回
# 焼肉: 98回
# 肉: 82回
#
# --- 【焼肉ここから 東陽町店】の頻出名詞 TOP 5 ---
# ...: 15回
# 店: 12回
# 肉: 12回
# 焼肉: 11回
# ここ: 7回
#
# --- 【焼肉と夜景 醍醐 お台場店】の頻出名詞 TOP 5 ---
# ...: 110回
# 肉: 62回
# 台場: 61回
# 店: 59回
# 焼肉: 50回
#
# --- 【焼鳥トリフク食堂】の頻出名詞 TOP 5 ---
# ...: 16回
# 台場: 11回
# 店: 10回
# アクアシティ: 8回
# 定食: 7回
#
# --- 【焼鶏ばんちょう】の頻出名詞 TOP 5 ---
# ...: 38回
# 焼き鳥: 25回
# 月島: 24回
# 店: 23回
# 本: 22回
#
# --- 【牛たん炭焼利久 有明ガーデン店】の頻出名詞 TOP 5 ---
# 牛: 105回
# タン: 76回
# ...: 57回
# ガーデン: 36回
# 定食: 35回
#
# --- 【牛カツ京都勝牛 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 牛: 65回
# カツ: 59回
# ...: 39回
# 店: 17回
# 円: 13回
#
# --- 【牛和鹿 葛西店】の頻出名詞 TOP 5 ---
# ...: 26回
# 店: 24回
# 牛: 22回
# 葛西: 19回
# 肉: 17回
#
# --- 【牛若 葛西店】の頻出名詞 TOP 5 ---
# ...: 20回
# 葛西: 17回
# 焼肉: 17回
# 店: 13回
# 肉: 9回
#
# --- 【生粋 葛西駅前店】の頻出名詞 TOP 5 ---
# ...: 10回
# 料理: 7回
# 居酒屋: 6回
# の: 6回
# 喫煙: 5回
#
# --- 【目利きの銀次 門前仲町駅前店】の頻出名詞 TOP 5 ---
# 店: 11回
# ...: 10回
# の: 7回
# チェーン: 6回
# 放題: 5回
#
# --- 【相鉄グランドフレッサ 東京ベイ有明】の頻出名詞 TOP 5 ---
# ...: 15回
# 朝食: 11回
# ホテル: 10回
# 利用: 8回
# 宿泊: 5回
#
# --- 【眺遊楼】の頻出名詞 TOP 5 ---
# ...: 117回
# コート: 79回
# ベイ: 76回
# 料理: 75回
# 中華: 54回
#
# --- 【石臼挽きそば 石楽】の頻出名詞 TOP 5 ---
# 蕎麦: 87回
# ...: 76回
# そば: 47回
# 豊洲: 36回
# 店: 35回
#
# --- 【磯寿司】の頻出名詞 TOP 5 ---
# 寿司: 134回
# ...: 128回
# 豊洲: 113回
# 市場: 107回
# 店: 79回
#
# --- 【社食DELI】の頻出名詞 TOP 5 ---
# 弁当: 3回
# 青海: 1回
# フロンティア: 1回
# ビル: 1回
# 内: 1回
#
# --- 【社食デリ】の頻出名詞 TOP 5 ---
# 弁当: 4回
# ビル: 2回
# 1: 2回
# ...: 2回
# 江東: 2回
#
# --- 【秀徳市場マルマサ】の頻出名詞 TOP 5 ---
# ...: 9回
# 店: 7回
# 築地: 6回
# 寿司: 5回
# の: 4回
#
# --- 【笑笑 お台場海浜公園駅前店】の頻出名詞 TOP 5 ---
# 笑: 35回
# ...: 22回
# そば: 12回
# 台場: 12回
# の: 11回
#
# --- 【笑笑 月島駅前店】の頻出名詞 TOP 5 ---
# ...: 16回
# 笑: 16回
# 店: 11回
# 月島: 10回
# 人: 8回
#
# --- 【築地 すし Omakase】の頻出名詞 TOP 5 ---
# ...: 208回
# 寿司: 140回
# 熟成: 110回
# 店: 107回
# コース: 98回
#
# --- 【築地 挙母鮨】の頻出名詞 TOP 5 ---
# ...: 83回
# 築地: 68回
# 店: 59回
# 寿司: 44回
# 握り: 37回
#
# --- 【築地さらしなの里】の頻出名詞 TOP 5 ---
# 蕎麦: 446回
# ...: 380回
# そば: 292回
# 築地: 183回
# 店: 162回
#
# --- 【築地玉寿司 晴海通り店】の頻出名詞 TOP 5 ---
# 寿司: 143回
# ...: 135回
# 築地: 121回
# 店: 97回
# 玉: 48回
#
# --- 【築地秀徳元祖】の頻出名詞 TOP 5 ---
# ...: 158回
# 店: 126回
# 築地: 93回
# 寿司: 88回
# 円: 62回
#
# --- 【築地銀だこ ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# ...: 50回
# 銀: 44回
# だこ: 43回
# たこ焼き: 36回
# ダイバー: 26回
#
# --- 【築地青空三代目 本店】の頻出名詞 TOP 5 ---
# ...: 474回
# 築地: 363回
# 店: 294回
# 寿司: 267回
# の: 151回
#
# --- 【築地食堂 源ちゃん アクアシティお台場店】の頻出名詞 TOP 5 ---
# ...: 74回
# 店: 65回
# 台場: 62回
# アクアシティ: 33回
# ランチ: 31回
#
# --- 【築地食堂 源ちゃん 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 76回
# 丼: 57回
# 店: 51回
# 有明: 38回
# ガーデン: 36回
#
# --- 【築地食堂 源ちゃん 東京ビックサイト店】の頻出名詞 TOP 5 ---
# ...: 64回
# 店: 49回
# ビッグ: 37回
# サイト: 37回
# 東京: 36回
#
# --- 【築地食堂　源ちゃん TFT有明店】の頻出名詞 TOP 5 ---
# ...: 112回
# 店: 76回
# 丼: 47回
# ランチ: 39回
# 東京: 37回
#
# --- 【米三角】の頻出名詞 TOP 5 ---
# ...: 25回
# 豊洲: 16回
# 店: 14回
# 千客万来: 14回
# 2: 13回
#
# --- 【翠苑】の頻出名詞 TOP 5 ---
# ...: 72回
# 店: 39回
# ランチ: 35回
# 麺: 32回
# 中華: 31回
#
# --- 【肉菜工房うしすけ 台場店】の頻出名詞 TOP 5 ---
# ...: 107回
# 店: 81回
# 焼肉: 73回
# 犬: 62回
# 肉: 59回
#
# --- 【自由が丘 蔭山 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 160回
# 鶏: 137回
# 白湯: 131回
# 有明: 130回
# フード: 124回
#
# --- 【芋蛸 お台場たこやきミュージアム店】の頻出名詞 TOP 5 ---
# たこ焼き: 160回
# ...: 104回
# ミュージアム: 67回
# 台場: 63回
# 芋: 55回
#
# --- 【花水木】の頻出名詞 TOP 5 ---
# ...: 23回
# すき焼き: 15回
# しゃぶしゃぶ: 14回
# 肉: 11回
# コース: 10回
#
# --- 【茂助だんご 豊洲市場】の頻出名詞 TOP 5 ---
# ...: 159回
# ん: 129回
# 市場: 129回
# 豊洲: 128回
# 茂助: 97回
#
# --- 【茶寮 伊藤園 有明ガーデン店】の頻出名詞 TOP 5 ---
# 抹茶: 65回
# ...: 65回
# 有明: 41回
# ガーデン: 37回
# 伊藤園: 31回
#
# --- 【菊屋】の頻出名詞 TOP 5 ---
# ...: 31回
# 店: 23回
# 東雲: 21回
# 中華: 12回
# ラーメン: 11回
#
# --- 【葛西ビアバー】の頻出名詞 TOP 5 ---
# ...: 13回
# ビール: 11回
# 時: 8回
# 店: 8回
# 葛西: 7回
#
# --- 【葛西臨海公園バーベキュー広場】の頻出名詞 TOP 5 ---
# バーベキュー: 12回
# ...: 8回
# 肉: 5回
# 放題: 4回
# の: 3回
#
# --- 【蔵乃ゑ】の頻出名詞 TOP 5 ---
# 柚子: 3回
# 内: 2回
# すか: 2回
# 炭酸: 2回
# ...: 2回
#
# --- 【親子丼 トリカイ エクスプレス ダイバーシティ東京店】の頻出名詞 TOP 5 ---
# 丼: 32回
# 親子: 29回
# ...: 26回
# フード: 24回
# コート: 21回
#
# --- 【豊洲市場 共同食堂】の頻出名詞 TOP 5 ---
# ...: 5回
# 豊洲: 3回
# 定食: 3回
# ２: 3回
# ０: 3回
#
# --- 【豊海ワイン食堂】の頻出名詞 TOP 5 ---
# ...: 5回
# 人: 3回
# 一: 3回
# マンション: 2回
# 店: 2回
#
# --- 【越後屋 竹千代】の頻出名詞 TOP 5 ---
# ...: 159回
# 定食: 100回
# 店: 87回
# ランチ: 57回
# 東京: 56回
#
# --- 【道頓堀 赤鬼】の頻出名詞 TOP 5 ---
# たこ焼き: 59回
# ...: 33回
# ミュージアム: 20回
# 店: 19回
# 台場: 17回
#
# --- 【都会の農園バーベキュー広場】の頻出名詞 TOP 5 ---
# ...: 25回
# バーベキュー: 20回
# BBQ: 20回
# 屋上: 18回
# 台場: 16回
#
# --- 【都立潮風公園バーベキュー広場】の頻出名詞 TOP 5 ---
# 潮風: 4回
# 公園: 4回
# BBQ: 4回
# ...: 4回
# 都立: 2回
#
# --- 【金澤濃厚豚骨ラーメン 神仙 アクアシティ店】の頻出名詞 TOP 5 ---
# ラーメン: 126回
# ...: 89回
# 豚: 82回
# 骨: 80回
# 濃厚: 77回
#
# --- 【鉄板焼 銀杏】の頻出名詞 TOP 5 ---
# ...: 198回
# 鉄板: 108回
# 台場: 98回
# 焼き: 90回
# 日: 74回
#
# --- 【銀座 深川玄庵】の頻出名詞 TOP 5 ---
# ...: 14回
# 蕎麦: 12回
# コース: 8回
# 料理: 8回
# 店: 7回
#
# --- 【銀座 祭や】の頻出名詞 TOP 5 ---
# ...: 126回
# 店: 104回
# コリドー: 59回
# の: 51回
# 街: 50回
#
# --- 【長寿韓酒房 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 麺: 47回
# ...: 42回
# みぞ: 38回
# 冷: 38回
# 円: 27回
#
# --- 【長寿韓酒房 有明店】の頻出名詞 TOP 5 ---
# ...: 68回
# 店: 44回
# ランチ: 35回
# の: 27回
# 韓国: 25回
#
# --- 【長生庵】の頻出名詞 TOP 5 ---
# ...: 722回
# 築地: 559回
# 蕎麦: 520回
# 店: 318回
# 朝: 286回
#
# --- 【門仲STAND】の頻出名詞 TOP 5 ---
# ...: 35回
# ワイン: 29回
# 店: 20回
# 料理: 17回
# の: 14回
#
# --- 【門前仲町 らっきょう】の頻出名詞 TOP 5 ---
# ...: 16回
# 店: 12回
# の: 8回
# 刺身: 6回
# メニュー: 5回
#
# --- 【青海珈琲 青海本店】の頻出名詞 TOP 5 ---
# コーヒー: 17回
# ...: 16回
# 円: 16回
# 青海: 14回
# 店: 10回
#
# --- 【青海食堂】の頻出名詞 TOP 5 ---
# ...: 55回
# 食堂: 54回
# 定食: 33回
# 青海: 31回
# 円: 23回
#
# --- 【韓美膳 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 37回
# 有明: 29回
# ガーデン: 28回
# コート: 25回
# フード: 24回
#
# --- 【頑者NEXT LEVEL】の頻出名詞 TOP 5 ---
# 麺: 274回
# つけ: 243回
# ...: 194回
# 台場: 157回
# ラーメン: 157回
#
# --- 【飛車角 有明ガーデン店】の頻出名詞 TOP 5 ---
# ...: 56回
# ランチ: 48回
# 店: 43回
# 肉: 35回
# 有明: 28回
#
# --- 【餃子の王様 龍吟 ダイバーシティ店】の頻出名詞 TOP 5 ---
# 餃子: 72回
# ...: 55回
# 店: 31回
# 円: 22回
# の: 21回
#
# --- 【餃子酒家 築地店】の頻出名詞 TOP 5 ---
# ...: 43回
# 餃子: 40回
# ランチ: 33回
# 店: 24回
# 円: 22回
#
# --- 【香港飲茶楼 ル・パルク】の頻出名詞 TOP 5 ---
# ...: 102回
# 展示: 61回
# 東京: 59回
# ビッグ: 51回
# サイト: 51回
#
# --- 【魚とと 東京ビックサイトEat iT!店】の頻出名詞 TOP 5 ---
# 丼: 14回
# ...: 13回
# 東京: 10回
# ビッグ: 9回
# サイト: 9回
#
# --- 【魚民 勝どき駅前店】の頻出名詞 TOP 5 ---
# 個室: 5回
# テレビ: 5回
# の: 4回
# 魚: 4回
# ...: 4回
#
# --- 【魚民 潮見駅前店】の頻出名詞 TOP 5 ---
# 魚: 3回
# 全国: 3回
# 潮見: 3回
# ...: 3回
# 位: 3回
#
# --- 【魚河岸トミーナ 豊洲市場店】の頻出名詞 TOP 5 ---
# ...: 49回
# 市場: 43回
# 豊洲: 43回
# ピザ: 34回
# 店: 28回
#
# --- 【鮒忠 有明店】の頻出名詞 TOP 5 ---
# ...: 138回
# 店: 78回
# ランチ: 78回
# 定食: 54回
# 展示: 40回
#
# --- 【鮨 もりなり】の頻出名詞 TOP 5 ---
# ...: 89回
# 鮨: 58回
# ネタ: 56回
# 寿司: 38回
# 築地: 34回
#
# --- 【鮨 玉かがり 天ぷら 玉衣】の頻出名詞 TOP 5 ---
# ...: 59回
# 寿司: 48回
# 天ぷら: 35回
# 台場: 30回
# 朝食: 27回
#
# --- 【鮨 酒 肴 杉玉 新木場】の頻出名詞 TOP 5 ---
# ...: 54回
# 寿司: 43回
# 店: 29回
# 新木場: 27回
# 駅: 20回
#
# --- 【鮨　宇田川】の頻出名詞 TOP 5 ---
# ...: 26回
# ランチ: 17回
# 有明: 16回
# 店: 16回
# 寿司: 16回
#
# --- 【鮨･酒･肴 杉玉 葛西店】の頻出名詞 TOP 5 ---
# ...: 38回
# 寿司: 24回
# 店: 21回
# 葛西: 13回
# ランチ: 11回
#
# --- 【鮮魚旬菜 魚福】の頻出名詞 TOP 5 ---
# ...: 29回
# 店: 28回
# ランチ: 23回
# 円: 12回
# 1: 12回
#
# --- 【鶏味座 ダイバーシティ東京プラザ店】の頻出名詞 TOP 5 ---
# 丼: 182回
# 親子: 170回
# ...: 128回
# 店: 91回
# ダイバー: 60回
#
# --- 【鶏鬨はなれ 勝どき清澄通り店】の頻出名詞 TOP 5 ---
# ...: 108回
# 鶏: 81回
# 店: 76回
# 蕎麦: 50回
# 勝どき: 49回
#
# --- 【鶴橋風月 お台場店】の頻出名詞 TOP 5 ---
# お好み焼き: 63回
# ...: 57回
# 台場: 42回
# 店: 38回
# 風月: 30回
#
# --- 【黄金鉄鍋餃子 HUG】の頻出名詞 TOP 5 ---
# ...: 36回
# 餃子: 33回
# 店: 28回
# 築地: 21回
# ランチ: 19回
#
# --- 【龍記 お台場デックス東京ビーチ店】の頻出名詞 TOP 5 ---
# ...: 47回
# 麺: 44回
# 円: 29回
# ランチ: 25回
# 刀: 25回
#
# --- 【＆ Ovo】の頻出名詞 TOP 5 ---
# 築地: 62回
# ...: 49回
# モーニング: 30回
# 本願寺: 29回
# 店: 25回
