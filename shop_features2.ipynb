# %% [markdown]
# ## TF-IDFのスコアを各店ごと計算

# %%
import pandas as pd
from janome.tokenizer import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# CSVファイルを読み込む
try:
    df = pd.read_csv('odaiba_reviews.csv')
except FileNotFoundError:
    print("エラー: 'odaiba_reviews.csv'が見つかりません。")
    df = pd.DataFrame()

# JanomeのTokenizerを準備
t = Tokenizer()

# ストップワード（頻出するが分析に不要な単語）
stop_words = ['こと', 'もの', 'それ', 'これ', 'さん', 'よう', 'ため', 'こちら', 'ところ', '感じ', '利用', '訪問', '注文', '提供', '料理', 'お店', '感じ', '雰囲気', '時間', '今回', '非常']

# ステップ1:店舗ごとの口コミを「分かち書き」する 
def tokenize(text):
    """テキストを形態素解析し、名詞・動詞・形容詞の原型を空白区切りで返す"""
    tokens = []
    for token in t.tokenize(text):
        # 品詞が名詞, 動詞, 形容詞のいずれかで、ストップワードに含まれない単語を抽出
        part_of_speech = token.part_of_speech.split(',')[0]
        if part_of_speech in ['名詞', '動詞', '形容詞'] and token.surface not in stop_words:
            # base_formは単語の原型（例：「食べました」→「食べる」）
            tokens.append(token.base_form)
    return ' '.join(tokens)

if not df.empty:
    # 店舗ごとに口コミを連結
    shop_docs = df.groupby('shop_name')['review_text'].apply(lambda x: ' '.join(x.dropna())).reset_index()
    
    # 各店舗の連結済み口コミに、分かち書き処理を適用
    print("各店舗の口コミを分かち書き中...")
    shop_docs['tokens'] = shop_docs['review_text'].apply(tokenize)
    
    # TF-IDFで分析するための「文書リスト」（コーパス）を作成
    corpus = shop_docs['tokens'].tolist()
    shop_names = shop_docs['shop_name'].tolist()

    # ステップ2：TF-IDF計算
    if corpus:
        print("TF-IDFスコアを計算中...")
        # TfidfVectorizerを初期化
        # min_df=2: 2店舗未満にしか出現しないレアすぎる単語は無視する
        vectorizer = TfidfVectorizer(min_df=2, max_df=0.95)
        
        # コーパスを元にTF-IDF行列を計算
        tfidf_matrix = vectorizer.fit_transform(corpus)
        
        # 単語のリスト（特徴量名）を取得
        feature_names = vectorizer.get_feature_names_out()

        # ステップ3：結果を店舗ごとに表示
        print("\n--- 店舗ごとの特徴語（TF-IDFスコア上位）---\n")
        
        for i, shop_name in enumerate(shop_names):
            print(f"【{shop_name}】")
            
            # i番目の店舗（文書）に対応するTF-IDFスコアの行を取得
            row = tfidf_matrix.toarray()[i]
            
            # スコアが高い順に単語のインデックスを並べ替え
            top_n_indices = row.argsort()[::-1][:7] # 上位7件
            
            # トップ7の単語とそのスコアを表示
            for index in top_n_indices:
                # スコアが0の単語は表示しない
                if row[index] > 0:
                    print(f"  - {feature_names[index]} (スコア: {row[index]:.3f})")
            print("-" * 20)
    else:
        print("分析対象のデータがありません。")
# Out:
# 各店舗の口コミを分かち書き中...
# TF-IDFスコアを計算中...
#
# --- 店舗ごとの特徴語（TF-IDFスコア上位）---
#
# 【1129 by Ogawa】
#   - ハンバーグ (スコア: 0.546)
#   - 台場 (スコア: 0.295)
#   - 景色 (スコア: 0.198)
#   - デックス (スコア: 0.189)
#   - ブリッジ (スコア: 0.163)
#   - レインボー (スコア: 0.162)
#   - 夜景 (スコア: 0.154)
# --------------------
# 【82 築地店】
#   - 築地 (スコア: 0.668)
#   - パブ (スコア: 0.318)
#   - 82 (スコア: 0.289)
#   - hub (スコア: 0.231)
#   - ビール (スコア: 0.123)
#   - 銀座 (スコア: 0.118)
#   - パイント (スコア: 0.110)
# --------------------
# 【ABURI 百貫 有明ガーデン店】
#   - 寿司 (スコア: 0.555)
#   - 炙る (スコア: 0.519)
#   - 回転 (スコア: 0.324)
#   - ガーデン (スコア: 0.215)
#   - 有明 (スコア: 0.186)
#   - ネタ (スコア: 0.184)
#   - 美味しい (スコア: 0.123)
# --------------------
# 【ARIAKE ARENA CAFE】
#   - アリーナ (スコア: 0.663)
#   - ライブ (スコア: 0.271)
#   - 有明 (スコア: 0.267)
#   - トリュフ (スコア: 0.177)
#   - 現金 (スコア: 0.123)
#   - ホットドッグ (スコア: 0.114)
#   - ariake (スコア: 0.112)
# --------------------
# 【ARIAKE ARENA DINING MOON RIVER】
#   - アリーナ (スコア: 0.509)
#   - マルゲリータ (スコア: 0.318)
#   - ライブ (スコア: 0.248)
#   - 有明 (スコア: 0.240)
#   - カフェ (スコア: 0.225)
#   - イベント (スコア: 0.186)
#   - ピザ (スコア: 0.184)
# --------------------
# 【AkeruE】
#   - panasonic (スコア: 0.374)
#   - akerue (スコア: 0.374)
#   - こども (スコア: 0.278)
#   - きのこ (スコア: 0.258)
#   - 左手 (スコア: 0.255)
#   - ある (スコア: 0.254)
#   - マルゲリータ (スコア: 0.252)
# --------------------
# 【Ariake Miraie】
#   - トヨタ (スコア: 0.485)
#   - ディーラー (スコア: 0.419)
#   - キッズスペース (スコア: 0.291)
#   - カフェ (スコア: 0.258)
#   - ある (スコア: 0.214)
#   - スペース (スコア: 0.211)
#   - いる (スコア: 0.102)
# --------------------
# 【BBQ PLAY GROUND お台場デックス東京ビーチ店】
#   - bbq (スコア: 0.459)
#   - 持ち込み (スコア: 0.359)
#   - 台場 (スコア: 0.189)
#   - 屋上 (スコア: 0.182)
#   - 食材 (スコア: 0.177)
#   - ある (スコア: 0.177)
#   - バーベキュー (スコア: 0.173)
# --------------------
# 【BISTRO うしすけ】
#   - うし (スコア: 0.353)
#   - すける (スコア: 0.332)
#   - わん (スコア: 0.303)
#   - ワンコ (スコア: 0.224)
#   - 台場 (スコア: 0.220)
#   - ビス (スコア: 0.207)
#   - ペット (スコア: 0.186)
# --------------------
# 【BLUE TABLE Odaiba】
#   - 愛犬 (スコア: 0.239)
#   - 海浜 (スコア: 0.224)
#   - 台場 (スコア: 0.205)
#   - 公園 (スコア: 0.201)
#   - ブリ (スコア: 0.201)
#   - ビーチ (スコア: 0.174)
#   - ロケーション (スコア: 0.155)
# --------------------
# 【Bistro961】
#   - マスター (スコア: 0.405)
#   - ワイン (スコア: 0.390)
#   - 月島 (スコア: 0.260)
#   - パスタ (スコア: 0.214)
#   - ジン (スコア: 0.203)
#   - バー (スコア: 0.185)
#   - ビス (スコア: 0.144)
# --------------------
# 【Bomb! Dogs】
#   - ロング (スコア: 0.286)
#   - チュロス (スコア: 0.269)
#   - ポテト (スコア: 0.261)
#   - ドック (スコア: 0.257)
#   - ホットドッグ (スコア: 0.247)
#   - 刻む (スコア: 0.242)
#   - カー (スコア: 0.231)
# --------------------
# 【Brew33 Bar】
#   - 溶け合う (スコア: 0.399)
#   - ヒルト (スコア: 0.399)
#   - 静けさ (スコア: 0.366)
#   - by (スコア: 0.305)
#   - ダブル (スコア: 0.256)
#   - ツリー (スコア: 0.252)
#   - ダイニング (スコア: 0.238)
# --------------------
# 【CAFE TERIA BLUE】
#   - オムライス (スコア: 0.277)
#   - 科学 (スコア: 0.269)
#   - 地球 (スコア: 0.248)
#   - ドーナツ (スコア: 0.204)
#   - 来館 (スコア: 0.202)
#   - 特別 (スコア: 0.187)
#   - カフェ (スコア: 0.159)
# --------------------
# 【Cha pi】
#   - ミルク (スコア: 0.399)
#   - ほうじ茶 (スコア: 0.317)
#   - 抹茶 (スコア: 0.285)
#   - デックス (スコア: 0.170)
#   - フォーム (スコア: 0.168)
#   - ホイップクリーム (スコア: 0.149)
#   - 台場 (スコア: 0.142)
# --------------------
# 【Chez コバラヘッタ 有明ガーデン店】
#   - ガーデン (スコア: 0.446)
#   - 有明 (スコア: 0.444)
#   - たい (スコア: 0.279)
#   - コバラヘッタ (スコア: 0.190)
#   - ある (スコア: 0.189)
#   - オムライス (スコア: 0.158)
#   - プレート (スコア: 0.150)
# --------------------
# 【CoCo壱番屋 ワンザ有明店】
#   - coco (スコア: 0.595)
#   - ココイチ (スコア: 0.328)
#   - カレー (スコア: 0.298)
#   - ビル (スコア: 0.126)
#   - パリ (スコア: 0.109)
#   - 我慢 (スコア: 0.109)
#   - サラダ (スコア: 0.106)
# --------------------
# 【Cuore】
#   - ホテルトラスティ (スコア: 0.398)
#   - ホテル (スコア: 0.383)
#   - ベイ (スコア: 0.308)
#   - ラウンジ (スコア: 0.295)
#   - サイド (スコア: 0.196)
#   - 朝食 (スコア: 0.165)
#   - ある (スコア: 0.149)
# --------------------
# 【D-ラウンジ】
#   - ジョイポリス (スコア: 0.566)
#   - ホットドッグ (スコア: 0.393)
#   - 東京 (スコア: 0.269)
#   - ケン (スコア: 0.248)
#   - 施設 (スコア: 0.177)
#   - コラボ (スコア: 0.147)
#   - ある (スコア: 0.126)
# --------------------
# 【DAIBA】
#   - 社員 (スコア: 0.443)
#   - 食堂 (スコア: 0.342)
#   - テレビ局 (スコア: 0.335)
#   - フジテレビ (スコア: 0.294)
#   - 合衆国 (スコア: 0.234)
#   - 一般人 (スコア: 0.223)
#   - 業界 (スコア: 0.198)
# --------------------
# 【DOG DEPT お台場東京ビーチ店】
#   - dept (スコア: 0.326)
#   - dog (スコア: 0.304)
#   - 果肉 (スコア: 0.288)
#   - ３月 (スコア: 0.266)
#   - bills (スコア: 0.261)
#   - ロコモコ (スコア: 0.261)
#   - 愉しい (スコア: 0.253)
# --------------------
# 【DOLCE VITA】
#   - イマーシブフォート (スコア: 0.391)
#   - パフェ (スコア: 0.312)
#   - 白玉 (スコア: 0.221)
#   - イマーシブ (スコア: 0.215)
#   - メロン (スコア: 0.202)
#   - ベリー (スコア: 0.174)
#   - チュロス (スコア: 0.147)
# --------------------
# 【Deli&Cafe Uran】
#   - デリ (スコア: 0.377)
#   - おかず (スコア: 0.277)
#   - 惣菜 (スコア: 0.268)
#   - 海浜 (スコア: 0.199)
#   - 公園 (スコア: 0.178)
#   - 台場 (スコア: 0.173)
#   - ショーケース (スコア: 0.143)
# --------------------
# 【Domino's Pizza  ARIAKE GARDEN】
#   - ピザ (スコア: 0.496)
#   - ドミノ (スコア: 0.382)
#   - ガーデン (スコア: 0.342)
#   - 有明 (スコア: 0.194)
#   - 歌姫 (スコア: 0.191)
#   - ノルウェー (スコア: 0.182)
#   - オーロラ (スコア: 0.175)
# --------------------
# 【Eat it! 東京ビッグサイト店】
#   - ビッグ (スコア: 0.378)
#   - コート (スコア: 0.355)
#   - サイト (スコア: 0.354)
#   - フード (スコア: 0.318)
#   - つけ (スコア: 0.239)
#   - 展示 (スコア: 0.226)
#   - 東京 (スコア: 0.185)
# --------------------
# 【FARMS' KITCHEN MIKIKE TOKYO ODAIBA】
#   - 美味しい (スコア: 0.177)
#   - ブリッジ (スコア: 0.173)
#   - レインボー (スコア: 0.172)
#   - レストラン (スコア: 0.167)
#   - 同席 (スコア: 0.165)
#   - 大胆 (スコア: 0.165)
#   - ぱくる (スコア: 0.165)
# --------------------
# 【GODIVA アクアシティお台場店】
#   - godiva (スコア: 0.614)
#   - ショコリキサー (スコア: 0.454)
#   - ゴディバ (スコア: 0.289)
#   - チョコレート (スコア: 0.271)
#   - ホワイト (スコア: 0.156)
#   - ダーク (スコア: 0.139)
#   - チョコ (スコア: 0.128)
# --------------------
# 【GODIVA ダイバーシティ東京プラザ店】
#   - ショコリキサー (スコア: 0.469)
#   - ゴディバ (スコア: 0.423)
#   - godiva (スコア: 0.376)
#   - チョコレート (スコア: 0.280)
#   - ダイバー (スコア: 0.234)
#   - シティ (スコア: 0.232)
#   - チョコ (スコア: 0.208)
# --------------------
# 【GOKUGOKU 有明ガーデン店】
#   - バナナ (スコア: 0.341)
#   - ガーデン (スコア: 0.244)
#   - ジュース (スコア: 0.221)
#   - 有明 (スコア: 0.215)
#   - ゴクゴク (スコア: 0.173)
#   - ミルク (スコア: 0.162)
#   - キウイ (スコア: 0.161)
# --------------------
# 【GREAT STEAK】
#   - ステーキ (スコア: 0.496)
#   - ブザー (スコア: 0.391)
#   - 1280 (スコア: 0.364)
#   - 60 (スコア: 0.321)
#   - 渡す (スコア: 0.295)
#   - ダイバー (スコア: 0.256)
#   - シティ (スコア: 0.254)
# --------------------
# 【GUNDAM Café　キッチンカー】
#   - ジークアクス (スコア: 0.362)
#   - ラテアート (スコア: 0.332)
#   - 描く (スコア: 0.313)
#   - フロート (スコア: 0.298)
#   - おまけ (スコア: 0.287)
#   - モチーフ (スコア: 0.287)
#   - アニメ (スコア: 0.273)
# --------------------
# 【Green×Green】
#   - green (スコア: 0.512)
#   - サラダ (スコア: 0.400)
#   - ドレッシング (スコア: 0.273)
#   - ボウル (スコア: 0.174)
#   - コート (スコア: 0.156)
#   - サイズ (スコア: 0.142)
#   - 台場 (スコア: 0.142)
# --------------------
# 【H.B.GRILL】
#   - 台場 (スコア: 0.335)
#   - grill (スコア: 0.284)
#   - ステーキ (スコア: 0.252)
#   - アクアシティ (スコア: 0.236)
#   - ランチ (スコア: 0.185)
#   - ハンバーガー (スコア: 0.178)
#   - テラス (スコア: 0.173)
# --------------------
# 【HELLO KITTYのこんがり焼 ダイバーシティ東京プラザ店】
#   - キティちゃん (スコア: 0.528)
#   - キティ (スコア: 0.445)
#   - ダイバー (スコア: 0.224)
#   - ハロー (スコア: 0.222)
#   - シティ (スコア: 0.209)
#   - カステラ (スコア: 0.173)
#   - 人形 (スコア: 0.149)
# --------------------
# 【HIRO ダイバーシティ東京店】
#   - ハンバーグ (スコア: 0.611)
#   - ステーキ (スコア: 0.353)
#   - ダイバー (スコア: 0.317)
#   - シティ (スコア: 0.274)
#   - 台場 (スコア: 0.154)
#   - 食べる (スコア: 0.123)
#   - 神戸 (スコア: 0.122)
# --------------------
# 【HUNZA】
#   - インド (スコア: 0.460)
#   - 葛西 (スコア: 0.453)
#   - カレー (スコア: 0.343)
#   - ヤニ (スコア: 0.313)
#   - ビリ (スコア: 0.307)
#   - ナン (スコア: 0.271)
#   - セット (スコア: 0.126)
# --------------------
# 【Hobson’s アクアシティお台場】
#   - アイスクリーム (スコア: 0.402)
#   - クレープ (スコア: 0.389)
#   - ホブソンズ (スコア: 0.268)
#   - アイス (スコア: 0.268)
#   - コート (スコア: 0.210)
#   - hobson (スコア: 0.208)
#   - フード (スコア: 0.202)
# --------------------
# 【KING OF THE PIRATES】
#   - 海賊 (スコア: 0.724)
#   - 台場 (スコア: 0.210)
#   - テラス (スコア: 0.187)
#   - 夜景 (スコア: 0.167)
#   - いる (スコア: 0.132)
#   - 景色 (スコア: 0.126)
#   - パイレーツ (スコア: 0.119)
# --------------------
# 【L'Agréable Esprit de GAMIN】
#   - フレンチ (スコア: 0.401)
#   - シェフ (スコア: 0.295)
#   - 創作 (スコア: 0.238)
#   - コース (スコア: 0.208)
#   - 門前仲町 (スコア: 0.208)
#   - 恵比寿 (スコア: 0.195)
#   - 美味しい (スコア: 0.159)
# --------------------
# 【LAWSON Tokyoビッグベイ店】
#   - 297 (スコア: 0.383)
#   - 陳列 (スコア: 0.351)
#   - はみ出す (スコア: 0.351)
#   - ローソン (スコア: 0.284)
#   - 発売 (スコア: 0.280)
#   - おにぎり (スコア: 0.248)
#   - tokyo (スコア: 0.221)
# --------------------
# 【LAWSON お台場店】
#   - 禁断 (スコア: 0.374)
#   - コンビニ (スコア: 0.223)
#   - コンビニエンスストア (スコア: 0.222)
#   - テレポート (スコア: 0.222)
#   - ｺﾝﾁｬ (スコア: 0.212)
#   - bankara (スコア: 0.212)
#   - named (スコア: 0.212)
# --------------------
# 【LAWSON しののめ店】
#   - ジャム (スコア: 0.367)
#   - おとめ (スコア: 0.367)
#   - 栃木 (スコア: 0.350)
#   - とちる (スコア: 0.350)
#   - ローソン (スコア: 0.272)
#   - シナモ (スコア: 0.184)
#   - サンクス (スコア: 0.175)
# --------------------
# 【LAWSON りんかい線東雲駅店】
#   - カスタード (スコア: 0.471)
#   - クリーム (スコア: 0.323)
#   - 注入 (スコア: 0.323)
#   - 製品 (スコア: 0.285)
#   - デニッシュ (スコア: 0.285)
#   - 茨城 (スコア: 0.273)
#   - いも (スコア: 0.273)
# --------------------
# 【LAWSON アクアシティお台場】
#   - ローソン (スコア: 0.540)
#   - 禁断 (スコア: 0.307)
#   - ワークス (スコア: 0.182)
#   - 三菱 (スコア: 0.182)
#   - ｺﾝﾁｬ (スコア: 0.174)
#   - 足跡 (スコア: 0.167)
#   - 常習犯 (スコア: 0.167)
# --------------------
# 【LAWSON フジテレビ店】
#   - アイドリング (スコア: 0.564)
#   - コンビニ (スコア: 0.297)
#   - グリーンスムージー (スコア: 0.296)
#   - 178 (スコア: 0.282)
#   - 会える (スコア: 0.234)
#   - ローソン (スコア: 0.219)
#   - 大陸 (スコア: 0.206)
# --------------------
# 【LAWSON ポートストア有明】
#   - 財団 (スコア: 0.301)
#   - port (スコア: 0.301)
#   - 港湾 (スコア: 0.287)
#   - ウェブサイト (スコア: 0.287)
#   - 厚生 (スコア: 0.277)
#   - 協会 (スコア: 0.277)
#   - 福利 (スコア: 0.268)
# --------------------
# 【LAWSON 国際展示場駅前店】
#   - おにぎり (スコア: 0.286)
#   - 国際 (スコア: 0.269)
#   - ローソン (スコア: 0.245)
#   - 展示 (スコア: 0.245)
#   - 飯店 (スコア: 0.221)
#   - コンビニエンスストア (スコア: 0.221)
#   - 重慶 (スコア: 0.221)
# --------------------
# 【LAWSON 有明コロシアム前店】
#   - ローソン (スコア: 0.618)
#   - カカオ (スコア: 0.247)
#   - 売切れる (スコア: 0.224)
#   - コロシアム (スコア: 0.209)
#   - 不便 (スコア: 0.196)
#   - 大通り (スコア: 0.189)
#   - キング (スコア: 0.183)
# --------------------
# 【LAWSON 有明セントラルタワー店】
#   - ローソン (スコア: 0.523)
#   - 桔梗 (スコア: 0.423)
#   - セントラルタワー (スコア: 0.251)
#   - どら (スコア: 0.238)
#   - フカ (スコア: 0.219)
#   - どっち (スコア: 0.183)
#   - サンドイッチ (スコア: 0.167)
# --------------------
# 【LAWSON 東京テレポート駅前店】
#   - コンビニ (スコア: 0.340)
#   - 住居 (スコア: 0.323)
#   - 新築 (スコア: 0.323)
#   - 見参 (スコア: 0.323)
#   - 解体 (スコア: 0.301)
#   - 拡大 (スコア: 0.279)
#   - 敷地 (スコア: 0.244)
# --------------------
# 【LAWSON 東京ビッグサイトエントランス】
#   - ローソン (スコア: 0.348)
#   - ビッグ (スコア: 0.232)
#   - シフト (スコア: 0.224)
#   - サイト (スコア: 0.223)
#   - めんどくさい (スコア: 0.180)
#   - ギフト (スコア: 0.180)
#   - 東京 (スコア: 0.153)
# --------------------
# 【LAWSON 東雲一丁目店】
#   - ローソン (スコア: 0.462)
#   - 東雲 (スコア: 0.308)
#   - おにぎり (スコア: 0.269)
#   - マンション (スコア: 0.248)
#   - 震災 (スコア: 0.207)
#   - 植物 (スコア: 0.179)
#   - 重量 (スコア: 0.175)
# --------------------
# 【LAWSON 相鉄グランドフレッサ有明店】
#   - 相鉄 (スコア: 0.262)
#   - 同名 (スコア: 0.262)
#   - グランドフレッサ (スコア: 0.262)
#   - 買い求める (スコア: 0.262)
#   - 見落とす (スコア: 0.253)
#   - 1930 (スコア: 0.253)
#   - 背徳 (スコア: 0.238)
# --------------------
# 【LAWSON Ｈ台場駅前店】
#   - 出自 (スコア: 0.336)
#   - 頭文字 (スコア: 0.336)
#   - グリーンスムージー (スコア: 0.336)
#   - スイーツ (スコア: 0.334)
#   - 178 (スコア: 0.320)
#   - 示す (スコア: 0.299)
#   - 推測 (スコア: 0.283)
# --------------------
# 【Louis Hamburger Restaurant】
#   - ハンバーガー (スコア: 0.466)
#   - 団地 (スコア: 0.339)
#   - バーガー (スコア: 0.327)
#   - 東陽 (スコア: 0.288)
#   - ブラザーズ (スコア: 0.195)
#   - restaurant (スコア: 0.183)
#   - バンズ (スコア: 0.164)
# --------------------
# 【MOMI&TOY'S 有明ガーデン店】
#   - クレープ (スコア: 0.822)
#   - ガーデン (スコア: 0.171)
#   - 有明 (スコア: 0.158)
#   - コート (スコア: 0.138)
#   - フード (スコア: 0.124)
#   - 食べる (スコア: 0.121)
#   - 甘い (スコア: 0.109)
# --------------------
# 【MONPAL 8】
#   - 美味しい (スコア: 0.295)
#   - 飲む (スコア: 0.283)
#   - 放題 (スコア: 0.275)
#   - 日本 (スコア: 0.261)
#   - コース (スコア: 0.195)
#   - ホッピー (スコア: 0.183)
#   - お通し (スコア: 0.182)
# --------------------
# 【N．Y．Kカフェ お台場・デックス東京ビーチ】
#   - クレープ (スコア: 0.526)
#   - 買う (スコア: 0.204)
#   - デックス (スコア: 0.200)
#   - ﾃﾞｯｸｽ (スコア: 0.197)
#   - 誘う (スコア: 0.182)
#   - いる (スコア: 0.173)
#   - がかる (スコア: 0.170)
# --------------------
# 【OEDO ARIAKE STYLE】
#   - フード (スコア: 0.303)
#   - 有明 (スコア: 0.272)
#   - 大江戸 (スコア: 0.260)
#   - 寿司 (スコア: 0.240)
#   - ガーデン (スコア: 0.240)
#   - 海鮮 (スコア: 0.225)
#   - 市場 (スコア: 0.204)
# --------------------
# 【OSMIC DISH】
#   - トマト (スコア: 0.697)
#   - 台場 (スコア: 0.222)
#   - ポモドーロ (スコア: 0.206)
#   - 220 (スコア: 0.168)
#   - パン (スコア: 0.149)
#   - アクアシティ (スコア: 0.130)
#   - レストラン (スコア: 0.129)
# --------------------
# 【Ozgur Kitchen Kebab】
#   - kitchen (スコア: 0.375)
#   - ケバブ (スコア: 0.375)
#   - アイランドモール (スコア: 0.375)
#   - カー (スコア: 0.303)
#   - どんぶり (スコア: 0.269)
#   - 辛口 (スコア: 0.253)
#   - キッチン (スコア: 0.227)
# --------------------
# 【PATISSERIE L11S】
#   - ケーキ (スコア: 0.332)
#   - レモンスカッシュ (スコア: 0.300)
#   - 飛ばす (スコア: 0.259)
#   - アウト (スコア: 0.246)
#   - 自身 (スコア: 0.225)
#   - 自転車 (スコア: 0.214)
#   - 間際 (スコア: 0.210)
# --------------------
# 【PERFECT BEER STAND MONNAKA】
#   - ビール (スコア: 0.361)
#   - beer (スコア: 0.353)
#   - 777 (スコア: 0.312)
#   - 門前仲 (スコア: 0.257)
#   - 門前仲町 (スコア: 0.213)
#   - stand (スコア: 0.212)
#   - クラフト (スコア: 0.153)
# --------------------
# 【PHO365】
#   - フォー (スコア: 0.816)
#   - 春巻き (スコア: 0.354)
#   - ベトナム (スコア: 0.204)
#   - 365 (スコア: 0.142)
#   - 食券 (スコア: 0.121)
#   - 探訪 (スコア: 0.094)
#   - 専門 (スコア: 0.086)
# --------------------
# 【PIZZA SALVATORE CUOMO 豊洲】
#   - ピザ (スコア: 0.566)
#   - 豊洲 (スコア: 0.402)
#   - パスタ (スコア: 0.249)
#   - ランチ (スコア: 0.218)
#   - ある (スコア: 0.185)
#   - いる (スコア: 0.148)
#   - サラダ (スコア: 0.146)
# --------------------
# 【PIZZA&WINE カヤバール 有明ガーデン店】
#   - ピザ (スコア: 0.437)
#   - バール (スコア: 0.369)
#   - パスタ (スコア: 0.356)
#   - 有明 (スコア: 0.298)
#   - ガーデン (スコア: 0.257)
#   - ある (スコア: 0.170)
#   - 前菜 (スコア: 0.162)
# --------------------
# 【PLANT LOVE】
#   - ベジカフェ (スコア: 0.583)
#   - マクロビマウス (スコア: 0.292)
#   - ヴィーガン (スコア: 0.268)
#   - ロールケーキ (スコア: 0.259)
#   - 日本一 (スコア: 0.220)
#   - ２月 (スコア: 0.211)
#   - 待ち (スコア: 0.203)
# --------------------
# 【Pacific PICKLE CLUB】
#   - パシフィック (スコア: 0.412)
#   - 七里ヶ浜 (スコア: 0.324)
#   - アーバンスポーツパーク (スコア: 0.309)
#   - ドライブイン (スコア: 0.309)
#   - タコ (スコア: 0.235)
#   - ライス (スコア: 0.174)
#   - ロコモコ (スコア: 0.165)
# --------------------
# 【R's Cafe】
#   - カラオケ (スコア: 0.601)
#   - 個室 (スコア: 0.297)
#   - パブ (スコア: 0.276)
#   - 歌う (スコア: 0.259)
#   - ちまき (スコア: 0.150)
#   - テキーラ (スコア: 0.143)
#   - コツ (スコア: 0.130)
# --------------------
# 【RESTAURANT WHITE ART】
#   - small (スコア: 0.525)
#   - スモールワールズ (スコア: 0.275)
#   - worlds (スコア: 0.263)
#   - 幻想 (スコア: 0.245)
#   - restaurant (スコア: 0.238)
#   - しな (スコア: 0.227)
#   - アート (スコア: 0.222)
# --------------------
# 【RIN&GOカレー 東京有明セントラルタワー店】
#   - 小麦粉 (スコア: 0.393)
#   - カレー (スコア: 0.343)
#   - ルー (スコア: 0.324)
#   - カツ (スコア: 0.237)
#   - 使う (スコア: 0.227)
#   - 加工 (スコア: 0.220)
#   - 自社 (スコア: 0.209)
# --------------------
# 【RISTORANTE OZIO】
#   - ベイ (スコア: 0.430)
#   - ozio (スコア: 0.334)
#   - コート (スコア: 0.274)
#   - 倶楽部 (スコア: 0.257)
#   - アフタヌーン (スコア: 0.235)
#   - エルメス (スコア: 0.192)
#   - ティー (スコア: 0.184)
# --------------------
# 【SAUS】
#   - ヒルトン (スコア: 0.309)
#   - by (スコア: 0.263)
#   - ハンバーガー (スコア: 0.242)
#   - ダブル (スコア: 0.221)
#   - ヌードル (スコア: 0.219)
#   - ツリー (スコア: 0.217)
#   - 有明 (スコア: 0.194)
# --------------------
# 【SONAE CAFE】
#   - 防災 (スコア: 0.515)
#   - 広域 (スコア: 0.410)
#   - 国営 (スコア: 0.284)
#   - 臨海 (スコア: 0.254)
#   - 公園 (スコア: 0.193)
#   - エリア (スコア: 0.186)
#   - 東京 (スコア: 0.162)
# --------------------
# 【STONE FACTORY Jr.】
#   - ステーキ (スコア: 0.424)
#   - 後釜 (スコア: 0.294)
#   - コート (スコア: 0.278)
#   - 国産 (スコア: 0.270)
#   - フード (スコア: 0.249)
#   - ジュー (スコア: 0.244)
#   - ハンバーグ (スコア: 0.220)
# --------------------
# 【SWITCH STAND ODAIBA】
#   - すっごい (スコア: 0.446)
#   - すごせる (スコア: 0.322)
#   - パスタ (スコア: 0.293)
#   - やばい (スコア: 0.235)
#   - カレー (スコア: 0.234)
#   - クラフト (スコア: 0.232)
#   - パターン (スコア: 0.232)
# --------------------
# 【Seaside Café SOLARIS】
#   - 乗り場 (スコア: 0.418)
#   - 水上 (スコア: 0.319)
#   - バス (スコア: 0.273)
#   - 台場 (スコア: 0.272)
#   - 公園 (スコア: 0.183)
#   - 海浜 (スコア: 0.176)
#   - ある (スコア: 0.144)
# --------------------
# 【Sky Restaurant シーガル】
#   - ビル (スコア: 0.332)
#   - 食堂 (スコア: 0.267)
#   - テレコム (スコア: 0.221)
#   - 24 (スコア: 0.194)
#   - レストラン (スコア: 0.181)
#   - 11 (スコア: 0.164)
#   - ある (スコア: 0.154)
# --------------------
# 【TGI FRIDAYS 有明ガーデン店】
#   - フライデーズ (スコア: 0.297)
#   - ガーデン (スコア: 0.274)
#   - 有明 (スコア: 0.272)
#   - ハンバーガー (スコア: 0.268)
#   - tgi (スコア: 0.233)
#   - アメリカン (スコア: 0.226)
#   - ある (スコア: 0.193)
# --------------------
# 【TGIフライデーズ お台場アクアシティ店】
#   - フライデーズ (スコア: 0.357)
#   - アメリカン (スコア: 0.308)
#   - 台場 (スコア: 0.267)
#   - ハンバーガー (スコア: 0.188)
#   - いる (スコア: 0.175)
#   - ランチ (スコア: 0.171)
#   - tgi (スコア: 0.159)
# --------------------
# 【THE BBQ BEACH in AQUA CITY ODAIBA】
#   - bbq (スコア: 0.537)
#   - 屋根 (スコア: 0.191)
#   - 屋上 (スコア: 0.176)
#   - バーベキュー (スコア: 0.167)
#   - 良い (スコア: 0.160)
#   - 台場 (スコア: 0.155)
#   - 景色 (スコア: 0.139)
# --------------------
# 【THEキャラCAFE お台場デックス店】
#   - コラボレーション (スコア: 0.556)
#   - コースター (スコア: 0.345)
#   - ランチョン (スコア: 0.316)
#   - ラブ (スコア: 0.316)
#   - マット (スコア: 0.284)
#   - キャラクター (スコア: 0.284)
#   - カフェ (スコア: 0.262)
# --------------------
# 【The Cabaret】
#   - ショー (スコア: 0.599)
#   - イマーシブ (スコア: 0.334)
#   - フォート (スコア: 0.308)
#   - イマーシブフォート (スコア: 0.303)
#   - テーマパーク (スコア: 0.195)
#   - レストラン (スコア: 0.173)
#   - キャバレー (スコア: 0.145)
# --------------------
# 【The Grill on 30th】
#   - ニッコー (スコア: 0.328)
#   - グランド (スコア: 0.284)
#   - 台場 (スコア: 0.228)
#   - ビュッフェ (スコア: 0.215)
#   - 景色 (スコア: 0.179)
#   - 30 (スコア: 0.177)
#   - デザート (スコア: 0.172)
# --------------------
# 【The Lobby Cafe】
#   - アフタヌーン (スコア: 0.502)
#   - ティー (スコア: 0.337)
#   - ニッコー (スコア: 0.319)
#   - グランド (スコア: 0.262)
#   - 台場 (スコア: 0.253)
#   - ホテル (スコア: 0.157)
#   - lobby (スコア: 0.136)
# --------------------
# 【Tokyo 串家】
#   - 台場 (スコア: 0.252)
#   - ビル (スコア: 0.247)
#   - ランチ (スコア: 0.235)
#   - フロンティア (スコア: 0.225)
#   - いる (スコア: 0.223)
#   - 替わり (スコア: 0.145)
#   - 日替わり (スコア: 0.139)
# --------------------
# 【Trattoria&Pizzeria LOGIC お台場】
#   - ピザ (スコア: 0.522)
#   - パスタ (スコア: 0.273)
#   - 台場 (スコア: 0.247)
#   - 美味しい (スコア: 0.208)
#   - マルゲリータ (スコア: 0.205)
#   - ピッツァ (スコア: 0.151)
#   - イタリアン (スコア: 0.142)
# --------------------
# 【WAGYU USHITOMI GINZA】
#   - 新富 (スコア: 0.496)
#   - 割烹 (スコア: 0.493)
#   - うし (スコア: 0.314)
#   - 八丁堀 (スコア: 0.267)
#   - 和牛 (スコア: 0.199)
#   - 麻布 (スコア: 0.158)
#   - 新富町 (スコア: 0.140)
# --------------------
# 【WINESTAND TEO】
#   - ワイン (スコア: 0.627)
#   - ナチュールワイン (スコア: 0.266)
#   - 白河 (スコア: 0.237)
#   - 清澄 (スコア: 0.211)
#   - ナチュラル (スコア: 0.200)
#   - 隅田川 (スコア: 0.135)
#   - パスポート (スコア: 0.129)
# --------------------
# 【WOOD DESIGN PARK お台場店】
#   - バーベキュー (スコア: 0.404)
#   - bbq (スコア: 0.260)
#   - 切れる (スコア: 0.232)
#   - ソフトドリンク (スコア: 0.215)
#   - アルコール (スコア: 0.174)
#   - トング (スコア: 0.170)
#   - ハサミ (スコア: 0.165)
# --------------------
# 【YORIMICHI Odaiba】
#   - アフタヌーン (スコア: 0.347)
#   - ティー (スコア: 0.272)
#   - 台場 (スコア: 0.267)
#   - 夜景 (スコア: 0.187)
#   - 土鍋 (スコア: 0.183)
#   - 良い (スコア: 0.179)
#   - 景色 (スコア: 0.171)
# --------------------
# 【Yakiniku 名もなき名店へ 一切入魂一枚売り焼肉】
#   - 焼肉 (スコア: 0.580)
#   - 月島 (スコア: 0.429)
#   - yakiniku (スコア: 0.239)
#   - 名店 (スコア: 0.226)
#   - タン (スコア: 0.137)
#   - 激戦 (スコア: 0.136)
#   - ランチ (スコア: 0.117)
# --------------------
# 【bills お台場】
#   - パンケーキ (スコア: 0.683)
#   - bills (スコア: 0.465)
#   - 台場 (スコア: 0.210)
#   - ビルズ (スコア: 0.142)
#   - 食べる (スコア: 0.121)
#   - 美味しい (スコア: 0.121)
#   - いる (スコア: 0.115)
# --------------------
# 【creperie kenny's ダイバーシティ店】
#   - クレープ (スコア: 0.751)
#   - 生クリーム (スコア: 0.354)
#   - ダイバー (スコア: 0.196)
#   - シティ (スコア: 0.176)
#   - 北海道 (スコア: 0.127)
#   - バナナ (スコア: 0.117)
#   - 食べる (スコア: 0.114)
# --------------------
# 【da pai dang 105 有明ガーデン店】
#   - 小籠 (スコア: 0.725)
#   - コート (スコア: 0.252)
#   - フード (スコア: 0.226)
#   - 台湾 (スコア: 0.167)
#   - セット (スコア: 0.165)
#   - ガーデン (スコア: 0.165)
#   - 有明 (スコア: 0.149)
# --------------------
# 【mal D'amour】
#   - フレンチ (スコア: 0.428)
#   - ベイ (スコア: 0.386)
#   - 会員 (スコア: 0.344)
#   - 倶楽部 (スコア: 0.293)
#   - コート (スコア: 0.245)
#   - マルダムール (スコア: 0.170)
#   - 東京 (スコア: 0.160)
# --------------------
# 【milky70 since1951 アクアシティお台場店】
#   - ミルキー (スコア: 0.684)
#   - milky (スコア: 0.310)
#   - ソフトクリーム (スコア: 0.223)
#   - アクアシティ (スコア: 0.187)
#   - 台場 (スコア: 0.174)
#   - 70 (スコア: 0.166)
#   - 不二家 (スコア: 0.148)
# --------------------
# 【mode super smoothie】
#   - プロテイン (スコア: 0.400)
#   - アーバンスポーツパーク (スコア: 0.382)
#   - オーシャン (スコア: 0.356)
#   - スムージー (スコア: 0.297)
#   - できる (スコア: 0.240)
#   - 価格 (スコア: 0.237)
#   - なれる (スコア: 0.224)
# --------------------
# 【root C 日本科学未来館 5Fロビー】
#   - 気が付く (スコア: 0.324)
#   - 撤退 (スコア: 0.285)
#   - 来館 (スコア: 0.277)
#   - みえる (スコア: 0.264)
#   - ある (スコア: 0.261)
#   - にぎる (スコア: 0.256)
#   - 科学 (スコア: 0.247)
# --------------------
# 【the BAR】
#   - プレ (スコア: 0.304)
#   - ビルディング (スコア: 0.247)
#   - 夜景 (スコア: 0.239)
#   - 見下ろす (スコア: 0.236)
#   - レンタル (スコア: 0.219)
#   - バー (スコア: 0.212)
#   - 貼り紙 (スコア: 0.199)
# --------------------
# 【the open bakery】
#   - パン (スコア: 0.734)
#   - 台場 (スコア: 0.236)
#   - ベーカリー (スコア: 0.208)
#   - テラス (スコア: 0.149)
#   - ある (スコア: 0.146)
#   - 海浜 (スコア: 0.138)
#   - 公園 (スコア: 0.132)
# --------------------
# 【あのり】
#   - 居酒屋 (スコア: 0.307)
#   - 海浜 (スコア: 0.272)
#   - 台場 (スコア: 0.263)
#   - 公園 (スコア: 0.243)
#   - 変身 (スコア: 0.187)
#   - イギリス (スコア: 0.179)
#   - 通り越す (スコア: 0.179)
# --------------------
# 【あばら大根 西葛西店】
#   - 西葛西 (スコア: 0.391)
#   - 大根 (スコア: 0.314)
#   - ばら (スコア: 0.273)
#   - 刺身 (スコア: 0.242)
#   - 美味しい (スコア: 0.240)
#   - ある (スコア: 0.177)
#   - 良い (スコア: 0.156)
# --------------------
# 【いろり庵 きらく 国際展示場駅店】
#   - そば (スコア: 0.467)
#   - 蕎麦 (スコア: 0.466)
#   - かき揚げ (スコア: 0.253)
#   - 食い (スコア: 0.224)
#   - 立ち (スコア: 0.224)
#   - 展示 (スコア: 0.202)
#   - 券売 (スコア: 0.139)
# --------------------
# 【うなぎ 明月川 豊洲店】
#   - うなぎ (スコア: 0.528)
#   - 千客万来 (スコア: 0.453)
#   - 豊洲 (スコア: 0.278)
#   - うな重 (スコア: 0.275)
#   - 鎌倉 (スコア: 0.195)
#   - 鰻重 (スコア: 0.183)
#   - 市場 (スコア: 0.157)
# --------------------
# 【おいらんち 葛西駅前店】
#   - 葛西 (スコア: 0.385)
#   - 焼き鳥 (スコア: 0.261)
#   - ある (スコア: 0.199)
#   - 居酒屋 (スコア: 0.198)
#   - いる (スコア: 0.181)
#   - 99 (スコア: 0.179)
#   - メニュー (スコア: 0.174)
# --------------------
# 【おぼんdeごはん ダイバーシティ東京プラザ店】
#   - 定食 (スコア: 0.331)
#   - ぼん (スコア: 0.287)
#   - de (スコア: 0.217)
#   - ごはん (スコア: 0.211)
#   - ダイバー (スコア: 0.183)
#   - シティ (スコア: 0.182)
#   - びん (スコア: 0.172)
# --------------------
# 【お食事処 ゆき】
#   - ゆき (スコア: 0.521)
#   - 定食 (スコア: 0.377)
#   - 台場 (スコア: 0.329)
#   - ラーメン (スコア: 0.196)
#   - 海浜 (スコア: 0.194)
#   - マルエツ (スコア: 0.176)
#   - 公園 (スコア: 0.160)
# --------------------
# 【かつゑもん ダイバーシティ東京プラザ】
#   - カツ (スコア: 0.418)
#   - めし (スコア: 0.418)
#   - コート (スコア: 0.300)
#   - フード (スコア: 0.269)
#   - ダイバー (スコア: 0.228)
#   - シティ (スコア: 0.226)
#   - 玉子とじ (スコア: 0.161)
# --------------------
# 【がぜん 有明】
#   - 海鮮 (スコア: 0.317)
#   - 展示 (スコア: 0.249)
#   - 有明 (スコア: 0.235)
#   - ビッグ (スコア: 0.233)
#   - サイト (スコア: 0.225)
#   - ランチ (スコア: 0.219)
#   - ワシントン (スコア: 0.208)
# --------------------
# 【くいもの屋わん お台場デックス東京ビーチ店】
#   - わん (スコア: 0.415)
#   - 個室 (スコア: 0.274)
#   - 台場 (スコア: 0.260)
#   - くい (スコア: 0.231)
#   - 居酒屋 (スコア: 0.189)
#   - チェーン (スコア: 0.164)
#   - デックス (スコア: 0.141)
# --------------------
# 【くずし割烹 天ぷら竹の庵 東銀座店】
#   - 天ぷら (スコア: 0.692)
#   - 地下 (スコア: 0.254)
#   - 個室 (スコア: 0.245)
#   - 銀座 (スコア: 0.220)
#   - 天丼 (スコア: 0.188)
#   - 割烹 (スコア: 0.171)
#   - ランチ (スコア: 0.154)
# --------------------
# 【こだわりから揚げの酒処 くらふと】
#   - 揚げ (スコア: 0.556)
#   - 展示 (スコア: 0.211)
#   - 国際 (スコア: 0.181)
#   - あげる (スコア: 0.175)
#   - 美味しい (スコア: 0.157)
#   - アワー (スコア: 0.154)
#   - もも (スコア: 0.143)
# --------------------
# 【こなな 有明ガーデン店】
#   - パスタ (スコア: 0.539)
#   - 有明 (スコア: 0.280)
#   - ガーデン (スコア: 0.278)
#   - 豆乳 (スコア: 0.252)
#   - 和風 (スコア: 0.194)
#   - ある (スコア: 0.169)
#   - ウォーター (スコア: 0.142)
# --------------------
# 【こめらく みんなで、お茶漬け日和。 有明ガーデン店】
#   - お茶漬け (スコア: 0.565)
#   - こめ (スコア: 0.312)
#   - らく (スコア: 0.257)
#   - コート (スコア: 0.225)
#   - ガーデン (スコア: 0.223)
#   - 有明 (スコア: 0.211)
#   - フード (スコア: 0.202)
# --------------------
# 【さち福や 台場アクアシティ店】
#   - アクアシティ (スコア: 0.349)
#   - ウェイトレス (スコア: 0.245)
#   - エリンギ (スコア: 0.229)
#   - 台場 (スコア: 0.217)
#   - 未満 (スコア: 0.204)
#   - 定食 (スコア: 0.203)
#   - 終日 (スコア: 0.200)
# --------------------
# 【さち福やCAFE 有明ガーデン】
#   - 定食 (スコア: 0.444)
#   - ガーデン (スコア: 0.375)
#   - 有明 (スコア: 0.332)
#   - 小鉢 (スコア: 0.158)
#   - ある (スコア: 0.157)
#   - いる (スコア: 0.152)
#   - フライ (スコア: 0.149)
# --------------------
# 【しゃぶしゃぶ 吟半 お台場店】
#   - しゃぶしゃぶ (スコア: 0.572)
#   - 台場 (スコア: 0.403)
#   - すき焼き (スコア: 0.292)
#   - 個室 (スコア: 0.260)
#   - コース (スコア: 0.205)
#   - デックス (スコア: 0.200)
#   - ビーチ (スコア: 0.133)
# --------------------
# 【しゃぶしゃぶ・点心 食べ放題ろく アクアシティお台場】
#   - しゃぶしゃぶ (スコア: 0.393)
#   - 台場 (スコア: 0.353)
#   - 放題 (スコア: 0.252)
#   - 点心 (スコア: 0.246)
#   - 食べる (スコア: 0.175)
#   - 景色 (スコア: 0.175)
#   - 飲茶 (スコア: 0.172)
# --------------------
# 【しゃぶ食べ 有明ガーデン店】
#   - しゃぶしゃぶ (スコア: 0.398)
#   - 放題 (スコア: 0.350)
#   - 食べる (スコア: 0.323)
#   - ガーデン (スコア: 0.240)
#   - 有明 (スコア: 0.203)
#   - 野菜 (スコア: 0.199)
#   - あめ (スコア: 0.174)
# --------------------
# 【しゅん】
#   - 東雲 (スコア: 0.531)
#   - 割烹 (スコア: 0.451)
#   - むつ (スコア: 0.253)
#   - 豊洲 (スコア: 0.145)
#   - いる (スコア: 0.133)
#   - 焼き (スコア: 0.118)
#   - ランチ (スコア: 0.113)
# --------------------
# 【すき家 ワンザ有明店】
#   - すき (スコア: 0.573)
#   - 展示 (スコア: 0.237)
#   - ワンザ (スコア: 0.230)
#   - tft (スコア: 0.172)
#   - コート (スコア: 0.160)
#   - 有明 (スコア: 0.150)
#   - フード (スコア: 0.144)
# --------------------
# 【すき家 東雲晴海通り店】
#   - すき (スコア: 0.494)
#   - 仕事場 (スコア: 0.225)
#   - 東雲 (スコア: 0.164)
#   - シメ (スコア: 0.161)
#   - 食べる (スコア: 0.153)
#   - すき鍋 (スコア: 0.147)
#   - 白髪 (スコア: 0.147)
# --------------------
# 【すしざんまい 奥の院】
#   - ざんまい (スコア: 0.619)
#   - すし (スコア: 0.459)
#   - 奥の院 (スコア: 0.314)
#   - 寿司 (スコア: 0.307)
#   - 築地 (スコア: 0.296)
#   - ある (スコア: 0.098)
#   - いる (スコア: 0.095)
# --------------------
# 【すしざんまい 築地駅前店】
#   - ざんまい (スコア: 0.582)
#   - 築地 (スコア: 0.492)
#   - すし (スコア: 0.464)
#   - 寿司 (スコア: 0.249)
#   - ある (スコア: 0.098)
#   - いる (スコア: 0.097)
#   - 本願寺 (スコア: 0.079)
# --------------------
# 【すし処おかめ】
#   - 豊洲 (スコア: 0.425)
#   - 市場 (スコア: 0.405)
#   - かめ (スコア: 0.337)
#   - 寿司 (スコア: 0.334)
#   - おまかせ (スコア: 0.220)
#   - 握り (スコア: 0.179)
#   - すし (スコア: 0.176)
# --------------------
# 【せきどうばなな】
#   - バナナ (スコア: 0.697)
#   - 乗れる (スコア: 0.354)
#   - ござる (スコア: 0.289)
#   - 初心者 (スコア: 0.276)
#   - モノ (スコア: 0.220)
#   - 流行る (スコア: 0.219)
#   - スタンダード (スコア: 0.214)
# --------------------
# 【そじ坊 ダイバーシティ東京プラザ店】
#   - 蕎麦 (スコア: 0.636)
#   - そば (スコア: 0.347)
#   - ダイバー (スコア: 0.203)
#   - シティ (スコア: 0.191)
#   - 坊さん (スコア: 0.172)
#   - 南蛮 (スコア: 0.125)
#   - 台場 (スコア: 0.121)
# --------------------
# 【そじ坊 ワンザ有明店】
#   - そば (スコア: 0.425)
#   - 蕎麦 (スコア: 0.355)
#   - 展示 (スコア: 0.224)
#   - ビル (スコア: 0.208)
#   - ワンザ (スコア: 0.206)
#   - とろろ (スコア: 0.182)
#   - 有明 (スコア: 0.166)
# --------------------
# 【そなエリア東京バーベキューガーデン】
#   - bbq (スコア: 0.459)
#   - 広域 (スコア: 0.309)
#   - 防災 (スコア: 0.291)
#   - バーベキュー (スコア: 0.237)
#   - 臨海 (スコア: 0.192)
#   - 有明 (スコア: 0.171)
#   - キャンプ (スコア: 0.168)
# --------------------
# 【たけぞー】
#   - 蕎麦 (スコア: 0.440)
#   - うどん (スコア: 0.367)
#   - そば (スコア: 0.270)
#   - ビッグ (スコア: 0.245)
#   - サイト (スコア: 0.236)
#   - たけ (スコア: 0.187)
#   - セントラルタワー (スコア: 0.158)
# --------------------
# 【たこやきやの元祖 本家 会津屋 お台場店】
#   - たこ焼き (スコア: 0.847)
#   - ミュージアム (スコア: 0.274)
#   - 元祖 (スコア: 0.243)
#   - 会津屋 (スコア: 0.212)
#   - 台場 (スコア: 0.121)
#   - たこやき (スコア: 0.098)
#   - 焼き (スコア: 0.085)
# --------------------
# 【たこ家道頓堀くくる お台場たこ焼きミュージアム店】
#   - たこ焼き (スコア: 0.829)
#   - ミュージアム (スコア: 0.310)
#   - くくる (スコア: 0.272)
#   - 台場 (スコア: 0.164)
#   - たこ (スコア: 0.111)
#   - 明石 (スコア: 0.108)
#   - 道頓堀 (スコア: 0.103)
# --------------------
# 【つきじ丼匠】
#   - 市場 (スコア: 0.536)
#   - 豊洲 (スコア: 0.465)
#   - 中落ち (スコア: 0.256)
#   - 海鮮 (スコア: 0.239)
#   - マグロ (スコア: 0.218)
#   - いくら (スコア: 0.145)
#   - 豪快 (スコア: 0.140)
# --------------------
# 【つきぢ神楽寿司 豊洲市場店】
#   - 寿司 (スコア: 0.484)
#   - 豊洲 (スコア: 0.442)
#   - 市場 (スコア: 0.441)
#   - 神楽 (スコア: 0.248)
#   - おまかせ (スコア: 0.172)
#   - 握り (スコア: 0.153)
#   - 美味しい (スコア: 0.125)
# --------------------
# 【つけ麺らーめん春樹 お台場店】
#   - つけ (スコア: 0.688)
#   - ラーメン (スコア: 0.365)
#   - 台場 (スコア: 0.215)
#   - ある (スコア: 0.123)
#   - 魚介 (スコア: 0.117)
#   - とんこつ (スコア: 0.115)
#   - めん (スコア: 0.106)
# --------------------
# 【つけ麺専門店 三田製麺所 ダイバーシティ東京 プラザ店】
#   - つけ (スコア: 0.670)
#   - 三田 (スコア: 0.505)
#   - ダイバー (スコア: 0.130)
#   - 濃厚 (スコア: 0.129)
#   - ワンタン (スコア: 0.124)
#   - シティ (スコア: 0.121)
#   - 中華 (スコア: 0.118)
# --------------------
# 【てしごとや ふくの鳥 木場店】
#   - 木場 (スコア: 0.284)
#   - 揚げ (スコア: 0.267)
#   - ふく (スコア: 0.202)
#   - いる (スコア: 0.184)
#   - 焼き鳥 (スコア: 0.184)
#   - 南蛮 (スコア: 0.180)
#   - ハニーマスタード (スコア: 0.167)
# --------------------
# 【てっぱん屋台 ダイバーシティ東京プラザ店】
#   - 焼きそば (スコア: 0.359)
#   - コート (スコア: 0.307)
#   - ダイバー (スコア: 0.305)
#   - ぱん (スコア: 0.295)
#   - フード (スコア: 0.282)
#   - シティ (スコア: 0.267)
#   - モダン (スコア: 0.239)
# --------------------
# 【とんかつ八千代】
#   - チャーシュー (スコア: 0.391)
#   - エッグ (スコア: 0.379)
#   - 八千代 (スコア: 0.359)
#   - 市場 (スコア: 0.358)
#   - フライ (スコア: 0.310)
#   - 豊洲 (スコア: 0.306)
#   - アジ (スコア: 0.277)
# --------------------
# 【どうとんぼり神座 有明ガーデン店】
#   - 神座 (スコア: 0.556)
#   - ラーメン (スコア: 0.442)
#   - ガーデン (スコア: 0.313)
#   - 有明 (スコア: 0.290)
#   - コート (スコア: 0.238)
#   - フード (スコア: 0.214)
#   - 白菜 (スコア: 0.178)
# --------------------
# 【なんで、や お台場店】
#   - 台場 (スコア: 0.496)
#   - アクアシティ (スコア: 0.367)
#   - 居酒屋 (スコア: 0.317)
#   - 大衆 (スコア: 0.204)
#   - ある (スコア: 0.194)
#   - ランチ (スコア: 0.148)
#   - いる (スコア: 0.103)
# --------------------
# 【にばん家 勝どき】
#   - 勝どき (スコア: 0.460)
#   - 路地 (スコア: 0.360)
#   - 見つける (スコア: 0.198)
#   - 弁当 (スコア: 0.185)
#   - にくい (スコア: 0.161)
#   - 晴海 (スコア: 0.160)
#   - 焼き (スコア: 0.153)
# --------------------
# 【ねぎま屋 武蔵 葛西店】
#   - ねぎま (スコア: 0.622)
#   - 焼き鳥 (スコア: 0.370)
#   - 葛西 (スコア: 0.224)
#   - 99 (スコア: 0.195)
#   - ある (スコア: 0.146)
#   - 美味しい (スコア: 0.129)
#   - モツ (スコア: 0.102)
# --------------------
# 【ねこねこチーズケーキ 有明ガーデンシティ店】
#   - ねこ (スコア: 0.531)
#   - ケーキ (スコア: 0.415)
#   - チーズ (スコア: 0.267)
#   - 有明 (スコア: 0.213)
#   - ガーデン (スコア: 0.169)
#   - 可愛らしい (スコア: 0.168)
#   - チーズタルト (スコア: 0.120)
# --------------------
# 【はなまるうどん ダイバーシティ東京店】
#   - うどん (スコア: 0.661)
#   - なまる (スコア: 0.511)
#   - ダイバー (スコア: 0.183)
#   - シティ (スコア: 0.165)
#   - コート (スコア: 0.148)
#   - フード (スコア: 0.137)
#   - かける (スコア: 0.124)
# --------------------
# 【はなまる屋 アクアシティお台場店】
#   - なまる (スコア: 0.664)
#   - うどん (スコア: 0.332)
#   - 台場 (スコア: 0.195)
#   - コート (スコア: 0.188)
#   - フード (スコア: 0.168)
#   - アクアシティ (スコア: 0.157)
#   - 蕎麦 (スコア: 0.144)
# --------------------
# 【ふくの鳥 東陽町】
#   - 南蛮 (スコア: 0.392)
#   - チキン (スコア: 0.288)
#   - 日替わり (スコア: 0.282)
#   - メンチ (スコア: 0.257)
#   - 定食 (スコア: 0.215)
#   - 挽く (スコア: 0.209)
#   - カツ (スコア: 0.203)
# --------------------
# 【ふぐ倶楽部ビルヂング】
#   - ふぐ (スコア: 0.792)
#   - ビルヂング (スコア: 0.327)
#   - 倶楽部 (スコア: 0.311)
#   - フグ (スコア: 0.165)
#   - 築地 (スコア: 0.151)
#   - 新富 (スコア: 0.076)
#   - ある (スコア: 0.075)
# --------------------
# 【ほおずきや】
#   - ワンザ (スコア: 0.335)
#   - 展示 (スコア: 0.307)
#   - ビッグ (スコア: 0.242)
#   - 定食 (スコア: 0.242)
#   - サイト (スコア: 0.234)
#   - ある (スコア: 0.224)
#   - tft (スコア: 0.214)
# --------------------
# 【ほっともっと 東雲店】
#   - 東雲 (スコア: 0.581)
#   - 弁当 (スコア: 0.526)
#   - すき焼き (スコア: 0.129)
#   - ハンバーグ (スコア: 0.124)
#   - おろす (スコア: 0.100)
#   - ある (スコア: 0.089)
#   - おかか (スコア: 0.087)
# --------------------
# 【ぼてや アクアシティお台場店】
#   - 焼きそば (スコア: 0.462)
#   - ぼる (スコア: 0.333)
#   - たこ焼き (スコア: 0.309)
#   - コート (スコア: 0.264)
#   - お好み焼き (スコア: 0.238)
#   - フード (スコア: 0.237)
#   - 台場 (スコア: 0.180)
# --------------------
# 【まいばすけっと 台場1丁目店】
#   - ipa (スコア: 0.651)
#   - バスケット (スコア: 0.404)
#   - 歩道 (スコア: 0.295)
#   - 諦める (スコア: 0.226)
#   - 品数 (スコア: 0.211)
#   - コンビニ (スコア: 0.203)
#   - ブリッジ (スコア: 0.188)
# --------------------
# 【まはらに】
#   - インド (スコア: 0.312)
#   - 居酒屋 (スコア: 0.237)
#   - 展示 (スコア: 0.214)
#   - 若者 (スコア: 0.214)
#   - 国際 (スコア: 0.189)
#   - ホテル (スコア: 0.172)
#   - ワシントン (スコア: 0.158)
# --------------------
# 【むら田】
#   - ワシントン (スコア: 0.387)
#   - 展示 (スコア: 0.307)
#   - ホテル (スコア: 0.227)
#   - 南蛮 (スコア: 0.216)
#   - 有明 (スコア: 0.207)
#   - ビッグ (スコア: 0.207)
#   - サイト (スコア: 0.200)
# --------------------
# 【やまちゃん お台場店】
#   - たこ焼き (スコア: 0.864)
#   - ミュージアム (スコア: 0.337)
#   - 台場 (スコア: 0.139)
#   - 大阪 (スコア: 0.104)
#   - ある (スコア: 0.086)
#   - ちゃん (スコア: 0.086)
#   - やむ (スコア: 0.085)
# --------------------
# 【アイランド・ヴィンテージ・コーヒー 台場店】
#   - アサイーボウル (スコア: 0.498)
#   - ハワイ (スコア: 0.398)
#   - コーヒー (スコア: 0.274)
#   - アサイー (スコア: 0.252)
#   - 台場 (スコア: 0.239)
#   - アサイーボール (スコア: 0.156)
#   - コナ (スコア: 0.149)
# --------------------
# 【アニミル お台場店】
#   - エリア (スコア: 0.452)
#   - decks (スコア: 0.398)
#   - キャンプ (スコア: 0.290)
#   - ピクニック (スコア: 0.266)
#   - 動物 (スコア: 0.229)
#   - パーク (スコア: 0.197)
#   - ３つ (スコア: 0.186)
# --------------------
# 【アマラ ダイバーシティ東京店】
#   - ナン (スコア: 0.398)
#   - カレー (スコア: 0.382)
#   - ダイバー (スコア: 0.305)
#   - シティ (スコア: 0.281)
#   - コート (スコア: 0.248)
#   - バターチキンカレー (スコア: 0.246)
#   - フード (スコア: 0.223)
# --------------------
# 【アルポルト 東京ビッグサイト店】
#   - アルポルト (スコア: 0.453)
#   - ビッグ (スコア: 0.376)
#   - サイト (スコア: 0.363)
#   - パスタ (スコア: 0.269)
#   - ランチ (スコア: 0.203)
#   - ある (スコア: 0.189)
#   - ビックサイト (スコア: 0.188)
# --------------------
# 【ア・タ・ゴール】
#   - 木場 (スコア: 0.564)
#   - 車両 (スコア: 0.321)
#   - シェフ (スコア: 0.276)
#   - フレンチ (スコア: 0.272)
#   - ジビエ (スコア: 0.159)
#   - 電車 (スコア: 0.155)
#   - 務める (スコア: 0.141)
# --------------------
# 【イオンスタイル 有明ガーデン】
#   - 惣菜 (スコア: 0.205)
#   - まぐろ (スコア: 0.188)
#   - スーパー (スコア: 0.187)
#   - 休日 (スコア: 0.185)
#   - コロッケ (スコア: 0.179)
#   - 餃子 (スコア: 0.173)
#   - ネタ (スコア: 0.165)
# --------------------
# 【イタリアン酒場 パステーカ】
#   - パスタ (スコア: 0.501)
#   - イタリアン (スコア: 0.204)
#   - ビッグ (スコア: 0.195)
#   - サイト (スコア: 0.188)
#   - ソース (スコア: 0.182)
#   - もち (スコア: 0.157)
#   - 展示 (スコア: 0.152)
# --------------------
# 【イマーシブ・フォート東京】
#   - ペローニ (スコア: 0.250)
#   - イマーシブフォート (スコア: 0.200)
#   - アサリ (スコア: 0.189)
#   - 体験 (スコア: 0.178)
#   - テーマパーク (スコア: 0.168)
#   - キャバレー (スコア: 0.167)
#   - ディ (スコア: 0.160)
# --------------------
# 【インコントロ オステリア&グリル】
#   - 台場 (スコア: 0.351)
#   - イタリアン (スコア: 0.230)
#   - ニッコー (スコア: 0.210)
#   - ランチ (スコア: 0.195)
#   - コース (スコア: 0.180)
#   - テリア (スコア: 0.174)
#   - デザート (スコア: 0.165)
# --------------------
# 【インドレストラン＆バー ムナル】
#   - ナン (スコア: 0.470)
#   - インド (スコア: 0.460)
#   - カレー (スコア: 0.418)
#   - 西葛西 (スコア: 0.351)
#   - ネパール (スコア: 0.187)
#   - チーズ (スコア: 0.112)
#   - チーズナン (スコア: 0.102)
# --------------------
# 【インド料理ムンバイ アクアシティお台場店】
#   - インド (スコア: 0.572)
#   - ナン (スコア: 0.368)
#   - カレー (スコア: 0.363)
#   - アクアシティ (スコア: 0.218)
#   - 台場 (スコア: 0.199)
#   - 夜景 (スコア: 0.123)
#   - マトン (スコア: 0.119)
# --------------------
# 【ウイスキーボイス 台場】
#   - サントリー (スコア: 0.373)
#   - 地下 (スコア: 0.303)
#   - カツ (スコア: 0.270)
#   - バー (スコア: 0.221)
#   - ボイス (スコア: 0.206)
#   - ランチ (スコア: 0.196)
#   - ある (スコア: 0.183)
# --------------------
# 【ウェンディーズ・ファーストキッチン アクアシティお台場店】
#   - ウェンディーズ (スコア: 0.620)
#   - usa (スコア: 0.244)
#   - 台場 (スコア: 0.228)
#   - アクアシティ (スコア: 0.221)
#   - コート (スコア: 0.146)
#   - フード (スコア: 0.131)
#   - タピオカ (スコア: 0.129)
# --------------------
# 【ウマミバーガー 有明ガーデン店】
#   - ウマミバーガー (スコア: 0.477)
#   - ガーデン (スコア: 0.391)
#   - 有明 (スコア: 0.380)
#   - バーガー (スコア: 0.378)
#   - ハンバーガー (スコア: 0.218)
#   - umami (スコア: 0.200)
#   - ポテト (スコア: 0.168)
# --------------------
# 【エクセルシオール カフェ ダイバーシティ東京プラザ店】
#   - ダイバー (スコア: 0.410)
#   - シティ (スコア: 0.361)
#   - プラザ (スコア: 0.337)
#   - ドトール (スコア: 0.243)
#   - 東京 (スコア: 0.230)
#   - エクセルシオールカフェ (スコア: 0.192)
#   - プレッツェル (スコア: 0.192)
# --------------------
# 【エクセルシオール カフェ バリスタ  ダイバーシティ東京プラザ店】
#   - エクセルシオールカフェ (スコア: 0.444)
#   - フロア (スコア: 0.250)
#   - バリスタ (スコア: 0.222)
#   - らち (スコア: 0.222)
#   - ニューヨークチーズケーキ (スコア: 0.222)
#   - カヌレ (スコア: 0.204)
#   - マップ (スコア: 0.176)
# --------------------
# 【エグゼクティブラウンジ】
#   - ヒルトン (スコア: 0.432)
#   - ラウンジ (スコア: 0.378)
#   - エグゼクティブラウンジ (スコア: 0.330)
#   - 台場 (スコア: 0.248)
#   - タイム (スコア: 0.202)
#   - カクテル (スコア: 0.201)
#   - 宿泊 (スコア: 0.145)
# --------------------
# 【エスプレッソ アメリカーノ テレコムセンター店】
#   - テレコム (スコア: 0.619)
#   - センター (スコア: 0.355)
#   - サンドイッチ (スコア: 0.263)
#   - カフェ (スコア: 0.245)
#   - ある (スコア: 0.185)
#   - いる (スコア: 0.176)
#   - テレコムセンタービル (スコア: 0.170)
# --------------------
# 【エッグスンシングス お台場店】
#   - パンケーキ (スコア: 0.796)
#   - エッグスンシングス (スコア: 0.223)
#   - エッグベネディクト (スコア: 0.193)
#   - 食べる (スコア: 0.149)
#   - ハワイ (スコア: 0.148)
#   - 生クリーム (スコア: 0.143)
#   - 台場 (スコア: 0.129)
# --------------------
# 【エフアイランド】
#   - 禁断 (スコア: 0.439)
#   - その他 (スコア: 0.253)
#   - bankara (スコア: 0.249)
#   - named (スコア: 0.249)
#   - 足跡 (スコア: 0.239)
#   - 常習犯 (スコア: 0.239)
#   - 出演 (スコア: 0.220)
# --------------------
# 【エフカイビーチ】
#   - 台場 (スコア: 0.467)
#   - 海浜 (スコア: 0.393)
#   - 公園 (スコア: 0.368)
#   - テラス (スコア: 0.160)
#   - ビーチ (スコア: 0.155)
#   - ある (スコア: 0.138)
#   - サンデー (スコア: 0.131)
# --------------------
# 【オイスターハウス お台場店】
#   - 牡蠣 (スコア: 0.829)
#   - オイスター (スコア: 0.320)
#   - ランチ (スコア: 0.116)
#   - パン (スコア: 0.114)
#   - 美味しい (スコア: 0.102)
#   - 食べる (スコア: 0.091)
#   - アクアシティ (スコア: 0.086)
# --------------------
# 【オリジナルパンケーキハウス 有明ガーデン店】
#   - パンケーキ (スコア: 0.836)
#   - ガーデン (スコア: 0.245)
#   - 有明 (スコア: 0.215)
#   - 食べる (スコア: 0.134)
#   - ある (スコア: 0.115)
#   - いる (スコア: 0.114)
#   - 生地 (スコア: 0.089)
# --------------------
# 【オーケー お台場店】
#   - ロース (スコア: 0.286)
#   - 広告 (スコア: 0.273)
#   - 出かける (スコア: 0.185)
#   - クッキーアンドクリーム (スコア: 0.182)
#   - 壁面 (スコア: 0.173)
#   - カナダ (スコア: 0.173)
#   - ハーゲンダッツ (スコア: 0.173)
# --------------------
# 【オーケー 東雲店】
#   - 東雲 (スコア: 0.574)
#   - オーケー (スコア: 0.435)
#   - 299 (スコア: 0.246)
#   - 知名度 (スコア: 0.237)
#   - スーパーマーケット (スコア: 0.213)
#   - 定番 (スコア: 0.204)
#   - 歩き (スコア: 0.174)
# --------------------
# 【オーシャンクラブビュッフェ デックス東京ビーチ店】
#   - ビュッフェ (スコア: 0.433)
#   - デックス (スコア: 0.319)
#   - 台場 (スコア: 0.246)
#   - ある (スコア: 0.204)
#   - いる (スコア: 0.192)
#   - ビーチ (スコア: 0.158)
#   - 東京 (スコア: 0.148)
# --------------------
# 【オーシャン東九フェリー】
#   - フェリー (スコア: 0.564)
#   - 自販機 (スコア: 0.406)
#   - 徳島 (スコア: 0.395)
#   - 船内 (スコア: 0.197)
#   - 販売 (スコア: 0.143)
#   - 食品 (スコア: 0.129)
#   - 電子 (スコア: 0.125)
# --------------------
# 【オールデイダイニング グランドエール(ヴィラフォンテーヌ グランド 東京有明)】
#   - ビュッフェ (スコア: 0.417)
#   - 海鮮 (スコア: 0.245)
#   - ある (スコア: 0.237)
#   - 有明 (スコア: 0.198)
#   - ホテル (スコア: 0.179)
#   - 美味しい (スコア: 0.164)
#   - 予約 (スコア: 0.156)
# --------------------
# 【カザーナ お台場店】
#   - カレー (スコア: 0.551)
#   - ナン (スコア: 0.378)
#   - バイキング (スコア: 0.349)
#   - インド (スコア: 0.247)
#   - カザーナ (スコア: 0.241)
#   - タンドリーチキン (スコア: 0.200)
#   - 台場 (スコア: 0.170)
# --------------------
# 【カツオたまご食堂】
#   - カツオ (スコア: 0.520)
#   - 食堂 (スコア: 0.330)
#   - テレコム (スコア: 0.319)
#   - 定食 (スコア: 0.215)
#   - たま (スコア: 0.198)
#   - センター (スコア: 0.183)
#   - 食券 (スコア: 0.161)
# --------------------
# 【カフェ ラ・ボエム お台場】
#   - ボエム (スコア: 0.402)
#   - パスタ (スコア: 0.339)
#   - 台場 (スコア: 0.315)
#   - 夜景 (スコア: 0.196)
#   - ラボエム (スコア: 0.179)
#   - いる (スコア: 0.160)
#   - 窓際 (スコア: 0.153)
# --------------------
# 【カフェ&ミール ムジ 東京有明】
#   - 無印 (スコア: 0.564)
#   - 良品 (スコア: 0.458)
#   - デリ (スコア: 0.333)
#   - カフェ (スコア: 0.246)
#   - 有明 (スコア: 0.193)
#   - コーヒー (スコア: 0.153)
#   - ガーデン (スコア: 0.127)
# --------------------
# 【カフェテラス　ロイヤル】
#   - 展示 (スコア: 0.413)
#   - サイト (スコア: 0.346)
#   - ビッグ (スコア: 0.343)
#   - カフェテラス (スコア: 0.250)
#   - ビックサイト (スコア: 0.217)
#   - ロイヤル (スコア: 0.209)
#   - ある (スコア: 0.182)
# --------------------
# 【カフェ＆レストラン レインボー】
#   - 病院 (スコア: 0.554)
#   - がん (スコア: 0.376)
#   - レストラン (スコア: 0.298)
#   - 有明 (スコア: 0.267)
#   - レインボー (スコア: 0.211)
#   - 運営 (スコア: 0.173)
#   - 検査 (スコア: 0.134)
# --------------------
# 【カフェ･ベローチェ  有明店】
#   - ベローチェ (スコア: 0.570)
#   - 展示 (スコア: 0.283)
#   - 国際 (スコア: 0.259)
#   - コーヒー (スコア: 0.236)
#   - ビッグ (スコア: 0.177)
#   - サイト (スコア: 0.171)
#   - ある (スコア: 0.158)
# --------------------
# 【カレス】
#   - カレス (スコア: 0.458)
#   - 台場 (スコア: 0.344)
#   - パスタ (スコア: 0.293)
#   - テラス (スコア: 0.220)
#   - ランチ (スコア: 0.200)
#   - 美味しい (スコア: 0.179)
#   - スパゲッティーニ (スコア: 0.174)
# --------------------
# 【カレーショップ C&Cダイニング 東京ビッグサイト店】
#   - カレー (スコア: 0.647)
#   - ビッグ (スコア: 0.267)
#   - サイト (スコア: 0.257)
#   - 展示 (スコア: 0.224)
#   - カツ (スコア: 0.196)
#   - 東京 (スコア: 0.178)
#   - ビックサイト (スコア: 0.164)
# --------------------
# 【カレー香房】
#   - カレー (スコア: 0.542)
#   - コート (スコア: 0.282)
#   - フード (スコア: 0.253)
#   - ビッグ (スコア: 0.232)
#   - ビックサイト (スコア: 0.229)
#   - サイト (スコア: 0.223)
#   - 東京 (スコア: 0.170)
# --------------------
# 【カンテボーレ イオンスタイル有明ガーデン】
#   - パン (スコア: 0.547)
#   - イオン (スコア: 0.498)
#   - 割愛 (スコア: 0.296)
#   - ベーカリー (スコア: 0.181)
#   - リベイク (スコア: 0.148)
#   - 購入 (スコア: 0.137)
#   - 追う (スコア: 0.123)
# --------------------
# 【カーサ・ディ・ペロー二】
#   - イマーシブフォート (スコア: 0.466)
#   - フォート (スコア: 0.233)
#   - イマーシブ (スコア: 0.214)
#   - レストラン (スコア: 0.167)
#   - カーサ (スコア: 0.152)
#   - 常連 (スコア: 0.146)
#   - 東京 (スコア: 0.143)
# --------------------
# 【カールスジュニア ダイバーシティ東京 プラザレストラン】
#   - ハンバーガー (スコア: 0.499)
#   - バーガー (スコア: 0.293)
#   - コート (スコア: 0.269)
#   - フード (スコア: 0.252)
#   - カールスジュニア (スコア: 0.216)
#   - ダイバー (スコア: 0.212)
#   - シティ (スコア: 0.202)
# --------------------
# 【ガルーバ】
#   - 焼肉 (スコア: 0.509)
#   - 台場 (スコア: 0.335)
#   - 景色 (スコア: 0.279)
#   - レインボー (スコア: 0.203)
#   - 夜景 (スコア: 0.201)
#   - ブリッジ (スコア: 0.193)
#   - アクアシティ (スコア: 0.166)
# --------------------
# 【ガーデン ダイニング】
#   - ビュッフェ (スコア: 0.418)
#   - ニッコー (スコア: 0.351)
#   - グランド (スコア: 0.267)
#   - フェア (スコア: 0.227)
#   - ホテル (スコア: 0.221)
#   - ダイニング (スコア: 0.215)
#   - 台場 (スコア: 0.192)
# --------------------
# 【キッチン有明】
#   - 食堂 (スコア: 0.393)
#   - 港湾 (スコア: 0.372)
#   - 替る (スコア: 0.339)
#   - ラーメン (スコア: 0.334)
#   - 有明 (スコア: 0.211)
#   - 定食 (スコア: 0.184)
#   - 今週 (スコア: 0.146)
# --------------------
# 【キッチン青海珈琲】
#   - ハンバーグ (スコア: 0.390)
#   - 000 (スコア: 0.271)
#   - できあがる (スコア: 0.251)
#   - 11 (スコア: 0.248)
#   - 現金 (スコア: 0.208)
#   - mm (スコア: 0.182)
#   - まろやか (スコア: 0.182)
# --------------------
# 【キムカツ亭 有明ガーデン店】
#   - キム (スコア: 0.641)
#   - カツ (スコア: 0.485)
#   - 有明 (スコア: 0.283)
#   - ガーデン (スコア: 0.277)
#   - コート (スコア: 0.208)
#   - フード (スコア: 0.187)
#   - 恵比寿 (スコア: 0.105)
# --------------------
# 【キラキラドンキ ダイバーシティ東京 プラザ店】
#   - ワッフル (スコア: 0.553)
#   - closed (スコア: 0.274)
#   - 成城 (スコア: 0.274)
#   - 後釜 (スコア: 0.261)
#   - 中核 (スコア: 0.251)
#   - 不動産 (スコア: 0.217)
#   - スタンド (スコア: 0.191)
# --------------------
# 【キリンシティプラス 有明ガーデン店】
#   - キリン (スコア: 0.540)
#   - ビール (スコア: 0.437)
#   - ガーデン (スコア: 0.223)
#   - シティ (スコア: 0.220)
#   - ある (スコア: 0.169)
#   - 有明 (スコア: 0.169)
#   - 美味しい (スコア: 0.136)
# --------------------
# 【クアアイナ アクアシティお台場店】
#   - クアアイナ (スコア: 0.552)
#   - ハンバーガー (スコア: 0.515)
#   - 台場 (スコア: 0.328)
#   - アクアシティ (スコア: 0.172)
#   - ハワイ (スコア: 0.161)
#   - バーガー (スコア: 0.145)
#   - ある (スコア: 0.131)
# --------------------
# 【クルックス カフェオ ヨーロピアンリゾートカフェ】
#   - カヌレ (スコア: 0.425)
#   - カフェ (スコア: 0.368)
#   - 台場 (スコア: 0.331)
#   - ビル (スコア: 0.200)
#   - コーヒー (スコア: 0.199)
#   - ある (スコア: 0.186)
#   - モーニング (スコア: 0.145)
# --------------------
# 【クレープおじさん お台場店】
#   - クレープ (スコア: 0.613)
#   - ジョイポリス (スコア: 0.327)
#   - 日月 (スコア: 0.219)
#   - 焼く (スコア: 0.160)
#   - カスタード (スコア: 0.160)
#   - ティラミス (スコア: 0.155)
#   - おじさん (スコア: 0.149)
# --------------------
# 【グランディール 有明ガーデン店】
#   - パン (スコア: 0.709)
#   - ベーグル (スコア: 0.293)
#   - ちぎる (スコア: 0.220)
#   - ガーデン (スコア: 0.216)
#   - もち (スコア: 0.210)
#   - 有明 (スコア: 0.178)
#   - 豚まん (スコア: 0.132)
# --------------------
# 【グランドニッコー東京 台場】
#   - ニッコー (スコア: 0.447)
#   - グランド (スコア: 0.318)
#   - 台場 (スコア: 0.295)
#   - ホテル (スコア: 0.237)
#   - アフタヌーン (スコア: 0.145)
#   - 朝食 (スコア: 0.143)
#   - 宿泊 (スコア: 0.140)
# --------------------
# 【グランドニッコー東京 台場 エグゼクティブラウンジ】
#   - エグゼクティブフロア (スコア: 0.275)
#   - 宿泊 (スコア: 0.226)
#   - ラウンジ (スコア: 0.201)
#   - ホワイトアフタヌーンティー (スコア: 0.199)
#   - メロン (スコア: 0.177)
#   - ホテル (スコア: 0.148)
#   - ニッコー (スコア: 0.144)
# --------------------
# 【グランブルー】
#   - プール (スコア: 0.479)
#   - ビアガーデン (スコア: 0.383)
#   - もどき (スコア: 0.232)
#   - アトリウム (スコア: 0.221)
#   - スリー (スコア: 0.213)
#   - ホテルグランパシフィック (スコア: 0.213)
#   - le (スコア: 0.206)
# --------------------
# 【グリロジー バー＆グリル】
#   - ヒルトン (スコア: 0.570)
#   - アフタヌーン (スコア: 0.318)
#   - 台場 (スコア: 0.277)
#   - ティー (スコア: 0.249)
#   - グリル (スコア: 0.126)
#   - ばら (スコア: 0.108)
#   - グリロジー (スコア: 0.108)
# --------------------
# 【グリーン アジア トウキョウ】
#   - タイ (スコア: 0.405)
#   - バー (スコア: 0.363)
#   - サラダ (スコア: 0.301)
#   - パクチー (スコア: 0.238)
#   - スープ (スコア: 0.196)
#   - カオマンガイ (スコア: 0.194)
#   - 台場 (スコア: 0.178)
# --------------------
# 【グリーンズシェフ】
#   - テレコム (スコア: 0.450)
#   - センター (スコア: 0.301)
#   - 食堂 (スコア: 0.259)
#   - グリーンズシェフ (スコア: 0.205)
#   - 食券 (スコア: 0.181)
#   - ビル (スコア: 0.150)
#   - カレー (スコア: 0.142)
# --------------------
# 【グロー ジュース スタンド】
#   - スムージー (スコア: 0.468)
#   - アサイーボウル (スコア: 0.372)
#   - ガーデン (スコア: 0.226)
#   - バナナ (スコア: 0.197)
#   - 有明 (スコア: 0.192)
#   - フルーツ (スコア: 0.166)
#   - ある (スコア: 0.139)
# --------------------
# 【ゲンの中華そば 東京ビックサイト南展示棟店】
#   - 中華 (スコア: 0.434)
#   - そば (スコア: 0.378)
#   - ラーメン (スコア: 0.362)
#   - 展示 (スコア: 0.269)
#   - ハンバーガー (スコア: 0.211)
#   - ビッグ (スコア: 0.201)
#   - ゲン (スコア: 0.201)
# --------------------
# 【ココス 有明パークビル店】
#   - ココス (スコア: 0.770)
#   - 有明 (スコア: 0.183)
#   - パーク (スコア: 0.170)
#   - ハンバーグ (スコア: 0.158)
#   - 展示 (スコア: 0.138)
#   - 国際 (スコア: 0.127)
#   - ある (スコア: 0.120)
# --------------------
# 【コムフォー アーバンドック ららぽーと豊洲店】
#   - フォー (スコア: 0.853)
#   - カレー (スコア: 0.201)
#   - パクチー (スコア: 0.198)
#   - ららぽーと (スコア: 0.154)
#   - レッド (スコア: 0.149)
#   - グリーン (スコア: 0.146)
#   - 食べる (スコア: 0.110)
# --------------------
# 【ゴクゴク ダイバーシティ東京プラザ店】
#   - バナナ (スコア: 0.560)
#   - ジュース (スコア: 0.363)
#   - スムージー (スコア: 0.221)
#   - ミルク (スコア: 0.221)
#   - ダイバー (スコア: 0.177)
#   - シティ (スコア: 0.175)
#   - ゴクゴク (スコア: 0.142)
# --------------------
# 【ゴンチャ アクアシティお台場店】
#   - タピオカ (スコア: 0.659)
#   - ゴンチャ (スコア: 0.553)
#   - ティー (スコア: 0.181)
#   - ミルク (スコア: 0.135)
#   - 並ぶ (スコア: 0.108)
#   - ある (スコア: 0.098)
#   - 台場 (スコア: 0.092)
# --------------------
# 【サイゼリヤ 有明フロンティアビル店】
#   - サイゼリヤ (スコア: 0.592)
#   - サイゼリア (スコア: 0.356)
#   - 展示 (スコア: 0.266)
#   - ビッグ (スコア: 0.160)
#   - サイト (スコア: 0.155)
#   - ランチ (スコア: 0.149)
#   - 国際 (スコア: 0.143)
# --------------------
# 【サザエさんのお店】
#   - フジテレビ (スコア: 0.602)
#   - 焼き (スコア: 0.313)
#   - タマ (スコア: 0.239)
#   - もんじゃ (スコア: 0.202)
#   - 台場 (スコア: 0.191)
#   - ある (スコア: 0.188)
#   - キャラクター (スコア: 0.177)
# --------------------
# 【サブウェイ TFT有明店】
#   - ウェイ (スコア: 0.619)
#   - サブ (スコア: 0.542)
#   - 復活 (スコア: 0.168)
#   - アボカド (スコア: 0.127)
#   - tft (スコア: 0.123)
#   - マシマシ (スコア: 0.113)
#   - 野菜 (スコア: 0.112)
# --------------------
# 【サーティワン エクスペリエンス ダイバーシティ東京プラザ店】
#   - サーティワン (スコア: 0.506)
#   - ダイバー (スコア: 0.359)
#   - シティ (スコア: 0.356)
#   - サーティーワン (スコア: 0.332)
#   - アイス (スコア: 0.223)
#   - クレープ (スコア: 0.158)
#   - プラザ (スコア: 0.139)
# --------------------
# 【サーティワンアイスクリーム デックス東京ビーチ店】
#   - サーティーワン (スコア: 0.496)
#   - アイスクリーム (スコア: 0.298)
#   - サーティワン (スコア: 0.220)
#   - 台場 (スコア: 0.209)
#   - デックス (スコア: 0.188)
#   - 食べる (スコア: 0.176)
#   - アイス (スコア: 0.159)
# --------------------
# 【サーティワンアイスクリーム 有明ガーデン店】
#   - サーティワン (スコア: 0.340)
#   - 有明 (スコア: 0.259)
#   - リボン (スコア: 0.243)
#   - サーティワンアイスクリーム (スコア: 0.243)
#   - アイス (スコア: 0.218)
#   - スモール (スコア: 0.210)
#   - キャラメル (スコア: 0.198)
# --------------------
# 【ザ バー&ラウンジ】
#   - ラウンジ (スコア: 0.313)
#   - ニッコー (スコア: 0.261)
#   - bar (スコア: 0.248)
#   - lounge (スコア: 0.246)
#   - バー (スコア: 0.244)
#   - 夜景 (スコア: 0.225)
#   - グランド (スコア: 0.214)
# --------------------
# 【ザ・コルトーナシーサイド台場】
#   - 結婚式 (スコア: 0.420)
#   - クリスマス (スコア: 0.325)
#   - 挙式 (スコア: 0.238)
#   - ヶ所 (スコア: 0.238)
#   - ポワレ (スコア: 0.229)
#   - 会場 (スコア: 0.168)
#   - 煮込み (スコア: 0.149)
# --------------------
# 【ザ・台場】
#   - 土産 (スコア: 0.568)
#   - 台場 (スコア: 0.204)
#   - むす (スコア: 0.182)
#   - 山積み (スコア: 0.182)
#   - ピカチュウ (スコア: 0.182)
#   - 撒く (スコア: 0.173)
#   - 迷い込む (スコア: 0.173)
# --------------------
# 【シズラー アクアシティ店】
#   - シズラー (スコア: 0.769)
#   - サラダ (スコア: 0.296)
#   - バー (スコア: 0.292)
#   - 台場 (スコア: 0.157)
#   - アクアシティ (スコア: 0.131)
#   - いる (スコア: 0.109)
#   - 食べる (スコア: 0.107)
# --------------------
# 【シュマッツ 有明ガーデン】
#   - ドイツ (スコア: 0.485)
#   - ビール (スコア: 0.460)
#   - ガーデン (スコア: 0.302)
#   - 有明 (スコア: 0.277)
#   - ソーセージ (スコア: 0.252)
#   - 美味しい (スコア: 0.179)
#   - ある (スコア: 0.149)
# --------------------
# 【シースケープ スイーツ＆コーヒー】
#   - ケーキ (スコア: 0.333)
#   - モンブラン (スコア: 0.251)
#   - ヒルトン (スコア: 0.221)
#   - イチゴ (スコア: 0.213)
#   - いちご (スコア: 0.185)
#   - 購入 (スコア: 0.173)
#   - なおす (スコア: 0.164)
# --------------------
# 【シースケープ テラス・ダイニング】
#   - ヒルトン (スコア: 0.484)
#   - ビュッフェ (スコア: 0.412)
#   - 台場 (スコア: 0.271)
#   - 北海道 (スコア: 0.171)
#   - いちご (スコア: 0.149)
#   - フェア (スコア: 0.141)
#   - スイーツビュッフェ (スコア: 0.126)
# --------------------
# 【シーフードキッチン ピチ】
#   - 葛西 (スコア: 0.354)
#   - バル (スコア: 0.247)
#   - 美味しい (スコア: 0.228)
#   - マッシュポテト (スコア: 0.212)
#   - ラム (スコア: 0.188)
#   - チョップ (スコア: 0.184)
#   - ワイン (スコア: 0.155)
# --------------------
# 【シーフードレストラン メヒコ 東京ベイ有明店】
#   - ピラフ (スコア: 0.631)
#   - カニ (スコア: 0.460)
#   - メヒコ (スコア: 0.337)
#   - 水槽 (スコア: 0.307)
#   - シーフード (スコア: 0.154)
#   - 福島 (スコア: 0.113)
#   - 展示 (スコア: 0.101)
# --------------------
# 【シーフードレストランネプチューン】
#   - 東雲 (スコア: 0.523)
#   - シーフード (スコア: 0.388)
#   - フライ (スコア: 0.247)
#   - 刺身 (スコア: 0.191)
#   - 海鮮 (スコア: 0.186)
#   - レストラン (スコア: 0.184)
#   - いる (スコア: 0.169)
# --------------------
# 【ジ オーブン アメリカン ビュッフェ】
#   - 台場 (スコア: 0.374)
#   - ビュッフェ (スコア: 0.263)
#   - アクアシティ (スコア: 0.220)
#   - アメリカン (スコア: 0.206)
#   - 食べる (スコア: 0.199)
#   - ある (スコア: 0.185)
#   - ロースト (スコア: 0.172)
# --------------------
# 【ジューシーパパ】
#   - コート (スコア: 0.349)
#   - フード (スコア: 0.313)
#   - ビッグ (スコア: 0.313)
#   - サイト (スコア: 0.301)
#   - ハンバーグ (スコア: 0.293)
#   - ジューシーパパ (スコア: 0.176)
#   - 東京 (スコア: 0.172)
# --------------------
# 【ジューススタンド】
#   - 無印 (スコア: 0.535)
#   - ml (スコア: 0.287)
#   - 良品 (スコア: 0.279)
#   - ウッド (スコア: 0.279)
#   - 外装 (スコア: 0.273)
#   - スタンド (スコア: 0.231)
#   - ベリー (スコア: 0.226)
# --------------------
# 【ジョナサン 台場デックス東京ビーチ店】
#   - 台場 (スコア: 0.361)
#   - ジョナサン (スコア: 0.357)
#   - デックス (スコア: 0.204)
#   - タブレット (スコア: 0.168)
#   - ある (スコア: 0.164)
#   - 配膳 (スコア: 0.146)
#   - ファミレス (スコア: 0.142)
# --------------------
# 【ジョンノ屋台村＆ネネチキン 有明ガーデン】
#   - 韓国 (スコア: 0.416)
#   - 屋台 (スコア: 0.308)
#   - ガーデン (スコア: 0.298)
#   - ジョン (スコア: 0.285)
#   - 新大久保 (スコア: 0.285)
#   - 有明 (スコア: 0.257)
#   - フード (スコア: 0.246)
# --------------------
# 【ジョージタウン】
#   - ワシントン (スコア: 0.455)
#   - ホテル (スコア: 0.400)
#   - バイキング (スコア: 0.296)
#   - 朝食 (スコア: 0.261)
#   - ジョージタウン (スコア: 0.257)
#   - 有明 (スコア: 0.200)
#   - 宿泊 (スコア: 0.175)
# --------------------
# 【ジー＆ジー】
#   - 集まり (スコア: 0.443)
#   - 人さま (スコア: 0.299)
#   - 取り合わせ (スコア: 0.285)
#   - ウィスキー (スコア: 0.266)
#   - パーティ (スコア: 0.222)
#   - プライベート (スコア: 0.219)
#   - ブッフェ (スコア: 0.188)
# --------------------
# 【スターバックス コーヒー ダイバーシティ東京プラザ店】
#   - スタバ (スコア: 0.601)
#   - フラペチーノ (スコア: 0.298)
#   - ダイバー (スコア: 0.292)
#   - シティ (スコア: 0.259)
#   - バックス (スコア: 0.173)
#   - スター (スコア: 0.149)
#   - いる (スコア: 0.136)
# --------------------
# 【スターバックスコーヒー 東京ビッグサイト店】
#   - スタバ (スコア: 0.574)
#   - ビッグ (スコア: 0.274)
#   - サイト (スコア: 0.257)
#   - ビックサイト (スコア: 0.232)
#   - 展示 (スコア: 0.196)
#   - ある (スコア: 0.183)
#   - 東京 (スコア: 0.179)
# --------------------
# 【スターバックス・コーヒー アクアシティお台場店】
#   - スタバ (スコア: 0.421)
#   - バックス (スコア: 0.390)
#   - スター (スコア: 0.349)
#   - 台場 (スコア: 0.346)
#   - アクアシティ (スコア: 0.283)
#   - フラペチーノ (スコア: 0.217)
#   - コーヒー (スコア: 0.180)
# --------------------
# 【スモール ワールズ トウキョウ】
#   - スモールワールズ (スコア: 0.548)
#   - ミニチュア (スコア: 0.304)
#   - 世界 (スコア: 0.196)
#   - ワールド (スコア: 0.168)
#   - スモール (スコア: 0.150)
#   - いる (スコア: 0.149)
#   - 景品 (スコア: 0.122)
# --------------------
# 【セブンイレブン DR東京有明ダイワロイネットホテル店】
#   - スープ (スコア: 0.286)
#   - 594 (スコア: 0.269)
#   - 飲み干せる (スコア: 0.239)
#   - 監修 (スコア: 0.222)
#   - セブン (スコア: 0.222)
#   - ラーメン (スコア: 0.214)
#   - to (スコア: 0.203)
# --------------------
# 【セブンイレブン ROYALビッグサイト店】
#   - イレブン (スコア: 0.483)
#   - セブン (スコア: 0.434)
#   - おにぎり (スコア: 0.341)
#   - 品薄 (スコア: 0.251)
#   - 模型 (スコア: 0.242)
#   - 品物 (スコア: 0.234)
#   - お供 (スコア: 0.181)
# --------------------
# 【セブンイレブン タイム24ビル店】
#   - イレブン (スコア: 0.336)
#   - セブン (スコア: 0.302)
#   - 購入 (スコア: 0.258)
#   - 寿司 (スコア: 0.246)
#   - パン (スコア: 0.228)
#   - メロン (スコア: 0.217)
#   - 生姜 (スコア: 0.200)
# --------------------
# 【セブンイレブン ダイバーシティ東京プラザ店】
#   - 寝かせる (スコア: 0.435)
#   - 玄米 (スコア: 0.368)
#   - おにぎり (スコア: 0.307)
#   - 検証 (スコア: 0.237)
#   - 食客 (スコア: 0.226)
#   - イレブン (スコア: 0.217)
#   - マス (スコア: 0.211)
# --------------------
# 【セブンイレブン ＴＦＴ有明店】
#   - めぼしい (スコア: 0.432)
#   - 絶賛 (スコア: 0.341)
#   - 消費 (スコア: 0.302)
#   - 飲食 (スコア: 0.291)
#   - 無事 (スコア: 0.288)
#   - カード (スコア: 0.259)
#   - 閉まる (スコア: 0.253)
# --------------------
# 【ゼスト キャンティーナ お台場】
#   - 洞窟 (スコア: 0.450)
#   - メキシコ (スコア: 0.305)
#   - 台場 (スコア: 0.299)
#   - ゼスト (スコア: 0.274)
#   - タコス (スコア: 0.191)
#   - メキシカン (スコア: 0.176)
#   - いる (スコア: 0.168)
# --------------------
# 【ゼッテリア TFT有明店】
#   - ロッテリア (スコア: 0.851)
#   - 絶品 (スコア: 0.219)
#   - バーガー (スコア: 0.188)
#   - いる (スコア: 0.097)
#   - ハンバーガー (スコア: 0.090)
#   - ポテト (スコア: 0.089)
#   - tft (スコア: 0.089)
# --------------------
# 【タコベル アクアシティお台場店】
#   - タコス (スコア: 0.543)
#   - ベル (スコア: 0.482)
#   - タコ (スコア: 0.441)
#   - 台場 (スコア: 0.210)
#   - アクアシティ (スコア: 0.132)
# ...
# --------------------
# 【炭火焼肉 牛和鹿 本店】
#   - 焼肉 (スコア: 0.479)
#   - タン (スコア: 0.443)
#   - 近江 (スコア: 0.321)
#   - 門前仲 (スコア: 0.221)
#   - ハラ (スコア: 0.181)
#   - カルビ (スコア: 0.178)
#   - キムチ (スコア: 0.176)
# --------------------
# 【炭火焼肉・韓国料理 KollaBo アクアシティお台場店】
#   - 韓国 (スコア: 0.423)
#   - チヂミ (スコア: 0.306)
#   - サムギョプサル (スコア: 0.305)
#   - 焼肉 (スコア: 0.278)
#   - 美味しい (スコア: 0.216)
#   - 台場 (スコア: 0.183)
#   - 食べる (スコア: 0.160)
# --------------------
# 【無印良品 東京有明店】
#   - 無印 (スコア: 0.674)
#   - 良品 (スコア: 0.333)
#   - 有明 (スコア: 0.178)
#   - ある (スコア: 0.157)
#   - 最大 (スコア: 0.134)
#   - muji (スコア: 0.121)
#   - パン (スコア: 0.109)
# --------------------
# 【焼うお いし川】
#   - 焼く (スコア: 0.459)
#   - 築地 (スコア: 0.370)
#   - 焼肉 (スコア: 0.289)
#   - 炙る (スコア: 0.250)
#   - トロ (スコア: 0.218)
#   - 美味しい (スコア: 0.202)
#   - コース (スコア: 0.185)
# --------------------
# 【焼きとんと旨い魚 甚四郎 本店】
#   - 刺身 (スコア: 0.331)
#   - トン (スコア: 0.227)
#   - 酒飲み (スコア: 0.221)
#   - コース (スコア: 0.211)
#   - 刺し (スコア: 0.195)
#   - くらべる (スコア: 0.195)
#   - 食する (スコア: 0.186)
# --------------------
# 【焼肉 平城苑 アクアシティお台場店】
#   - 焼肉 (スコア: 0.493)
#   - 平城 (スコア: 0.411)
#   - 台場 (スコア: 0.319)
#   - ある (スコア: 0.206)
#   - 美味しい (スコア: 0.161)
#   - カルビ (スコア: 0.158)
#   - アクアシティ (スコア: 0.157)
# --------------------
# 【焼肉ここから 東陽町店】
#   - 焼肉 (スコア: 0.408)
#   - 東陽 (スコア: 0.326)
#   - ホルモン (スコア: 0.226)
#   - タン (スコア: 0.206)
#   - ハラ (スコア: 0.183)
#   - カルビ (スコア: 0.179)
#   - 伝説 (スコア: 0.166)
# --------------------
# 【焼肉と夜景 醍醐 お台場店】
#   - 焼肉 (スコア: 0.383)
#   - 醍醐 (スコア: 0.378)
#   - 夜景 (スコア: 0.305)
#   - タン (スコア: 0.255)
#   - 台場 (スコア: 0.251)
#   - ハラ (スコア: 0.188)
#   - ランチ (スコア: 0.151)
# --------------------
# 【焼鳥トリフク食堂】
#   - アクアシティ (スコア: 0.297)
#   - 台場 (スコア: 0.254)
#   - 親子 (スコア: 0.249)
#   - 定食 (スコア: 0.227)
#   - 美味しい (スコア: 0.203)
#   - タレ (スコア: 0.194)
#   - 焼鳥 (スコア: 0.180)
# --------------------
# 【焼鶏ばんちょう】
#   - 月島 (スコア: 0.457)
#   - 焼き鳥 (スコア: 0.427)
#   - 焼鳥 (スコア: 0.416)
#   - ちょう (スコア: 0.193)
#   - 手羽 (スコア: 0.176)
#   - 骨抜き (スコア: 0.162)
#   - ばん (スコア: 0.153)
# --------------------
# 【牛たん炭焼利久 有明ガーデン店】
#   - タン (スコア: 0.603)
#   - 利久 (スコア: 0.426)
#   - たん (スコア: 0.319)
#   - ガーデン (スコア: 0.264)
#   - 定食 (スコア: 0.226)
#   - テール (スコア: 0.175)
#   - 有明 (スコア: 0.172)
# --------------------
# 【牛カツ京都勝牛 ダイバーシティ東京プラザ店】
#   - カツ (スコア: 0.801)
#   - サーロイン (スコア: 0.199)
#   - 食べる (スコア: 0.161)
#   - ロース (スコア: 0.119)
#   - レア (スコア: 0.105)
#   - 京都 (スコア: 0.101)
#   - ポン酢 (スコア: 0.098)
# --------------------
# 【牛和鹿 葛西店】
#   - 葛西 (スコア: 0.519)
#   - 美味しい (スコア: 0.268)
#   - 近江 (スコア: 0.232)
#   - 門前仲 (スコア: 0.214)
#   - タン (スコア: 0.213)
#   - キムチ (スコア: 0.188)
#   - 焼肉 (スコア: 0.184)
# --------------------
# 【牛若 葛西店】
#   - 葛西 (スコア: 0.561)
#   - 焼肉 (スコア: 0.472)
#   - カルビ (スコア: 0.134)
#   - 地元 (スコア: 0.126)
#   - 宮崎 (スコア: 0.124)
#   - いる (スコア: 0.121)
#   - 和牛 (スコア: 0.115)
# --------------------
# 【生粋 葛西駅前店】
#   - 喫煙 (スコア: 0.321)
#   - 葛西 (スコア: 0.296)
#   - 居酒屋 (スコア: 0.293)
#   - ハイボール (スコア: 0.224)
#   - 飲む (スコア: 0.208)
#   - 九州 (スコア: 0.179)
#   - 個室 (スコア: 0.177)
# --------------------
# 【目利きの銀次 門前仲町駅前店】
#   - チェーン (スコア: 0.261)
#   - 放題 (スコア: 0.212)
#   - 目利き (スコア: 0.207)
#   - 豚カツ (スコア: 0.202)
#   - 飲む (スコア: 0.183)
#   - 電源 (スコア: 0.179)
#   - ある (スコア: 0.146)
# --------------------
# 【相鉄グランドフレッサ 東京ベイ有明】
#   - 朝食 (スコア: 0.399)
#   - ホテル (スコア: 0.320)
#   - バイキング (スコア: 0.190)
#   - 宿泊 (スコア: 0.178)
#   - 宴会 (スコア: 0.172)
#   - ディズニーランド (スコア: 0.170)
#   - ホテルサンルート (スコア: 0.157)
# --------------------
# 【眺遊楼】
#   - ベイ (スコア: 0.466)
#   - 眺遊楼 (スコア: 0.355)
#   - コート (スコア: 0.316)
#   - 中華 (スコア: 0.275)
#   - 倶楽部 (スコア: 0.235)
#   - 会員 (スコア: 0.209)
#   - フカ (スコア: 0.173)
# --------------------
# 【石臼挽きそば 石楽】
#   - 蕎麦 (スコア: 0.746)
#   - そば (スコア: 0.303)
#   - 豊洲 (スコア: 0.241)
#   - 石臼 (スコア: 0.185)
#   - いる (スコア: 0.136)
#   - 挽く (スコア: 0.131)
#   - 天ぷら (スコア: 0.128)
# --------------------
# 【磯寿司】
#   - 寿司 (スコア: 0.556)
#   - 市場 (スコア: 0.503)
#   - 豊洲 (スコア: 0.452)
#   - 築地 (スコア: 0.114)
#   - ネタ (スコア: 0.113)
#   - マグロ (スコア: 0.100)
#   - いる (スコア: 0.098)
# --------------------
# 【社食DELI】
#   - 弁当 (スコア: 0.567)
#   - グリーンズシェフ (スコア: 0.375)
#   - ビニール (スコア: 0.309)
#   - フロンティア (スコア: 0.282)
#   - みそ (スコア: 0.258)
#   - 青海 (スコア: 0.192)
#   - 食堂 (スコア: 0.189)
# --------------------
# 【社食デリ】
#   - 弁当 (スコア: 0.533)
#   - deli (スコア: 0.264)
#   - 区画 (スコア: 0.228)
#   - カート (スコア: 0.213)
#   - 相場 (スコア: 0.206)
#   - 江東 (スコア: 0.202)
#   - ビル (スコア: 0.194)
# --------------------
# 【秀徳市場マルマサ】
#   - 秀徳 (スコア: 0.399)
#   - 築地 (スコア: 0.335)
#   - 寿司 (スコア: 0.243)
#   - 美味しい (スコア: 0.186)
#   - 海鮮 (スコア: 0.182)
#   - 中落ち (スコア: 0.161)
#   - おでん (スコア: 0.161)
# --------------------
# 【笑笑 お台場海浜公園駅前店】
#   - おろす (スコア: 0.406)
#   - そば (スコア: 0.319)
#   - 台場 (スコア: 0.216)
#   - 居酒屋 (スコア: 0.210)
#   - 飲める (スコア: 0.180)
#   - 地区 (スコア: 0.129)
#   - 白木屋 (スコア: 0.122)
# --------------------
# 【笑笑 月島駅前店】
#   - 月島 (スコア: 0.551)
#   - 居酒屋 (スコア: 0.225)
#   - モンテローザ (スコア: 0.209)
#   - もむ (スコア: 0.174)
#   - チェーン (スコア: 0.167)
#   - 飲む (スコア: 0.156)
#   - いる (スコア: 0.123)
# --------------------
# 【築地 すし Omakase】
#   - 熟成 (スコア: 0.535)
#   - 寿司 (スコア: 0.438)
#   - 築地 (スコア: 0.298)
#   - コース (スコア: 0.236)
#   - ネタ (スコア: 0.147)
#   - 美味しい (スコア: 0.144)
#   - 大将 (スコア: 0.126)
# --------------------
# 【築地 挙母鮨】
#   - 築地 (スコア: 0.557)
#   - 握り (スコア: 0.360)
#   - モーニング (スコア: 0.338)
#   - 寿司 (スコア: 0.314)
#   - 場外 (スコア: 0.177)
#   - カウンター (スコア: 0.143)
#   - 握る (スコア: 0.130)
# --------------------
# 【築地さらしなの里】
#   - 蕎麦 (スコア: 0.702)
#   - そば (スコア: 0.346)
#   - しな (スコア: 0.291)
#   - さら (スコア: 0.284)
#   - 築地 (スコア: 0.268)
#   - 天ぷら (スコア: 0.128)
#   - ある (スコア: 0.088)
# --------------------
# 【築地玉寿司 晴海通り店】
#   - 寿司 (スコア: 0.606)
#   - 築地 (スコア: 0.589)
#   - 晴海 (スコア: 0.210)
#   - ある (スコア: 0.117)
#   - 通り (スコア: 0.115)
#   - 食べる (スコア: 0.107)
#   - いる (スコア: 0.104)
# --------------------
# 【築地秀徳元祖】
#   - 築地 (スコア: 0.491)
#   - 寿司 (スコア: 0.404)
#   - 秀徳 (スコア: 0.330)
#   - ネタ (スコア: 0.222)
#   - 場外 (スコア: 0.174)
#   - 本店 (スコア: 0.136)
#   - ビニール (スコア: 0.135)
# --------------------
# 【築地銀だこ ダイバーシティ東京プラザ店】
#   - だこ (スコア: 0.685)
#   - たこ焼き (スコア: 0.469)
#   - ダイバー (スコア: 0.238)
#   - シティ (スコア: 0.218)
#   - コート (スコア: 0.160)
#   - フード (スコア: 0.144)
#   - 食べる (スコア: 0.102)
# --------------------
# 【築地青空三代目 本店】
#   - 築地 (スコア: 0.581)
#   - 寿司 (スコア: 0.372)
#   - 代目 (スコア: 0.300)
#   - 青空 (スコア: 0.225)
#   - 握り (スコア: 0.158)
#   - おまかせ (スコア: 0.154)
#   - コース (スコア: 0.151)
# --------------------
# 【築地食堂 源ちゃん アクアシティお台場店】
#   - 台場 (スコア: 0.415)
#   - アクアシティ (スコア: 0.356)
#   - ちゃん (スコア: 0.262)
#   - 築地 (スコア: 0.257)
#   - 海鮮 (スコア: 0.220)
#   - 食堂 (スコア: 0.216)
#   - ある (スコア: 0.202)
# --------------------
# 【築地食堂 源ちゃん 有明ガーデン店】
#   - ガーデン (スコア: 0.362)
#   - 海鮮 (スコア: 0.293)
#   - 有明 (スコア: 0.289)
#   - 刺身 (スコア: 0.261)
#   - 築地 (スコア: 0.231)
#   - ある (スコア: 0.191)
#   - ちゃん (スコア: 0.178)
# --------------------
# 【築地食堂 源ちゃん 東京ビックサイト店】
#   - ビッグ (スコア: 0.349)
#   - サイト (スコア: 0.336)
#   - 展示 (スコア: 0.265)
#   - 定食 (スコア: 0.226)
#   - ちゃん (スコア: 0.220)
#   - ビックサイト (スコア: 0.188)
#   - 東京 (スコア: 0.187)
# --------------------
# 【築地食堂　源ちゃん TFT有明店】
#   - 海鮮 (スコア: 0.253)
#   - 定食 (スコア: 0.252)
#   - ビッグ (スコア: 0.216)
#   - サイト (スコア: 0.209)
#   - ある (スコア: 0.195)
#   - 刺身 (スコア: 0.195)
#   - いる (スコア: 0.192)
# --------------------
# 【米三角】
#   - 千客万来 (スコア: 0.482)
#   - 豊洲 (スコア: 0.311)
#   - おむすび (スコア: 0.301)
#   - 三角 (スコア: 0.289)
#   - 市場 (スコア: 0.160)
#   - 立ち (スコア: 0.159)
#   - ある (スコア: 0.138)
# --------------------
# 【翠苑】
#   - 中華 (スコア: 0.373)
#   - 展示 (スコア: 0.213)
#   - ランチ (スコア: 0.206)
#   - ある (スコア: 0.200)
#   - ワンザ (スコア: 0.184)
#   - いる (スコア: 0.179)
#   - tft (スコア: 0.164)
# --------------------
# 【肉菜工房うしすけ 台場店】
#   - 焼肉 (スコア: 0.438)
#   - わん (スコア: 0.347)
#   - 愛犬 (スコア: 0.299)
#   - ワンコ (スコア: 0.282)
#   - うし (スコア: 0.218)
#   - ペット (スコア: 0.196)
#   - ちゃん (スコア: 0.182)
# --------------------
# 【自由が丘 蔭山 有明ガーデン店】
#   - 白湯 (スコア: 0.616)
#   - ラーメン (スコア: 0.289)
#   - コート (スコア: 0.273)
#   - 有明 (スコア: 0.270)
#   - 蔭山 (スコア: 0.264)
#   - ガーデン (スコア: 0.262)
#   - フード (スコア: 0.247)
# --------------------
# 【芋蛸 お台場たこやきミュージアム店】
#   - たこ焼き (スコア: 0.830)
#   - ミュージアム (スコア: 0.355)
#   - 山芋 (スコア: 0.244)
#   - 台場 (スコア: 0.136)
#   - たこやき (スコア: 0.110)
#   - たこ (スコア: 0.096)
#   - ある (スコア: 0.080)
# --------------------
# 【花水木】
#   - すき焼き (スコア: 0.514)
#   - しゃぶしゃぶ (スコア: 0.480)
#   - 参道 (スコア: 0.220)
#   - 門前仲 (スコア: 0.193)
#   - 不動尊 (スコア: 0.185)
#   - コース (スコア: 0.159)
#   - 美味しい (スコア: 0.149)
# --------------------
# 【茂助だんご 豊洲市場】
#   - 茂助 (スコア: 0.577)
#   - 市場 (スコア: 0.408)
#   - 豊洲 (スコア: 0.344)
#   - 団子 (スコア: 0.342)
#   - 管理 (スコア: 0.178)
#   - あん (スコア: 0.123)
#   - 和菓子 (スコア: 0.122)
# --------------------
# 【茶寮 伊藤園 有明ガーデン店】
#   - 抹茶 (スコア: 0.554)
#   - 伊藤園 (スコア: 0.467)
#   - ほうじ茶 (スコア: 0.283)
#   - ガーデン (スコア: 0.249)
#   - 有明 (スコア: 0.209)
#   - お茶 (スコア: 0.205)
#   - ソフトクリーム (スコア: 0.176)
# --------------------
# 【菊屋】
#   - 東雲 (スコア: 0.613)
#   - 団地 (スコア: 0.259)
#   - 町中 (スコア: 0.252)
#   - 中華 (スコア: 0.216)
#   - ラーメン (スコア: 0.172)
#   - ある (スコア: 0.167)
#   - いる (スコア: 0.117)
# --------------------
# 【葛西ビアバー】
#   - 葛西 (スコア: 0.414)
#   - ビール (スコア: 0.320)
#   - ビアバー (スコア: 0.273)
#   - hub (スコア: 0.191)
#   - 半額 (スコア: 0.184)
#   - ハッピー (スコア: 0.182)
#   - ハッピーアワー (スコア: 0.182)
# --------------------
# 【葛西臨海公園バーベキュー広場】
#   - バーベキュー (スコア: 0.734)
#   - 葛西 (スコア: 0.162)
#   - 臨海 (スコア: 0.148)
#   - ある (スコア: 0.147)
#   - 手ぶら (スコア: 0.143)
#   - 舞浜 (スコア: 0.143)
#   - 飲む (スコア: 0.130)
# --------------------
# 【蔵乃ゑ】
#   - すか (スコア: 0.453)
#   - 柚子 (スコア: 0.426)
#   - 炭酸 (スコア: 0.324)
#   - 称す (スコア: 0.218)
#   - 上り (スコア: 0.218)
#   - キツイ (スコア: 0.200)
#   - デパート (スコア: 0.188)
# --------------------
# 【親子丼 トリカイ エクスプレス ダイバーシティ東京店】
#   - 親子 (スコア: 0.635)
#   - ダイバー (スコア: 0.325)
#   - シティ (スコア: 0.288)
#   - フード (スコア: 0.280)
#   - コート (スコア: 0.273)
#   - カイ (スコア: 0.138)
#   - エクスプレス (スコア: 0.133)
# --------------------
# 【豊洲市場 共同食堂】
#   - 水産 (スコア: 0.268)
#   - 豊洲 (スコア: 0.244)
#   - 定食 (スコア: 0.223)
#   - 市場 (スコア: 0.191)
#   - 食堂 (スコア: 0.190)
#   - 都庁 (スコア: 0.188)
#   - 商用 (スコア: 0.188)
# --------------------
# 【豊海ワイン食堂】
#   - マンション (スコア: 0.220)
#   - シェフ (スコア: 0.210)
#   - アルコ (スコア: 0.185)
#   - ポロネーゼ (スコア: 0.185)
#   - 豊海 (スコア: 0.185)
#   - 笑い声 (スコア: 0.185)
#   - 力強い (スコア: 0.176)
# --------------------
# 【越後屋 竹千代】
#   - 定食 (スコア: 0.409)
#   - 干物 (スコア: 0.249)
#   - 越後屋 (スコア: 0.239)
#   - ビッグ (スコア: 0.221)
#   - サイト (スコア: 0.213)
#   - 焼き魚 (スコア: 0.210)
#   - 展示 (スコア: 0.184)
# --------------------
# 【道頓堀 赤鬼】
#   - たこ焼き (スコア: 0.855)
#   - ミュージアム (スコア: 0.296)
#   - ちゃ (スコア: 0.115)
#   - 道頓堀 (スコア: 0.109)
#   - 台場 (スコア: 0.103)
#   - 明石 (スコア: 0.091)
#   - 食べる (スコア: 0.085)
# --------------------
# 【都会の農園バーベキュー広場】
#   - バーベキュー (スコア: 0.444)
#   - bbq (スコア: 0.430)
#   - 屋上 (スコア: 0.422)
#   - 都会 (スコア: 0.241)
#   - シティ (スコア: 0.193)
#   - ダイバー (スコア: 0.179)
#   - 手ぶら (スコア: 0.156)
# --------------------
# 【都立潮風公園バーベキュー広場】
#   - 潮風 (スコア: 0.529)
#   - bbq (スコア: 0.377)
#   - 公園 (スコア: 0.240)
#   - 都立 (スコア: 0.239)
#   - テント (スコア: 0.228)
#   - 広場 (スコア: 0.206)
#   - バーベキュー (スコア: 0.195)
# --------------------
# 【金澤濃厚豚骨ラーメン 神仙 アクアシティ店】
#   - ラーメン (スコア: 0.630)
#   - 濃厚 (スコア: 0.399)
#   - 国技 (スコア: 0.313)
#   - 神仙 (スコア: 0.180)
#   - 醤油 (スコア: 0.176)
#   - 台場 (スコア: 0.159)
#   - スープ (スコア: 0.156)
# --------------------
# 【鉄板焼 銀杏】
#   - 鉄板 (スコア: 0.453)
#   - 鉄板焼 (スコア: 0.277)
#   - 焼き (スコア: 0.223)
#   - 台場 (スコア: 0.219)
#   - 景色 (スコア: 0.203)
#   - ホテル (スコア: 0.189)
#   - コース (スコア: 0.159)
# --------------------
# 【銀座 深川玄庵】
#   - 蕎麦 (スコア: 0.497)
#   - 移転 (スコア: 0.267)
#   - 銀座 (スコア: 0.230)
#   - 門前仲 (スコア: 0.209)
#   - コース (スコア: 0.207)
#   - 深川 (スコア: 0.175)
#   - 南瓜 (スコア: 0.143)
# --------------------
# 【銀座 祭や】
#   - 銀座 (スコア: 0.403)
#   - 居酒屋 (スコア: 0.296)
#   - 地下 (スコア: 0.271)
#   - いる (スコア: 0.224)
#   - 焼酎 (スコア: 0.218)
#   - 元気 (スコア: 0.204)
#   - ある (スコア: 0.192)
# --------------------
# 【長寿韓酒房 ダイバーシティ東京プラザ店】
#   - みぞ (スコア: 0.658)
#   - 長寿 (スコア: 0.441)
#   - ダイバー (スコア: 0.179)
#   - シティ (スコア: 0.178)
#   - 1300 (スコア: 0.145)
#   - 凍る (スコア: 0.138)
#   - 韓国 (スコア: 0.131)
# --------------------
# 【長寿韓酒房 有明店】
#   - 韓国 (スコア: 0.386)
#   - 長寿 (スコア: 0.259)
#   - ビビンバ (スコア: 0.250)
#   - ソルロンタン (スコア: 0.227)
#   - サイト (スコア: 0.207)
#   - ビッグ (スコア: 0.205)
#   - ランチ (スコア: 0.194)
# --------------------
# 【長生庵】
#   - 築地 (スコア: 0.584)
#   - 蕎麦 (スコア: 0.583)
#   - そば (スコア: 0.220)
#   - 場外 (スコア: 0.170)
#   - 天ぷら (スコア: 0.126)
#   - いる (スコア: 0.114)
#   - ある (スコア: 0.104)
# --------------------
# 【門仲STAND】
#   - ワイン (スコア: 0.560)
#   - 閲覧 (スコア: 0.295)
#   - 自然 (スコア: 0.193)
#   - stand (スコア: 0.163)
#   - 定期 (スコア: 0.158)
#   - 自身 (スコア: 0.147)
#   - 前菜 (スコア: 0.138)
# --------------------
# 【門前仲町 らっきょう】
#   - 京橋 (スコア: 0.281)
#   - ある (スコア: 0.235)
#   - 刺身 (スコア: 0.227)
#   - ぼう (スコア: 0.224)
#   - 美味しい (スコア: 0.155)
#   - 良い (スコア: 0.149)
#   - 移転 (スコア: 0.145)
# --------------------
# 【青海珈琲 青海本店】
#   - 青海 (スコア: 0.401)
#   - コーヒー (スコア: 0.375)
#   - 珈琲 (スコア: 0.295)
#   - テレコム (スコア: 0.245)
#   - 焙る (スコア: 0.224)
#   - 煎る (スコア: 0.213)
#   - センター (スコア: 0.188)
# --------------------
# 【青海食堂】
#   - 食堂 (スコア: 0.580)
#   - 青海 (スコア: 0.338)
#   - 定食 (スコア: 0.277)
#   - テレコム (スコア: 0.187)
#   - 港湾 (スコア: 0.183)
#   - センター (スコア: 0.134)
#   - カツ (スコア: 0.112)
# --------------------
# 【韓美膳 有明ガーデン店】
#   - ビビンバ (スコア: 0.432)
#   - ガーデン (スコア: 0.375)
#   - 韓国 (スコア: 0.337)
#   - 有明 (スコア: 0.294)
#   - コート (スコア: 0.270)
#   - スンドゥブ (スコア: 0.247)
#   - フード (スコア: 0.232)
# --------------------
# 【頑者NEXT LEVEL】
#   - つけ (スコア: 0.671)
#   - 頑者 (スコア: 0.343)
#   - 国技 (スコア: 0.338)
#   - ラーメン (スコア: 0.307)
#   - 台場 (スコア: 0.217)
#   - 海老 (スコア: 0.137)
#   - 川越 (スコア: 0.131)
# --------------------
# 【飛車角 有明ガーデン店】
#   - 焼肉 (スコア: 0.320)
#   - カルビ (スコア: 0.316)
#   - ガーデン (スコア: 0.312)
#   - ランチ (スコア: 0.300)
#   - タン (スコア: 0.269)
#   - 有明 (スコア: 0.264)
#   - ハラ (スコア: 0.232)
# --------------------
# 【餃子の王様 龍吟 ダイバーシティ店】
#   - 餃子 (スコア: 0.795)
#   - ダイバー (スコア: 0.180)
#   - シティ (スコア: 0.178)
#   - 定食 (スコア: 0.150)
#   - チャーハン (スコア: 0.138)
#   - 王様 (スコア: 0.129)
#   - メン (スコア: 0.115)
# --------------------
# 【餃子酒家 築地店】
#   - 餃子 (スコア: 0.556)
#   - 酒家 (スコア: 0.360)
#   - 新富 (スコア: 0.293)
#   - 中華 (スコア: 0.242)
#   - チャーハン (スコア: 0.231)
#   - 新富町 (スコア: 0.208)
#   - ランチ (スコア: 0.186)
# --------------------
# 【香港飲茶楼 ル・パルク】
#   - 飲茶 (スコア: 0.350)
#   - 展示 (スコア: 0.339)
#   - ビッグ (スコア: 0.302)
#   - サイト (スコア: 0.291)
#   - ちまき (スコア: 0.240)
#   - 香港 (スコア: 0.238)
#   - ビックサイト (スコア: 0.197)
# --------------------
# 【魚とと 東京ビックサイトEat iT!店】
#   - ビッグ (スコア: 0.305)
#   - サイト (スコア: 0.294)
#   - コート (スコア: 0.248)
#   - フード (スコア: 0.223)
#   - ネギ (スコア: 0.192)
#   - ビックサイト (スコア: 0.188)
#   - トロ (スコア: 0.187)
# --------------------
# 【魚民 勝どき駅前店】
#   - テレビ (スコア: 0.378)
#   - 個室 (スコア: 0.374)
#   - いる (スコア: 0.239)
#   - 長居 (スコア: 0.193)
#   - 部屋 (スコア: 0.173)
#   - 着く (スコア: 0.166)
#   - ある (スコア: 0.154)
# --------------------
# 【魚民 潮見駅前店】
#   - 潮見 (スコア: 0.543)
#   - 全国 (スコア: 0.285)
#   - 平凡 (スコア: 0.166)
#   - 定着 (スコア: 0.152)
#   - スーパーマーケット (スコア: 0.149)
#   - リアル (スコア: 0.149)
#   - 居酒屋 (スコア: 0.148)
# --------------------
# 【魚河岸トミーナ 豊洲市場店】
#   - 市場 (スコア: 0.514)
#   - 豊洲 (スコア: 0.438)
#   - ピザ (スコア: 0.417)
#   - パスタ (スコア: 0.226)
#   - ばあちゃん (スコア: 0.158)
#   - イタリアン (スコア: 0.129)
#   - 魚河岸 (スコア: 0.117)
# --------------------
# 【鮒忠 有明店】
#   - 定食 (スコア: 0.280)
#   - 南蛮 (スコア: 0.275)
#   - 焼き鳥 (スコア: 0.232)
#   - ランチ (スコア: 0.230)
#   - ビッグ (スコア: 0.197)
#   - 展示 (スコア: 0.194)
#   - チキン (スコア: 0.187)
# --------------------
# 【鮨 もりなり】
#   - ネタ (スコア: 0.458)
#   - 大将 (スコア: 0.312)
#   - 寿し (スコア: 0.275)
#   - 築地 (スコア: 0.271)
#   - 寿司 (スコア: 0.263)
#   - 大きい (スコア: 0.178)
#   - シャリ (スコア: 0.167)
# --------------------
# 【鮨 玉かがり 天ぷら 玉衣】
#   - 寿司 (スコア: 0.450)
#   - 天ぷら (スコア: 0.402)
#   - ニッコー (スコア: 0.378)
#   - グランド (スコア: 0.310)
#   - 朝食 (スコア: 0.261)
#   - 台場 (スコア: 0.176)
#   - 宿泊 (スコア: 0.133)
# --------------------
# 【鮨 酒 肴 杉玉 新木場】
#   - 新木場 (スコア: 0.542)
#   - 寿司 (スコア: 0.459)
#   - スシロー (スコア: 0.306)
#   - 居酒屋 (スコア: 0.156)
#   - ある (スコア: 0.150)
#   - 美味しい (スコア: 0.122)
#   - シャリ (スコア: 0.121)
# --------------------
# 【鮨　宇田川】
#   - 寿司 (スコア: 0.365)
#   - 有明 (スコア: 0.276)
#   - ワシントン (スコア: 0.243)
#   - ちらす (スコア: 0.210)
#   - パーク (スコア: 0.208)
#   - ランチ (スコア: 0.194)
#   - ビル (スコア: 0.187)
# --------------------
# 【鮨･酒･肴 杉玉 葛西店】
#   - 寿司 (スコア: 0.466)
#   - 葛西 (スコア: 0.350)
#   - スシロー (スコア: 0.239)
#   - いる (スコア: 0.167)
#   - ある (スコア: 0.162)
#   - コース (スコア: 0.134)
#   - 美味しい (スコア: 0.132)
# --------------------
# 【鮮魚旬菜 魚福】
#   - toc (スコア: 0.389)
#   - ランチ (スコア: 0.264)
#   - 有明 (スコア: 0.208)
#   - ある (スコア: 0.200)
#   - サイト (スコア: 0.195)
#   - ビッグ (スコア: 0.182)
#   - 展示 (スコア: 0.171)
# --------------------
# 【鶏味座 ダイバーシティ東京プラザ店】
#   - 親子 (スコア: 0.815)
#   - 究極 (スコア: 0.274)
#   - ダイバー (スコア: 0.225)
#   - シティ (スコア: 0.197)
#   - 山椒 (スコア: 0.163)
#   - 軍鶏 (スコア: 0.103)
#   - 焼き鳥 (スコア: 0.095)
# --------------------
# 【鶏鬨はなれ 勝どき清澄通り店】
#   - 勝どき (スコア: 0.449)
#   - まぶしい (スコア: 0.337)
#   - 蕎麦 (スコア: 0.336)
#   - ひつ (スコア: 0.328)
#   - 焼き鳥 (スコア: 0.322)
#   - はなれる (スコア: 0.183)
#   - 焼鳥 (スコア: 0.169)
# --------------------
# 【鶴橋風月 お台場店】
#   - お好み焼き (スコア: 0.728)
#   - 風月 (スコア: 0.467)
#   - モダン (スコア: 0.196)
#   - 台場 (スコア: 0.184)
#   - 大阪 (スコア: 0.143)
#   - 焼きそば (スコア: 0.111)
#   - 焼き (スコア: 0.097)
# --------------------
# 【黄金鉄鍋餃子 HUG】
#   - 餃子 (スコア: 0.657)
#   - 築地 (スコア: 0.389)
#   - ランチ (スコア: 0.154)
#   - いる (スコア: 0.126)
#   - 焼き (スコア: 0.112)
#   - 黄金 (スコア: 0.110)
#   - 路地 (スコア: 0.106)
# --------------------
# 【龍記 お台場デックス東京ビーチ店】
#   - 削る (スコア: 0.603)
#   - 豆腐 (スコア: 0.253)
#   - 石鍋 (スコア: 0.201)
#   - ランチ (スコア: 0.169)
#   - 定食 (スコア: 0.166)
#   - チリ (スコア: 0.145)
#   - 中華 (スコア: 0.138)
# --------------------
# 【＆ Ovo】
#   - 築地 (スコア: 0.628)
#   - 本願寺 (スコア: 0.424)
#   - モーニング (スコア: 0.339)
#   - ovo (スコア: 0.276)
#   - カフェ (スコア: 0.172)
#   - テラス (スコア: 0.163)
#   - オープン (スコア: 0.110)
# --------------------
